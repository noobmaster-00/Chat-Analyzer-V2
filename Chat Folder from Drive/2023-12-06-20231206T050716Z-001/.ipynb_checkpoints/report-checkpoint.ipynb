# %%
import os
import pandas as pd
import re
from datetime import datetime, timedelta
import logging
from datetime import timedelta

# Configure logging
logging.basicConfig(level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s')
# Set of processed chats to ensure each chat is analyzed only once
processed_chats = set()

# Function to process a single line of chat
def process_line(line):
    pattern = r'(\d{2}/\d{2}/\d{2}), (\d{1,2}:\d{2}\s?[APMapm]{2}) - (.*?): (.*)'
    match = re.match(pattern, line)
    if match:
        date_str, time_str, sender, message = match.groups()
        date = datetime.strptime(date_str, '%d/%m/%y')
        time = datetime.strptime(time_str, '%I:%M %p').strftime('%H:%M')
        return {'date': date, 'time': time, 'sender': sender, 'message': message}
    else:
        return None

def process_line_for_delay(line):
    pattern = r'(\d{2}/\d{2}/\d{2}), (\d{1,2}:\d{2}\s?[APMapm]{2}) - (.*?): (.*)'
    match = re.match(pattern, line)
    if match:
        date_str, time_str, sender, message = match.groups()
        datetime_str = date_str + ' ' + time_str
        datetime_obj = datetime.strptime(datetime_str, '%d/%m/%y %I:%M %p')
        return {'datetime': datetime_obj, 'sender': sender, 'message': message}
    else:
        return None

# Function to read the chat file specifically for delay calculation
def read_chat_file_for_delay(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        lines = file.readlines()

    concatenated_lines = []
    current_message = ""
    date_pattern = re.compile(r'^\d{2}/\d{2}/\d{2}, \d{1,2}:\d{2}\s?[APMapm]{2} - ')

    for line in lines:
        if date_pattern.match(line):
            if current_message:
                concatenated_lines.append(current_message)
            current_message = line.rstrip()
        else:
            # Append this line to the current message, if it's not empty
            if current_message:
                current_message += " " + line.strip()
    if current_message:
        concatenated_lines.append(current_message)

    return pd.DataFrame([process_line_for_delay(line) for line in concatenated_lines if process_line_for_delay(line) is not None])

# The process_line_for_delay function remains the same
       
    
def calculate_time_spent_student(chat_df, target_date, employee_name):
    student_messages = chat_df[(chat_df['date'].dt.date == target_date) & (chat_df['sender'] != employee_name)]
    total_chars = student_messages['message'].str.len().sum()
    time_spent_seconds = (total_chars / 10) * 5
    return strfdelta(timedelta(seconds=time_spent_seconds)) 

def format_delay_time(seconds):
    hours = seconds // 3600
    minutes = (seconds % 3600) // 60
    if hours > 0:
        return f"{hours} hr {minutes} mins"
    else:
        return f"{minutes} mins"

def calculate_employee_delay(chat_df, employee_name, target_date):
    delays = []
    delay_times = []
    messages_for_reference = []

    last_student_message_time = None
    employee_responded_after_student = False

    delay_counter = 1

    for index, row in chat_df.iterrows():
        # Ensure datetime is correctly formatted
        row_date = row['datetime'].date()

        if row_date != target_date:
            continue

        if row['sender'] != employee_name:
            last_student_message_time = row['datetime']
            employee_responded_after_student = False
        elif row['sender'] == employee_name and last_student_message_time is not None and not employee_responded_after_student:
            time_diff = row['datetime'] - last_student_message_time

            if time_diff > timedelta(minutes=15):
                formatted_time = row['datetime'].strftime('%d %b %Y %I:%M%p')
                delays.append(f"{delay_counter} - {formatted_time}")
                delay_counter += 1

                delay_times.append(format_delay_time(time_diff.seconds))

                start_index = max(0, index - 5)
                end_index = min(index + 5, len(chat_df))
                context_messages = chat_df.iloc[start_index:end_index]

                formatted_context_messages = [f"{idx+1} - {message_row['datetime'].strftime('%d %b %Y %I:%M%p')} - {message_row['sender']}: {message_row['message']}" for idx, message_row in context_messages.iterrows()]
                formatted_message = "\n".join(formatted_context_messages)
                messages_for_reference.append(formatted_message)

            employee_responded_after_student = True

    # Combine the lists into multiline strings
    delays_str = "\n".join(delays)
    delay_times_str = "\n".join(delay_times)
    messages_for_reference_str = "\n".join(messages_for_reference)

    return delays_str, delay_times_str, messages_for_reference_str

def is_broken_chat_student(chat_df, employee_name, target_date):
    # Adjust for the previous day
    previous_day = target_date - timedelta(days=1)

    # Filter messages for the previous day
    daily_messages = chat_df[chat_df['date'].dt.date == previous_day]

    # Check if both the employee and the student had at least one text on that day
    if daily_messages.empty:
        return 'No'  # No conversation happened on this day

    employee_messages = daily_messages[daily_messages['sender'] == employee_name]
    student_messages = daily_messages[daily_messages['sender'] != employee_name]

    # Check if both parties have sent at least one message
    if employee_messages.empty or student_messages.empty:
        return 'No'  # One of the parties did not send any message

    # Check the sender of the last message of the day
    last_message_sender = daily_messages.iloc[-1]['sender']

    # If the last message is from the employee, it's a broken chat by the student
    if last_message_sender == employee_name:
        return 'Yes'

    return 'No'
    
def count_missed_replies_student(chat_df, employee_name, report_date):
    count = 0
    for i in range(7):
        check_date = report_date - timedelta(days=i)
        messages_on_date = chat_df[chat_df['date'].dt.date == check_date]
        employee_messages = messages_on_date[messages_on_date['sender'] == employee_name]
        student_messages = messages_on_date[messages_on_date['sender'] != employee_name]
        if employee_messages.empty and not student_messages.empty:
            count += 1
    return count

def count_missed_replies_studentt(chat_df, employee_name, target_date):
    previous_day = target_date - timedelta(days=1)
    #print(f"Checking for missed replies on: {previous_day}")

    daily_messages = chat_df[chat_df['date'].dt.date == previous_day]
    
    employee_messages = daily_messages[daily_messages['sender'] == employee_name]
    student_messages = daily_messages[daily_messages['sender'] != employee_name]

    #print(f"Employee messages count: {len(employee_messages)}")
    #print(f"Student messages count: {len(student_messages)}")

    # Check if there are messages from the employee but none from the student
    if not employee_messages.empty and student_messages.empty:
        #print("Missed reply found.")
        return 'Yes'
    
    #print("No missed reply.")
    return 'No'

def count_missed_replies_last_7_days(chat_df, employee_name, start_date):
    missed_replies_count = 0

    # Iterate over the last 7 days
    for i in range(7):
        date_to_check = start_date - timedelta(days=i)
        messages_on_date = chat_df[chat_df['date'].dt.date == date_to_check]

        # Check if there are messages on this date
        if not messages_on_date.empty:
            # Check if there's any message from the employee on this day
            employee_messages = messages_on_date[messages_on_date['sender'] == employee_name]
            
            # Check if there's any message from others (leads) on this day
            lead_messages = messages_on_date[messages_on_date['sender'] != employee_name]

            # If there are messages from others but none from the employee, count as a missed reply
            if not lead_messages.empty and employee_messages.empty:
                missed_replies_count += 1

    return missed_replies_count

# Function to calculate the time spent in chat based on message lengths
def calculate_time_spent(chat_df, target_date, employee_name, team_folder):
    daily_messages = chat_df[(chat_df['date'].dt.date == target_date) & (chat_df['sender'] == employee_name)]

    if daily_messages.empty:
        return '00:00:00'

    total_time_spent_seconds = 0

    for index, row in daily_messages.iterrows():
        message = row['message']
        total_chars = len(message)

        if team_folder == "KAM" and total_chars > 700:
            time_spent_seconds = 5  # Cap at 5 seconds for long messages in KAM team folder
        else:
            time_spent_seconds = total_chars * 0.2  # Assuming 0.2 seconds per character

        total_time_spent_seconds += time_spent_seconds

        # Optional: Debug print
        #print(f"New Chat Found in {team_folder}")
        #print(f"Message Length: '{total_chars}'")
        #print(f"Message: '{message}' - Time Spent: {time_spent_seconds} seconds")

    time_spent_timedelta = timedelta(seconds=total_time_spent_seconds)
    formatted_time_spent = strfdelta(time_spent_timedelta)

    return formatted_time_spent

def strfdelta(tdelta):
    hours, remainder = divmod(tdelta.seconds, 3600)
    minutes, seconds = divmod(remainder, 60)
    return f"{hours:02}:{minutes:02}:{seconds:02}"   

def calculate_lead_response(chat_df, employee_name, target_date):
    """
    Calculates the lead response based on the number of texts exchanged between the employee and others (non-employee).
    - If only the employee sent messages, the response is 100%.
    - If only non-employees sent messages, the response is 0%.
    - Otherwise, it's the ratio of the employee's texts to the total texts, constrained between 1% and 99%.
    """
    # Filter messages for the target date
    daily_messages = chat_df[chat_df['date'].dt.date == target_date]
    
    # Check if there are any messages from the employee and others on the target date
    employee_messages = daily_messages[daily_messages['sender'] == employee_name]
    non_employee_messages = daily_messages[daily_messages['sender'] != employee_name]

    # If only the employee sent messages
    if not employee_messages.empty and non_employee_messages.empty:
        return 0

    # If only non-employees sent messages
    if employee_messages.empty and not non_employee_messages.empty:
        return 100

    # If both the employee and non-employees have sent messages
    if not employee_messages.empty and not non_employee_messages.empty:
        num_texts_employee = len(employee_messages)
        num_texts_non_employee = len(non_employee_messages)
        total_texts = num_texts_employee + num_texts_non_employee
        lead_response = (num_texts_employee / total_texts) * 100
        return max(min(lead_response, 99), 1)

    # If neither the employee nor non-employees sent messages
    return 0



def calculate_broken_chat_within_working_hrs(chat_df, employee_name, report_date, team_folder):
    # Adjust working hours based on team folder
    if team_folder == 'EWYL':
        # KAM Team working hours: 7:30 AM to 4:00 PM
        work_start_time = datetime(report_date.year, report_date.month, report_date.day, 7, 30, 0)
        work_end_time = datetime(report_date.year, report_date.month, report_date.day, 16, 30, 0)
    else:
        # Default working hours for other teams: 12:00 AM to 12:00 PM
        work_start_time = datetime(report_date.year, report_date.month, report_date.day, 0, 0, 0)
        work_end_time = datetime(report_date.year, report_date.month, report_date.day, 23, 59, 0)

    # Filter the messages for the given report date
    messages_on_date = chat_df[chat_df['datetime'].dt.date == report_date.date()]

    # Check if both employee and lead have messaged on the report date
    if not messages_on_date.empty:
        employee_messages = messages_on_date[messages_on_date['sender'] == employee_name]
        lead_messages = messages_on_date[messages_on_date['sender'] != employee_name]
        last_message_sender = messages_on_date.iloc[-1]['sender']
        # Ensure both the employee and lead have at least one message
        if not employee_messages.empty and not lead_messages.empty:
            # Get the time of the last message from the lead
            last_lead_message_time = lead_messages.iloc[-1]['datetime']

            # Check if the last message is from the lead and within working hours
            if last_message_sender != employee_name and (work_start_time <= last_lead_message_time <= work_end_time):
                return 'Yes'  # Broken chat if last message from the lead is within working hours
            else:
                return 'No'  # Not a broken chat if last message from the lead is outside working hours or from the employee

    # If no messages or only one party messaged, return 'No'
    return 'No'

def calculate_broken_chat(chat_df, employee_name, report_date):
    # Filter the messages for the given report date
    messages_on_date = chat_df[chat_df['date'].dt.date == report_date]
    
    # Check if both employee and lead have messaged on the report date
    if not messages_on_date.empty:
        employee_messages = messages_on_date[messages_on_date['sender'] == employee_name]
        lead_messages = messages_on_date[messages_on_date['sender'] != employee_name]
        
        # Ensure both the employee and lead have at least one message
        if not employee_messages.empty and not lead_messages.empty:
            # Check if the last message is from the lead
            last_message_sender = messages_on_date.iloc[-1]['sender']
            return last_message_sender != employee_name

    

def missed_replies_employee(chat_df, employee_name, target_date):
    # Filter messages for the target date
    daily_messages = chat_df[chat_df['date'].dt.date == target_date]
    
    # Check if there are any messages from the student
    student_messages = daily_messages[daily_messages['sender'] != employee_name]
    
    # Check if there are any messages from the employee
    employee_messages = daily_messages[daily_messages['sender'] == employee_name]
    
    # If there are student messages but no employee messages, consider it a missed reply
    if not student_messages.empty and employee_messages.empty:
        return 'Yes'
    
    return 'No'

def missed_replies_employee_after_working_hrs(chat_df, employee_name, target_date, team_folder):
    # Check if the team folder is 'KAM Team' to define different working hours
    if team_folder == 'EWYL':
        # EWYL Team working hours: 7:30 AM to 4:00 PM
        work_start_time = datetime(target_date.year, target_date.month, target_date.day, 7, 30, 0)
        work_end_time = datetime(target_date.year, target_date.month, target_date.day, 16, 30, 0)
    
    if team_folder == 'KAM':
       # KAM Team working hours: 7:30 AM to 4:00 PM
        work_start_time = datetime(target_date.year, target_date.month, target_date.day, 11, 30, 0)
        work_end_time = datetime(target_date.year, target_date.month, target_date.day, 21, 30, 0)

    else:
        # Default working hours for other teams: 12:00 AM to 12:00 PM
        work_start_time = datetime(target_date.year, target_date.month, target_date.day, 0, 0, 0)
        work_end_time = datetime(target_date.year, target_date.month, target_date.day, 23, 59, 0)

    # Ensure target_date is a datetime object
    if not isinstance(target_date, datetime):
        raise ValueError("target_date must be a datetime object")

    # Filter messages for the target date using 'datetime' column
    daily_messages = chat_df[chat_df['datetime'].dt.date == target_date.date()]
    
    # Check if there are any messages from the student
    student_messages = daily_messages[daily_messages['sender'] != employee_name]
    
    # Check if there are any messages from the employee
    employee_messages = daily_messages[daily_messages['sender'] == employee_name]

    # If there are student messages but no employee messages
    if not student_messages.empty and employee_messages.empty:
        print(f"ENTER THE LOOP:{student_messages}")
        # Check if any student message is within working hours
        for _, row in student_messages.iterrows():
            message_time = row['datetime']
            if work_start_time <= message_time <= work_end_time:
                return 'Yes'  # Missed reply within working hours
        return 'No'  # All student messages are outside working hours

    return 'No'

# Function to read the chat file and return a dataframe
def read_chat_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        lines = file.readlines()

    concatenated_lines = []
    current_message = ""
    date_pattern = re.compile(r'^\d{2}/\d{2}/\d{2}, \d{1,2}:\d{2}\s?[APMapm]{2} - ')

    for line in lines:
        if date_pattern.match(line):
            if current_message:
                concatenated_lines.append(current_message)
            current_message = line.rstrip()
        else:
            # Append this line to the current message, if it's not empty
            if current_message:
                current_message += " " + line.strip()
    if current_message:
        concatenated_lines.append(current_message)

    return pd.DataFrame([process_line(line) for line in concatenated_lines if process_line(line) is not None])

# process_line function remains the same


# Function to extract the chat file name based on a specific pattern
def extract_chat_name(chat_file_name):
    #logging.debug(f"Extracting name from chat file: {chat_file_name}")
    match = re.search(r'WhatsApp Chat with _?(.*?)(?:\(\d+\))?_?\.txt', chat_file_name)
    if match:
        extracted_name = re.sub(r'_*(?:\(\d+\))?$', '', match.group(1))
        #logging.debug(f"Extracted chat name: {extracted_name}")
        return extracted_name
    #logging.warning(f"No match found for chat file name: {chat_file_name}")
    return None

# Function to calculate the total count of missed replies by the student for the last N days
def calculate_total_count_missed_replies_student(chat_df, employee_name, num_days):
    total_count = 0

    # Iterate over the last N days
    for i in range(num_days):
        target_date = report_date - timedelta(days=i)
        count = count_missed_replies_student(chat_df, employee_name, target_date)
        total_count += count

    return total_count

# Function to extract the start date from a chat file
def get_chat_start_date(chat_df):
    if not chat_df.empty:
        #logging.debug(f"Extracted chat name: {chat_df['date'].min().date()}")
        return chat_df['date'].min().date()
    return None

# Function to process a single chat file
def process_chat_file(file_path, report_date, main_directory, team_folder, employee_folder):
    global processed_chats
    broken_chat_count = 0
    missed_reply_count = 0
    max_time_spent = ('', '00:00:00')  # (date, time)

    chat_file_name = os.path.basename(file_path)
    #logging.debug(f"Processing chat file: {chat_file_name}")

    chat_name = extract_chat_name(chat_file_name)
    #logging.debug(f"Chat name extracted: {chat_name}")



    

    if chat_name is None:
        #logging.warning(f"Chat name could not be extracted for file: {chat_file_name}")
        return None
    if chat_name in processed_chats:
        #logging.info(f"Chat file already processed: {chat_name}")
        return None

    processed_chats.add(chat_name)
    #logging.debug(f"Chat file added to processed list: {chat_name}")

    chat_df = read_chat_file(file_path)
    if chat_df.empty:
        #logging.warning(f"Chat DataFrame is empty for file: {chat_file_name}")
        return None
    chat_start_date = get_chat_start_date(chat_df)

    # Use read_chat_file_for_delay specifically for delay calculations
    chat_df_for_delay = read_chat_file_for_delay(file_path)
    if chat_df_for_delay.empty:
        return None

    
    target_date = report_date - timedelta(days=1)

    # Call the function with the target date
    delays, delay_times, messages_for_reference = calculate_employee_delay(chat_df_for_delay, employee_folder, target_date)
    



    # Calculate the time spent on Day 0 (report_date - 1 day)
    day_0_date = report_date - timedelta(days=1)
    day_0_time_spent = calculate_time_spent(chat_df, day_0_date, employee_folder,team_folder)
    #day_0_time_spent = timedelta(hours=int(day_0_time_spent.split(':')[0]), minutes=int(day_0_time_spent.split(':')[1]), seconds=int(day_0_time_spent.split(':')[2]))
    # Calculate the lead response based on text length difference for Day 0
    lead_response_day_0 = calculate_lead_response(chat_df, employee_folder, day_0_date)
     
    day_0_date = report_date - timedelta(days=1)  # Assuming report_date is a datetime object of the target date
    broken_chat = calculate_broken_chat(chat_df, employee_folder, day_0_date)
    missed_replies_day_0 = missed_replies_employee(chat_df, employee_folder, day_0_date)

    # Get the current datetime
    today_datetime = datetime.now()

    # Get today's date with time part (assuming start of the day as default)
    today_date_1 = today_datetime.replace(hour=0, minute=0, second=0, microsecond=0)

    # If today_date.weekday() logic remains the same
    # ...

    # Now, when you calculate target_date, it remains a datetime object
    target_date_1 = today_date_1 - timedelta(days=1)


    Actual_missed_Reply = missed_replies_employee_after_working_hrs(chat_df_for_delay, employee_folder, target_date_1,team_folder)
    Actual_broken_chat = calculate_broken_chat_within_working_hrs(chat_df_for_delay, employee_folder, target_date_1,team_folder)
    total_count_missed_reply_student = calculate_total_count_missed_replies_student(chat_df, employee_folder, 14)
    


    
    for i in range(7):  # Assuming you're checking the past 7 days
        check_date = report_date - timedelta(days=i)
        
        # Check for broken chats
        if calculate_broken_chat(chat_df, employee_folder, check_date):
            broken_chat_count += 1

        # Check for missed replies
        start_date_for_missed_replies = report_date - timedelta(days=7)
        
        missed_replies_count = count_missed_replies_last_7_days(chat_df, employee_folder, start_date_for_missed_replies)

        # Check for max time spent
        time_spent = calculate_time_spent(chat_df, check_date, employee_folder,team_folder)
        if time_spent > max_time_spent[1]:
            max_time_spent = (check_date.strftime('%m-%d-%Y'), time_spent)
    
    
    
    # Calculate the time spent by students
    time_spent_student = {
    'Day 0 (Student)': calculate_time_spent_student(chat_df, report_date - timedelta(days=1), employee_folder),
    'Day 1 (Student)': calculate_time_spent_student(chat_df, report_date - timedelta(days=2), employee_folder),
    'Day 2 (Student)': calculate_time_spent_student(chat_df, report_date - timedelta(days=3), employee_folder),
    }
    
    # Inside the process_chat_file function, after calculating day_0_time_spent:
    day_0_date = report_date - timedelta(days=1)
    day_1_date = report_date - timedelta(days=2)
    day_2_date = report_date - timedelta(days=3)

    # Calculate time spent by student for Day 0, Day 1, and Day 2
    time_spent_student_day_0 = calculate_time_spent_student(chat_df, day_0_date, employee_folder)
    time_spent_student_day_1 = calculate_time_spent_student(chat_df, day_1_date, employee_folder)
    time_spent_student_day_2 = calculate_time_spent_student(chat_df, day_2_date, employee_folder)



    total_time_spent_student = time_spent_student['Day 0 (Student)']

    broken_chat_student = is_broken_chat_student(chat_df, employee_folder, report_date)

    mmissed_reply_student = count_missed_replies_studentt(chat_df, employee_folder, report_date)

    # Calculate the time spent on each day relative to the report date
    time_spent = {}
    for i in range(1, 4):  # Start from 1 since we want Day 0 to be the day before the report date
        target_date = report_date - timedelta(days=i)
        time_spent[f'Day {i-1}'] = calculate_time_spent(chat_df, target_date, employee_folder,team_folder)
    
    target_date_for_chat_start_Date = report_date - timedelta(days=1)
    day_indicator_employee = (target_date_for_chat_start_Date - chat_start_date).days
    #logging.debug(f"day indicator employee: {day_indicator_employee}")
    # Determine Day Indicator based on chat start date
    if chat_start_date:
        if (target_date_for_chat_start_Date - chat_start_date).days == 0:
          
            day_indicator = 'Day 0'
        elif (target_date_for_chat_start_Date - chat_start_date).days == 1:
            
            day_indicator = 'Day 1'
        elif (target_date_for_chat_start_Date - chat_start_date).days == 2:
            
            day_indicator = 'Day 2'

        elif (target_date_for_chat_start_Date - chat_start_date).days == 3:
            
            day_indicator = 'OLD'

        else:
            day_indicator = 'OLD'  # For chats that don't fall into Day 0, Day 1, or Day 2

    

    main_directory_name = os.path.basename(main_directory)

    row = {
        'Date': main_directory_name,
        'Team Folder': team_folder,
        'Employee Folder': employee_folder,
        'Chat File Name': chat_name,        # Inserting the extracted chat name
        'Day Indicator': day_indicator,
        'Total_Time_Spent_Employee': day_0_time_spent,  # Use Day 0 time as the total time spent
        'LR': lead_response_day_0,  # Add the lead response here
        'Broken Chat(Employee)': 'Yes' if broken_chat else 'No',
        'Missed Replies (Employee)': missed_replies_day_0,
        'Count_Broken_Chat_Employee (Employee)': broken_chat_count,
        'Count_Missed_Replies_Missed_Replies (Employee)': missed_replies_count,
        'Date of Max time': max_time_spent[0],
        **time_spent,
        'Total Time Spent (Student)': total_time_spent_student,
        'Broken Chat (Student)': broken_chat_student,
        'Missed Replies (Student)': mmissed_reply_student,
        'Day_0_Time_Spent_Student': time_spent_student_day_0,  # Add time spent for Day 0
        'Day_1_Time_Spent_Student': time_spent_student_day_1,  # Add time spent for Day 1
        'Day_2_Time_Spent_Student': time_spent_student_day_2,
        'Total_Count_Missed_Reply_Chat_Student' : total_count_missed_reply_student,
        'Employee Delays': delays,
        'Delay Durations': delay_times,
        'Messages for Reference': messages_for_reference,
        'Actual Missed Reply from Employee': Actual_missed_Reply,
        'Actual Broken Chat from Employee' : Actual_broken_chat,
    }
    #logging.debug(f"Row created for chat: {row}")
    return row

# Main directory path construction and report date setting
# Main directory path construction and report date setting
local_date_format = '%Y-%m-%d'  # Adjust this to your local date format
main_directory = 'C:\\Users\\mauriceyeng\\Python\\Daily-Reports\\Chat Folder from Drive\\2023-12-06-20231206T061845Z-001'  # Replace with your base directory path

# Get today's date
today_date = datetime.now().date()

# Check the day of the week
if today_date.weekday() in range(1, 6):  # Tuesday to Saturday
    report_date = today_date
else:  # Monday
    # You can adjust the number of days to subtract based on your specific requirements
    report_date = today_date - timedelta(days=1)
    logging.debug(f"Report Date: {report_date}")
report_date_str_local = report_date.strftime(local_date_format)
main_directory_path = os.path.join(main_directory, report_date_str_local)

# Function to navigate through the directory structure and process all chat files
def process_team_folders(main_directory, report_date):
    all_data = []
    for team_folder in os.listdir(main_directory):
        team_path = os.path.join(main_directory, team_folder)
        if not os.path.isdir(team_path):
            continue
        for employee_folder in os.listdir(team_path):
            employee_path = os.path.join(team_path, employee_folder)
            if not os.path.isdir(employee_path):
                continue
            for chat_file in os.listdir(employee_path):
                chat_file_path = os.path.join(employee_path, chat_file)
                row = process_chat_file(chat_file_path, report_date, main_directory, team_folder, employee_folder)
                if row:
                    all_data.append(row)
                    logging.debug(f"Row appended for chat file: {chat_file}")
    df = pd.DataFrame(all_data)
    #logging.debug(f"DataFrame constructed with {len(df)} rows")
    return df

# Process all team folders and chats based on the report date
all_chats_df = process_team_folders(main_directory_path, report_date)


# Save to a CSV file
csv_file_path = 'C:\\Users\\mauriceyeng\\Python\\Daily-Reports\\Chat Folder from Drive\\2023-12-06-20231206T061845Z-001\\chat_data14.csv'  # Define your desired path and file name
all_chats_df.to_csv(csv_file_path, index=False)
#print(f"DataFrame saved as CSV at {csv_file_path}")
# Display the result
#print(all_chats_df)
# Out:
# 2023-12-06 10:51:59,284 - DEBUG - Row appended for chat file: WhatsApp Chat with Abdul_Edoofa(28_11)AA.txt
# 2023-12-06 10:51:59,405 - DEBUG - Row appended for chat file: WhatsApp Chat with Abiee_Edoofa(06_12)AA.txt
# 2023-12-06 10:51:59,634 - DEBUG - Row appended for chat file: WhatsApp Chat with Adelaide_Edoofa(16_11)AA.txt
# 2023-12-06 10:51:59,808 - DEBUG - Row appended for chat file: WhatsApp Chat with Aleta_Edoofa(20_11)AA-IE.txt
# 2023-12-06 10:51:59,929 - DEBUG - Row appended for chat file: WhatsApp Chat with Amadu_Edoofa(06_12)AA-IE.txt
# 2023-12-06 10:52:00,100 - DEBUG - Row appended for chat file: WhatsApp Chat with Angel_Edoofa(16_11)AA.txt
# 2023-12-06 10:52:00,309 - DEBUG - Row appended for chat file: WhatsApp Chat with Asher_Edoofa(28_11)AA.txt
# 2023-12-06 10:52:00,514 - DEBUG - Row appended for chat file: WhatsApp Chat with Ashleigh_Edoofa(25_10)AA.txt
# 2023-12-06 10:52:00,704 - DEBUG - Row appended for chat file: WhatsApp Chat with Benjamin_Edoofa(04_12)AA-IE.txt
# 2023-12-06 10:52:00,904 - DEBUG - Row appended for chat file: WhatsApp Chat with Blessing_Edoofa(20_11)AA-IE.txt
# 2023-12-06 10:52:01,073 - DEBUG - Row appended for chat file: WhatsApp Chat with Bopoto_Edoofa(24_11)AA.txt
# 2023-12-06 10:52:01,258 - DEBUG - Row appended for chat file: WhatsApp Chat with Caleb_Edoofa(23_11)AA.txt
# 2023-12-06 10:52:01,450 - DEBUG - Row appended for chat file: WhatsApp Chat with Calvin_Edoofa(29_11)AA.txt
# 2023-12-06 10:52:01,642 - DEBUG - Row appended for chat file: WhatsApp Chat with Chido_Edoofa(28_11)AA-IE.txt
# 2023-12-06 10:52:01,825 - DEBUG - Row appended for chat file: WhatsApp Chat with Danda_Edoofa(27_10)AA.txt
# 2023-12-06 10:52:01,975 - DEBUG - Row appended for chat file: WhatsApp Chat with Deka_Edoofa(15_11)AA.txt
# 2023-12-06 10:52:02,092 - DEBUG - Row appended for chat file: WhatsApp Chat with Farai_Edoofa(06_12)AA.txt
# 2023-12-06 10:52:02,209 - DEBUG - Row appended for chat file: WhatsApp Chat with Fortune_Edoofa(05_12)AA.txt
# 2023-12-06 10:52:02,429 - DEBUG - Row appended for chat file: WhatsApp Chat with Freda_Edoofa(22_11)AA.txt
# 2023-12-06 10:52:02,583 - DEBUG - Row appended for chat file: WhatsApp Chat with Homokade_Edoofa(28_11)AA.txt
# 2023-12-06 10:52:02,698 - DEBUG - Row appended for chat file: WhatsApp Chat with James_Edoofa(06_12)AA.txt
# 2023-12-06 10:52:02,875 - DEBUG - Row appended for chat file: WhatsApp Chat with Johannes_Edoofa(22_11)AA.txt
# 2023-12-06 10:52:03,095 - DEBUG - Row appended for chat file: WhatsApp Chat with Keratiloe_Edoofa(31_10)AA.txt
# 2023-12-06 10:52:03,312 - DEBUG - Row appended for chat file: WhatsApp Chat with Lenos_Edoofa(24_11)AA.txt
# ENTER THE LOOP:               datetime            sender               message
# 238 2023-12-05 06:07:00  +263 77 903 3457  Yes I am comfortable
# 2023-12-06 10:52:03,476 - DEBUG - Row appended for chat file: WhatsApp Chat with Lerato_Edoofa(30_11)AA.txt
# 2023-12-06 10:52:03,624 - DEBUG - Row appended for chat file: WhatsApp Chat with Lethukuthula_Edoofa(04_12)AA.txt
# 2023-12-06 10:52:03,807 - DEBUG - Row appended for chat file: WhatsApp Chat with Lincopeternel_Edoofa(23_06)AA.txt
# 2023-12-06 10:52:03,940 - DEBUG - Row appended for chat file: WhatsApp Chat with Liralipaletsoe_Edoofa(06_12)AA.txt
# 2023-12-06 10:52:04,128 - DEBUG - Row appended for chat file: WhatsApp Chat with Macdonald_Edoofa(29_11)AA.txt
# 2023-12-06 10:52:04,248 - DEBUG - Row appended for chat file: WhatsApp Chat with Madalitso_Edoofa(06_12)AA-IE.txt
# 2023-12-06 10:52:04,413 - DEBUG - Row appended for chat file: WhatsApp Chat with Magadzire_Edoofa(29_11)AA.txt
# 2023-12-06 10:52:04,621 - DEBUG - Row appended for chat file: WhatsApp Chat with Makaita_Edoofa(21_11)AA-IE.txt
# 2023-12-06 10:52:04,854 - DEBUG - Row appended for chat file: WhatsApp Chat with Makono_Edoofa(22_11)AA.txt
# 2023-12-06 10:52:04,985 - DEBUG - Row appended for chat file: WhatsApp Chat with Mandaza_Edoofa(30_11)AA.txt
# 2023-12-06 10:52:05,109 - DEBUG - Row appended for chat file: WhatsApp Chat with Mano_Edoofa(04_12)AA-IE.txt
# 2023-12-06 10:52:05,325 - DEBUG - Row appended for chat file: WhatsApp Chat with Mashaba_Edoofa(22_11)AA.txt
# 2023-12-06 10:52:05,453 - DEBUG - Row appended for chat file: WhatsApp Chat with Melanie_Edoofa(04_12)AA.txt
# 2023-12-06 10:52:05,634 - DEBUG - Row appended for chat file: WhatsApp Chat with Mguquka_Edoofa(23_10)AA.txt
# 2023-12-06 10:52:05,768 - DEBUG - Row appended for chat file: WhatsApp Chat with Mhunza_Edoofa(04_12)AA-IE.txt
# 2023-12-06 10:52:06,002 - DEBUG - Row appended for chat file: WhatsApp Chat with Mickelly_Edoofa(09_10)AA-IE.txt
# 2023-12-06 10:52:06,121 - DEBUG - Row appended for chat file: WhatsApp Chat with Moyo_Edoofa(06_12)AA-IE.txt
# 2023-12-06 10:52:06,337 - DEBUG - Row appended for chat file: WhatsApp Chat with Mudenda_Edoofa(23_11)AA.txt
# 2023-12-06 10:52:06,473 - DEBUG - Row appended for chat file: WhatsApp Chat with Munozogara_Edoofa(29_11)AA.txt
# 2023-12-06 10:52:06,635 - DEBUG - Row appended for chat file: WhatsApp Chat with Murandu_Edoofa(23_11)AA.txt
# 2023-12-06 10:52:06,752 - DEBUG - Row appended for chat file: WhatsApp Chat with Musingafi_Edoofa(06_12)AA.txt
# 2023-12-06 10:52:06,870 - DEBUG - Row appended for chat file: WhatsApp Chat with Muza_Edoofa(06_12)AA.txt
# 2023-12-06 10:52:07,101 - DEBUG - Row appended for chat file: WhatsApp Chat with Myckeilah_Edoofa(14_11)AA.txt
# 2023-12-06 10:52:07,231 - DEBUG - Row appended for chat file: WhatsApp Chat with M_suku_Edoofa(04_12)AA.txt
# 2023-12-06 10:52:07,376 - DEBUG - Row appended for chat file: WhatsApp Chat with Nigel_Edoofa(01_12)AA-IE.txt
# 2023-12-06 10:52:07,556 - DEBUG - Row appended for chat file: WhatsApp Chat with Nomathamsanqua_Edoofa(01_12)AA-IE.txt
# 2023-12-06 10:52:07,711 - DEBUG - Row appended for chat file: WhatsApp Chat with Nomthunzi_Edoofa(04_12)AA.txt
# 2023-12-06 10:52:07,890 - DEBUG - Row appended for chat file: WhatsApp Chat with Ntando_Edoofa(01_12)AA-IE.txt
# 2023-12-06 10:52:08,088 - DEBUG - Row appended for chat file: WhatsApp Chat with Pearl_Edoofa(17_11)AA.txt
# 2023-12-06 10:52:08,292 - DEBUG - Row appended for chat file: WhatsApp Chat with Polite_Edoofa(14_11)AA.txt
# 2023-12-06 10:52:08,491 - DEBUG - Row appended for chat file: WhatsApp Chat with Praise_Edoofa(16_11)AA.txt
# 2023-12-06 10:52:08,689 - DEBUG - Row appended for chat file: WhatsApp Chat with Prince_Edoofa(01_12)AA.txt
# 2023-12-06 10:52:08,888 - DEBUG - Row appended for chat file: WhatsApp Chat with Rukombo_Edoofa(04_12)AA-IE.txt
# 2023-12-06 10:52:09,056 - DEBUG - Row appended for chat file: WhatsApp Chat with Ruvarashe_Edoofa(21_11)AA.txt
# 2023-12-06 10:52:09,176 - DEBUG - Row appended for chat file: WhatsApp Chat with Shumba_Edoofa(06_12)AA.txt
# 2023-12-06 10:52:09,394 - DEBUG - Row appended for chat file: WhatsApp Chat with Silas_Edoofa(20_09)AA.txt
# 2023-12-06 10:52:09,617 - DEBUG - Row appended for chat file: WhatsApp Chat with Sithole_Edoofa(24_11)AA.txt
# 2023-12-06 10:52:09,752 - DEBUG - Row appended for chat file: WhatsApp Chat with Tadiwa_Edoofa(04_12)AA-IE.txt
# 2023-12-06 10:52:09,942 - DEBUG - Row appended for chat file: WhatsApp Chat with Tawananyasha_Edoofa(08_11)AA.txt
# 2023-12-06 10:52:10,150 - DEBUG - Row appended for chat file: WhatsApp Chat with Thandoluhle_Edoofa(08_11)AA.txt
# 2023-12-06 10:52:10,355 - DEBUG - Row appended for chat file: WhatsApp Chat with Tinayeishe_Edoofa(01_12)AA-IE.txt
# 2023-12-06 10:52:10,534 - DEBUG - Row appended for chat file: WhatsApp Chat with Tinevimbo_Edoofa(07_11)AA.txt
# 2023-12-06 10:52:10,719 - DEBUG - Row appended for chat file: WhatsApp Chat with Trust_Edoofa(14_11)AA.txt
# 2023-12-06 10:52:10,903 - DEBUG - Row appended for chat file: WhatsApp Chat with Ashley_Edoofa(15_11)PG.txt
# 2023-12-06 10:52:11,140 - DEBUG - Row appended for chat file: WhatsApp Chat with Chaurura Anesu Blessing_Edoofa(07_11)KA.txt
# 2023-12-06 10:52:11,337 - DEBUG - Row appended for chat file: WhatsApp Chat with Chrismore_Edoofa(01_12)PG-IE.txt
# 2023-12-06 10:52:11,518 - DEBUG - Row appended for chat file: WhatsApp Chat with Daniel_Edoofa(01_12)PG-IE.txt
# 2023-12-06 10:52:11,727 - DEBUG - Row appended for chat file: WhatsApp Chat with Edward_Edoofa(28_11)PG-IE.txt
# 2023-12-06 10:52:11,962 - DEBUG - Row appended for chat file: WhatsApp Chat with Elijah_Edoofa(23_10)AA.txt
# 2023-12-06 10:52:12,170 - DEBUG - Row appended for chat file: WhatsApp Chat with Faith_Edoofa(28_11)PG.txt
# 2023-12-06 10:52:12,348 - DEBUG - Row appended for chat file: WhatsApp Chat with George_Edoofa(29_11)PG-IE.txt
# 2023-12-06 10:52:12,607 - DEBUG - Row appended for chat file: WhatsApp Chat with Isheunesu_Edoofa(6_11)PG.txt
# 2023-12-06 10:52:12,800 - DEBUG - Row appended for chat file: WhatsApp Chat with Lesley_Zoraunye_Edoofa(16_11)KA.txt
# 2023-12-06 10:52:13,002 - DEBUG - Row appended for chat file: WhatsApp Chat with Linda_Edoofa(30_11)AA.txt
# ENTER THE LOOP:               datetime           sender  \
# 261 2023-12-05 20:45:00  +27 62 624 6940
#
#                                                message
# 261  4..$2000-3000 7..yes l am clear 6...it is a tr...
# 2023-12-06 10:52:13,269 - DEBUG - Row appended for chat file: WhatsApp Chat with Max_Edoofa(23_11)AA.txt
# 2023-12-06 10:52:13,470 - DEBUG - Row appended for chat file: WhatsApp Chat with Mututa_Edoofa(29_11)AA.txt
# 2023-12-06 10:52:13,672 - DEBUG - Row appended for chat file: WhatsApp Chat with Nephew_Edoofa(14_11)AA.txt
# 2023-12-06 10:52:13,901 - DEBUG - Row appended for chat file: WhatsApp Chat with Nigel Dion Mashatini_Edoofa(16_11)KA.txt
# 2023-12-06 10:52:14,108 - DEBUG - Row appended for chat file: WhatsApp Chat with Nyasha_Edoofa(20_10)PG.txt
# 2023-12-06 10:52:14,363 - DEBUG - Row appended for chat file: WhatsApp Chat with Nzombe_Edoofa(08_11)AA.txt
# 2023-12-06 10:52:14,607 - DEBUG - Row appended for chat file: WhatsApp Chat with Polite_Edoofa(17_11)PG.txt
# 2023-12-06 10:52:14,875 - DEBUG - Row appended for chat file: WhatsApp Chat with Rubby_Edoofa(08_11)PG.txt
# 2023-12-06 10:52:15,087 - DEBUG - Row appended for chat file: WhatsApp Chat with Rutendo_Edoofa(08_09)KA.txt
# 2023-12-06 10:52:15,321 - DEBUG - Row appended for chat file: WhatsApp Chat with Ruvimbonashe_Edoofa(17_11)PG.txt
# 2023-12-06 10:52:15,506 - DEBUG - Row appended for chat file: WhatsApp Chat with Saniel_Edoofa(28_09)AA.txt
# 2023-12-06 10:52:15,732 - DEBUG - Row appended for chat file: WhatsApp Chat with Sarah_Edoofa(15_11)AA.txt
# 2023-12-06 10:52:15,955 - DEBUG - Row appended for chat file: WhatsApp Chat with Shalom_Edoofa(28_11)AA-IE.txt
# 2023-12-06 10:52:16,172 - DEBUG - Row appended for chat file: WhatsApp Chat with Shamaine Chari_Edoofa(21_11)AA-IE.txt
# 2023-12-06 10:52:16,396 - DEBUG - Row appended for chat file: WhatsApp Chat with Shuntel Mujikwa_Edoofa(02_11)KA.txt
# 2023-12-06 10:52:16,623 - DEBUG - Row appended for chat file: WhatsApp Chat with Silibele_Edoofa(28_11)PG-IE.txt
# 2023-12-06 10:52:16,823 - DEBUG - Row appended for chat file: WhatsApp Chat with Stanley_Edoofa(01_12)AA-IE.txt
# 2023-12-06 10:52:17,037 - DEBUG - Row appended for chat file: WhatsApp Chat with Steven_Edoofa(24_11)AA.txt
# 2023-12-06 10:52:17,225 - DEBUG - Row appended for chat file: WhatsApp Chat with Tadala_Edoofa(23_11)PG-IE.txt
# 2023-12-06 10:52:17,423 - DEBUG - Row appended for chat file: WhatsApp Chat with Tadiwanashe_Edoofa(01_12)PG-IE.txt
# 2023-12-06 10:52:17,661 - DEBUG - Row appended for chat file: WhatsApp Chat with Takudzwa_Edoofa(29_11)PG-IE.txt
# 2023-12-06 10:52:17,892 - DEBUG - Row appended for chat file: WhatsApp Chat with Tanaka Sasa_Edoofa(31_10)KA.txt
# 2023-12-06 10:52:18,127 - DEBUG - Row appended for chat file: WhatsApp Chat with Tanaka_Edoofa(24_11)AA.txt
# 2023-12-06 10:52:18,340 - DEBUG - Row appended for chat file: WhatsApp Chat with Tanatswa Pfende_Edoofa(17_11)KA.txt
# 2023-12-06 10:52:18,589 - DEBUG - Row appended for chat file: WhatsApp Chat with Tinotenda_Edoofa(09_11)PG.txt
# 2023-12-06 10:52:18,812 - DEBUG - Row appended for chat file: WhatsApp Chat with Unathi_Edoofa(28_11)AA-IE.txt
# 2023-12-06 10:52:19,055 - DEBUG - Row appended for chat file: WhatsApp Chat with Violet 2K23NOV1095.txt
# ENTER THE LOOP:               datetime           sender  \
# 297 2023-12-05 09:08:00  +260 97 9774398
# 298 2023-12-05 09:32:00  +260 96 7541638
# 299 2023-12-05 09:38:00  +91 96505 37098
# 300 2023-12-05 09:38:00  +91 96505 37098
# 301 2023-12-05 09:38:00  +260 96 7541638
# 302 2023-12-05 09:39:00  +260 96 7541638
# 303 2023-12-05 09:41:00  +91 96505 37098
# 304 2023-12-05 09:41:00  +91 96505 37098
# 305 2023-12-05 09:42:00  +260 96 7541638
# 306 2023-12-05 09:58:00  +260 96 7541638
# 307 2023-12-05 09:59:00  +260 96 7541638
# 308 2023-12-05 10:46:00  +91 96505 37098
# 309 2023-12-05 11:01:00  +260 96 7541638
# 310 2023-12-05 12:07:00  +91 96505 37098
# 311 2023-12-05 12:08:00  +91 96505 37098
# 312 2023-12-05 13:47:00  +260 96 7541638
# 313 2023-12-05 13:48:00  +91 96505 37098
# 314 2023-12-05 13:48:00  +260 96 7541638
# 315 2023-12-05 13:53:00  +91 96505 37098
# 316 2023-12-05 13:57:00  +260 96 7541638
# 317 2023-12-05 13:57:00  +260 96 7541638
# 318 2023-12-05 14:00:00  +91 96505 37098
# 319 2023-12-05 14:01:00  +260 96 7541638
# 320 2023-12-05 14:02:00  +260 96 7541638
# 321 2023-12-05 14:04:00  +91 96505 37098
# 322 2023-12-05 14:05:00  +260 96 7541638
# 323 2023-12-05 14:11:00  +91 96505 37098
# 324 2023-12-05 14:18:00  +260 96 7541638
# 325 2023-12-05 14:22:00  +91 96505 37098
# 326 2023-12-05 14:23:00  +260 96 7541638
# 327 2023-12-05 21:27:00  +91 96505 37098
# 328 2023-12-05 21:28:00  +260 96 7541638
# 329 2023-12-05 21:28:00  +260 96 7541638
# 330 2023-12-05 21:28:00  +91 96505 37098
#
#                                                message
# 297  hello Ms sorry for not responding yesterday am...
# 298                    What's for our today's session?
# 299  Good Morning Parents and Violet, I hope you ar...
# 300  I noticed that someone has just left the group...
# 301               Am good thank you  hope you are well
# 302  That is the old number I used to use the one w...
# 303     Oh alright dear, Thank you for letting me know
# 304  On this note please share your pending documen...
# 305                                            Alright
# 306  My school is finding it a bit difficult to sen...
# 307       So I really do not know how it's going to be
# 308  Thank you for letting me know @260967541638, h...
# 309  Hello Admission officer,  I am now in touch wi...
# 310  It's wonderful to hear that you've connected w...
# 311  On this note, I would like to emphasize the im...
# 312      Which are my secondary school results alright
# 313  Dear, we need your 10th grade and 12th grade r...
# 314                                               Okay
# 315  May I please know by when you will be able to ...
# 316  Let me share I have my grade 10 results I will...
# 317                            Which I will also share
# 318  Thank you for sharing an update with me Violet...
# 319                                    <Media omitted>
# 320                                    <Media omitted>
# 321  Thank you for sharing the above document dear,...
# 322                             So I need another one?
# 323  You can ask the authorities to mention the sub...
# 324                                     Alright I will
# 325  Thank you dear, Have a good day ahead and plea...
# 326                                     Alright I will
# 327  We were waiting for your response, however it ...
# 328                            I will be able to do so
# 329                                        Same to you
# 330                                       Alright dear
# 2023-12-06 10:52:19,184 - DEBUG - Row appended for chat file: WhatsApp Chat with Angela lwinda_EDOOFAZAM(5_12)GS.txt
# 2023-12-06 10:52:19,328 - DEBUG - Row appended for chat file: WhatsApp Chat with Anotida Mudzingwa_EDOOFA(04_12)GS.txt
# 2023-12-06 10:52:19,485 - DEBUG - Row appended for chat file: WhatsApp Chat with Asia Moto_EDOOFA(28_11)GS.txt
# 2023-12-06 10:52:19,638 - DEBUG - Row appended for chat file: WhatsApp Chat with Ayanda Sibanda_EDOOFA(22_11)GS.txt
# 2023-12-06 10:52:19,862 - DEBUG - Row appended for chat file: WhatsApp Chat with Benjamin Zingwina_EDOOFA(24_11)GS.txt
# 2023-12-06 10:52:20,017 - DEBUG - Row appended for chat file: WhatsApp Chat with Bernard Ndoro_EDOOFA(1_12)GS.txt
# 2023-12-06 10:52:20,171 - DEBUG - Row appended for chat file: WhatsApp Chat with Brendon mafuta_EDOOFA(25_11)GS.txt
# 2023-12-06 10:52:20,314 - DEBUG - Row appended for chat file: WhatsApp Chat with Chitoshi joy_EDOOFA(24_11)GS.txt
# 2023-12-06 10:52:20,475 - DEBUG - Row appended for chat file: WhatsApp Chat with Chleolyn Marambakuyana_EDOOFA(30_11)GS.txt
# 2023-12-06 10:52:20,638 - DEBUG - Row appended for chat file: WhatsApp Chat with Cleopatra Madzvimbo_EDOOFA(1_12)GS.txt
# 2023-12-06 10:52:20,788 - DEBUG - Row appended for chat file: WhatsApp Chat with Daphne Guramatunhu_EDOOFA(1_12)GS.txt
# 2023-12-06 10:52:20,936 - DEBUG - Row appended for chat file: WhatsApp Chat with Delight Tshuma_EDOOFA(30_11)GS.txt
# 2023-12-06 10:52:21,058 - DEBUG - Row appended for chat file: WhatsApp Chat with Dellan Tichareva_EDOOFA(04_12)GS.txt
# 2023-12-06 10:52:21,183 - DEBUG - Row appended for chat file: WhatsApp Chat with Dingiswayo Njobvu_EDOOFAZAM(5_12)GS.txt
# 2023-12-06 10:52:21,318 - DEBUG - Row appended for chat file: WhatsApp Chat with Dzino Tafadzwa_EDOOFA(25_11)GS.txt
# 2023-12-06 10:52:21,459 - DEBUG - Row appended for chat file: WhatsApp Chat with Elisha Makorose_EDOOFA(30_11)GS.txt
# 2023-12-06 10:52:21,597 - DEBUG - Row appended for chat file: WhatsApp Chat with Gumbere Prominent_EDOOFA(04_12)GS.txt
# 2023-12-06 10:52:21,764 - DEBUG - Row appended for chat file: WhatsApp Chat with Heather Nhema_EDOOFA(28_11)GS.txt
# 2023-12-06 10:52:21,921 - DEBUG - Row appended for chat file: WhatsApp Chat with Innocent Laison_EDOOFA(24_11)GS.txt
# 2023-12-06 10:52:22,054 - DEBUG - Row appended for chat file: WhatsApp Chat with Isaac Mutsvunguma_EDOOFA(1_12)GS.txt
# 2023-12-06 10:52:22,199 - DEBUG - Row appended for chat file: WhatsApp Chat with Ivy Zikhuyumo_EDOOFA(1_12)GS.txt
# 2023-12-06 10:52:22,327 - DEBUG - Row appended for chat file: WhatsApp Chat with Josphat Mashandure_EDOOFA(1_12)GS.txt
# 2023-12-06 10:52:22,462 - DEBUG - Row appended for chat file: WhatsApp Chat with Junior Mpofu_EDOOFA(28_11)GS.txt
# 2023-12-06 10:52:22,579 - DEBUG - Row appended for chat file: WhatsApp Chat with Kamilo_EDOOFAZAM(5_12)GS.txt
# 2023-12-06 10:52:22,704 - DEBUG - Row appended for chat file: WhatsApp Chat with Kersty Magauze_EDOOFA(30_11)GS.txt
# 2023-12-06 10:52:22,914 - DEBUG - Row appended for chat file: WhatsApp Chat with Liberty Zinzombe_EDOOFA(20_11)GS.txt
# 2023-12-06 10:52:23,052 - DEBUG - Row appended for chat file: WhatsApp Chat with Loveness Chibila_EDOOFA(30_11)GS.txt
# 2023-12-06 10:52:23,199 - DEBUG - Row appended for chat file: WhatsApp Chat with Lubelihle Dondo_EDOOFA(23_11)GS.txt
# 2023-12-06 10:52:23,328 - DEBUG - Row appended for chat file: WhatsApp Chat with Luyando siavwapa_EDOOFAZAM(5_12)GS.txt
# 2023-12-06 10:52:23,450 - DEBUG - Row appended for chat file: WhatsApp Chat with Makanaka Nyamazana_EDOOFA(30_11)GS.txt
# 2023-12-06 10:52:23,588 - DEBUG - Row appended for chat file: WhatsApp Chat with Marikopo Ropafadzo_EDOOFA(04_12)GS.txt
# 2023-12-06 10:52:23,789 - DEBUG - Row appended for chat file: WhatsApp Chat with Mauswa Kelvin_EDOOFA(30_11)GS.txt
# 2023-12-06 10:52:23,923 - DEBUG - Row appended for chat file: WhatsApp Chat with Mbiba Mollyn_EDOOFA(29_11)GS.txt
# 2023-12-06 10:52:24,086 - DEBUG - Row appended for chat file: WhatsApp Chat with Meloncia Murwirapachena_EDOOFA(23_11)GS.txt
# 2023-12-06 10:52:24,236 - DEBUG - Row appended for chat file: WhatsApp Chat with Mubonda Namwaka_EDOOFA(04_12)GS.txt
# 2023-12-06 10:52:24,361 - DEBUG - Row appended for chat file: WhatsApp Chat with Muleya Lushomo Autricia_EDOOFAZAM(5_12)GS.txt
# 2023-12-06 10:52:24,558 - DEBUG - Row appended for chat file: WhatsApp Chat with Musiwa Juliet_EDOOFA(1_12)GS.txt
# 2023-12-06 10:52:24,709 - DEBUG - Row appended for chat file: WhatsApp Chat with Mutasa T_EDOOFA(22_11)GS.txt
# 2023-12-06 10:52:24,877 - DEBUG - Row appended for chat file: WhatsApp Chat with Mwaka Ngulube_EDOOFA(04_12)GS.txt
# 2023-12-06 10:52:25,005 - DEBUG - Row appended for chat file: WhatsApp Chat with Nathan_Edoofa(05_10)SM.txt
# ENTER THE LOOP:              datetime           sender                  message
# 46 2023-12-05 19:27:00  +260 97 7226946  https://fb.me/3iUFYPMgj
# 2023-12-06 10:52:25,153 - DEBUG - Row appended for chat file: WhatsApp Chat with Nchimunya Sautu_EDOOFAZAM(5_12)GS.txt
# 2023-12-06 10:52:25,294 - DEBUG - Row appended for chat file: WhatsApp Chat with Ncube M_EDOOFA(25_11)GS.txt
# 2023-12-06 10:52:25,496 - DEBUG - Row appended for chat file: WhatsApp Chat with Ncube Shaloam_EDOOFA(30_11)GS.txt
# 2023-12-06 10:52:25,614 - DEBUG - Row appended for chat file: WhatsApp Chat with Newman Kabondo_EDOOFA(04_12)GS.txt
# 2023-12-06 10:52:25,766 - DEBUG - Row appended for chat file: WhatsApp Chat with Nothando Mararike_EDOOFA(30_11)GS.txt
# 2023-12-06 10:52:25,917 - DEBUG - Row appended for chat file: WhatsApp Chat with Nyashadzashe Mutimbu_EDOOFA(1_12)GS.txt
# 2023-12-06 10:52:26,061 - DEBUG - Row appended for chat file: WhatsApp Chat with Oleen Makuwe_EDOOFA(24_11)GS.txt
# 2023-12-06 10:52:26,183 - DEBUG - Row appended for chat file: WhatsApp Chat with Persuade Ziwada_EDOOFA(04_12)GS.txt
# 2023-12-06 10:52:26,315 - DEBUG - Row appended for chat file: WhatsApp Chat with Pride Ndirwo_EDOOFA(25_11)GS.txt
# 2023-12-06 10:52:26,491 - DEBUG - Row appended for chat file: WhatsApp Chat with Prisca zumani_EDOOFA(23_11)GS.txt
# 2023-12-06 10:52:26,710 - DEBUG - Row appended for chat file: WhatsApp Chat with Prominent Jena_EDOOFA(1_12)GS.txt
# 2023-12-06 10:52:26,951 - DEBUG - Row appended for chat file: WhatsApp Chat with Rilliah Ncube_EDOOFA(23_11)GS.txt
# 2023-12-06 10:52:27,099 - DEBUG - Row appended for chat file: WhatsApp Chat with Rwatiringa Felistas_EDOOFA(24_11)GS.txt
# 2023-12-06 10:52:27,252 - DEBUG - Row appended for chat file: WhatsApp Chat with Samathar Matanhire_EDOOFA(1_12)GS.txt
# 2023-12-06 10:52:27,378 - DEBUG - Row appended for chat file: WhatsApp Chat with Samu Samuel_EDOOFA(30_11)GS.txt
# 2023-12-06 10:52:27,532 - DEBUG - Row appended for chat file: WhatsApp Chat with Seline Mutsvangwa_EDOOFA(1_12)GS.txt
# 2023-12-06 10:52:27,728 - DEBUG - Row appended for chat file: WhatsApp Chat with Shamiso Mawunze_EDOOFA(24_11)GS.txt
# 2023-12-06 10:52:27,877 - DEBUG - Row appended for chat file: WhatsApp Chat with Shaun Chiworeso_EDOOFA(28_11)GS.txt
# 2023-12-06 10:52:28,049 - DEBUG - Row appended for chat file: WhatsApp Chat with Simbarashe Mujuru_EDOOFA(22_11)GS.txt
# 2023-12-06 10:52:28,186 - DEBUG - Row appended for chat file: WhatsApp Chat with Tadiwanashe Chakanyuka_EDOOFA(1_12)GS.txt
# 2023-12-06 10:52:28,336 - DEBUG - Row appended for chat file: WhatsApp Chat with Tadiwanashe Gatsi_EDOOFA(1_12)GS.txt
# 2023-12-06 10:52:28,542 - DEBUG - Row appended for chat file: WhatsApp Chat with Tafadzwa Mahawu_EDOOFA(30_11)GS.txt
# 2023-12-06 10:52:28,693 - DEBUG - Row appended for chat file: WhatsApp Chat with Takudzwa Zisengwe_EDOOFA(04_12)GS.txt
# 2023-12-06 10:52:28,874 - DEBUG - Row appended for chat file: WhatsApp Chat with Takunda Mahupe_EDOOFA(25_11)GS.txt
# 2023-12-06 10:52:29,017 - DEBUG - Row appended for chat file: WhatsApp Chat with Tanya Munzeiwa_EDOOFA(30_11)GS.txt
# 2023-12-06 10:52:29,140 - DEBUG - Row appended for chat file: WhatsApp Chat with Taonga_EDOOFAZAM(5_12)GS.txt
# 2023-12-06 10:52:29,274 - DEBUG - Row appended for chat file: WhatsApp Chat with Thandiwe Jakachira_EDOOFA(30_11)GS.txt
# 2023-12-06 10:52:29,426 - DEBUG - Row appended for chat file: WhatsApp Chat with Tinotenda Gomo_EDOOFA(29_11)GS.txt
# 2023-12-06 10:52:29,564 - DEBUG - Row appended for chat file: WhatsApp Chat with Tinotenda manjengwa_EDOOFA(1_12)GS.txt
# 2023-12-06 10:52:29,742 - DEBUG - Row appended for chat file: WhatsApp Chat with Tolerance Chivavaya_EDOOFA(30_11)GS.txt
# 2023-12-06 10:52:29,899 - DEBUG - Row appended for chat file: WhatsApp Chat with Trace mahuma_EDOOFAZAM(5_12)GS.txt
# 2023-12-06 10:52:30,056 - DEBUG - Row appended for chat file: WhatsApp Chat with Trust Mbaura_EDOOFA(30_11)GS.txt
# 2023-12-06 10:52:30,199 - DEBUG - Row appended for chat file: WhatsApp Chat with Tsitsi Mudzoki_EDOOFA(30_11)GS.txt
# 2023-12-06 10:52:30,319 - DEBUG - Row appended for chat file: WhatsApp Chat with Vannessa Chimombe_EDOOFAZAM(5_12)GS.txt
# 2023-12-06 10:52:30,461 - DEBUG - Row appended for chat file: WhatsApp Chat with Vimbai Nyangani_EDOOFA(25_11)GS.txt
# 2023-12-06 10:52:30,611 - DEBUG - Row appended for chat file: WhatsApp Chat with Wana Mugala_EDOOFA(1_12)GS.txt
# 2023-12-06 10:52:30,755 - DEBUG - Row appended for chat file: WhatsApp Chat with ZUZE DESIRE_EDOOFA(1_12)GS.txt
# 2023-12-06 10:52:30,911 - DEBUG - Row appended for chat file: WhatsApp Chat with Amin_Edoofa(05_12)HP.txt
# 2023-12-06 10:52:31,041 - DEBUG - Row appended for chat file: WhatsApp Chat with Aswell_Edoofa(01_12)HP.txt
# 2023-12-06 10:52:31,178 - DEBUG - Row appended for chat file: WhatsApp Chat with Blessed_Edoofa(01_12)HP.txt
# 2023-12-06 10:52:31,308 - DEBUG - Row appended for chat file: WhatsApp Chat with Christabel_Edoofa(05_12)HP.txt
# 2023-12-06 10:52:31,458 - DEBUG - Row appended for chat file: WhatsApp Chat with Elias_Edoofa(01_12)HP.txt
# 2023-12-06 10:52:31,607 - DEBUG - Row appended for chat file: WhatsApp Chat with Ethelbert_Edoofa(05_12)HP.txt
# 2023-12-06 10:52:31,752 - DEBUG - Row appended for chat file: WhatsApp Chat with Grace_Edoofa(05_12)HP.txt
# 2023-12-06 10:52:31,896 - DEBUG - Row appended for chat file: WhatsApp Chat with Joyce_Edoofa(01_12)HP.txt
# 2023-12-06 10:52:32,016 - DEBUG - Row appended for chat file: WhatsApp Chat with Leondah_Edoofa(05_12)HP.txt
# 2023-12-06 10:52:32,149 - DEBUG - Row appended for chat file: WhatsApp Chat with Liana_Edoofa(06_11)HP.txt
# 2023-12-06 10:52:32,290 - DEBUG - Row appended for chat file: WhatsApp Chat with Lisa_Edoofa(30_11)HP.txt
# 2023-12-06 10:52:32,424 - DEBUG - Row appended for chat file: WhatsApp Chat with Michael_Edoofa(01_12)HP.txt
# 2023-12-06 10:52:32,602 - DEBUG - Row appended for chat file: WhatsApp Chat with Munashe_Edoofa(27_11)HP.txt
# 2023-12-06 10:52:32,764 - DEBUG - Row appended for chat file: WhatsApp Chat with Munyaradzi_Edoofa(05_12)HP.txt
# 2023-12-06 10:52:32,907 - DEBUG - Row appended for chat file: WhatsApp Chat with Natasha_Edoofa(01_12)HP.txt
# 2023-12-06 10:52:33,028 - DEBUG - Row appended for chat file: WhatsApp Chat with Nenyasha_Edoofa(05_12)HP.txt
# 2023-12-06 10:52:33,171 - DEBUG - Row appended for chat file: WhatsApp Chat with Nomakhosi_Edoofa(05_12)HP.txt
# 2023-12-06 10:52:33,296 - DEBUG - Row appended for chat file: WhatsApp Chat with Nyasha_Edoofa(05_12)HP.txt
# 2023-12-06 10:52:33,458 - DEBUG - Row appended for chat file: WhatsApp Chat with Panashe_Edoofa(06_11)HP.txt
# 2023-12-06 10:52:33,653 - DEBUG - Row appended for chat file: WhatsApp Chat with Precious_DM01(17_08)PN.txt
# ENTER THE LOOP:               datetime            sender  \
# 338 2023-12-05 14:49:00  +263 77 412 4684
#
#                                                message
# 338  How are you sir l have failed to pay Precious'...
# 2023-12-06 10:52:33,777 - DEBUG - Row appended for chat file: WhatsApp Chat with Precious_Edoofa(01_12)HP.txt
# 2023-12-06 10:52:33,947 - DEBUG - Row appended for chat file: WhatsApp Chat with Priscilla_Edoofa(05_12)HP.txt
# 2023-12-06 10:52:34,131 - DEBUG - Row appended for chat file: WhatsApp Chat with Rosemary_Edoofa(22_11)HP.txt
# 2023-12-06 10:52:34,250 - DEBUG - Row appended for chat file: WhatsApp Chat with Russell_Edoofa(05_12)HP.txt
# 2023-12-06 10:52:34,374 - DEBUG - Row appended for chat file: WhatsApp Chat with Tadiwa_Edoofa(05_12)HP.txt
# 2023-12-06 10:52:34,497 - DEBUG - Row appended for chat file: WhatsApp Chat with Tanaka_Edoofa(05_12)HP.txt
# 2023-12-06 10:52:34,655 - DEBUG - Row appended for chat file: WhatsApp Chat with Tanatswa_Edoofa(01_12)HP.txt
# 2023-12-06 10:52:34,776 - DEBUG - Row appended for chat file: WhatsApp Chat with Thandiwe_Edoofa(05_12)HP.txt
# 2023-12-06 10:52:34,964 - DEBUG - Row appended for chat file: WhatsApp Chat with Tinashe_Edoofa(03_11)HP.txt
# 2023-12-06 10:52:35,100 - DEBUG - Row appended for chat file: WhatsApp Chat with Leeroy Wekare_Edoofa(08_11)KA.txt
# 2023-12-06 10:52:35,284 - DEBUG - Row appended for chat file: WhatsApp Chat with Albert_Edoofa(28_11)PG.txt
# ENTER THE LOOP:              datetime            sender                 message
# 73 2023-12-05 08:12:00  +263 77 650 2518  Kuri cei hako mwanangu
# 2023-12-06 10:52:35,411 - DEBUG - Row appended for chat file: WhatsApp Chat with Alvin_Edoofa(06_12)PG.txt
# 2023-12-06 10:52:35,552 - DEBUG - Row appended for chat file: WhatsApp Chat with Amara_Edoofa(02_12)PG.txt
# 2023-12-06 10:52:35,704 - DEBUG - Row appended for chat file: WhatsApp Chat with Anelka_Edoofa(28_11)PG.txt
# 2023-12-06 10:52:35,824 - DEBUG - Row appended for chat file: WhatsApp Chat with Ashley_Edoofa(06_12)PG-IE.txt
# 2023-12-06 10:52:36,058 - DEBUG - Row appended for chat file: WhatsApp Chat with Awakhiwe_Edoofa(20_11)PG.txt
# 2023-12-06 10:52:36,186 - DEBUG - Row appended for chat file: WhatsApp Chat with Brain_Edoofa(05_12)PG.txt
# 2023-12-06 10:52:36,403 - DEBUG - Row appended for chat file: WhatsApp Chat with Cleave_Edoofa(29_11)PG-IE.txt
# 2023-12-06 10:52:36,568 - DEBUG - Row appended for chat file: WhatsApp Chat with Dylan_Edoofa(24_11)PG.txt
# ENTER THE LOOP:              datetime            sender  \
# 47 2023-12-05 06:30:00  +263 78 388 8312
# 48 2023-12-05 22:47:00  +263 78 388 8312
#
#                                               message
# 47                                            I'm sir
# 48  My name is Dylan  Hapanyengwi born on the 26th...
# 2023-12-06 10:52:36,774 - DEBUG - Row appended for chat file: WhatsApp Chat with Elijjah_Edoofa(28_11)PG.txt
# 2023-12-06 10:52:36,896 - DEBUG - Row appended for chat file: WhatsApp Chat with Elizabeth_Edoofa(06_12)PG.txt
# 2023-12-06 10:52:37,091 - DEBUG - Row appended for chat file: WhatsApp Chat with Evelyn_Edoofa(23_11)PG-IE.txt
# 2023-12-06 10:52:37,227 - DEBUG - Row appended for chat file: WhatsApp Chat with Excellence_Edoofa(15_11)PG.txt
# ENTER THE LOOP:              datetime            sender message
# 18 2023-12-05 20:42:00  +263 78 877 1780   Hello
# 2023-12-06 10:52:37,425 - DEBUG - Row appended for chat file: WhatsApp Chat with Fadzisai_Edoofa(09_11)PG.txt
# 2023-12-06 10:52:37,597 - DEBUG - Row appended for chat file: WhatsApp Chat with Faith_Edoofa(29_11)PG.txt
# 2023-12-06 10:52:37,745 - DEBUG - Row appended for chat file: WhatsApp Chat with Gamuchirai_Edoofa(16_11)PG-IE.txt
# 2023-12-06 10:52:37,874 - DEBUG - Row appended for chat file: WhatsApp Chat with Gilbert_Edoofa(02_12)PG.txt
# 2023-12-06 10:52:37,993 - DEBUG - Row appended for chat file: WhatsApp Chat with Isabel_Edoofa(06_12)PG.txt
# 2023-12-06 10:52:38,117 - DEBUG - Row appended for chat file: WhatsApp Chat with Kieran_Edoofa(05_12)PG.txt
# 2023-12-06 10:52:38,285 - DEBUG - Row appended for chat file: WhatsApp Chat with Kudakwashe_Edoofa(02_12)PG.txt
# 2023-12-06 10:52:38,461 - DEBUG - Row appended for chat file: WhatsApp Chat with Linny_Edoofa(6_11)PG.txt
# ENTER THE LOOP:              datetime            sender   message
# 14 2023-12-05 08:00:00  +263 71 798 7515  Hie guys
# 2023-12-06 10:52:38,691 - DEBUG - Row appended for chat file: WhatsApp Chat with Mangoma_Edoofa(02_12)PG.txt
# 2023-12-06 10:52:38,893 - DEBUG - Row appended for chat file: WhatsApp Chat with Mathias_Edoofa(15_11)PG.txt
# 2023-12-06 10:52:39,049 - DEBUG - Row appended for chat file: WhatsApp Chat with Michael_Edoofa(01_12)PG.txt
# 2023-12-06 10:52:39,188 - DEBUG - Row appended for chat file: WhatsApp Chat with Michell_Edoofa(01_12)PG.txt
# 2023-12-06 10:52:39,311 - DEBUG - Row appended for chat file: WhatsApp Chat with Millicent_Edoofa(02_12)PG.txt
# 2023-12-06 10:52:39,519 - DEBUG - Row appended for chat file: WhatsApp Chat with Mitchelle_Edoofa(28_11)PG.txt
# ENTER THE LOOP:               datetime            sender  \
# 244 2023-12-05 20:44:00  +263 78 373 6848
#
#                                                message
# 244  Good afternoon,I wanted to ask after completin...
# 2023-12-06 10:52:39,643 - DEBUG - Row appended for chat file: WhatsApp Chat with Mqhele_Edoofa(06_12)PG.txt
# 2023-12-06 10:52:39,831 - DEBUG - Row appended for chat file: WhatsApp Chat with Mugede_Edoofa(20_11)PG-IE.txt
# 2023-12-06 10:52:39,955 - DEBUG - Row appended for chat file: WhatsApp Chat with Munashe_Edoofa(06_12)PG.txt
# 2023-12-06 10:52:40,126 - DEBUG - Row appended for chat file: WhatsApp Chat with Nathan_Edoofa(01_12)PG-IE.txt
# 2023-12-06 10:52:40,245 - DEBUG - Row appended for chat file: WhatsApp Chat with Nicole_Edoofa(06_12)PG.txt
# 2023-12-06 10:52:40,470 - DEBUG - Row appended for chat file: WhatsApp Chat with Nobuhle_Edoofa(27_10)PG-IE.txt
# 2023-12-06 10:52:40,619 - DEBUG - Row appended for chat file: WhatsApp Chat with Nokutenda_Edoofa(29_11)PG.txt
# 2023-12-06 10:52:40,768 - DEBUG - Row appended for chat file: WhatsApp Chat with Panashe_Edoofa(28_11)PG.txt
# 2023-12-06 10:52:40,917 - DEBUG - Row appended for chat file: WhatsApp Chat with Payne_Edoofa(04_12)PG-IE.txt
# 2023-12-06 10:52:41,033 - DEBUG - Row appended for chat file: WhatsApp Chat with Peter_Edoofa(06_12)PG-IE.txt
# 2023-12-06 10:52:41,151 - DEBUG - Row appended for chat file: WhatsApp Chat with Prince_Edoofa(06_12)PG.txt
# 2023-12-06 10:52:41,273 - DEBUG - Row appended for chat file: WhatsApp Chat with Purity_Edoofa(04_12)PG-IE.txt
# 2023-12-06 10:52:41,435 - DEBUG - Row appended for chat file: WhatsApp Chat with Rachel_Edoofa(11_10)PG.txt
# 2023-12-06 10:52:41,577 - DEBUG - Row appended for chat file: WhatsApp Chat with Richard_Edoofa(04_12)PG-IE.txt
# 2023-12-06 10:52:41,738 - DEBUG - Row appended for chat file: WhatsApp Chat with Ropafadzo_Edoofa(23_11)PG-IE.txt
# ENTER THE LOOP:              datetime            sender                    message
# 22 2023-12-05 22:27:00  +263 77 783 7477  Hie is my form in process
# 2023-12-06 10:52:41,876 - DEBUG - Row appended for chat file: WhatsApp Chat with Rufaro_Edoofa(05_12)PG.txt
# 2023-12-06 10:52:42,061 - DEBUG - Row appended for chat file: WhatsApp Chat with Rutendo_Edoofa(20_11)PG.txt
# 2023-12-06 10:52:42,271 - DEBUG - Row appended for chat file: WhatsApp Chat with Ryan_Edoofa(29_11)PG.txt
# 2023-12-06 10:52:42,548 - DEBUG - Row appended for chat file: WhatsApp Chat with Sithabile_Edoofa(20_11)PG.txt
# 2023-12-06 10:52:42,768 - DEBUG - Row appended for chat file: WhatsApp Chat with Tadiwanashe Tsindi_Edoofa(23_11)PG.txt
# 2023-12-06 10:52:42,962 - DEBUG - Row appended for chat file: WhatsApp Chat with Tadiwanashe_Edoofa(23_11)PG-IE.txt
# 2023-12-06 10:52:43,205 - DEBUG - Row appended for chat file: WhatsApp Chat with Takudzwa_Edoofa(02_11)PG.txt
# 2023-12-06 10:52:43,330 - DEBUG - Row appended for chat file: WhatsApp Chat with Tanaka_Edoofa(05_12)PG.txt
# 2023-12-06 10:52:43,459 - DEBUG - Row appended for chat file: WhatsApp Chat with Tanatswa_Edoofa(06_12)PG.txt
# 2023-12-06 10:52:43,647 - DEBUG - Row appended for chat file: WhatsApp Chat with Tashinga_Edoofa(20_11)PG-IE.txt
# 2023-12-06 10:52:43,819 - DEBUG - Row appended for chat file: WhatsApp Chat with Tawanda_Edoofa(16_11)PG-IE.txt
# 2023-12-06 10:52:43,984 - DEBUG - Row appended for chat file: WhatsApp Chat with Tendai_Edoofa(28_11)PG.txt
# 2023-12-06 10:52:44,101 - DEBUG - Row appended for chat file: WhatsApp Chat with Thokozani_Edoofa(06_12)PG-IE.txt
# 2023-12-06 10:52:44,216 - DEBUG - Row appended for chat file: WhatsApp Chat with Tinashe_Edoofa(06_12)PG.txt
# 2023-12-06 10:52:44,421 - DEBUG - Row appended for chat file: WhatsApp Chat with Tinatsei_Edoofa(27_10)PG.txt
# 2023-12-06 10:52:44,555 - DEBUG - Row appended for chat file: WhatsApp Chat with Tinaye_Edoofa(04_12)PG-IE.txt
# 2023-12-06 10:52:44,793 - DEBUG - Row appended for chat file: WhatsApp Chat with Tinotenda_Edoofa(16_11)PG.txt
# 2023-12-06 10:52:44,994 - DEBUG - Row appended for chat file: WhatsApp Chat with Tinotenda_Edoofa(17_11)PG.txt
# 2023-12-06 10:52:45,111 - DEBUG - Row appended for chat file: WhatsApp Chat with Tumelo_Edoofa(06_12)PG.txt
# 2023-12-06 10:52:45,236 - DEBUG - Row appended for chat file: WhatsApp Chat with Vanessa_Edoofa(01_12)PG-IE.txt
# 2023-12-06 10:52:45,470 - DEBUG - Row appended for chat file: WhatsApp Chat with Vuyisile_Edoofa(20_11)PG.txt
# 2023-12-06 10:52:45,606 - DEBUG - Row appended for chat file: WhatsApp Chat with Walter_Edoofa(02_12)PG.txt
# 2023-12-06 10:52:45,742 - DEBUG - Row appended for chat file: WhatsApp Chat with Wilfred_Edoofa(01_12)PG.txt
# 2023-12-06 10:52:45,934 - DEBUG - Row appended for chat file: WhatsApp Chat with Winslet_Edoofa(20_11)PG.txt
# 2023-12-06 10:52:46,162 - DEBUG - Row appended for chat file: WhatsApp Chat with Adonis_DM02(21_11)HP.txt
# 2023-12-06 10:52:46,400 - DEBUG - Row appended for chat file: WhatsApp Chat with Albert Phiri Edoofa (16_11) SZ.txt
# 2023-12-06 10:52:46,605 - DEBUG - Row appended for chat file: WhatsApp Chat with Ashley_DM02(21_11)HP.txt
# 2023-12-06 10:52:46,843 - DEBUG - Row appended for chat file: WhatsApp Chat with Ashley_Edoofa(15_11)HP.txt
# 2023-12-06 10:52:47,113 - DEBUG - Row appended for chat file: WhatsApp Chat with BekithembaJNR_Edoofa(18_10)HP.txt
# 2023-12-06 10:52:47,331 - DEBUG - Row appended for chat file: WhatsApp Chat with Bernice_Edoofa(22_11)HP.txt
# 2023-12-06 10:52:47,563 - DEBUG - Row appended for chat file: WhatsApp Chat with Bongani_Edoofa(23_11)HP.txt
# 2023-12-06 10:52:47,793 - DEBUG - Row appended for chat file: WhatsApp Chat with Brendon Makwasha Edoofa (18_11) SZ.txt
# 2023-12-06 10:52:48,038 - DEBUG - Row appended for chat file: WhatsApp Chat with Brian_Edoofa(15_11)HP.txt
# 2023-12-06 10:52:48,246 - DEBUG - Row appended for chat file: WhatsApp Chat with Brian_Edoofa(27_11)HP.txt
# 2023-12-06 10:52:48,474 - DEBUG - Row appended for chat file: WhatsApp Chat with Caleb Chunga Edoofa (08_11) SZ.txt
# 2023-12-06 10:52:48,720 - DEBUG - Row appended for chat file: WhatsApp Chat with Candice Zulu Edoofa (08_11) SZ 2025.txt
# 2023-12-06 10:52:49,003 - DEBUG - Row appended for chat file: WhatsApp Chat with Casper Taruvinga Edoofa (16_11) SZ 2025.txt
# 2023-12-06 10:52:49,249 - DEBUG - Row appended for chat file: WhatsApp Chat with Charmaine Chikanya T Edoofa (15_11) SZ 2025.txt
# 2023-12-06 10:52:49,531 - DEBUG - Row appended for chat file: WhatsApp Chat with Chirasikwa Ropafadzo Edoofa (23_10) SZ.txt
# 2023-12-06 10:52:49,800 - DEBUG - Row appended for chat file: WhatsApp Chat with Chisanhu Nyashadzashe Edoofa (07_11) SZ 2025.txt
# 2023-12-06 10:52:50,039 - DEBUG - Row appended for chat file: WhatsApp Chat with Chitungo Chipo Edoofa (15_11) SZ.txt
# 2023-12-06 10:52:50,278 - DEBUG - Row appended for chat file: WhatsApp Chat with Danai_Edoofa(06_09)HP.txt
# 2023-12-06 10:52:50,512 - DEBUG - Row appended for chat file: WhatsApp Chat with Dube Laurrie Edoofa (15_11) SZ 2025.txt
# 2023-12-06 10:52:50,737 - DEBUG - Row appended for chat file: WhatsApp Chat with Ebony_Edoofa(30_10)HP.txt
# 2023-12-06 10:52:51,006 - DEBUG - Row appended for chat file: WhatsApp Chat with Ekalhi_Edoofa(20_10)HP.txt
# 2023-12-06 10:52:51,228 - DEBUG - Row appended for chat file: WhatsApp Chat with Farai Chipfuwamuti EDOOFA(15_11)SR.txt
# 2023-12-06 10:52:51,479 - DEBUG - Row appended for chat file: WhatsApp Chat with Fourpence Monalisa Edoofa (01_11) SZ.txt
# 2023-12-06 10:52:51,695 - DEBUG - Row appended for chat file: WhatsApp Chat with Gofa Deonaly EDOOFA(15_11)SR.txt
# 2023-12-06 10:52:51,960 - DEBUG - Row appended for chat file: WhatsApp Chat with Grace_Edoofa(22_11)HP.txt
# 2023-12-06 10:52:52,222 - DEBUG - Row appended for chat file: WhatsApp Chat with Gracious_Edoofa(07_11)HP.txt
# 2023-12-06 10:52:52,429 - DEBUG - Row appended for chat file: WhatsApp Chat with Great_Edoofa(23_11)HP.txt
# 2023-12-06 10:52:52,625 - DEBUG - Row appended for chat file: WhatsApp Chat with Hugh_Edoofa(01_12)HP.txt
# 2023-12-06 10:52:52,868 - DEBUG - Row appended for chat file: WhatsApp Chat with Innocent_Edoofa(21_11)HP.txt
# 2023-12-06 10:52:53,117 - DEBUG - Row appended for chat file: WhatsApp Chat with Isheanesu E Atukwa Edoofa (10_11) SZ 2025.txt
# 2023-12-06 10:52:53,360 - DEBUG - Row appended for chat file: WhatsApp Chat with Ivainashe_Edoofa(30_10)HP.txt
# 2023-12-06 10:52:53,618 - DEBUG - Row appended for chat file: WhatsApp Chat with Joshua_Edoofa(20_11)HP.txt
# 2023-12-06 10:52:53,818 - DEBUG - Row appended for chat file: WhatsApp Chat with Juliet Malowa Edoofa (27_11) SZ 2025.txt
# 2023-12-06 10:52:54,019 - DEBUG - Row appended for chat file: WhatsApp Chat with Kayembe Israel Edoofa(30_10)SR300.txt
# 2023-12-06 10:52:54,267 - DEBUG - Row appended for chat file: WhatsApp Chat with Kudakwashe_Edoofa(20_04)HP.txt
# 2023-12-06 10:52:54,508 - DEBUG - Row appended for chat file: WhatsApp Chat with Kumbirai Kelvin Tsapo  EDOOFA(01_11)SR.txt
# ENTER THE LOOP:               datetime           sender  \
# 389 2023-12-05 18:22:00  +27 71 707 0139
#
#                                                message
# 389  Mukuru: Thanks for paying Ordr:113748822 for $...
# 2023-12-06 10:52:54,755 - DEBUG - Row appended for chat file: WhatsApp Chat with Kuzoraunye Tatenda EDOOFA(15_11)SR 2025.txt
# 2023-12-06 10:52:54,951 - DEBUG - Row appended for chat file: WhatsApp Chat with Langton 2K23NOV0654R.txt
# ENTER THE LOOP:               datetime            sender  \
# 249 2023-12-05 18:49:00   +91 83840 48513
# 250 2023-12-05 20:16:00  +263 77 118 4986
# 251 2023-12-05 21:18:00   +91 83840 48513
# 252 2023-12-05 21:27:00  +263 77 118 4986
#
#                                                message
# 249  Good Evening, dear parents and My dear student...
# 250  Hello how are you sorry for late reply  networ...
# 251  I was not able to have our session productivel...
# 252        Thank you may you have a warm night as well
# 2023-12-06 10:52:55,239 - DEBUG - Row appended for chat file: WhatsApp Chat with Madombi Eufemia Edoofa (27_09) SZ.txt
# 2023-12-06 10:52:55,471 - DEBUG - Row appended for chat file: WhatsApp Chat with Malvern Chiwashira Edoofa (14_11) SZ.txt
# 2023-12-06 10:52:55,694 - DEBUG - Row appended for chat file: WhatsApp Chat with Mapalo_Edoofa(13_09)HP.txt
# 2023-12-06 10:52:55,917 - DEBUG - Row appended for chat file: WhatsApp Chat with Mark Kabwe Edoofa (03_11) SZ.txt
# 2023-12-06 10:52:56,182 - DEBUG - Row appended for chat file: WhatsApp Chat with Mary Sitali EDOOFA(17_10)SS 2025.txt
# 2023-12-06 10:52:56,391 - DEBUG - Row appended for chat file: WhatsApp Chat with Mashava Sharbonau Espinosar EDOOFA(15_11)SR.txt
# 2023-12-06 10:52:56,652 - DEBUG - Row appended for chat file: WhatsApp Chat with Mawire Confidence Edoofa (31_08) SZ.txt
# ENTER THE LOOP:               datetime            sender    message
# 457 2023-12-05 17:58:00  +263 77 532 6412  I'm ready
# 2023-12-06 10:52:56,881 - DEBUG - Row appended for chat file: WhatsApp Chat with Mcnally_Edoofa(02_11)HP.txt
# 2023-12-06 10:52:57,115 - DEBUG - Row appended for chat file: WhatsApp Chat with Melody_Edoofa(20_11)HP.txt
# 2023-12-06 10:52:57,396 - DEBUG - Row appended for chat file: WhatsApp Chat with Melyndah_Edoofa(15_11)HP.txt
# 2023-12-06 10:52:57,646 - DEBUG - Row appended for chat file: WhatsApp Chat with Michael_Edoofa(20_11)HP.txt
# 2023-12-06 10:52:57,875 - DEBUG - Row appended for chat file: WhatsApp Chat with Michelle Gorekore Edoofa (21_11) SZ 2025.txt
# 2023-12-06 10:52:58,065 - DEBUG - Row appended for chat file: WhatsApp Chat with Michelle Tsvanu G EDOOFA(3_11)SR.txt
# 2023-12-06 10:52:58,294 - DEBUG - Row appended for chat file: WhatsApp Chat with Mubvakure Anashe EDOOFA(15_11)SR.txt
# 2023-12-06 10:52:58,527 - DEBUG - Row appended for chat file: WhatsApp Chat with Munashe_Edoofa(21_11)HP.txt
# 2023-12-06 10:52:58,775 - DEBUG - Row appended for chat file: WhatsApp Chat with Munotida Gillian Makumbi Edoofa (10_11) SZ 2025.txt
# 2023-12-06 10:52:59,016 - DEBUG - Row appended for chat file: WhatsApp Chat with Natasha_Edoofa(17_11)HP.txt
# 2023-12-06 10:52:59,213 - DEBUG - Row appended for chat file: WhatsApp Chat with Nigel Chada EDOOFA(27_10)SR 2025.txt
# 2023-12-06 10:52:59,476 - DEBUG - Row appended for chat file: WhatsApp Chat with Nigel_Edoofa(22_11)HP.txt
# 2023-12-06 10:52:59,722 - DEBUG - Row appended for chat file: WhatsApp Chat with Nokutenda Gapara  EDOOFA(15_11)SR.txt
# 2023-12-06 10:52:59,925 - DEBUG - Row appended for chat file: WhatsApp Chat with Nomthandazo_Edoofa(27_11)HP.txt
# 2023-12-06 10:53:00,162 - DEBUG - Row appended for chat file: WhatsApp Chat with Peter_DM02(21_11)HP.txt
# 2023-12-06 10:53:00,417 - DEBUG - Row appended for chat file: WhatsApp Chat with Praise_Edoofa(02_11)HP.txt
# 2023-12-06 10:53:00,638 - DEBUG - Row appended for chat file: WhatsApp Chat with Pride Munyuki Edoofa (24_11) SZ.txt
# 2023-12-06 10:53:00,772 - DEBUG - Row appended for chat file: WhatsApp Chat with Pride Mutukunyu EDOOFA(21_06)SR.txt
# ENTER THE LOOP:              datetime           sender  \
# 38 2023-12-05 09:25:00  +27 68 793 3040
#
#                                               message
# 38  *Shazzy* *Lottery* *DreamGuide* *1* .👑 *King H...
# 2023-12-06 10:53:01,025 - DEBUG - Row appended for chat file: WhatsApp Chat with Providence_Edoofa(06_11)HP.txt
# 2023-12-06 10:53:01,315 - DEBUG - Row appended for chat file: WhatsApp Chat with Raymond_Edoofa(06_11)HP.txt
# 2023-12-06 10:53:01,530 - DEBUG - Row appended for chat file: WhatsApp Chat with Rutendo_Edoofa(27_11)HP.txt
# 2023-12-06 10:53:01,712 - DEBUG - Row appended for chat file: WhatsApp Chat with Ruvimbo_Edoofa(27_11)HP.txt
# 2023-12-06 10:53:01,935 - DEBUG - Row appended for chat file: WhatsApp Chat with Ryan_CM01(16_11)HP.txt
# 2023-12-06 10:53:02,162 - DEBUG - Row appended for chat file: WhatsApp Chat with Ryan_Edoofa(19_10)HP.txt
# 2023-12-06 10:53:02,398 - DEBUG - Row appended for chat file: WhatsApp Chat with Samuel_DM01(15_11)HP.txt
# 2023-12-06 10:53:02,639 - DEBUG - Row appended for chat file: WhatsApp Chat with Sandra_Edoofa(07_11)HP.txt
# 2023-12-06 10:53:02,868 - DEBUG - Row appended for chat file: WhatsApp Chat with Scotch Renaissance R Edoofa (20_11) SZ.txt
# 2023-12-06 10:53:03,143 - DEBUG - Row appended for chat file: WhatsApp Chat with Shamiso Chamusingarevi Edoofa (25_10) SZ.txt
# 2023-12-06 10:53:03,363 - DEBUG - Row appended for chat file: WhatsApp Chat with Shamma Malilwe Edoofa (22_11) SZ.txt
# 2023-12-06 10:53:03,571 - DEBUG - Row appended for chat file: WhatsApp Chat with Sharmaine_Edoofa(27_11)HP.txt
# 2023-12-06 10:53:03,764 - DEBUG - Row appended for chat file: WhatsApp Chat with Shumirai_Edoofa(01_12)HP.txt
# 2023-12-06 10:53:04,004 - DEBUG - Row appended for chat file: WhatsApp Chat with Sijamali Michelo Edoofa (22_11) SZ.txt
# 2023-12-06 10:53:04,200 - DEBUG - Row appended for chat file: WhatsApp Chat with Spiwe_EA(31_10)HP.txt
# 2023-12-06 10:53:04,425 - DEBUG - Row appended for chat file: WhatsApp Chat with Stacey Rurayi Nyakabau Edoofa (14_11) SZ 2025.txt
# 2023-12-06 10:53:04,679 - DEBUG - Row appended for chat file: WhatsApp Chat with Tadiwanashe Murandu Edoofa (30_10) SZ.txt
# 2023-12-06 10:53:04,885 - DEBUG - Row appended for chat file: WhatsApp Chat with Tadiwanashe_Edoofa(27_11)HP.txt
# 2023-12-06 10:53:05,156 - DEBUG - Row appended for chat file: WhatsApp Chat with Takudzwa_Edoofa(08_11)HP.txt
# 2023-12-06 10:53:05,432 - DEBUG - Row appended for chat file: WhatsApp Chat with Takunda_Edoofa(23_10)HP.txt
# 2023-12-06 10:53:05,639 - DEBUG - Row appended for chat file: WhatsApp Chat with Tamara_DM02(27_11)HP.txt
# 2023-12-06 10:53:05,856 - DEBUG - Row appended for chat file: WhatsApp Chat with Tanatswa_Edoofa(22_11)HP.txt
# 2023-12-06 10:53:06,125 - DEBUG - Row appended for chat file: WhatsApp Chat with Tanil Rudo Handiseni Edoofa (01_11) SZ 2025.txt
# 2023-12-06 10:53:06,368 - DEBUG - Row appended for chat file: WhatsApp Chat with Tanyaradzwa_Edoofa(03_11)HP.txt
# 2023-12-06 10:53:06,606 - DEBUG - Row appended for chat file: WhatsApp Chat with Tanyaradzwa_Edoofa(15_11)HP.txt
# 2023-12-06 10:53:06,832 - DEBUG - Row appended for chat file: WhatsApp Chat with Tashinga_DM01(15_11)HP.txt
# 2023-12-06 10:53:07,076 - DEBUG - Row appended for chat file: WhatsApp Chat with Tatenda_DM01(15_11)HP.txt
# 2023-12-06 10:53:07,342 - DEBUG - Row appended for chat file: WhatsApp Chat with Tatiana Ruvimbo Kapungu Edoofa (25_10) SZ.txt
# ...
# 2023-12-06 10:53:16,540 - DEBUG - Row appended for chat file: WhatsApp Chat with Masvikeni Ange_lique C V Edoofa (21_11) SZ.txt
# 2023-12-06 10:53:16,663 - DEBUG - Row appended for chat file: WhatsApp Chat with Matangwa Tariro Shawn Edoofa (01_12) SZ.txt
# 2023-12-06 10:53:16,794 - DEBUG - Row appended for chat file: WhatsApp Chat with Mickely Pombi Edoofa (28_11) SZ.txt
# ENTER THE LOOP:              datetime           sender                             message
# 12 2023-12-05 06:20:00  +27 78 587 6514  Good day. I'm no longer interested
# 2023-12-06 10:53:16,976 - DEBUG - Row appended for chat file: WhatsApp Chat with Misheck Mutunami Edoofa (18_11) SZ.txt
# 2023-12-06 10:53:17,188 - DEBUG - Row appended for chat file: WhatsApp Chat with Mishel Tadiwa Diwura Edoofa (16_11) SZ.txt
# 2023-12-06 10:53:17,336 - DEBUG - Row appended for chat file: WhatsApp Chat with Mitchell Mbiri Edoofa (28_11) SZ.txt
# 2023-12-06 10:53:17,470 - DEBUG - Row appended for chat file: WhatsApp Chat with Mufaro Tembo Edoofa (04_12) SZ.txt
# 2023-12-06 10:53:17,645 - DEBUG - Row appended for chat file: WhatsApp Chat with Mukangaya Kudzai C Edoofa (09_10) SZ.txt
# ENTER THE LOOP:               datetime            sender  \
# 135 2023-12-05 17:10:00  +263 78 657 4215
#
#                                   message
# 135  Those are the pictures yiu requested
# 2023-12-06 10:53:17,794 - DEBUG - Row appended for chat file: WhatsApp Chat with Musasira Rutendo Edoofa (29_11) SZ.txt
# 2023-12-06 10:53:17,994 - DEBUG - Row appended for chat file: WhatsApp Chat with Mushayavanhu Tapiwanashe SM Edoofa (21_11) SZ.txt
# 2023-12-06 10:53:18,155 - DEBUG - Row appended for chat file: WhatsApp Chat with Mutabeya Lyn Edoofa (28_11) SZ.txt
# 2023-12-06 10:53:18,341 - DEBUG - Row appended for chat file: WhatsApp Chat with Naume Sabiti Edoofa (06_11) SZ.txt
# 2023-12-06 10:53:18,497 - DEBUG - Row appended for chat file: WhatsApp Chat with Ncube Violet Edoofa (29_11) SZ.txt
# 2023-12-06 10:53:18,618 - DEBUG - Row appended for chat file: WhatsApp Chat with Nesbert Edoofa (04_12) SZ.txt
# 2023-12-06 10:53:18,751 - DEBUG - Row appended for chat file: WhatsApp Chat with Nicole Tokora Edoofa (05_12) SZ.txt
# 2023-12-06 10:53:18,924 - DEBUG - Row appended for chat file: WhatsApp Chat with Njanji Ruvarashe S Edoofa (28_11) SZ.txt
# 2023-12-06 10:53:19,075 - DEBUG - Row appended for chat file: WhatsApp Chat with Nwafor Ifeoma C Edoofa (20_11) SZ.txt
# ENTER THE LOOP:              datetime             sender                   message
# 45 2023-12-05 05:11:00  +234 811 297 9354              Good morning
# 46 2023-12-05 05:43:00  +234 703 798 3136  This message was deleted
# 2023-12-06 10:53:19,213 - DEBUG - Row appended for chat file: WhatsApp Chat with Nyasha Mukaka Edoofa (01_12) SZ.txt
# 2023-12-06 10:53:19,444 - DEBUG - Row appended for chat file: WhatsApp Chat with Nyashadzashe Muvirimi B Edoofa (27_11) SZ.txt
# 2023-12-06 10:53:19,591 - DEBUG - Row appended for chat file: WhatsApp Chat with Nyengeterai Mbenguzana Edoofa (23_11) SZ.txt
# 2023-12-06 10:53:19,722 - DEBUG - Row appended for chat file: WhatsApp Chat with Panashe Chideme Edoofa (04_12) SZ.txt
# 2023-12-06 10:53:19,878 - DEBUG - Row appended for chat file: WhatsApp Chat with Panashe Mumvuma Edoofa (30_11) SZ.txt
# 2023-12-06 10:53:20,079 - DEBUG - Row appended for chat file: WhatsApp Chat with Ritah Langa Kawimbe Edoofa (22_11) SZ.txt
# 2023-12-06 10:53:20,224 - DEBUG - Row appended for chat file: WhatsApp Chat with Rumbidzai Susan Joseph Edoofa (30_11) SZ.txt
# 2023-12-06 10:53:20,451 - DEBUG - Row appended for chat file: WhatsApp Chat with Shalom Chatsauka Edoofa (24_11) SZ.txt
# 2023-12-06 10:53:20,678 - DEBUG - Row appended for chat file: WhatsApp Chat with Shantel Tinaye Mahachi Edoofa (22_11) SZ.txt
# 2023-12-06 10:53:20,902 - DEBUG - Row appended for chat file: WhatsApp Chat with Sibanda Ruvarashe Edoofa (24_11) SZ.txt
# 2023-12-06 10:53:21,046 - DEBUG - Row appended for chat file: WhatsApp Chat with Simbarashe Manomano Edoofa (29_11) SZ.txt
# 2023-12-06 10:53:21,243 - DEBUG - Row appended for chat file: WhatsApp Chat with Simbarashe T. Mujuru Edoofa (24_11) SZ.txt
# 2023-12-06 10:53:21,505 - DEBUG - Row appended for chat file: WhatsApp Chat with Tabeth Mandembwe Edoofa (24_11) SZ.txt
# 2023-12-06 10:53:21,647 - DEBUG - Row appended for chat file: WhatsApp Chat with Tadiwanashe Moyo Edoofa (05_12) SZ.txt
# 2023-12-06 10:53:21,865 - DEBUG - Row appended for chat file: WhatsApp Chat with Tafara Mukucha Edoofa (23_11) SZ.txt
# 2023-12-06 10:53:22,021 - DEBUG - Row appended for chat file: WhatsApp Chat with Tafara Tirivashe Rukovo Edoofa (28_11) SZ.txt
# 2023-12-06 10:53:22,249 - DEBUG - Row appended for chat file: WhatsApp Chat with Takudzwa Chari Edoofa (27_11) SZ.txt
# 2023-12-06 10:53:22,471 - DEBUG - Row appended for chat file: WhatsApp Chat with Takudzwa Chinyama Edoofa (22_11) SZ.txt
# 2023-12-06 10:53:22,593 - DEBUG - Row appended for chat file: WhatsApp Chat with Takudzwa Kwenda Edoofa (05_12) SZ.txt
# 2023-12-06 10:53:22,822 - DEBUG - Row appended for chat file: WhatsApp Chat with Takunda Samantha Tinarwo Edoofa (18_11) SZ.txt
# 2023-12-06 10:53:22,971 - DEBUG - Row appended for chat file: WhatsApp Chat with Tarutira Anopaishe Edoofa (28_11) SZ.txt
# 2023-12-06 10:53:23,119 - DEBUG - Row appended for chat file: WhatsApp Chat with Tashinga Muvirimi Edoofa (29_11) SZ.txt
# 2023-12-06 10:53:23,284 - DEBUG - Row appended for chat file: WhatsApp Chat with Tsungi Nyasha Mushapaidze Edoofa (27_11) SZ.txt
# 2023-12-06 10:53:23,487 - DEBUG - Row appended for chat file: WhatsApp Chat with Urshler Mutevhani Edoofa (22_11) SZ.txt
# 2023-12-06 10:53:23,690 - DEBUG - Row appended for chat file: WhatsApp Chat with Vimbiso P. Dzvimbo Edoofa (23_10) SZ.txt
# 2023-12-06 10:53:23,820 - DEBUG - Row appended for chat file: WhatsApp Chat with Vongaishe Oliver Tendengu Edoofa (05_12) SZ.txt
# 2023-12-06 10:53:24,092 - DEBUG - Row appended for chat file: WhatsApp Chat with Adelaide Ndlovu_EDOOFA(16_11)SM23.txt
# 2023-12-06 10:53:24,324 - DEBUG - Row appended for chat file: WhatsApp Chat with Amanda Chidzoba_EDOOFAFFA(22_11)SM23.txt
# 2023-12-06 10:53:24,561 - DEBUG - Row appended for chat file: WhatsApp Chat with Antonette Ndlovu_EDOOFA(22_11)GS.txt
# 2023-12-06 10:53:24,804 - DEBUG - Row appended for chat file: WhatsApp Chat with Ashleigh Dumba_EDOOFA(20_11)GS.txt
# 2023-12-06 10:53:25,044 - DEBUG - Row appended for chat file: WhatsApp Chat with Bongozozo Rutendo_EDOOFALHS(09_11)SM23.txt
# 2023-12-06 10:53:25,286 - DEBUG - Row appended for chat file: WhatsApp Chat with Bradley Welae_EDOOFA(24_11)GS.txt
# 2023-12-06 10:53:25,451 - DEBUG - Row appended for chat file: WhatsApp Chat with Chantell Zvenyika_EDOOFA(22_11)SM23.txt
# 2023-12-06 10:53:25,683 - DEBUG - Row appended for chat file: WhatsApp Chat with Chantelle Garaba_Edoofa(16_10)SM.txt
# 2023-12-06 10:53:25,848 - DEBUG - Row appended for chat file: WhatsApp Chat with Charmaine Konsati_EDOOFA(17_11)SM23.txt
# 2023-12-06 10:53:26,050 - DEBUG - Row appended for chat file: WhatsApp Chat with Chibuwe Bradley_EA(02_11)TR.txt
# 2023-12-06 10:53:26,241 - DEBUG - Row appended for chat file: WhatsApp Chat with CHOOKA CHOOKA_EDOOFA(24_11)GS.txt
# 2023-12-06 10:53:26,384 - DEBUG - Row appended for chat file: WhatsApp Chat with Delane Marawa_EDOOFA(01_12)SM23.txt
# 2023-12-06 10:53:26,503 - DEBUG - Row appended for chat file: WhatsApp Chat with Fredannan Zinyakatira_EDOOFA(04_12)SM23.txt
# ENTER THE LOOP:             datetime            sender message
# 5 2023-12-05 23:36:00  +263 71 597 4887      Hi
# 2023-12-06 10:53:26,681 - DEBUG - Row appended for chat file: WhatsApp Chat with Gomba R_EDOOFA(29_11)GS.txt
# 2023-12-06 10:53:26,839 - DEBUG - Row appended for chat file: WhatsApp Chat with Gumbo Prosper_EA(17_11)TR.txt
# 2023-12-06 10:53:27,027 - DEBUG - Row appended for chat file: WhatsApp Chat with Hillary Muneriro_EDOOFA(17_11)SM23.txt
# 2023-12-06 10:53:27,220 - DEBUG - Row appended for chat file: WhatsApp Chat with Isheunesu Murandu_EDOOFAMHS(17_11)TR.txt
# 2023-12-06 10:53:27,450 - DEBUG - Row appended for chat file: WhatsApp Chat with Jephtah Masikati_EDOOFA(23_11)GS.txt
# 2023-12-06 10:53:27,719 - DEBUG - Row appended for chat file: WhatsApp Chat with Kelvin Maronga_EA(20_10)TR.txt
# 2023-12-06 10:53:27,923 - DEBUG - Row appended for chat file: WhatsApp Chat with Khumbulani Mundeta_EDOOFACHS(09_11)TR.txt
# 2023-12-06 10:53:28,157 - DEBUG - Row appended for chat file: WhatsApp Chat with Kudzai Ndongwe_EDOOFA(20_11)SM23.txt
# 2023-12-06 10:53:28,349 - DEBUG - Row appended for chat file: WhatsApp Chat with Kundai Nyamhanza_EDOOFA(14_11)SM23.txt
# 2023-12-06 10:53:28,564 - DEBUG - Row appended for chat file: WhatsApp Chat with Leah_Edoofa(10_05)SM.txt
# 2023-12-06 10:53:28,764 - DEBUG - Row appended for chat file: WhatsApp Chat with Lenon Marange_EA(16_11)TR.txt
# 2023-12-06 10:53:28,995 - DEBUG - Row appended for chat file: WhatsApp Chat with Leon_EDOOFAFFCA(18_09)SM.txt
# 2023-12-06 10:53:29,143 - DEBUG - Row appended for chat file: WhatsApp Chat with Limuere Chamunorwa_Edoofa(10_10)SM.txt
# ENTER THE LOOP:               datetime            sender                        message
# 137 2023-12-05 16:21:00  +263 78 091 6649                   Good day sir
# 138 2023-12-05 16:21:00  +263 78 091 6649  Sorry I was not coming online
# 2023-12-06 10:53:29,372 - DEBUG - Row appended for chat file: WhatsApp Chat with Lizbertin Mpofu_EDOOFA(16_11)SM23.txt
# 2023-12-06 10:53:29,602 - DEBUG - Row appended for chat file: WhatsApp Chat with Lydia Mukumba_EDOOFA(23_11)GS.txt
# 2023-12-06 10:53:29,835 - DEBUG - Row appended for chat file: WhatsApp Chat with Madzima Blessing_EDOOFA(24_11)GS.txt
# 2023-12-06 10:53:29,963 - DEBUG - Row appended for chat file: WhatsApp Chat with Maimba sibuyunji_EDOOFAZAM(5_12)GS.txt
# 2023-12-06 10:53:30,184 - DEBUG - Row appended for chat file: WhatsApp Chat with Makhosi Moyo_EDOOFA(20_11)GS.txt
# 2023-12-06 10:53:30,419 - DEBUG - Row appended for chat file: WhatsApp Chat with Malebogo Zulu_EDOOFA(14_11)SM23.txt
# 2023-12-06 10:53:30,652 - DEBUG - Row appended for chat file: WhatsApp Chat with Malunga Daniel_EDOOFA(23_11)GS.txt
# 2023-12-06 10:53:30,893 - DEBUG - Row appended for chat file: WhatsApp Chat with Manhamo Tanak_EDOOFA(24_11)GS.txt
# 2023-12-06 10:53:31,064 - DEBUG - Row appended for chat file: WhatsApp Chat with Margaret Matandirotya_EDOOFA(22_11)SM23.txt
# 2023-12-06 10:53:31,277 - DEBUG - Row appended for chat file: WhatsApp Chat with MARGARETH_BRIGHT_EDOOFACHS(09_11)TR.txt
# 2023-12-06 10:53:31,444 - DEBUG - Row appended for chat file: WhatsApp Chat with Melissa Masora_EDOOFA(29_11)GS.txt
# 2023-12-06 10:53:31,644 - DEBUG - Row appended for chat file: WhatsApp Chat with Michel Songano_EDOOFA(24_11)GS.txt
# 2023-12-06 10:53:31,833 - DEBUG - Row appended for chat file: WhatsApp Chat with Midzi Ancilla_EDOOFA(25_11)GS.txt
# 2023-12-06 10:53:32,013 - DEBUG - Row appended for chat file: WhatsApp Chat with Mudzamba Fadzai_EDOOFA(29_11)GS.txt
# 2023-12-06 10:53:32,247 - DEBUG - Row appended for chat file: WhatsApp Chat with Mufaro Simon_EDOOFA(18_11)GS.txt
# 2023-12-06 10:53:32,465 - DEBUG - Row appended for chat file: WhatsApp Chat with Munyanyiwa Nercia_EA(17_11)TR.txt
# 2023-12-06 10:53:32,662 - DEBUG - Row appended for chat file: WhatsApp Chat with Musiyiwa wepions_EA(16_11)TR.txt
# 2023-12-06 10:53:32,906 - DEBUG - Row appended for chat file: WhatsApp Chat with MUTEMA_MUNASHE_EDOOFA(22_11)GS.txt
# 2023-12-06 10:53:33,134 - DEBUG - Row appended for chat file: WhatsApp Chat with Mutsawashe Anhise_EDOOFA(14_11)SM23.txt
# 2023-12-06 10:53:33,364 - DEBUG - Row appended for chat file: WhatsApp Chat with Mutsawashe Makanya_EDOOFA(24_11)GS.txt
# 2023-12-06 10:53:33,582 - DEBUG - Row appended for chat file: WhatsApp Chat with Natalie_EDOOFA(01_11)SM23.txt
# 2023-12-06 10:53:33,793 - DEBUG - Row appended for chat file: WhatsApp Chat with Nenyasha Munzararikwa_EDOOFA(24_11)GS.txt
# 2023-12-06 10:53:33,962 - DEBUG - Row appended for chat file: WhatsApp Chat with Nesisa Mpofu_EDOOFA(17_11)SM23.txt
# 2023-12-06 10:53:34,119 - DEBUG - Row appended for chat file: WhatsApp Chat with Nigel Chiora_EDOOFA(16_11)SM23.txt
# 2023-12-06 10:53:34,258 - DEBUG - Row appended for chat file: WhatsApp Chat with Nigel Marowa_EDOOFA(01_12)SM23.txt
# 2023-12-06 10:53:34,514 - DEBUG - Row appended for chat file: WhatsApp Chat with Nisha Mungwira_EA(27_10)TR.txt
# 2023-12-06 10:53:34,735 - DEBUG - Row appended for chat file: WhatsApp Chat with Praise Mutema_EDOOFA(23_11)GS.txt
# 2023-12-06 10:53:34,978 - DEBUG - Row appended for chat file: WhatsApp Chat with Quinton Mudzi_Edoofa(16_11)SM23.txt
# 2023-12-06 10:53:35,100 - DEBUG - Row appended for chat file: WhatsApp Chat with Ropafadzo Khosah_EDOOFA(01_12)SM23.txt
# 2023-12-06 10:53:35,291 - DEBUG - Row appended for chat file: WhatsApp Chat with Runyararo Muchabaiwa_EDOOFA(29_11)GS.txt
# 2023-12-06 10:53:35,528 - DEBUG - Row appended for chat file: WhatsApp Chat with Rutendo Chitate_EDOOFA(30_10)SM23.txt
# 2023-12-06 10:53:35,708 - DEBUG - Row appended for chat file: WhatsApp Chat with Shallom Chimhowa_EDOOFA(20_11)SM23.txt
# 2023-12-06 10:53:35,933 - DEBUG - Row appended for chat file: WhatsApp Chat with Sharmaine Tsiga_EA(14_10)TR.txt
# ENTER THE LOOP:               datetime            sender  \
# 401 2023-12-05 10:29:00  +263 77 295 0153
# 402 2023-12-05 11:16:00  +263 77 295 0153
#
#                                                message
# 401                                            Morning
# 402  I have $150 now  can i take to the bank then t...
# 2023-12-06 10:53:36,155 - DEBUG - Row appended for chat file: WhatsApp Chat with Shindi Samuel_EA(21_11)TR.txt
# 2023-12-06 10:53:36,411 - DEBUG - Row appended for chat file: WhatsApp Chat with Shingirai Vunganai_EA(16_11)TR.txt
# 2023-12-06 10:53:36,619 - DEBUG - Row appended for chat file: WhatsApp Chat with Sigireta Tariro_EDOOFA(22_11)GS.txt
# 2023-12-06 10:53:36,806 - DEBUG - Row appended for chat file: WhatsApp Chat with Simeon Wamedzwa_EDOOFA(16_11)SM23.txt
# 2023-12-06 10:53:37,032 - DEBUG - Row appended for chat file: WhatsApp Chat with Surprise Mavhunga_EDOOFA(23_11)GS.txt
# 2023-12-06 10:53:37,245 - DEBUG - Row appended for chat file: WhatsApp Chat with TAFADZWA MUTINDI_EDOOFA(24_11)GS.txt
# 2023-12-06 10:53:37,428 - DEBUG - Row appended for chat file: WhatsApp Chat with Tanaka_Edoofa(29_08)GS.txt
# 2023-12-06 10:53:37,615 - DEBUG - Row appended for chat file: WhatsApp Chat with Tanyaradzwa Jiyah_EDOOFAMHS(17_11)TR.txt
# 2023-12-06 10:53:37,810 - DEBUG - Row appended for chat file: WhatsApp Chat with TENDEKAI MUMANYI_EA(30_10)TR.txt
# 2023-12-06 10:53:37,952 - DEBUG - Row appended for chat file: WhatsApp Chat with Thandeka Sigauke_EDOOFA(20_11)SM23.txt
# 2023-12-06 10:53:38,080 - DEBUG - Row appended for chat file: WhatsApp Chat with Tinotenda Mandishora_EDOOFA(01_12)SM23.txt
# 2023-12-06 10:53:38,288 - DEBUG - Row appended for chat file: WhatsApp Chat with Tinotenda_EDOOFAAHA(26_10)SM.txt
# 2023-12-06 10:53:38,425 - DEBUG - Row appended for chat file: WhatsApp Chat with Tinotenda_EdoofaMHS(08_08)SM.txt
# ENTER THE LOOP:              datetime            sender  \
# 99 2023-12-05 14:35:00  +263 71 214 8743
#
#                                               message
# 99  How are you doing sir  I am Tinotenda Mapedzam...
# 2023-12-06 10:53:38,621 - DEBUG - Row appended for chat file: WhatsApp Chat with Trevor Matende_EA(25_10)TR.txt
# 2023-12-06 10:53:38,822 - DEBUG - Row appended for chat file: WhatsApp Chat with Trish Mukari_EA(15_11)TR.txt
# 2023-12-06 10:53:38,944 - DEBUG - Row appended for chat file: WhatsApp Chat with Trynos Nemvura_EDOOFA(01_12)SM23.txt
# 2023-12-06 10:53:39,122 - DEBUG - Row appended for chat file: WhatsApp Chat with WINNIE MARUWA_EDOOFA(28_11)GS.txt
# 2023-12-06 10:53:39,250 - DEBUG - Row appended for chat file: WhatsApp Chat with Annatoria_EA(19_08)TR.txt
# ENTER THE LOOP:              datetime            sender  \
# 58 2023-12-05 06:32:00  +263 71 148 6114
#
#                                               message
# 58  Hie please l would like to resume with my appl...
