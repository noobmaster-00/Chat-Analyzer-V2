# %%
import os
import pandas as pd
import re
from datetime import datetime, timedelta
import logging
from datetime import timedelta

# Configure logging
logging.basicConfig(level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s')
# Set of processed chats to ensure each chat is analyzed only once
processed_chats = set()

# Function to process a single line of chat
def process_line(line):
    pattern = r'(\d{1,2}/\d{1,2}/\d{2}), (\d{1,2}:\d{2}\s?[AaPp][Mm]) - (.*?): (.*)'
    match = re.match(pattern, line)
    if match:
        logging.debug(f"match file")
        date_str, time_str, sender, message = match.groups()
        date = datetime.strptime(date_str, '%d/%m/%y')
        time = datetime.strptime(time_str, '%I:%M %p').strftime('%H:%M')
        return {'date': date, 'time': time, 'sender': sender, 'message': message}
    else:
        return None

def process_line_for_delay(line):
    pattern = r'(\d{1,2}/\d{1,2}/\d{2}), (\d{1,2}:\d{2}\s?[AaPp][Mm]) - (.*?): (.*)'
    match = re.match(pattern, line)
    if match:
        date_str, time_str, sender, message = match.groups()
        datetime_str = date_str + ' ' + time_str
        datetime_obj = datetime.strptime(datetime_str, '%d/%m/%y %I:%M %p')
        return {'datetime': datetime_obj, 'sender': sender, 'message': message}
    else:
        return None

# Function to read the chat file specifically for delay calculation
def read_chat_file_for_delay(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        lines = file.readlines()

    concatenated_lines = []
    current_message = ""
    date_pattern = re.compile(r'^\d{1,2}/\d{1,2}/\d{2}, \d{1,2}:\d{2}\s?[AaPp][Mm] - ')

    for line in lines:
        if date_pattern.match(line):
            if current_message:
                concatenated_lines.append(current_message)
            current_message = line.rstrip()
        else:
            # Append this line to the current message, if it's not empty
            if current_message:
                current_message += " " + line.strip()
    if current_message:
        concatenated_lines.append(current_message)

    return pd.DataFrame([process_line_for_delay(line) for line in concatenated_lines if process_line_for_delay(line) is not None])

# The process_line_for_delay function remains the same
       
    
def calculate_time_spent_student(chat_df, target_date, employee_name):
    student_messages = chat_df[(chat_df['date'].dt.date == target_date) & (chat_df['sender'] != employee_name)]
    total_chars = student_messages['message'].str.len().sum()
    time_spent_seconds = (total_chars / 10) * 5
    return strfdelta(timedelta(seconds=time_spent_seconds)) 

def format_delay_time(seconds):
    hours = seconds // 3600
    minutes = (seconds % 3600) // 60
    if hours > 0:
        return f"{hours} hr {minutes} mins"
    else:
        return f"{minutes} mins"

def calculate_employee_delay(chat_df, employee_name, target_date):
    delays = []
    delay_times = []
    messages_for_reference = []

    last_student_message_time = None
    employee_responded_after_student = False

    delay_counter = 1

    for index, row in chat_df.iterrows():
        # Ensure datetime is correctly formatted
        row_date = row['datetime'].date()

        if row_date != target_date:
            continue

        if row['sender'] != employee_name:
            last_student_message_time = row['datetime']
            employee_responded_after_student = False
        elif row['sender'] == employee_name and last_student_message_time is not None and not employee_responded_after_student:
            time_diff = row['datetime'] - last_student_message_time

            if time_diff > timedelta(minutes=15):
                formatted_time = row['datetime'].strftime('%d %b %Y %I:%M%p')
                delays.append(f"{delay_counter} - {formatted_time}")
                delay_counter += 1

                delay_times.append(format_delay_time(time_diff.seconds))

                start_index = max(0, index - 5)
                end_index = min(index + 5, len(chat_df))
                context_messages = chat_df.iloc[start_index:end_index]

                formatted_context_messages = [f"{idx+1} - {message_row['datetime'].strftime('%d %b %Y %I:%M%p')} - {message_row['sender']}: {message_row['message']}" for idx, message_row in context_messages.iterrows()]
                formatted_message = "\n".join(formatted_context_messages)
                messages_for_reference.append(formatted_message)

            employee_responded_after_student = True

    # Combine the lists into multiline strings
    delays_str = "\n".join(delays)
    delay_times_str = "\n".join(delay_times)
    messages_for_reference_str = "\n".join(messages_for_reference)

    return delays_str, delay_times_str, messages_for_reference_str

def is_broken_chat_student(chat_df, employee_name, target_date):
    # Adjust for the previous day
    previous_day = target_date - timedelta(days=1)

    # Filter messages for the previous day
    daily_messages = chat_df[chat_df['date'].dt.date == previous_day]

    # Check if both the employee and the student had at least one text on that day
    if daily_messages.empty:
        return 'No'  # No conversation happened on this day

    employee_messages = daily_messages[daily_messages['sender'] == employee_name]
    student_messages = daily_messages[daily_messages['sender'] != employee_name]

    # Check if both parties have sent at least one message
    if employee_messages.empty or student_messages.empty:
        return 'No'  # One of the parties did not send any message

    # Check the sender of the last message of the day
    last_message_sender = daily_messages.iloc[-1]['sender']

    # If the last message is from the employee, it's a broken chat by the student
    if last_message_sender == employee_name:
        return 'Yes'

    return 'No'
    
def count_missed_replies_student(chat_df, employee_name, report_date):
    count = 0
    for i in range(7):
        check_date = report_date - timedelta(days=i)
        messages_on_date = chat_df[chat_df['date'].dt.date == check_date]
        employee_messages = messages_on_date[messages_on_date['sender'] == employee_name]
        student_messages = messages_on_date[messages_on_date['sender'] != employee_name]
        if employee_messages.empty and not student_messages.empty:
            count += 1
    return count

def count_missed_replies_studentt(chat_df, employee_name, target_date):
    previous_day = target_date - timedelta(days=1)
    #print(f"Checking for missed replies on: {previous_day}")

    daily_messages = chat_df[chat_df['date'].dt.date == previous_day]
    
    employee_messages = daily_messages[daily_messages['sender'] == employee_name]
    student_messages = daily_messages[daily_messages['sender'] != employee_name]

    #print(f"Employee messages count: {len(employee_messages)}")
    #print(f"Student messages count: {len(student_messages)}")

    # Check if there are messages from the employee but none from the student
    if not employee_messages.empty and student_messages.empty:
        #print("Missed reply found.")
        return 'Yes'
    
    #print("No missed reply.")
    return 'No'

def count_missed_replies_last_7_days(chat_df, employee_name, start_date):
    missed_replies_count = 0

    # Iterate over the last 7 days
    for i in range(7):
        date_to_check = start_date - timedelta(days=i)
        messages_on_date = chat_df[chat_df['date'].dt.date == date_to_check]

        # Check if there are messages on this date
        if not messages_on_date.empty:
            # Check if there's any message from the employee on this day
            employee_messages = messages_on_date[messages_on_date['sender'] == employee_name]
            
            # Check if there's any message from others (leads) on this day
            lead_messages = messages_on_date[messages_on_date['sender'] != employee_name]

            # If there are messages from others but none from the employee, count as a missed reply
            if not lead_messages.empty and employee_messages.empty:
                missed_replies_count += 1

    return missed_replies_count

# Function to calculate the time spent in chat based on message lengths
def calculate_time_spent(chat_df, target_date, employee_name, team_folder):
    daily_messages = chat_df[(chat_df['date'].dt.date == target_date) & (chat_df['sender'] == employee_name)]

    if daily_messages.empty:
        return '00:00:00'

    total_time_spent_seconds = 0

    for index, row in daily_messages.iterrows():
        message = row['message']
        total_chars = len(message)

        if team_folder == "KAM" and total_chars > 700:
            time_spent_seconds = 5  # Cap at 5 seconds for long messages in KAM team folder
        else:
            time_spent_seconds = total_chars * 0.2  # Assuming 0.2 seconds per character

        total_time_spent_seconds += time_spent_seconds

        # Optional: Debug print
        #print(f"New Chat Found in {team_folder}")
        #print(f"Message Length: '{total_chars}'")
        #print(f"Message: '{message}' - Time Spent: {time_spent_seconds} seconds")

    time_spent_timedelta = timedelta(seconds=total_time_spent_seconds)
    formatted_time_spent = strfdelta(time_spent_timedelta)

    return formatted_time_spent

def strfdelta(tdelta):
    hours, remainder = divmod(tdelta.seconds, 3600)
    minutes, seconds = divmod(remainder, 60)
    return f"{hours:02}:{minutes:02}:{seconds:02}"   

def calculate_lead_response(chat_df, employee_name, target_date):
    """
    Calculates the lead response based on the number of texts exchanged between the employee and others (non-employee).
    - If only the employee sent messages, the response is 100%.
    - If only non-employees sent messages, the response is 0%.
    - Otherwise, it's the ratio of the employee's texts to the total texts, constrained between 1% and 99%.
    """
    # Filter messages for the target date
    daily_messages = chat_df[chat_df['date'].dt.date == target_date]
    
    # Check if there are any messages from the employee and others on the target date
    employee_messages = daily_messages[daily_messages['sender'] == employee_name]
    non_employee_messages = daily_messages[daily_messages['sender'] != employee_name]

    # If only the employee sent messages
    if not employee_messages.empty and non_employee_messages.empty:
        return 0

    # If only non-employees sent messages
    if employee_messages.empty and not non_employee_messages.empty:
        return 100

    # If both the employee and non-employees have sent messages
    if not employee_messages.empty and not non_employee_messages.empty:
        num_texts_employee = len(employee_messages)
        num_texts_non_employee = len(non_employee_messages)
        total_texts = num_texts_employee + num_texts_non_employee
        lead_response = (num_texts_employee / total_texts) * 100
        return max(min(lead_response, 99), 1)

    # If neither the employee nor non-employees sent messages
    return 0



def calculate_broken_chat_within_working_hrs(chat_df, employee_name, report_date, team_folder):
    # Adjust working hours based on team folder
    if team_folder == 'EWYL':
        # KAM Team working hours: 7:30 AM to 4:00 PM
        work_start_time = datetime(report_date.year, report_date.month, report_date.day, 7, 30, 0)
        work_end_time = datetime(report_date.year, report_date.month, report_date.day, 16, 30, 0)
    else:
        # Default working hours for other teams: 12:00 AM to 12:00 PM
        work_start_time = datetime(report_date.year, report_date.month, report_date.day, 0, 0, 0)
        work_end_time = datetime(report_date.year, report_date.month, report_date.day, 23, 59, 0)

    # Filter the messages for the given report date
    messages_on_date = chat_df[chat_df['datetime'].dt.date == report_date.date()]

    # Check if both employee and lead have messaged on the report date
    if not messages_on_date.empty:
        employee_messages = messages_on_date[messages_on_date['sender'] == employee_name]
        lead_messages = messages_on_date[messages_on_date['sender'] != employee_name]
        last_message_sender = messages_on_date.iloc[-1]['sender']
        # Ensure both the employee and lead have at least one message
        if not employee_messages.empty and not lead_messages.empty:
            # Get the time of the last message from the lead
            last_lead_message_time = lead_messages.iloc[-1]['datetime']

            # Check if the last message is from the lead and within working hours
            if last_message_sender != employee_name and (work_start_time <= last_lead_message_time <= work_end_time):
                return 'Yes'  # Broken chat if last message from the lead is within working hours
            else:
                return 'No'  # Not a broken chat if last message from the lead is outside working hours or from the employee

    # If no messages or only one party messaged, return 'No'
    return 'No'

def calculate_broken_chat(chat_df, employee_name, report_date):
    # Filter the messages for the given report date
    messages_on_date = chat_df[chat_df['date'].dt.date == report_date]
    
    # Check if both employee and lead have messaged on the report date
    if not messages_on_date.empty:
        employee_messages = messages_on_date[messages_on_date['sender'] == employee_name]
        lead_messages = messages_on_date[messages_on_date['sender'] != employee_name]
        
        # Ensure both the employee and lead have at least one message
        if not employee_messages.empty and not lead_messages.empty:
            # Check if the last message is from the lead
            last_message_sender = messages_on_date.iloc[-1]['sender']
            return last_message_sender != employee_name

    

def missed_replies_employee(chat_df, employee_name, target_date):
    # Filter messages for the target date
    daily_messages = chat_df[chat_df['date'].dt.date == target_date]
    
    # Check if there are any messages from the student
    student_messages = daily_messages[daily_messages['sender'] != employee_name]
    
    # Check if there are any messages from the employee
    employee_messages = daily_messages[daily_messages['sender'] == employee_name]
    
    # If there are student messages but no employee messages, consider it a missed reply
    if not student_messages.empty and employee_messages.empty:
        return 'Yes'
    
    return 'No'

def missed_replies_employee_after_working_hrs(chat_df, employee_name, target_date, team_folder):
    # Check if the team folder is 'KAM Team' to define different working hours
    if team_folder == 'EWYL':
        # EWYL Team working hours: 7:30 AM to 4:00 PM
        work_start_time = datetime(target_date.year, target_date.month, target_date.day, 7, 30, 0)
        work_end_time = datetime(target_date.year, target_date.month, target_date.day, 16, 30, 0)
    
    elif team_folder == 'KAM':
       # KAM Team working hours: 7:30 AM to 4:00 PM
        work_start_time = datetime(target_date.year, target_date.month, target_date.day, 11, 30, 0)
        work_end_time = datetime(target_date.year, target_date.month, target_date.day, 21, 30, 0)

    else:
        # Default working hours for other teams: 12:00 AM to 12:00 PM
        work_start_time = datetime(target_date.year, target_date.month, target_date.day, 0, 0, 0)
        work_end_time = datetime(target_date.year, target_date.month, target_date.day, 23, 59, 0)

    # Ensure target_date is a datetime object
    if not isinstance(target_date, datetime):
        raise ValueError("target_date must be a datetime object")

    # Filter messages for the target date using 'datetime' column
    daily_messages = chat_df[chat_df['datetime'].dt.date == target_date.date()]
    
    # Check if there are any messages from the student
    student_messages = daily_messages[daily_messages['sender'] != employee_name]
    
    # Check if there are any messages from the employee
    employee_messages = daily_messages[daily_messages['sender'] == employee_name]

    # If there are student messages but no employee messages
    if not student_messages.empty and employee_messages.empty:
        print(f"ENTER THE LOOP:{student_messages}")
        # Check if any student message is within working hours
        for _, row in student_messages.iterrows():
            message_time = row['datetime']
            if work_start_time <= message_time <= work_end_time:
                return 'Yes'  # Missed reply within working hours
        return 'No'  # All student messages are outside working hours

    return 'No'

# Function to read the chat file and return a dataframe
def read_chat_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        lines = file.readlines()

    concatenated_lines = []
    current_message = ""
    date_pattern = re.compile(r'^\d{1,2}/\d{1,2}/\d{2}, \d{1,2}:\d{2}\s?[AaPp][Mm] - ')

    for line in lines:
        if date_pattern.match(line):
            if current_message:
                concatenated_lines.append(current_message)
            current_message = line.rstrip()
        else:
            # Append this line to the current message, if it's not empty
            if current_message:
                current_message += " " + line.strip()
    if current_message:
        concatenated_lines.append(current_message)

    return pd.DataFrame([process_line(line) for line in concatenated_lines if process_line(line) is not None])

# process_line function remains the same


# Function to extract the chat file name based on a specific pattern
def extract_chat_name(chat_file_name):
    #logging.debug(f"Extracting name from chat file: {chat_file_name}")
    match = re.search(r'WhatsApp Chat with _?(.*?)(?:\(\d+\))?_?\.txt', chat_file_name)
    if match:
        extracted_name = re.sub(r'_*(?:\(\d+\))?$', '', match.group(1))
        #logging.debug(f"Extracted chat name: {extracted_name}")
        return extracted_name
    #logging.warning(f"No match found for chat file name: {chat_file_name}")
    return None

# Function to calculate the total count of missed replies by the student for the last N days
def calculate_total_count_missed_replies_student(chat_df, employee_name, num_days):
    total_count = 0

    # Iterate over the last N days
    for i in range(num_days):
        target_date = report_date - timedelta(days=i)
        count = count_missed_replies_student(chat_df, employee_name, target_date)
        total_count += count

    return total_count

# Function to extract the start date from a chat file
def get_chat_start_date(chat_df):
    if not chat_df.empty:
        #logging.debug(f"Extracted chat name: {chat_df['date'].min().date()}")
        return chat_df['date'].min().date()
    return None

# Function to process a single chat file
def process_chat_file(file_path, report_date, main_directory, team_folder, employee_folder):
    global processed_chats
    broken_chat_count = 0
    missed_reply_count = 0
    max_time_spent = ('', '00:00:00')  # (date, time)

    chat_file_name = os.path.basename(file_path)
    #logging.debug(f"Processing chat file: {chat_file_name}")

    chat_name = extract_chat_name(chat_file_name)
    #logging.debug(f"Chat name extracted: {chat_name}")



    

    if chat_name is None:
        #logging.warning(f"Chat name could not be extracted for file: {chat_file_name}")
        return None
    if chat_name in processed_chats:
        #logging.info(f"Chat file already processed: {chat_name}")
        return None

    processed_chats.add(chat_name)
    #logging.debug(f"Chat file added to processed list: {chat_name}")

    chat_df = read_chat_file(file_path)
    if chat_df.empty:
        #logging.warning(f"Chat DataFrame is empty for file: {chat_file_name}")
        return None
    chat_start_date = get_chat_start_date(chat_df)

    # Use read_chat_file_for_delay specifically for delay calculations
    chat_df_for_delay = read_chat_file_for_delay(file_path)
    if chat_df_for_delay.empty:
        return None

    
    target_date = report_date - timedelta(days=1)

    # Call the function with the target date
    delays, delay_times, messages_for_reference = calculate_employee_delay(chat_df_for_delay, employee_folder, target_date)
    



    # Calculate the time spent on Day 0 (report_date - 1 day)
    day_0_date = report_date - timedelta(days=1)
    day_0_time_spent = calculate_time_spent(chat_df, day_0_date, employee_folder,team_folder)
    #day_0_time_spent = timedelta(hours=int(day_0_time_spent.split(':')[0]), minutes=int(day_0_time_spent.split(':')[1]), seconds=int(day_0_time_spent.split(':')[2]))
    # Calculate the lead response based on text length difference for Day 0
    lead_response_day_0 = calculate_lead_response(chat_df, employee_folder, day_0_date)
     
    day_0_date = report_date - timedelta(days=1)  # Assuming report_date is a datetime object of the target date
    broken_chat = calculate_broken_chat(chat_df, employee_folder, day_0_date)
    missed_replies_day_0 = missed_replies_employee(chat_df, employee_folder, day_0_date)

    # Get the current datetime
    today_datetime = datetime.now()

    # Get today's date with time part (assuming start of the day as default)
    today_date_1 = today_datetime.replace(hour=0, minute=0, second=0, microsecond=0)

    # If today_date.weekday() logic remains the same
    # ...

    # Now, when you calculate target_date, it remains a datetime object
    target_date_1 = today_date_1 - timedelta(days=1)


    Actual_missed_Reply = missed_replies_employee_after_working_hrs(chat_df_for_delay, employee_folder, target_date_1,team_folder)
    Actual_broken_chat = calculate_broken_chat_within_working_hrs(chat_df_for_delay, employee_folder, target_date_1,team_folder)
    total_count_missed_reply_student = calculate_total_count_missed_replies_student(chat_df, employee_folder, 14)
    


    
    for i in range(7):  # Assuming you're checking the past 7 days
        check_date = report_date - timedelta(days=i)
        
        # Check for broken chats
        if calculate_broken_chat(chat_df, employee_folder, check_date):
            broken_chat_count += 1

        # Check for missed replies
        start_date_for_missed_replies = report_date - timedelta(days=7)
        
        missed_replies_count = count_missed_replies_last_7_days(chat_df, employee_folder, start_date_for_missed_replies)

        # Check for max time spent
        time_spent = calculate_time_spent(chat_df, check_date, employee_folder,team_folder)
        if time_spent > max_time_spent[1]:
            max_time_spent = (check_date.strftime('%m-%d-%Y'), time_spent)
    
    
    
    # Calculate the time spent by students
    time_spent_student = {
    'Day 0 (Student)': calculate_time_spent_student(chat_df, report_date - timedelta(days=1), employee_folder),
    'Day 1 (Student)': calculate_time_spent_student(chat_df, report_date - timedelta(days=2), employee_folder),
    'Day 2 (Student)': calculate_time_spent_student(chat_df, report_date - timedelta(days=3), employee_folder),
    }
    
    # Inside the process_chat_file function, after calculating day_0_time_spent:
    day_0_date = report_date - timedelta(days=1)
    day_1_date = report_date - timedelta(days=2)
    day_2_date = report_date - timedelta(days=3)

    # Calculate time spent by student for Day 0, Day 1, and Day 2
    time_spent_student_day_0 = calculate_time_spent_student(chat_df, day_0_date, employee_folder)
    time_spent_student_day_1 = calculate_time_spent_student(chat_df, day_1_date, employee_folder)
    time_spent_student_day_2 = calculate_time_spent_student(chat_df, day_2_date, employee_folder)



    total_time_spent_student = time_spent_student['Day 0 (Student)']

    broken_chat_student = is_broken_chat_student(chat_df, employee_folder, report_date)

    mmissed_reply_student = count_missed_replies_studentt(chat_df, employee_folder, report_date)

    # Calculate the time spent on each day relative to the report date
    time_spent = {}
    for i in range(1, 4):  # Start from 1 since we want Day 0 to be the day before the report date
        target_date = report_date - timedelta(days=i)
        time_spent[f'Day {i-1}'] = calculate_time_spent(chat_df, target_date, employee_folder,team_folder)
    
    target_date_for_chat_start_Date = report_date - timedelta(days=1)
    day_indicator_employee = (target_date_for_chat_start_Date - chat_start_date).days
    #logging.debug(f"day indicator employee: {day_indicator_employee}")
    # Determine Day Indicator based on chat start date
    if chat_start_date:
        if (target_date_for_chat_start_Date - chat_start_date).days == 0:
          
            day_indicator = 'Day 0'
        elif (target_date_for_chat_start_Date - chat_start_date).days == 1:
            
            day_indicator = 'Day 1'
        elif (target_date_for_chat_start_Date - chat_start_date).days == 2:
            
            day_indicator = 'Day 2'

        elif (target_date_for_chat_start_Date - chat_start_date).days == 3:
            
            day_indicator = 'OLD'

        else:
            day_indicator = 'OLD'  # For chats that don't fall into Day 0, Day 1, or Day 2

    

    main_directory_name = os.path.basename(main_directory)

    row = {
        'Date': main_directory_name,
        'Team Folder': team_folder,
        'Employee Folder': employee_folder,
        'Chat File Name': chat_name,        # Inserting the extracted chat name
        'Day Indicator': day_indicator,
        'Total_Time_Spent_Employee': day_0_time_spent,  # Use Day 0 time as the total time spent
        'LR': lead_response_day_0,  # Add the lead response here
        'Broken Chat(Employee)': 'Yes' if broken_chat else 'No',
        'Missed Replies (Employee)': missed_replies_day_0,
        'Count_Broken_Chat_Employee (Employee)': broken_chat_count,
        'Count_Missed_Replies_Missed_Replies (Employee)': missed_replies_count,
        'Date of Max time': max_time_spent[0],
        **time_spent,
        'Total Time Spent (Student)': total_time_spent_student,
        'Broken Chat (Student)': broken_chat_student,
        'Missed Replies (Student)': mmissed_reply_student,
        'Day_0_Time_Spent_Student': time_spent_student_day_0,  # Add time spent for Day 0
        'Day_1_Time_Spent_Student': time_spent_student_day_1,  # Add time spent for Day 1
        'Day_2_Time_Spent_Student': time_spent_student_day_2,
        'Total_Count_Missed_Reply_Chat_Student' : total_count_missed_reply_student,
        'Employee Delays': delays,
        'Delay Durations': delay_times,
        'Messages for Reference': messages_for_reference,
        'Actual Missed Reply from Employee': Actual_missed_Reply,
        'Actual Broken Chat from Employee' : Actual_broken_chat,
    }
    #logging.debug(f"Row created for chat: {row}")
    return row

# Main directory path construction and report date setting
# Main directory path construction and report date setting
local_date_format = '%Y-%m-%d'  # Adjust this to your local date format
main_directory = 'F:\\Github-mauriceyeng\\Chat-Analyzer-V2\\Chat Folder from Drive\\2024-01-06-20240106T044019Z-001'  # Replace with your base directory path

# Get today's date
today_date = datetime.now().date()

# Check the day of the week
if today_date.weekday() in range(1, 6):  # Tuesday to Saturday
    report_date = today_date
else:  # Monday
    # You can adjust the number of days to subtract based on your specific requirements
    report_date = today_date - timedelta(days=1)
    logging.debug(f"Report Date: {report_date}")
report_date_str_local = report_date.strftime(local_date_format)
main_directory_path = os.path.join(main_directory, report_date_str_local)

# Function to navigate through the directory structure and process all chat files
def process_team_folders(main_directory, report_date):
    all_data = []
    for team_folder in os.listdir(main_directory):
        team_path = os.path.join(main_directory, team_folder)
        if not os.path.isdir(team_path):
            continue
        for employee_folder in os.listdir(team_path):
            employee_path = os.path.join(team_path, employee_folder)
            if not os.path.isdir(employee_path):
                continue
            for chat_file in os.listdir(employee_path):
                chat_file_path = os.path.join(employee_path, chat_file)
                row = process_chat_file(chat_file_path, report_date, main_directory, team_folder, employee_folder)
                if row:
                    all_data.append(row)
                    logging.debug(f"Row appended for chat file: {chat_file}")
    df = pd.DataFrame(all_data)
    #logging.debug(f"DataFrame constructed with {len(df)} rows")
    return df

# Process all team folders and chats based on the report date
all_chats_df = process_team_folders(main_directory_path, report_date)


# Save to a CSV file
csv_file_path = 'F:\\Github-mauriceyeng\\Chat-Analyzer-V2\\Chat Folder from Drive\\2024-01-06-20240106T044019Z-001\\data.csv'  # Define your desired path and file name

all_chats_df.to_csv(csv_file_path, index=False)
#print(f"DataFrame saved as CSV at {csv_file_path}")
# Display the result
#print(all_chats_df)
# Out:
# 2024-01-06 10:35:44,270 - DEBUG - Row appended for chat file: WhatsApp Chat with Abraham EWYL22E0848.txt
# 2024-01-06 10:35:44,398 - DEBUG - Row appended for chat file: WhatsApp Chat with Allen EWYL22E0762.txt
# 2024-01-06 10:35:44,544 - DEBUG - Row appended for chat file: WhatsApp Chat with Alson EWYL22E0675.txt
# 2024-01-06 10:35:44,663 - DEBUG - Row appended for chat file: WhatsApp Chat with Andipa EWYL22E0389.txt
# 2024-01-06 10:35:44,794 - DEBUG - Row appended for chat file: WhatsApp Chat with Anesu EWYL22E0418.txt
# 2024-01-06 10:35:44,919 - DEBUG - Row appended for chat file: WhatsApp Chat with Anotidaishe EWYL23E0378.txt
# 2024-01-06 10:35:45,044 - DEBUG - Row appended for chat file: WhatsApp Chat with Ayanda EWYL23E0703.txt
# 2024-01-06 10:35:45,204 - DEBUG - Row appended for chat file: WhatsApp Chat with Benjamin EWYL23E1044.txt
# 2024-01-06 10:35:45,322 - DEBUG - Row appended for chat file: WhatsApp Chat with Bernadette EWYL22E0557.txt
# 2024-01-06 10:35:45,447 - DEBUG - Row appended for chat file: WhatsApp Chat with Beverly EWYL22E1177.txt
# 2024-01-06 10:35:45,593 - DEBUG - Row appended for chat file: WhatsApp Chat with Bhekinkosi EWYL22E0840.txt
# 2024-01-06 10:35:45,725 - DEBUG - Row appended for chat file: WhatsApp Chat with Blessed EWYL23E0278.txt
# 2024-01-06 10:35:45,843 - DEBUG - Row appended for chat file: WhatsApp Chat with Blessing EWYL22E1325.txt
# 2024-01-06 10:35:45,968 - DEBUG - Row appended for chat file: WhatsApp Chat with Blessing EWYL23E0133.txt
# 2024-01-06 10:35:46,079 - DEBUG - Row appended for chat file: WhatsApp Chat with Brenda EWYL22E1282.txt
# 2024-01-06 10:35:46,225 - DEBUG - Row appended for chat file: WhatsApp Chat with Chiedza EWYL23E0865.txt
# 2024-01-06 10:35:46,343 - DEBUG - Row appended for chat file: WhatsApp Chat with CHIKONDI EWYL23E0333.txt
# 2024-01-06 10:35:46,468 - DEBUG - Row appended for chat file: WhatsApp Chat with CHINAZVO EWYL22E0873.txt
# 2024-01-06 10:35:46,614 - DEBUG - Row appended for chat file: WhatsApp Chat with Cinderella EWYL23E0067.txt
# 2024-01-06 10:35:46,732 - DEBUG - Row appended for chat file: WhatsApp Chat with Cleopatra EWYL22E1239.txt
# 2024-01-06 10:35:46,857 - DEBUG - Row appended for chat file: WhatsApp Chat with Cloudious EWYL22E0796.txt
# 2024-01-06 10:35:46,982 - DEBUG - Row appended for chat file: WhatsApp Chat with Colleen EWYL22E0929.txt
# 2024-01-06 10:35:47,107 - DEBUG - Row appended for chat file: WhatsApp Chat with Davison EWYL22E0716.txt
# 2024-01-06 10:35:47,225 - DEBUG - Row appended for chat file: WhatsApp Chat with Ellary EWYL23E0906.txt
# 2024-01-06 10:35:47,350 - DEBUG - Row appended for chat file: WhatsApp Chat with Enock EWYL23E0363.txt
# 2024-01-06 10:35:47,475 - DEBUG - Row appended for chat file: WhatsApp Chat with Getrude EWYL23E1062.txt
# 2024-01-06 10:35:47,607 - DEBUG - Row appended for chat file: WhatsApp Chat with Hove EWYL23E0076.txt
# 2024-01-06 10:35:47,739 - DEBUG - Row appended for chat file: WhatsApp Chat with Jenipher EWYL22E0685.txt
# 2024-01-06 10:35:47,871 - DEBUG - Row appended for chat file: WhatsApp Chat with Jonathan EWYL23E0310.txt
# 2024-01-06 10:35:47,989 - DEBUG - Row appended for chat file: WhatsApp Chat with Kimberly EWYL23E0623.txt
# 2024-01-06 10:35:48,111 - DEBUG - Row appended for chat file: WhatsApp Chat with KUDAKWASHE EWYL22E1307.txt
# 2024-01-06 10:35:48,220 - DEBUG - Row appended for chat file: WhatsApp Chat with Kudziwaishe EWYL22E0865.txt
# 2024-01-06 10:35:48,350 - DEBUG - Row appended for chat file: WhatsApp Chat with Kupakwashe EWYL23E0939.txt
# 2024-01-06 10:35:48,503 - DEBUG - Row appended for chat file: WhatsApp Chat with Leonora EWYL23E0129.txt
# 2024-01-06 10:35:48,621 - DEBUG - Row appended for chat file: WhatsApp Chat with LILIAN EWYL22E0211.txt
# 2024-01-06 10:35:48,739 - DEBUG - Row appended for chat file: WhatsApp Chat with Linda EWYL22E1250.txt
# 2024-01-06 10:35:48,857 - DEBUG - Row appended for chat file: WhatsApp Chat with LISA EWYL22E0237.txt
# 2024-01-06 10:35:48,975 - DEBUG - Row appended for chat file: WhatsApp Chat with Loice EWYL22E1310.txt
# 2024-01-06 10:35:49,100 - DEBUG - Row appended for chat file: WhatsApp Chat with Lucia EWYL22E1322.txt
# 2024-01-06 10:35:49,218 - DEBUG - Row appended for chat file: WhatsApp Chat with Mbalenhle EWYL23E0069.txt
# 2024-01-06 10:35:49,343 - DEBUG - Row appended for chat file: WhatsApp Chat with Melisa EWYL23E0145.txt
# 2024-01-06 10:35:49,461 - DEBUG - Row appended for chat file: WhatsApp Chat with Memory EWYL22E0850.txt
# 2024-01-06 10:35:49,579 - DEBUG - Row appended for chat file: WhatsApp Chat with Mercynay EWYL23E0353.txt
# 2024-01-06 10:35:49,711 - DEBUG - Row appended for chat file: WhatsApp Chat with Michael EWYL23E0994.txt
# 2024-01-06 10:35:49,829 - DEBUG - Row appended for chat file: WhatsApp Chat with Mirandah EWYL23E0097.txt
# 2024-01-06 10:35:49,947 - DEBUG - Row appended for chat file: WhatsApp Chat with Miriam EWYL22E0363.txt
# 2024-01-06 10:35:50,064 - DEBUG - Row appended for chat file: WhatsApp Chat with Moreblessing EWYL22E0588.txt
# 2024-01-06 10:35:50,203 - DEBUG - Row appended for chat file: WhatsApp Chat with Munyaradzi EWYL23E0166.txt
# 2024-01-06 10:35:50,323 - DEBUG - Row appended for chat file: WhatsApp Chat with Nashville EWYL23E0589.txt
# 2024-01-06 10:35:50,441 - DEBUG - Row appended for chat file: WhatsApp Chat with Nathan EWYL23E0218.txt
# 2024-01-06 10:35:50,573 - DEBUG - Row appended for chat file: WhatsApp Chat with Nathanael EWYL22E1319.txt
# 2024-01-06 10:35:50,691 - DEBUG - Row appended for chat file: WhatsApp Chat with Nicole EWYL22E0025.txt
# 2024-01-06 10:35:50,823 - DEBUG - Row appended for chat file: WhatsApp Chat with Nicole EWYL23E0178.txt
# 2024-01-06 10:35:50,941 - DEBUG - Row appended for chat file: WhatsApp Chat with Nigel EWYL23E0738.txt
# 2024-01-06 10:35:51,059 - DEBUG - Row appended for chat file: WhatsApp Chat with Nqoba EWYL23E0066.txt
# 2024-01-06 10:35:51,177 - DEBUG - Row appended for chat file: WhatsApp Chat with Nyasha EWYL22E0634.txt
# 2024-01-06 10:35:51,295 - DEBUG - Row appended for chat file: WhatsApp Chat with Nyasha EWYL23E0540.txt
# 2024-01-06 10:35:51,420 - DEBUG - Row appended for chat file: WhatsApp Chat with Nyungu EWYL23E1084.txt
# 2024-01-06 10:35:51,552 - DEBUG - Row appended for chat file: WhatsApp Chat with Oliver EWYL23E1057.txt
# 2024-01-06 10:35:51,677 - DEBUG - Row appended for chat file: WhatsApp Chat with Pauline EWYL23E0047.txt
# 2024-01-06 10:35:51,795 - DEBUG - Row appended for chat file: WhatsApp Chat with Precious EWYL22E0613.txt
# 2024-01-06 10:35:51,913 - DEBUG - Row appended for chat file: WhatsApp Chat with Prince EWYL21E0930.txt
# 2024-01-06 10:35:52,017 - DEBUG - Row appended for chat file: WhatsApp Chat with Priscilla EWYL21E0818.txt
# 2024-01-06 10:35:52,161 - DEBUG - Row appended for chat file: WhatsApp Chat with Providence EWYL23E0993.txt
# 2024-01-06 10:35:52,269 - DEBUG - Row appended for chat file: WhatsApp Chat with Rebecca EWYL23E0290.txt
# 2024-01-06 10:35:52,413 - DEBUG - Row appended for chat file: WhatsApp Chat with Redeem EWYL22E0729.txt
# 2024-01-06 10:35:52,531 - DEBUG - Row appended for chat file: WhatsApp Chat with Reward EWYL22E0292.txt
# 2024-01-06 10:35:52,649 - DEBUG - Row appended for chat file: WhatsApp Chat with Richmore EWYL23E0931.txt
# 2024-01-06 10:35:52,767 - DEBUG - Row appended for chat file: WhatsApp Chat with Sandra EWYL21E0815.txt
# 2024-01-06 10:35:52,885 - DEBUG - Row appended for chat file: WhatsApp Chat with Sasha EWYL23E0235.txt
# 2024-01-06 10:35:53,003 - DEBUG - Row appended for chat file: WhatsApp Chat with Shalom EWYL23E0187.txt
# 2024-01-06 10:35:53,121 - DEBUG - Row appended for chat file: WhatsApp Chat with Shammah EWYL22E1246.txt
# 2024-01-06 10:35:53,267 - DEBUG - Row appended for chat file: WhatsApp Chat with Sharmaine EWYL23E1030.txt
# 2024-01-06 10:35:53,392 - DEBUG - Row appended for chat file: WhatsApp Chat with Sharon EWYL22E0561.txt
# 2024-01-06 10:35:53,510 - DEBUG - Row appended for chat file: WhatsApp Chat with Shelter EWYL23E0304.txt
# 2024-01-06 10:35:53,629 - DEBUG - Row appended for chat file: WhatsApp Chat with Shingirai EWYL23E0606.txt
# 2024-01-06 10:35:53,740 - DEBUG - Row appended for chat file: WhatsApp Chat with Shyne EWYL21E0758.txt
# 2024-01-06 10:35:53,865 - DEBUG - Row appended for chat file: WhatsApp Chat with Sibongile EWYL23E0041.txt
# 2024-01-06 10:35:54,033 - DEBUG - Row appended for chat file: WhatsApp Chat with Sijamali EWYL23E1017.txt
# 2024-01-06 10:35:54,144 - DEBUG - Row appended for chat file: WhatsApp Chat with Sikhululekile EWYL23E0108.txt
# 2024-01-06 10:35:54,271 - DEBUG - Row appended for chat file: WhatsApp Chat with Sithabisiwe EWYL22E1220.txt
# 2024-01-06 10:35:54,399 - DEBUG - Row appended for chat file: WhatsApp Chat with Tadiwa EWYL23E1065.txt
# 2024-01-06 10:35:54,531 - DEBUG - Row appended for chat file: WhatsApp Chat with Tadiwanashe EWYL22E0420.txt
# 2024-01-06 10:35:54,656 - DEBUG - Row appended for chat file: WhatsApp Chat with Tadiwanashe EWYL23E0879.txt
# 2024-01-06 10:35:54,774 - DEBUG - Row appended for chat file: WhatsApp Chat with Tafadzwa EWYL22E0128.txt
# 2024-01-06 10:35:54,906 - DEBUG - Row appended for chat file: WhatsApp Chat with Tafadzwa EWYL22E1230.txt
# 2024-01-06 10:35:55,031 - DEBUG - Row appended for chat file: WhatsApp Chat with Taisha EWYL23E0131.txt
# 2024-01-06 10:35:55,150 - DEBUG - Row appended for chat file: WhatsApp Chat with Takudzwa EWYL22E0792.txt
# 2024-01-06 10:35:55,268 - DEBUG - Row appended for chat file: WhatsApp Chat with Takudzwa EWYL22E1184.txt
# 2024-01-06 10:35:55,393 - DEBUG - Row appended for chat file: WhatsApp Chat with Takudzwa EWYL23E0688.txt
# 2024-01-06 10:35:55,525 - DEBUG - Row appended for chat file: WhatsApp Chat with Takudzwa EWYL23E1059.txt
# 2024-01-06 10:35:55,643 - DEBUG - Row appended for chat file: WhatsApp Chat with Talent EWYL22E0263.txt
# 2024-01-06 10:35:55,775 - DEBUG - Row appended for chat file: WhatsApp Chat with Tanyaradzwa EWYL23E0301.txt
# 2024-01-06 10:35:55,907 - DEBUG - Row appended for chat file: WhatsApp Chat with Tatenda EWYL23E0034.txt
# 2024-01-06 10:35:56,017 - DEBUG - Row appended for chat file: WhatsApp Chat with Theodore EWYL22E1181.txt
# 2024-01-06 10:35:56,146 - DEBUG - Row appended for chat file: WhatsApp Chat with Thomas EWYL23E1007.txt
# 2024-01-06 10:35:56,262 - DEBUG - Row appended for chat file: WhatsApp Chat with Thubelihle EWYL22E1326.txt
# 2024-01-06 10:35:56,386 - DEBUG - Row appended for chat file: WhatsApp Chat with Tinashe EWYL22E0704.txt
# 2024-01-06 10:35:56,504 - DEBUG - Row appended for chat file: WhatsApp Chat with TINASHE EWYL22E1238.txt
# 2024-01-06 10:35:56,629 - DEBUG - Row appended for chat file: WhatsApp Chat with Tinashe EWYL23E1080.txt
# 2024-01-06 10:35:56,761 - DEBUG - Row appended for chat file: WhatsApp Chat with Tino EWYL22E0829.txt
# 2024-01-06 10:35:56,872 - DEBUG - Row appended for chat file: WhatsApp Chat with Tinotendaishe EWYL22E0678.txt
# 2024-01-06 10:35:56,990 - DEBUG - Row appended for chat file: WhatsApp Chat with Tracy EWYL22E0131.txt
# 2024-01-06 10:35:57,150 - DEBUG - Row appended for chat file: WhatsApp Chat with Trish EWYL23E1035.txt
# 2024-01-06 10:35:57,268 - DEBUG - Row appended for chat file: WhatsApp Chat with Twanani EWYL23E0599.txt
# 2024-01-06 10:35:57,386 - DEBUG - Row appended for chat file: WhatsApp Chat with Vincient EWYL22E1247.txt
# 2024-01-06 10:35:57,525 - DEBUG - Row appended for chat file: WhatsApp Chat with Adrian EWYL23E0744.txt
# 2024-01-06 10:35:57,643 - DEBUG - Row appended for chat file: WhatsApp Chat with Allan EWYL23E0455.txt
# 2024-01-06 10:35:57,754 - DEBUG - Row appended for chat file: WhatsApp Chat with Amani EWYL23E0532.txt
# 2024-01-06 10:35:57,893 - DEBUG - Row appended for chat file: WhatsApp Chat with Anopa EWYL23E0772.txt
# 2024-01-06 10:35:58,007 - DEBUG - Row appended for chat file: WhatsApp Chat with Antony EWYL21E0880.txt
# 2024-01-06 10:35:58,125 - DEBUG - Row appended for chat file: WhatsApp Chat with Arthur EWYL22E0218.txt
# 2024-01-06 10:35:58,235 - DEBUG - Row appended for chat file: WhatsApp Chat with Asher EWYL23E0188.txt
# 2024-01-06 10:35:58,351 - DEBUG - Row appended for chat file: WhatsApp Chat with Audrey EWYL22E0063.txt
# 2024-01-06 10:35:58,497 - DEBUG - Row appended for chat file: WhatsApp Chat with BekithembaJNR EWYL23E1012.txt
# 2024-01-06 10:35:58,622 - DEBUG - Row appended for chat file: WhatsApp Chat with Betty EWYL23E1054.txt
# 2024-01-06 10:35:58,740 - DEBUG - Row appended for chat file: WhatsApp Chat with Blessing EWYL23E0682.txt
# 2024-01-06 10:35:58,879 - DEBUG - Row appended for chat file: WhatsApp Chat with Bongani EWYL23E1021.txt
# 2024-01-06 10:35:59,004 - DEBUG - Row appended for chat file: WhatsApp Chat with Bright EWYL22E0899.txt
# 2024-01-06 10:35:59,122 - DEBUG - Row appended for chat file: WhatsApp Chat with Bupe EWYL23E0573.txt
# 2024-01-06 10:35:59,247 - DEBUG - Row appended for chat file: WhatsApp Chat with Cleave EWYL23E1069.txt
# 2024-01-06 10:35:59,393 - DEBUG - Row appended for chat file: WhatsApp Chat with Covenant EWYL23E0238.txt
# 2024-01-06 10:35:59,511 - DEBUG - Row appended for chat file: WhatsApp Chat with Danzel EWYL22E1099.txt
# 2024-01-06 10:35:59,650 - DEBUG - Row appended for chat file: WhatsApp Chat with Delight EWYL23E0697.txt
# 2024-01-06 10:35:59,768 - DEBUG - Row appended for chat file: WhatsApp Chat with Devine EWYL23E0146.txt
# 2024-01-06 10:35:59,900 - DEBUG - Row appended for chat file: WhatsApp Chat with Diana EWYL23E0210.txt
# 2024-01-06 10:36:00,025 - DEBUG - Row appended for chat file: WhatsApp Chat with Elina EWYL22E1197.txt
# 2024-01-06 10:36:00,160 - DEBUG - Row appended for chat file: WhatsApp Chat with Elshaddai EWYL23E0204.txt
# 2024-01-06 10:36:00,286 - DEBUG - Row appended for chat file: WhatsApp Chat with Emelia EWYL22E1237.txt
# 2024-01-06 10:36:00,407 - DEBUG - Row appended for chat file: WhatsApp Chat with Fadzai EWYL22E1105.txt
# 2024-01-06 10:36:00,518 - DEBUG - Row appended for chat file: WhatsApp Chat with Francesca EWYL23E0581.txt
# 2024-01-06 10:36:00,657 - DEBUG - Row appended for chat file: WhatsApp Chat with Geilen EWYL23E0509.txt
# 2024-01-06 10:36:00,817 - DEBUG - Row appended for chat file: WhatsApp Chat with George EWYL23E1028.txt
# 2024-01-06 10:36:00,970 - DEBUG - Row appended for chat file: WhatsApp Chat with Grace EWYL23E1014.txt
# 2024-01-06 10:36:01,088 - DEBUG - Row appended for chat file: WhatsApp Chat with Gugulethu EWYL23E0605.txt
# 2024-01-06 10:36:01,199 - DEBUG - Row appended for chat file: WhatsApp Chat with Humphrey EWYL21E0656.txt
# 2024-01-06 10:36:01,331 - DEBUG - Row appended for chat file: WhatsApp Chat with Isheanesu EWYL23E0237.txt
# 2024-01-06 10:36:01,442 - DEBUG - Row appended for chat file: WhatsApp Chat with Joe EWYL22E1196.txt
# 2024-01-06 10:36:01,553 - DEBUG - Row appended for chat file: WhatsApp Chat with Joseph EWYL22E1200.txt
# 2024-01-06 10:36:01,671 - DEBUG - Row appended for chat file: WhatsApp Chat with Kabongwe EWYL23E0954.txt
# 2024-01-06 10:36:01,789 - DEBUG - Row appended for chat file: WhatsApp Chat with Kelly EWYL22E0137.txt
# 2024-01-06 10:36:01,907 - DEBUG - Row appended for chat file: WhatsApp Chat with Kelvin EWYL22E0590.txt
# 2024-01-06 10:36:02,034 - DEBUG - Row appended for chat file: WhatsApp Chat with Kimberly EWYL23E0828.txt
# 2024-01-06 10:36:02,145 - DEBUG - Row appended for chat file: WhatsApp Chat with Kudakwashe EWYL23E0289.txt
# 2024-01-06 10:36:02,287 - DEBUG - Row appended for chat file: WhatsApp Chat with Kudzai EWYL23E1041.txt
# 2024-01-06 10:36:02,428 - DEBUG - Row appended for chat file: WhatsApp Chat with Kudzaiishe EWYL22E1214.txt
# 2024-01-06 10:36:02,557 - DEBUG - Row appended for chat file: WhatsApp Chat with Kunashe EWYL23E0883.txt
# 2024-01-06 10:36:02,671 - DEBUG - Row appended for chat file: WhatsApp Chat with Kuzivakwashe EWYL22E1331.txt
# 2024-01-06 10:36:02,782 - DEBUG - Row appended for chat file: WhatsApp Chat with Lorraine EWYL22E1130.txt
# 2024-01-06 10:36:02,893 - DEBUG - Row appended for chat file: WhatsApp Chat with Luyanda EWYL21E0764.txt
# 2024-01-06 10:36:03,025 - DEBUG - Row appended for chat file: WhatsApp Chat with Luyanda EWYL22E1313.txt
# 2024-01-06 10:36:03,143 - DEBUG - Row appended for chat file: WhatsApp Chat with Lynnte EWYL22E0400.txt
# 2024-01-06 10:36:03,268 - DEBUG - Row appended for chat file: WhatsApp Chat with Makanaka EWYL23E0221.txt
# 2024-01-06 10:36:03,407 - DEBUG - Row appended for chat file: WhatsApp Chat with Marc EWYL23E0115.txt
# 2024-01-06 10:36:03,532 - DEBUG - Row appended for chat file: WhatsApp Chat with Margreth EWYL22E1157.txt
# 2024-01-06 10:36:03,664 - DEBUG - Row appended for chat file: WhatsApp Chat with Memory EWYL23E0756.txt
# 2024-01-06 10:36:03,775 - DEBUG - Row appended for chat file: WhatsApp Chat with Michael EWYL22E0173.txt
# 2024-01-06 10:36:03,922 - DEBUG - Row appended for chat file: WhatsApp Chat with Milan EWYL23E0847.txt
# 2024-01-06 10:36:04,050 - DEBUG - Row appended for chat file: WhatsApp Chat with Mishael EWYL23E0479.txt
# 2024-01-06 10:36:04,184 - DEBUG - Row appended for chat file: WhatsApp Chat with Mthuli EWYL23E0227.txt
# 2024-01-06 10:36:04,291 - DEBUG - Row appended for chat file: WhatsApp Chat with Munyaradzi EWYL21E0861.txt
# 2024-01-06 10:36:04,421 - DEBUG - Row appended for chat file: WhatsApp Chat with Munyaradzi EWYL23E1052.txt
# 2024-01-06 10:36:04,560 - DEBUG - Row appended for chat file: WhatsApp Chat with Natasha EWYL22E1100.txt
# 2024-01-06 10:36:04,692 - DEBUG - Row appended for chat file: WhatsApp Chat with Neo EWYL23E0196.txt
# 2024-01-06 10:36:04,831 - DEBUG - Row appended for chat file: WhatsApp Chat with Nicole EWYL23E1068.txt
# 2024-01-06 10:36:04,963 - DEBUG - Row appended for chat file: WhatsApp Chat with Nicole EWYL23E1081.txt
# 2024-01-06 10:36:05,088 - DEBUG - Row appended for chat file: WhatsApp Chat with Nyasha EWYL22E0653.txt
# 2024-01-06 10:36:05,234 - DEBUG - Row appended for chat file: WhatsApp Chat with Nyasha EWYL23E0655.txt
# 2024-01-06 10:36:05,352 - DEBUG - Row appended for chat file: WhatsApp Chat with Panashe EWYL22E0216.txt
# 2024-01-06 10:36:05,477 - DEBUG - Row appended for chat file: WhatsApp Chat with Panashe EWYL23E0291.txt
# 2024-01-06 10:36:05,602 - DEBUG - Row appended for chat file: WhatsApp Chat with Patience EWYL22E0053.txt
# 2024-01-06 10:36:05,729 - DEBUG - Row appended for chat file: WhatsApp Chat with Patience EWYL23E0870.txt
# 2024-01-06 10:36:05,866 - DEBUG - Row appended for chat file: WhatsApp Chat with Phelistas EWYL23E0829.txt
# 2024-01-06 10:36:05,992 - DEBUG - Row appended for chat file: WhatsApp Chat with Precious EWYL23E0624.txt
# 2024-01-06 10:36:06,102 - DEBUG - Row appended for chat file: WhatsApp Chat with Rachael EWYL21E0557.txt
# 2024-01-06 10:36:06,234 - DEBUG - Row appended for chat file: WhatsApp Chat with Ropafadzo EWYL23E0230.txt
# 2024-01-06 10:36:06,353 - DEBUG - Row appended for chat file: WhatsApp Chat with Rutendo EWYL23E1051.txt
# 2024-01-06 10:36:06,477 - DEBUG - Row appended for chat file: WhatsApp Chat with Sandra EWYL22E0637.txt
# 2024-01-06 10:36:06,604 - DEBUG - Row appended for chat file: WhatsApp Chat with Scott EWYL22E0507.txt
# 2024-01-06 10:36:06,714 - DEBUG - Row appended for chat file: WhatsApp Chat with SHANTEL EWYL22E0543.txt
# 2024-01-06 10:36:06,840 - DEBUG - Row appended for chat file: WhatsApp Chat with Sharmaine EWYL23E0816.txt
# 2024-01-06 10:36:07,000 - DEBUG - Row appended for chat file: WhatsApp Chat with Stanley EWYL23E1036.txt
# 2024-01-06 10:36:07,116 - DEBUG - Row appended for chat file: WhatsApp Chat with Takudzwa EWYL23E0675.txt
# 2024-01-06 10:36:07,227 - DEBUG - Row appended for chat file: WhatsApp Chat with Tanatswa EWYL22E0419.txt
# 2024-01-06 10:36:07,352 - DEBUG - Row appended for chat file: WhatsApp Chat with Tanatswa EWYL23E0560.txt
# 2024-01-06 10:36:07,498 - DEBUG - Row appended for chat file: WhatsApp Chat with Tanyaradzwa EWYL23E0202.txt
# 2024-01-06 10:36:07,623 - DEBUG - Row appended for chat file: WhatsApp Chat with Tapiwanashe EWYL23E0031.txt
# 2024-01-06 10:36:07,741 - DEBUG - Row appended for chat file: WhatsApp Chat with Tatenda EWYL22E0834.txt
# 2024-01-06 10:36:07,853 - DEBUG - Row appended for chat file: WhatsApp Chat with Tavanashe EWYL23E0293.txt
# 2024-01-06 10:36:07,978 - DEBUG - Row appended for chat file: WhatsApp Chat with THANDIWE EWYL22E1229.txt
# 2024-01-06 10:36:08,099 - DEBUG - Row appended for chat file: WhatsApp Chat with Thandoluhle EWYL23E0942.txt
# 2024-01-06 10:36:08,241 - DEBUG - Row appended for chat file: WhatsApp Chat with Thubalami EWYL22E1030.txt
# 2024-01-06 10:36:08,360 - DEBUG - Row appended for chat file: WhatsApp Chat with Tinashe EWYL22E0943.txt
# 2024-01-06 10:36:08,485 - DEBUG - Row appended for chat file: WhatsApp Chat with Tinotenda EWYL23E1095.txt
# 2024-01-06 10:36:08,610 - DEBUG - Row appended for chat file: WhatsApp Chat with Tiriwashe EWYL23E0461.txt
# 2024-01-06 10:36:08,755 - DEBUG - Row appended for chat file: WhatsApp Chat with Trish EWYL23E0632.txt
# 2024-01-06 10:36:08,866 - DEBUG - Row appended for chat file: WhatsApp Chat with Utloile EWYL22E1168.txt
# 2024-01-06 10:36:08,991 - DEBUG - Row appended for chat file: WhatsApp Chat with Valentine EWYL23E0872.txt
# 2024-01-06 10:36:09,111 - DEBUG - Row appended for chat file: WhatsApp Chat with Valerie EWYL22E1161.txt
# 2024-01-06 10:36:09,227 - DEBUG - Row appended for chat file: WhatsApp Chat with Vanessa EWYL22E0589.txt
# 2024-01-06 10:36:09,345 - DEBUG - Row appended for chat file: WhatsApp Chat with Victor EWYL23E0822.txt
# 2024-01-06 10:36:09,464 - DEBUG - Row appended for chat file: WhatsApp Chat with Wellington EWYL22E1109.txt
# 2024-01-06 10:36:09,609 - DEBUG - Row appended for chat file: WhatsApp Chat with Abigail EWYL22E1215.txt
# 2024-01-06 10:36:09,727 - DEBUG - Row appended for chat file: WhatsApp Chat with Abigail EWYL23E0568.txt
# 2024-01-06 10:36:09,846 - DEBUG - Row appended for chat file: WhatsApp Chat with Adella EWYL22E0158.txt
# 2024-01-06 10:36:09,985 - DEBUG - Row appended for chat file: WhatsApp Chat with Albert EWYL23E0769.txt
# 2024-01-06 10:36:10,110 - DEBUG - Row appended for chat file: WhatsApp Chat with ANESU EWYL23E0361.txt
# 2024-01-06 10:36:10,270 - DEBUG - Row appended for chat file: WhatsApp Chat with Anesu EWYL23E0721.txt
# 2024-01-06 10:36:10,387 - DEBUG - Row appended for chat file: WhatsApp Chat with Anesuishe EWYL22E1135.txt
# 2024-01-06 10:36:10,519 - DEBUG - Row appended for chat file: WhatsApp Chat with Anna EWYL21E0882.txt
# 2024-01-06 10:36:10,637 - DEBUG - Row appended for chat file: WhatsApp Chat with Anna EWYL22E0289.txt
# 2024-01-06 10:36:10,769 - DEBUG - Row appended for chat file: WhatsApp Chat with Ariel EWYL23E0815.txt
# 2024-01-06 10:36:10,887 - DEBUG - Row appended for chat file: WhatsApp Chat with Ashley EWYL22E1236.txt
# 2024-01-06 10:36:11,012 - DEBUG - Row appended for chat file: WhatsApp Chat with Audrey EWYL23E0790.txt
# 2024-01-06 10:36:11,130 - DEBUG - Row appended for chat file: WhatsApp Chat with Austin EWYL22E1248.txt
# 2024-01-06 10:36:11,262 - DEBUG - Row appended for chat file: WhatsApp Chat with Bethel EWYL23E0313.txt
# 2024-01-06 10:36:11,394 - DEBUG - Row appended for chat file: WhatsApp Chat with Blessing EWYL22E0849.txt
# 2024-01-06 10:36:11,547 - DEBUG - Row appended for chat file: WhatsApp Chat with Bradley EWYL23E1046.txt
# 2024-01-06 10:36:11,700 - DEBUG - Row appended for chat file: WhatsApp Chat with Bridget EWYL23E0746.txt
# 2024-01-06 10:36:11,825 - DEBUG - Row appended for chat file: WhatsApp Chat with Brita EWYL22E0591.txt
# 2024-01-06 10:36:11,951 - DEBUG - Row appended for chat file: WhatsApp Chat with Catherine EWYL23E0300.txt
# 2024-01-06 10:36:12,058 - DEBUG - Row appended for chat file: WhatsApp Chat with Charleen EWYL22E1137.txt
# 2024-01-06 10:36:12,186 - DEBUG - Row appended for chat file: WhatsApp Chat with Charles EWYL23E0091.txt
# 2024-01-06 10:36:12,297 - DEBUG - Row appended for chat file: WhatsApp Chat with Chiedza EWYL22E0119.txt
# 2024-01-06 10:36:12,429 - DEBUG - Row appended for chat file: WhatsApp Chat with Courage EWYL22E0496.txt
# 2024-01-06 10:36:12,547 - DEBUG - Row appended for chat file: WhatsApp Chat with Courage EWYL23E0215.txt
# 2024-01-06 10:36:12,665 - DEBUG - Row appended for chat file: WhatsApp Chat with Courtney EWYL23E0079.txt
# 2024-01-06 10:36:12,783 - DEBUG - Row appended for chat file: WhatsApp Chat with Creed EWYL22E0973.txt
# 2024-01-06 10:36:12,936 - DEBUG - Row appended for chat file: WhatsApp Chat with CRYSTAL EWYL22E0541.txt
# 2024-01-06 10:36:13,061 - DEBUG - Row appended for chat file: WhatsApp Chat with Cuthbert EWYL22E0531.txt
# 2024-01-06 10:36:13,186 - DEBUG - Row appended for chat file: WhatsApp Chat with Delight EWYL22E0571.txt
# 2024-01-06 10:36:13,318 - DEBUG - Row appended for chat file: WhatsApp Chat with Denise EWYL22E0987.txt
# 2024-01-06 10:36:13,429 - DEBUG - Row appended for chat file: WhatsApp Chat with Denzel EWYL23E0490.txt
# 2024-01-06 10:36:13,568 - DEBUG - Row appended for chat file: WhatsApp Chat with Dephine EWYL22E0579.txt
# 2024-01-06 10:36:13,700 - DEBUG - Row appended for chat file: WhatsApp Chat with Derylin EWYL23E0863.txt
# 2024-01-06 10:36:13,818 - DEBUG - Row appended for chat file: WhatsApp Chat with Desire EWYL22E0689.txt
# 2024-01-06 10:36:13,950 - DEBUG - Row appended for chat file: WhatsApp Chat with Edwin EWYL22E0823.txt
# 2024-01-06 10:36:14,066 - DEBUG - Row appended for chat file: WhatsApp Chat with Ephinas EWYL23E0036.txt
# 2024-01-06 10:36:14,186 - DEBUG - Row appended for chat file: WhatsApp Chat with Evans EWYL22E1255.txt
# 2024-01-06 10:36:14,299 - DEBUG - Row appended for chat file: WhatsApp Chat with Francine EWYL22E1258.txt
# 2024-01-06 10:36:14,436 - DEBUG - Row appended for chat file: WhatsApp Chat with Fungai EWYL22E0706.txt
# 2024-01-06 10:36:14,557 - DEBUG - Row appended for chat file: WhatsApp Chat with Gerald EWYL22E1202.txt
# 2024-01-06 10:36:14,680 - DEBUG - Row appended for chat file: WhatsApp Chat with Glory EWYL23E0796.txt
# 2024-01-06 10:36:14,818 - DEBUG - Row appended for chat file: WhatsApp Chat with Gugulethu EWYL23E0566.txt
# 2024-01-06 10:36:14,929 - DEBUG - Row appended for chat file: WhatsApp Chat with Irene EWYL23E0254.txt
# 2024-01-06 10:36:15,054 - DEBUG - Row appended for chat file: WhatsApp Chat with James EWYL22E1124.txt
# 2024-01-06 10:36:15,179 - DEBUG - Row appended for chat file: WhatsApp Chat with Jeston EWYL22E0671.txt
# 2024-01-06 10:36:15,305 - DEBUG - Row appended for chat file: WhatsApp Chat with John EWYL22E0542.txt
# 2024-01-06 10:36:15,416 - DEBUG - Row appended for chat file: WhatsApp Chat with Juliet EWYL22E0663.txt
# 2024-01-06 10:36:15,534 - DEBUG - Row appended for chat file: WhatsApp Chat with Katelyn EWYL22E0584.txt
# 2024-01-06 10:36:15,659 - DEBUG - Row appended for chat file: WhatsApp Chat with Katendi EWYL22E1283.txt
# 2024-01-06 10:36:15,777 - DEBUG - Row appended for chat file: WhatsApp Chat with Keith EWYL23E0120.txt
# 2024-01-06 10:36:15,909 - DEBUG - Row appended for chat file: WhatsApp Chat with Kelly EWYL23E0151.txt
# 2024-01-06 10:36:16,035 - DEBUG - Row appended for chat file: WhatsApp Chat with Kester EWYL22E0495.txt
# 2024-01-06 10:36:16,159 - DEBUG - Row appended for chat file: WhatsApp Chat with Lenny EWYL23E0895.txt
# 2024-01-06 10:36:16,266 - DEBUG - Row appended for chat file: WhatsApp Chat with Leona EWYL23E0105.txt
# 2024-01-06 10:36:16,409 - DEBUG - Row appended for chat file: WhatsApp Chat with Lorent EWYL22E0724.txt
# 2024-01-06 10:36:16,527 - DEBUG - Row appended for chat file: WhatsApp Chat with Lorraine EWYL21E0796.txt
# 2024-01-06 10:36:16,645 - DEBUG - Row appended for chat file: WhatsApp Chat with Lorraine EWYL22E0393.txt
# 2024-01-06 10:36:16,765 - DEBUG - Row appended for chat file: WhatsApp Chat with Lorraine EWYL23E0192.txt
# 2024-01-06 10:36:16,895 - DEBUG - Row appended for chat file: WhatsApp Chat with Lyvinia EWYL22E0981.txt
# 2024-01-06 10:36:17,027 - DEBUG - Row appended for chat file: WhatsApp Chat with Master EWYL23E0576.txt
# 2024-01-06 10:36:17,145 - DEBUG - Row appended for chat file: WhatsApp Chat with Mazvita EWYL22E0659.txt
# 2024-01-06 10:36:17,277 - DEBUG - Row appended for chat file: WhatsApp Chat with Mbuso EWYL23E0768.txt
# 2024-01-06 10:36:17,395 - DEBUG - Row appended for chat file: WhatsApp Chat with McKrion EWYL23E0515.txt
# 2024-01-06 10:36:17,521 - DEBUG - Row appended for chat file: WhatsApp Chat with Melanie EWYL22E1265.txt
# 2024-01-06 10:36:17,766 - DEBUG - Row appended for chat file: WhatsApp Chat with Melody EWYL23E1038.txt
# 2024-01-06 10:36:17,889 - DEBUG - Row appended for chat file: WhatsApp Chat with Mercy EWYL23E0136.txt
# 2024-01-06 10:36:18,007 - DEBUG - Row appended for chat file: WhatsApp Chat with Michael EWYL22E1280.txt
# 2024-01-06 10:36:18,138 - DEBUG - Row appended for chat file: WhatsApp Chat with Mitchelle EWYL22E0945.txt
# 2024-01-06 10:36:18,250 - DEBUG - Row appended for chat file: WhatsApp Chat with Moreblessing EWYL22E0948.txt
# 2024-01-06 10:36:18,402 - DEBUG - Row appended for chat file: WhatsApp Chat with Munyaradzi EWYL23E0386.txt
# 2024-01-06 10:36:18,541 - DEBUG - Row appended for chat file: WhatsApp Chat with Mwenya EWYL23E0902.txt
# 2024-01-06 10:36:18,701 - DEBUG - Row appended for chat file: WhatsApp Chat with Namwaka EWYL23E1050.txt
# 2024-01-06 10:36:18,888 - DEBUG - Row appended for chat file: WhatsApp Chat with Natalie EWYL22E0759.txt
# 2024-01-06 10:36:19,028 - DEBUG - Row appended for chat file: WhatsApp Chat with Nathaniel EWYL23E0065.txt
# 2024-01-06 10:36:19,160 - DEBUG - Row appended for chat file: WhatsApp Chat with Nicassio EWYL22E0536.txt
# 2024-01-06 10:36:19,298 - DEBUG - Row appended for chat file: WhatsApp Chat with Nicole EWYL23E0098.txt
# 2024-01-06 10:36:19,416 - DEBUG - Row appended for chat file: WhatsApp Chat with Nigel EWYL23E0051.txt
# 2024-01-06 10:36:19,535 - DEBUG - Row appended for chat file: WhatsApp Chat with Nigel EWYL23E0125.txt
# 2024-01-06 10:36:19,653 - DEBUG - Row appended for chat file: WhatsApp Chat with Nkosilomusa EWYL22E0132.txt
# 2024-01-06 10:36:19,785 - DEBUG - Row appended for chat file: WhatsApp Chat with Nokutenda EWYL23E0186.txt
# 2024-01-06 10:36:19,923 - DEBUG - Row appended for chat file: WhatsApp Chat with Nokutenda EWYL23E0824.txt
# 2024-01-06 10:36:20,043 - DEBUG - Row appended for chat file: WhatsApp Chat with Nokuthaba EWYL22E0645.txt
# 2024-01-06 10:36:20,171 - DEBUG - Row appended for chat file: WhatsApp Chat with Nozizwe EWYL23E0006.txt
# 2024-01-06 10:36:20,294 - DEBUG - Row appended for chat file: WhatsApp Chat with Nyasha EWYL23E0116.txt
# 2024-01-06 10:36:20,423 - DEBUG - Row appended for chat file: WhatsApp Chat with Nyashadzashe EWYL23E0028.txt
# 2024-01-06 10:36:20,590 - DEBUG - Row appended for chat file: WhatsApp Chat with Olivia EWYL22E1244.txt
# 2024-01-06 10:36:20,708 - DEBUG - Row appended for chat file: WhatsApp Chat with Pamella EWYL22E0986.txt
# 2024-01-06 10:36:20,840 - DEBUG - Row appended for chat file: WhatsApp Chat with Panashe EWYL22E0468.txt
# 2024-01-06 10:36:20,958 - DEBUG - Row appended for chat file: WhatsApp Chat with PATIENCE EWYL22E0439.txt
# 2024-01-06 10:36:21,097 - DEBUG - Row appended for chat file: WhatsApp Chat with Patience EWYL22E0730.txt
# 2024-01-06 10:36:21,222 - DEBUG - Row appended for chat file: WhatsApp Chat with Patience EWYL23E0394.txt
# 2024-01-06 10:36:21,361 - DEBUG - Row appended for chat file: WhatsApp Chat with Patrick EWYL22E0592.txt
# 2024-01-06 10:36:21,514 - DEBUG - Row appended for chat file: WhatsApp Chat with Plaxedes EWYL22E0919.txt
# 2024-01-06 10:36:21,645 - DEBUG - Row appended for chat file: WhatsApp Chat with Praise EWYL23E0804.txt
# 2024-01-06 10:36:21,792 - DEBUG - Row appended for chat file: WhatsApp Chat with Precious EWYL23E0757.txt
# 2024-01-06 10:36:21,977 - DEBUG - Row appended for chat file: WhatsApp Chat with Priscillar EWYL22E0798.txt
# 2024-01-06 10:36:22,099 - DEBUG - Row appended for chat file: WhatsApp Chat with Progress EWYL22E0894.txt
# 2024-01-06 10:36:22,232 - DEBUG - Row appended for chat file: WhatsApp Chat with Promise EWYL22E1029.txt
# 2024-01-06 10:36:22,382 - DEBUG - Row appended for chat file: WhatsApp Chat with Promise EWYL23E0200.txt
# 2024-01-06 10:36:22,507 - DEBUG - Row appended for chat file: WhatsApp Chat with Rudorwashe EWYL23E0128.txt
# 2024-01-06 10:36:22,632 - DEBUG - Row appended for chat file: WhatsApp Chat with Rufaro EWYL23E0287.txt
# 2024-01-06 10:36:22,761 - DEBUG - Row appended for chat file: WhatsApp Chat with Rumbidzai EWYL22E0628.txt
# 2024-01-06 10:36:22,896 - DEBUG - Row appended for chat file: WhatsApp Chat with Rutendo EWYL23E0845.txt
# 2024-01-06 10:36:23,123 - DEBUG - Row appended for chat file: WhatsApp Chat with RUTH EWYL23E0072.txt
# 2024-01-06 10:36:23,344 - DEBUG - Row appended for chat file: WhatsApp Chat with Ruvimbo EWYL23E1016.txt
# 2024-01-06 10:36:23,500 - DEBUG - Row appended for chat file: WhatsApp Chat with Ryan EWYL22E1190.txt
# 2024-01-06 10:36:23,665 - DEBUG - Row appended for chat file: WhatsApp Chat with Salma EWYL23E0208.txt
# 2024-01-06 10:36:23,828 - DEBUG - Row appended for chat file: WhatsApp Chat with Senelisiwe EWYL22E0239.txt
# 2024-01-06 10:36:23,995 - DEBUG - Row appended for chat file: WhatsApp Chat with Shalom EWYL23E0026.txt
# 2024-01-06 10:36:24,163 - DEBUG - Row appended for chat file: WhatsApp Chat with Shalom EWYL23E1018.txt
# 2024-01-06 10:36:24,283 - DEBUG - Row appended for chat file: WhatsApp Chat with Shantel EWYL22E1156.txt
# 2024-01-06 10:36:24,407 - DEBUG - Row appended for chat file: WhatsApp Chat with Sharon EWYL23E0497.txt
# 2024-01-06 10:36:24,525 - DEBUG - Row appended for chat file: WhatsApp Chat with Shawn EWYL22E0868.txt
# 2024-01-06 10:36:24,653 - DEBUG - Row appended for chat file: WhatsApp Chat with Shekinah EWYL22E0169.txt
# 2024-01-06 10:36:24,785 - DEBUG - Row appended for chat file: WhatsApp Chat with Sibongile EWYL22E0635.txt
# 2024-01-06 10:36:24,917 - DEBUG - Row appended for chat file: WhatsApp Chat with Sibonginkosi EWYL23E0528.txt
# 2024-01-06 10:36:25,046 - DEBUG - Row appended for chat file: WhatsApp Chat with Silence EWYL22E1150.txt
# 2024-01-06 10:36:25,173 - DEBUG - Row appended for chat file: WhatsApp Chat with Simphiwe EWYL22E0976.txt
# 2024-01-06 10:36:25,290 - DEBUG - Row appended for chat file: WhatsApp Chat with Stina EWYL23E0256.txt
# 2024-01-06 10:36:25,414 - DEBUG - Row appended for chat file: WhatsApp Chat with Tadiwa EWYL22E0603.txt
# 2024-01-06 10:36:25,534 - DEBUG - Row appended for chat file: WhatsApp Chat with Tadiwanashe EWYL22E1023.txt
# 2024-01-06 10:36:25,658 - DEBUG - Row appended for chat file: WhatsApp Chat with Tadiwanashe EWYL22E1034.txt
# 2024-01-06 10:36:25,783 - DEBUG - Row appended for chat file: WhatsApp Chat with Tadiwanashe EWYL23E0095.txt
# 2024-01-06 10:36:25,900 - DEBUG - Row appended for chat file: WhatsApp Chat with Tafadzwa EWYL22E0469.txt
# 2024-01-06 10:36:26,019 - DEBUG - Row appended for chat file: WhatsApp Chat with Takudzwa EWYL22E0793.txt
# 2024-01-06 10:36:26,139 - DEBUG - Row appended for chat file: WhatsApp Chat with Takudzwa EWYL23E0197.txt
# 2024-01-06 10:36:26,263 - DEBUG - Row appended for chat file: WhatsApp Chat with Talent EWYL23E0649.txt
# 2024-01-06 10:36:26,388 - DEBUG - Row appended for chat file: WhatsApp Chat with TANAKA EWYL22E1052.txt
# 2024-01-06 10:36:26,513 - DEBUG - Row appended for chat file: WhatsApp Chat with Tanaka EWYL23E0370.txt
# 2024-01-06 10:36:26,654 - DEBUG - Row appended for chat file: WhatsApp Chat with Tanatswa EWYL23E0462.txt
# 2024-01-06 10:36:26,774 - DEBUG - Row appended for chat file: WhatsApp Chat with Tanyaradzwa EWYL22E0528.txt
# 2024-01-06 10:36:26,926 - DEBUG - Row appended for chat file: WhatsApp Chat with Tanyaradzwa EWYL22E0700.txt
# 2024-01-06 10:36:27,033 - DEBUG - Row appended for chat file: WhatsApp Chat with Tanyaradzwa EWYL22E0963.txt
# 2024-01-06 10:36:27,173 - DEBUG - Row appended for chat file: WhatsApp Chat with Taonga EWYL22E1068.txt
# 2024-01-06 10:36:27,296 - DEBUG - Row appended for chat file: WhatsApp Chat with TARIRO EWYL22E0205.txt
# 2024-01-06 10:36:27,424 - DEBUG - Row appended for chat file: WhatsApp Chat with Tariro EWYL22E1110.txt
# 2024-01-06 10:36:27,549 - DEBUG - Row appended for chat file: WhatsApp Chat with Tatenda EWYL22E0429.txt
# 2024-01-06 10:36:27,711 - DEBUG - Row appended for chat file: WhatsApp Chat with Tatenda EWYL22E0845.txt
# 2024-01-06 10:36:27,860 - DEBUG - Row appended for chat file: WhatsApp Chat with Tatire EWYL21E0942.txt
# 2024-01-06 10:36:28,010 - DEBUG - Row appended for chat file: WhatsApp Chat with Tecla EWYL22E0095.txt
# 2024-01-06 10:36:28,142 - DEBUG - Row appended for chat file: WhatsApp Chat with Tendai EWYL23E0335.txt
# 2024-01-06 10:36:28,266 - DEBUG - Row appended for chat file: WhatsApp Chat with Thelma EWYL23E0463.txt
# 2024-01-06 10:36:28,397 - DEBUG - Row appended for chat file: WhatsApp Chat with Thomas EWYL22E0431.txt
# 2024-01-06 10:36:28,521 - DEBUG - Row appended for chat file: WhatsApp Chat with Tiara EWYL23E0282.txt
# 2024-01-06 10:36:28,660 - DEBUG - Row appended for chat file: WhatsApp Chat with Tinashe EWYL22E0903.txt
# 2024-01-06 10:36:28,778 - DEBUG - Row appended for chat file: WhatsApp Chat with Tinevimbo EWYL22E0458.txt
# 2024-01-06 10:36:28,910 - DEBUG - Row appended for chat file: WhatsApp Chat with Tinotenda EWYL22E0333.txt
# 2024-01-06 10:36:29,032 - DEBUG - Row appended for chat file: WhatsApp Chat with Trinity EWYL23E0100.txt
# 2024-01-06 10:36:29,141 - DEBUG - Row appended for chat file: WhatsApp Chat with Vinah EWYL22E0844.txt
# 2024-01-06 10:36:29,282 - DEBUG - Row appended for chat file: WhatsApp Chat with Vincent EWYL22E1141.txt
# 2024-01-06 10:36:29,407 - DEBUG - Row appended for chat file: WhatsApp Chat with Walusungu EWYL22E0600.txt
# 2024-01-06 10:36:29,547 - DEBUG - Row appended for chat file: WhatsApp Chat with Whitney EWYL23E0836.txt
# 2024-01-06 10:36:29,684 - DEBUG - Row appended for chat file: WhatsApp Chat with Yankho EWYL22E0488.txt
# 2024-01-06 10:36:29,794 - DEBUG - Row appended for chat file: WhatsApp Chat with Yolanda EWYL22E0296.txt
# 2024-01-06 10:36:29,923 - DEBUG - Row appended for chat file: WhatsApp Chat with Yvonne EWYL23E0022.txt
# 2024-01-06 10:36:30,033 - DEBUG - Row appended for chat file: WhatsApp Chat with Zolani EWYL22E1263.txt
# 2024-01-06 10:36:30,166 - DEBUG - Row appended for chat file: WhatsApp Chat with Aaliyah EWYL22E0311.txt
# 2024-01-06 10:36:30,300 - DEBUG - Row appended for chat file: WhatsApp Chat with Agutha EWYL22E1314.txt
# 2024-01-06 10:36:30,438 - DEBUG - Row appended for chat file: WhatsApp Chat with Ammy EWYL22E1242.txt
# 2024-01-06 10:36:30,563 - DEBUG - Row appended for chat file: WhatsApp Chat with Anesu EWYL22E1129.txt
# 2024-01-06 10:36:30,681 - DEBUG - Row appended for chat file: WhatsApp Chat with Angeline EWYL23E0018.txt
# 2024-01-06 10:36:30,827 - DEBUG - Row appended for chat file: WhatsApp Chat with Audrey EWYL22E0890.txt
# 2024-01-06 10:36:30,945 - DEBUG - Row appended for chat file: WhatsApp Chat with Barnabas EWYL22E0666.txt
# 2024-01-06 10:36:31,091 - DEBUG - Row appended for chat file: WhatsApp Chat with Beauty EWYL23E0009.txt
# 2024-01-06 10:36:31,214 - DEBUG - Row appended for chat file: WhatsApp Chat with Benedict EWYL23E0035.txt
# 2024-01-06 10:36:31,361 - DEBUG - Row appended for chat file: WhatsApp Chat with Blessed EWYL22E0909.txt
# 2024-01-06 10:36:31,503 - DEBUG - Row appended for chat file: WhatsApp Chat with Blessing EWYL22E0533.txt
# 2024-01-06 10:36:31,674 - DEBUG - Row appended for chat file: WhatsApp Chat with Blessing EWYL22E1300.txt
# 2024-01-06 10:36:31,809 - DEBUG - Row appended for chat file: WhatsApp Chat with Blessing EWYL23E0156.txt
# 2024-01-06 10:36:31,924 - DEBUG - Row appended for chat file: WhatsApp Chat with Blessing EWYL23E0831.txt
# 2024-01-06 10:36:32,042 - DEBUG - Row appended for chat file: WhatsApp Chat with Brian EWYL22E0387.txt
# 2024-01-06 10:36:32,161 - DEBUG - Row appended for chat file: WhatsApp Chat with Brian EWYL22E0749.txt
# 2024-01-06 10:36:32,286 - DEBUG - Row appended for chat file: WhatsApp Chat with Bridget EWYL23E0216.txt
# 2024-01-06 10:36:32,432 - DEBUG - Row appended for chat file: WhatsApp Chat with Brooke EWYL23E0198.txt
# 2024-01-06 10:36:32,553 - DEBUG - Row appended for chat file: WhatsApp Chat with Canfred EWYL21E0801.txt
# 2024-01-06 10:36:32,692 - DEBUG - Row appended for chat file: WhatsApp Chat with Caroline EWYL22E0709.txt
# 2024-01-06 10:36:32,821 - DEBUG - Row appended for chat file: WhatsApp Chat with Chantelle EWYL22E0741.txt
# 2024-01-06 10:36:32,959 - DEBUG - Row appended for chat file: WhatsApp Chat with Charity EWYL22E1095.txt
# 2024-01-06 10:36:33,077 - DEBUG - Row appended for chat file: WhatsApp Chat with Chinyama EWYL23E0279.txt
# 2024-01-06 10:36:33,229 - DEBUG - Row appended for chat file: WhatsApp Chat with Clayton EWYL22E0436.txt
# 2024-01-06 10:36:33,350 - DEBUG - Row appended for chat file: WhatsApp Chat with Cloudious EWYL23E0015.txt
# 2024-01-06 10:36:33,494 - DEBUG - Row appended for chat file: WhatsApp Chat with Danai EWYL23E0751.txt
# 2024-01-06 10:36:33,618 - DEBUG - Row appended for chat file: WhatsApp Chat with DENZEL EWYL22E1253.txt
# 2024-01-06 10:36:33,764 - DEBUG - Row appended for chat file: WhatsApp Chat with Deon EWYL22E0478.txt
# 2024-01-06 10:36:33,902 - DEBUG - Row appended for chat file: WhatsApp Chat with Dezyline EWYL22E0752.txt
# 2024-01-06 10:36:34,041 - DEBUG - Row appended for chat file: WhatsApp Chat with Edgar EWYL23E0044.txt
# 2024-01-06 10:36:34,177 - DEBUG - Row appended for chat file: WhatsApp Chat with Elton EWYL22E1178.txt
# 2024-01-06 10:36:34,332 - DEBUG - Row appended for chat file: WhatsApp Chat with Ethan EWYL22E0530.txt
# 2024-01-06 10:36:34,453 - DEBUG - Row appended for chat file: WhatsApp Chat with Evidence EWYL22E0440.txt
# 2024-01-06 10:36:34,585 - DEBUG - Row appended for chat file: WhatsApp Chat with Faith EWYL23E0159.txt
# 2024-01-06 10:36:34,710 - DEBUG - Row appended for chat file: WhatsApp Chat with Fanuel EWYL22E0893.txt
# 2024-01-06 10:36:34,874 - DEBUG - Row appended for chat file: WhatsApp Chat with Freda EWYL23E0996.txt
# 2024-01-06 10:36:34,999 - DEBUG - Row appended for chat file: WhatsApp Chat with Gervais EWYL22E1186.txt
# 2024-01-06 10:36:35,109 - DEBUG - Row appended for chat file: WhatsApp Chat with Grace EWYL23E0201.txt
# 2024-01-06 10:36:35,234 - DEBUG - Row appended for chat file: WhatsApp Chat with Gracious EWYL22E0492.txt
# 2024-01-06 10:36:35,372 - DEBUG - Row appended for chat file: WhatsApp Chat with Hazel EWYL22E1166.txt
# 2024-01-06 10:36:35,480 - DEBUG - Row appended for chat file: WhatsApp Chat with Heggah EWYL22E1270.txt
# 2024-01-06 10:36:35,661 - DEBUG - Row appended for chat file: WhatsApp Chat with Henriata EWYL22E1139.txt
# 2024-01-06 10:36:35,812 - DEBUG - Row appended for chat file: WhatsApp Chat with Hester EWYL22E1303.txt
# 2024-01-06 10:36:35,959 - DEBUG - Row appended for chat file: WhatsApp Chat with Hilario EWYL22E1267.txt
# 2024-01-06 10:36:36,106 - DEBUG - Row appended for chat file: WhatsApp Chat with Hilton EWYL22E1040.txt
# 2024-01-06 10:36:36,233 - DEBUG - Row appended for chat file: WhatsApp Chat with Ivy EWYL22E1298.txt
# 2024-01-06 10:36:36,355 - DEBUG - Row appended for chat file: WhatsApp Chat with Jenipher EWYL22E0036.txt
# 2024-01-06 10:36:36,496 - DEBUG - Row appended for chat file: WhatsApp Chat with Jeremiah EWYL23E0017.txt
# 2024-01-06 10:36:36,621 - DEBUG - Row appended for chat file: WhatsApp Chat with Joyce EWYL22E0785.txt
# 2024-01-06 10:36:36,742 - DEBUG - Row appended for chat file: WhatsApp Chat with Juliet EWYL22E1125.txt
# 2024-01-06 10:36:36,884 - DEBUG - Row appended for chat file: WhatsApp Chat with Justine EWYL21E0737.txt
# 2024-01-06 10:36:37,025 - DEBUG - Row appended for chat file: WhatsApp Chat with Karen EWYL22E0647.txt
# 2024-01-06 10:36:37,148 - DEBUG - Row appended for chat file: WhatsApp Chat with Kelvin EWYL23E0911.txt
# 2024-01-06 10:36:37,287 - DEBUG - Row appended for chat file: WhatsApp Chat with Kimberly EWYL23E0247.txt
# 2024-01-06 10:36:37,432 - DEBUG - Row appended for chat file: WhatsApp Chat with Kudakwashe EWYL22E0465.txt
# 2024-01-06 10:36:37,553 - DEBUG - Row appended for chat file: WhatsApp Chat with Kudzanai EWYL22E0790.txt
# 2024-01-06 10:36:37,711 - DEBUG - Row appended for chat file: WhatsApp Chat with Leiann EWYL23E0191.txt
# 2024-01-06 10:36:37,848 - DEBUG - Row appended for chat file: WhatsApp Chat with Loice EWYL22E0782.txt
# 2024-01-06 10:36:37,996 - DEBUG - Row appended for chat file: WhatsApp Chat with Lordwell EWYL23E0760.txt
# 2024-01-06 10:36:38,150 - DEBUG - Row appended for chat file: WhatsApp Chat with Lushomo EWYL23E0598.txt
# 2024-01-06 10:36:38,275 - DEBUG - Row appended for chat file: WhatsApp Chat with Lydia EWYL23E0158.txt
# 2024-01-06 10:36:38,395 - DEBUG - Row appended for chat file: WhatsApp Chat with Lydia EWYL23E0234.txt
# 2024-01-06 10:36:38,530 - DEBUG - Row appended for chat file: WhatsApp Chat with Lyona EWYL22E0030.txt
# 2024-01-06 10:36:38,662 - DEBUG - Row appended for chat file: WhatsApp Chat with Makaita EWYL23E0969.txt
# 2024-01-06 10:36:38,807 - DEBUG - Row appended for chat file: WhatsApp Chat with Makanaka EWYL22E0814.txt
# 2024-01-06 10:36:38,940 - DEBUG - Row appended for chat file: WhatsApp Chat with Malvern EWYL23E1066.txt
# 2024-01-06 10:36:39,065 - DEBUG - Row appended for chat file: WhatsApp Chat with Manwere EWYL21E0852.txt
# 2024-01-06 10:36:39,215 - DEBUG - Row appended for chat file: WhatsApp Chat with Mark EWYL23E0409.txt
# 2024-01-06 10:36:39,343 - DEBUG - Row appended for chat file: WhatsApp Chat with Marlon EWYL22E1317.txt
# 2024-01-06 10:36:39,477 - DEBUG - Row appended for chat file: WhatsApp Chat with Marvellous EWYL22E0556.txt
# 2024-01-06 10:36:39,638 - DEBUG - Row appended for chat file: WhatsApp Chat with Mascelyn EWYL22E0755.txt
# 2024-01-06 10:36:39,758 - DEBUG - Row appended for chat file: WhatsApp Chat with Mayibingwe EWYL21E0760.txt
# 2024-01-06 10:36:39,926 - DEBUG - Row appended for chat file: WhatsApp Chat with Memory EWYL23E0596.txt
# 2024-01-06 10:36:40,099 - DEBUG - Row appended for chat file: WhatsApp Chat with Mitchell EWYL22E0620.txt
# 2024-01-06 10:36:40,250 - DEBUG - Row appended for chat file: WhatsApp Chat with Munashe EWYL23E0226.txt
# 2024-01-06 10:36:40,411 - DEBUG - Row appended for chat file: WhatsApp Chat with Munashe EWYL23E1034.txt
# 2024-01-06 10:36:40,560 - DEBUG - Row appended for chat file: WhatsApp Chat with Munyaradzi EWYL22E0836.txt
# 2024-01-06 10:36:40,696 - DEBUG - Row appended for chat file: WhatsApp Chat with Natalie EWYL23E0556.txt
# 2024-01-06 10:36:40,830 - DEBUG - Row appended for chat file: WhatsApp Chat with Neville EWYL22E0911.txt
# 2024-01-06 10:36:40,957 - DEBUG - Row appended for chat file: WhatsApp Chat with Ngonidzashe EWYL23E0004.txt
# 2024-01-06 10:36:41,104 - DEBUG - Row appended for chat file: WhatsApp Chat with Nkazimulo EWYL23E0803.txt
# 2024-01-06 10:36:41,240 - DEBUG - Row appended for chat file: WhatsApp Chat with Nontokozo EWYL22E0324.txt
# 2024-01-06 10:36:41,374 - DEBUG - Row appended for chat file: WhatsApp Chat with Nyasha EWYL22E1290.txt
# 2024-01-06 10:36:41,489 - DEBUG - Row appended for chat file: WhatsApp Chat with Nyasha EWYL23E1063.txt
# 2024-01-06 10:36:41,610 - DEBUG - Row appended for chat file: WhatsApp Chat with Panashe EWYL22E1111.txt
# 2024-01-06 10:36:41,721 - DEBUG - Row appended for chat file: WhatsApp Chat with Patience EWYL21E0379.txt
# 2024-01-06 10:36:41,846 - DEBUG - Row appended for chat file: WhatsApp Chat with Persistance EWYL21E0574.txt
# 2024-01-06 10:36:41,974 - DEBUG - Row appended for chat file: WhatsApp Chat with Prayer EWYL22E1143.txt
# 2024-01-06 10:36:42,092 - DEBUG - Row appended for chat file: WhatsApp Chat with Precious EWYL22E0313.txt
# 2024-01-06 10:36:42,233 - DEBUG - Row appended for chat file: WhatsApp Chat with Pride EWYL23E0010.txt
# 2024-01-06 10:36:42,373 - DEBUG - Row appended for chat file: WhatsApp Chat with Prince EWYL22E0896.txt
# 2024-01-06 10:36:42,498 - DEBUG - Row appended for chat file: WhatsApp Chat with Princess EWYL22E0553.txt
# 2024-01-06 10:36:42,621 - DEBUG - Row appended for chat file: WhatsApp Chat with QUINTON EWYL23E0233.txt
# 2024-01-06 10:36:42,776 - DEBUG - Row appended for chat file: WhatsApp Chat with Rachael EWYL23E0232.txt
# 2024-01-06 10:36:42,899 - DEBUG - Row appended for chat file: WhatsApp Chat with Rejoice EWYL22E1133.txt
# 2024-01-06 10:36:43,033 - DEBUG - Row appended for chat file: WhatsApp Chat with Resistance EWYL23E0195.txt
# 2024-01-06 10:36:43,155 - DEBUG - Row appended for chat file: WhatsApp Chat with Revelation EWYL23E0533.txt
# 2024-01-06 10:36:43,294 - DEBUG - Row appended for chat file: WhatsApp Chat with Ropafadzo EWYL23E0011.txt
# ...
# 2024-01-06 10:38:06,355 - DEBUG - Row appended for chat file: WhatsApp Chat with Ashley Kasaira  Edoofa(IE28_12)SR(1).txt
# 2024-01-06 10:38:06,596 - DEBUG - Row appended for chat file: WhatsApp Chat with Ashley_DM02(21_11)HP(1).txt
# 2024-01-06 10:38:06,857 - DEBUG - Row appended for chat file: WhatsApp Chat with Ashley_Edoofa(15_11)HP(1).txt
# 2024-01-06 10:38:07,073 - DEBUG - Row appended for chat file: WhatsApp Chat with Audrey Patience_EDOOFA(20_12)GJ 2025(1).txt
# 2024-01-06 10:38:07,302 - DEBUG - Row appended for chat file: WhatsApp Chat with Babongile Phiri Edoofa (19_12) SZ(1).txt
# 2024-01-06 10:38:07,566 - DEBUG - Row appended for chat file: WhatsApp Chat with Blessed Nqobani Mupondo Edoofa (08_12) SZ(1).txt
# 2024-01-06 10:38:07,820 - DEBUG - Row appended for chat file: WhatsApp Chat with Brighton Mudzukwa Edoofa (21_11) SZ 2025(1).txt
# 2024-01-06 10:38:08,079 - DEBUG - Row appended for chat file: WhatsApp Chat with Casper Taruvinga Edoofa (16_11) SZ 2025(1).txt
# 2024-01-06 10:38:08,223 - DEBUG - Row appended for chat file: WhatsApp Chat with Catherine Ng’ombe  (DC03_01)SR(1).txt
# 2024-01-06 10:38:08,354 - DEBUG - Row appended for chat file: WhatsApp Chat with Chibesa chibesakunda (DC03_01)SR(1).txt
# 2024-01-06 10:38:08,613 - DEBUG - Row appended for chat file: WhatsApp Chat with Christabel_Edoofa(05_12)HP 2025(1).txt
# 2024-01-06 10:38:08,736 - DEBUG - Row appended for chat file: WhatsApp Chat with Christine Musonda (DC03_01)SR(1).txt
# 2024-01-06 10:38:08,948 - DEBUG - Row appended for chat file: WhatsApp Chat with Debora Chunda Edoofa (20_12) SZ(1).txt
# 2024-01-06 10:38:09,140 - DEBUG - Row appended for chat file: WhatsApp Chat with Eleina Mapengo Edoofa (28_12) SZ 2025(1).txt
# 2024-01-06 10:38:09,372 - DEBUG - Row appended for chat file: WhatsApp Chat with Great_Edoofa(23_11)HP(1).txt
# 2024-01-06 10:38:09,494 - DEBUG - Row appended for chat file: WhatsApp Chat with IVY MWILA (DC03_01)SR(1).txt
# 2024-01-06 10:38:09,754 - DEBUG - Row appended for chat file: WhatsApp Chat with Kayembe Israel Edoofa(30_10)SR300(1).txt
# 2024-01-06 10:38:09,964 - DEBUG - Row appended for chat file: WhatsApp Chat with Kunashe Joel Munyoro Edoofa (30_11) SZ 2025(1).txt
# 2024-01-06 10:38:10,197 - DEBUG - Row appended for chat file: WhatsApp Chat with Luzia_Edoofa(22_11)HP(1).txt
# 2024-01-06 10:38:10,446 - DEBUG - Row appended for chat file: WhatsApp Chat with Makomborero Tsoka Edoofa (11_12) SZ(1).txt
# 2024-01-06 10:38:10,715 - DEBUG - Row appended for chat file: WhatsApp Chat with Manyonganise Komborero Edoofa (19_12) SZ(1).txt
# 2024-01-06 10:38:10,985 - DEBUG - Row appended for chat file: WhatsApp Chat with Masvikeni Ange_lique C V Edoofa (21_11) SZ 2025(1).txt
# 2024-01-06 10:38:11,242 - DEBUG - Row appended for chat file: WhatsApp Chat with Mengezi Mkwananzi Edoofa (18_12) SZ(1).txt
# 2024-01-06 10:38:11,373 - DEBUG - Row appended for chat file: WhatsApp Chat with Njinga Margaret. C Edoofa(IE28_12)SR(1).txt
# 2024-01-06 10:38:11,658 - DEBUG - Row appended for chat file: WhatsApp Chat with Nkala Sharon Edoofa (19_12) SZ(1).txt
# 2024-01-06 10:38:12,025 - DEBUG - Row appended for chat file: WhatsApp Chat with Nokutenda_Edoofa(15_12)HP 2025(1).txt
# 2024-01-06 10:38:12,360 - DEBUG - Row appended for chat file: WhatsApp Chat with Peter_DM02(21_11)HP(1).txt
# 2024-01-06 10:38:12,592 - DEBUG - Row appended for chat file: WhatsApp Chat with Praise_Edoofa(02_11)HP(1).txt
# 2024-01-06 10:38:12,852 - DEBUG - Row appended for chat file: WhatsApp Chat with Serena Edoofa (20_12) SZ(1).txt
# 2024-01-06 10:38:13,127 - DEBUG - Row appended for chat file: WhatsApp Chat with Sharmaine Victoria Tore Edoofa (06_12) SZ 2025(1).txt
# 2024-01-06 10:38:13,386 - DEBUG - Row appended for chat file: WhatsApp Chat with Tadiwanashe Moyo Edoofa (05_12) SZ 2025(1).txt
# 2024-01-06 10:38:13,679 - DEBUG - Row appended for chat file: WhatsApp Chat with Takudzwa Chinyama Edoofa (22_11) SZ 2025(1).txt
# 2024-01-06 10:38:13,940 - DEBUG - Row appended for chat file: WhatsApp Chat with Tapuwanashe_EDOOFA(19_12)GJ(1).txt
# 2024-01-06 10:38:14,192 - DEBUG - Row appended for chat file: WhatsApp Chat with Tarisai_DM05(14_09)HP(1).txt
# 2024-01-06 10:38:14,456 - DEBUG - Row appended for chat file: WhatsApp Chat with Tatiana Ruvimbo Kapungu Edoofa (25_10) SZ(1).txt
# 2024-01-06 10:38:14,596 - DEBUG - Row appended for chat file: WhatsApp Chat with Thandiwe Zipporah Soko(DC03_01)SR(1).txt
# 2024-01-06 10:38:14,909 - DEBUG - Row appended for chat file: WhatsApp Chat with Tinotenda_DM03(19_12)HP(1).txt
# 2024-01-06 10:38:15,141 - DEBUG - Row appended for chat file: WhatsApp Chat with Tivaoneshe_EDOOFA(21_12)GJ(1).txt
# 2024-01-06 10:38:15,377 - DEBUG - Row appended for chat file: WhatsApp Chat with Vanessa_SA(20_12)HP(1).txt
# 2024-01-06 10:38:15,589 - DEBUG - Row appended for chat file: WhatsApp Chat with Vimbai_EDOOFA(19_12)GJ(1).txt
# 2024-01-06 10:38:15,743 - DEBUG - Row appended for chat file: WhatsApp Chat with WELLBRAVE TARUWINGA Edoofa(IE28_12)SR(1).txt
# 2024-01-06 10:38:15,916 - DEBUG - Row appended for chat file: WhatsApp Chat with Alice Muchara Edoofa (26_12) SZ.txt
# 2024-01-06 10:38:16,054 - DEBUG - Row appended for chat file: WhatsApp Chat with Antoinette Nyirenda Edoofa (04_01) SZ.txt
# 2024-01-06 10:38:16,286 - DEBUG - Row appended for chat file: WhatsApp Chat with Auther Munhamo Edoofa (30_11) SZ.txt
# 2024-01-06 10:38:16,471 - DEBUG - Row appended for chat file: WhatsApp Chat with Bella Mutema Edoofa (30_11) SZ.txt
# 2024-01-06 10:38:16,655 - DEBUG - Row appended for chat file: WhatsApp Chat with Chibakwe Trish Edoofa (28_12) SZ.txt
# 2024-01-06 10:38:16,895 - DEBUG - Row appended for chat file: WhatsApp Chat with Chido Natalie Mberikwazvo Edoofa (20_12) SZ.txt
# 2024-01-06 10:38:17,111 - DEBUG - Row appended for chat file: WhatsApp Chat with Chiminya Rutendo H Edoofa (06_12) SZ.txt
# 2024-01-06 10:38:17,374 - DEBUG - Row appended for chat file: WhatsApp Chat with Chiturumani Takudzwa Edoofa (05_12) SZ.txt
# 2024-01-06 10:38:17,628 - DEBUG - Row appended for chat file: WhatsApp Chat with Daryl T. Maenzanise Edoofa (20_12) SZ.txt
# 2024-01-06 10:38:17,913 - DEBUG - Row appended for chat file: WhatsApp Chat with Dhinda Tanyaradzwa Edoofa (18_12) SZ.txt
# 2024-01-06 10:38:18,140 - DEBUG - Row appended for chat file: WhatsApp Chat with Esther Princess Moyo Edoofa (02_01) SZ 2025.txt
# 2024-01-06 10:38:18,387 - DEBUG - Row appended for chat file: WhatsApp Chat with Ethina Ngwenyama Edoofa (28_12) SZ 2025.txt
# 2024-01-06 10:38:18,618 - DEBUG - Row appended for chat file: WhatsApp Chat with Fortune Magwenzi Edoofa (08_12) SZ 2025.txt
# 2024-01-06 10:38:18,729 - DEBUG - Row appended for chat file: WhatsApp Chat with Frankie Mavura Edoofa (05_01) SZ.txt
# 2024-01-06 10:38:18,868 - DEBUG - Row appended for chat file: WhatsApp Chat with Fredrick Mboshi Edoofa (05_01) SZ.txt
# 2024-01-06 10:38:19,021 - DEBUG - Row appended for chat file: WhatsApp Chat with James Mzila Edoofa (26_12) SZ.txt
# 2024-01-06 10:38:19,182 - DEBUG - Row appended for chat file: WhatsApp Chat with Kasanda Blessings Edoofa (26_12) SZ.txt
# 2024-01-06 10:38:19,330 - DEBUG - Row appended for chat file: WhatsApp Chat with Kokera Derrick Edoofa (28_12) SZ.txt
# 2024-01-06 10:38:19,473 - DEBUG - Row appended for chat file: WhatsApp Chat with Linda Malaba Edoofa (26_12) SZ.txt
# 2024-01-06 10:38:19,616 - DEBUG - Row appended for chat file: WhatsApp Chat with Mambara Faith Edoofa (05_01) SZ.txt
# 2024-01-06 10:38:19,763 - DEBUG - Row appended for chat file: WhatsApp Chat with Matongo Brighton Edoofa (26_12) SZ.txt
# 2024-01-06 10:38:19,905 - DEBUG - Row appended for chat file: WhatsApp Chat with Mirriam Ngalula Edoofa (04_01) SZ.txt
# 2024-01-06 10:38:20,137 - DEBUG - Row appended for chat file: WhatsApp Chat with Mishel Tadiwa Diwura Edoofa (16_11) SZ.txt
# 2024-01-06 10:38:20,335 - DEBUG - Row appended for chat file: WhatsApp Chat with Moyo Emma Edoofa (20_12) SZ.txt
# 2024-01-06 10:38:20,478 - DEBUG - Row appended for chat file: WhatsApp Chat with Munashe Oniswence Tomy Edoofa (02_01) SZ.txt
# 2024-01-06 10:38:20,610 - DEBUG - Row appended for chat file: WhatsApp Chat with Munga Praise Edoofa (26_12) SZ.txt
# 2024-01-06 10:38:20,764 - DEBUG - Row appended for chat file: WhatsApp Chat with Mutsigiri Rufaro Edoofa (28_12) SZ 2025.txt
# 2024-01-06 10:38:21,011 - DEBUG - Row appended for chat file: WhatsApp Chat with Mutsvairo Tanatswanashe Belinda Edoofa (19_12) SZ.txt
# 2024-01-06 10:38:21,161 - DEBUG - Row appended for chat file: WhatsApp Chat with Nazare Daphane Edoofa (02_01) SZ.txt
# 2024-01-06 10:38:21,301 - DEBUG - Row appended for chat file: WhatsApp Chat with Nkandu Mulenga Edoofa (04_01) SZ.txt
# 2024-01-06 10:38:21,420 - DEBUG - Row appended for chat file: WhatsApp Chat with Nkomo Thembela Kgomotso Edoofa (05_01) SZ.txt
# 2024-01-06 10:38:21,651 - DEBUG - Row appended for chat file: WhatsApp Chat with Nyasha Chipwanya Edoofa (26_12) SZ.txt
# 2024-01-06 10:38:21,872 - DEBUG - Row appended for chat file: WhatsApp Chat with Persevere Mudavanhu Edoofa (28_12) SZ.txt
# 2024-01-06 10:38:22,076 - DEBUG - Row appended for chat file: WhatsApp Chat with Phiri Simphiwe Edoofa (08_12) SZ.txt
# 2024-01-06 10:38:22,268 - DEBUG - Row appended for chat file: WhatsApp Chat with Salem Mubvumbi Edoofa (26_12) SZ 2025.txt
# 2024-01-06 10:38:22,408 - DEBUG - Row appended for chat file: WhatsApp Chat with Shekinah Edoofa (04_01) SZ.txt
# 2024-01-06 10:38:22,531 - DEBUG - Row appended for chat file: WhatsApp Chat with Simbarashe Madzokere Edoofa (05_01) SZ.txt
# 2024-01-06 10:38:22,704 - DEBUG - Row appended for chat file: WhatsApp Chat with Stanley Nemashapa Edoofa (19_12) SZ.txt
# 2024-01-06 10:38:22,966 - DEBUG - Row appended for chat file: WhatsApp Chat with Tafara Mukucha Edoofa (23_11) SZ 2025.txt
# 2024-01-06 10:38:23,126 - DEBUG - Row appended for chat file: WhatsApp Chat with Tafara Rooney Ekely Mombili Edoofa (18_12) SZ.txt
# 2024-01-06 10:38:23,277 - DEBUG - Row appended for chat file: WhatsApp Chat with Tatenda Marimo Edoofa (26_12) SZ.txt
# 2024-01-06 10:38:23,397 - DEBUG - Row appended for chat file: WhatsApp Chat with Trisha Mulenga Edoofa (04_01) SZ.txt
# 2024-01-06 10:38:23,528 - DEBUG - Row appended for chat file: WhatsApp Chat with Wellington Mnyama Edoofa (02_01) SZ.txt
# 2024-01-06 10:38:23,687 - DEBUG - Row appended for chat file: WhatsApp Chat with Wilbert Simango Edoofa (26_12) SZ.txt
# 2024-01-06 10:38:23,829 - DEBUG - Row appended for chat file: WhatsApp Chat with Abigail Mudau_EDOOFA(03_01)SM24.txt
# 2024-01-06 10:38:23,950 - DEBUG - Row appended for chat file: WhatsApp Chat with Abigail Mundokweya_EDOOFA(04_01)SM24 - IE.txt
# 2024-01-06 10:38:24,215 - DEBUG - Row appended for chat file: WhatsApp Chat with Allan Nyapfumbi_EDOOFA(19_12)GS.txt
# 2024-01-06 10:38:24,451 - DEBUG - Row appended for chat file: WhatsApp Chat with Anotida Zvavamwe_EDOOFA(26_12)GS-IE.txt
# 2024-01-06 10:38:24,720 - DEBUG - Row appended for chat file: WhatsApp Chat with Anotida_EDOOFAMHS(17_11)TR.txt
# 2024-01-06 10:38:24,943 - DEBUG - Row appended for chat file: WhatsApp Chat with Ashley Nyambi_EA(20_12)TR.txt
# 2024-01-06 10:38:25,173 - DEBUG - Row appended for chat file: WhatsApp Chat with Beenzu chilumba_EDOOFAZAMBNGS(19_12)GS.txt
# 2024-01-06 10:38:25,426 - DEBUG - Row appended for chat file: WhatsApp Chat with Benhura Natasha_EDOOFA(20_12)GS.txt
# 2024-01-06 10:38:25,655 - DEBUG - Row appended for chat file: WhatsApp Chat with Birthwell Chagomoka_EDOOFA(12_12)GS.txt
# 2024-01-06 10:38:25,797 - DEBUG - Row appended for chat file: WhatsApp Chat with Bupe Nalavwe_EDOOFA(04_01)SM24 - IE.txt
# 2024-01-06 10:38:26,082 - DEBUG - Row appended for chat file: WhatsApp Chat with Carlos_EA(21_11)TR.txt
# 2024-01-06 10:38:26,242 - DEBUG - Row appended for chat file: WhatsApp Chat with Cassandra Nyathi_EDOOFAIE(29_12)SM23.txt
# 2024-01-06 10:38:26,444 - DEBUG - Row appended for chat file: WhatsApp Chat with Cathrine MnyulwaIA_EA(21_12)TR.txt
# 2024-01-06 10:38:26,825 - DEBUG - Row appended for chat file: WhatsApp Chat with Chantell Zvenyika_EDOOFA(22_11)SM23.txt
# 2024-01-06 10:38:27,071 - DEBUG - Row appended for chat file: WhatsApp Chat with CHIREMBWE C_EA(22_12)TR.txt
# 2024-01-06 10:38:27,331 - DEBUG - Row appended for chat file: WhatsApp Chat with Claudius Ziyamba_EA(21_12)TR.txt
# 2024-01-06 10:38:27,569 - DEBUG - Row appended for chat file: WhatsApp Chat with Craig Jemwa_EDOOFA(18_12)GS.txt
# 2024-01-06 10:38:27,685 - DEBUG - Row appended for chat file: WhatsApp Chat with Davintyne Chikanyanza_EDOOFAMHS(03_01)SM24.txt
# 2024-01-06 10:38:27,970 - DEBUG - Row appended for chat file: WhatsApp Chat with DIVINE NOKUTENDA_EA(12_12)TR.txt
# 2024-01-06 10:38:28,102 - DEBUG - Row appended for chat file: WhatsApp Chat with Edinah Chipenya_EA(28_12)TR.txt
# 2024-01-06 10:38:28,349 - DEBUG - Row appended for chat file: WhatsApp Chat with Fumani Chauke_EDOOFA(18_12)GS.txt
# 2024-01-06 10:38:28,587 - DEBUG - Row appended for chat file: WhatsApp Chat with Hilary Mukwesha_EDOOFA(29_12)SM23.txt
# 2024-01-06 10:38:28,703 - DEBUG - Row appended for chat file: WhatsApp Chat with Julius Dhliwayo_EDOOFA(04_01)SM24 - IE.txt
# 2024-01-06 10:38:28,919 - DEBUG - Row appended for chat file: WhatsApp Chat with Luyando Siasulingana_EA(15_12)TR.txt
# 2024-01-06 10:38:29,150 - DEBUG - Row appended for chat file: WhatsApp Chat with Luyando siavwapa_EDOOFAZAM(5_12)GS.txt
# 2024-01-06 10:38:29,281 - DEBUG - Row appended for chat file: WhatsApp Chat with Mapesho Kakwata_EDOOFAZAMB(03_01)SM24.txt
# 2024-01-06 10:38:29,500 - DEBUG - Row appended for chat file: WhatsApp Chat with Mercy Chivhumba_EA(21_12)TR.txt
# 2024-01-06 10:38:29,713 - DEBUG - Row appended for chat file: WhatsApp Chat with Mitch Mhungu_EDOOFA(18_12)GS-IE.txt
# 2024-01-06 10:38:29,915 - DEBUG - Row appended for chat file: WhatsApp Chat with Mitchell Mpofu_EA(22_12)TR.txt
# 2024-01-06 10:38:30,158 - DEBUG - Row appended for chat file: WhatsApp Chat with Mutevera Michael_EDOOFAIE(19_12)SM23.txt
# 2024-01-06 10:38:30,299 - DEBUG - Row appended for chat file: WhatsApp Chat with Naomi Zulu_EDOOFAZAMBNGS(03_01)SM24.txt
# 2024-01-06 10:38:30,521 - DEBUG - Row appended for chat file: WhatsApp Chat with Natalie Msipa_EDOOFAIE(19_12)SM23.txt
# 2024-01-06 10:38:30,652 - DEBUG - Row appended for chat file: WhatsApp Chat with Neo Banda_EDOOFAIE(03_01)SM24.txt
# 2024-01-06 10:38:30,923 - DEBUG - Row appended for chat file: WhatsApp Chat with Ng_andu Felicity_EDOOFAZAMB(18_12)SM23.txt
# 2024-01-06 10:38:31,163 - DEBUG - Row appended for chat file: WhatsApp Chat with NICOLE NDLOVU_EDOOFA(18_12)GS.txt
# 2024-01-06 10:38:31,376 - DEBUG - Row appended for chat file: WhatsApp Chat with Nyabereka T_EA(21_12)TR.txt
# 2024-01-06 10:38:31,567 - DEBUG - Row appended for chat file: WhatsApp Chat with Otilia Chivanganye_EA(21_12)TR.txt
# 2024-01-06 10:38:31,708 - DEBUG - Row appended for chat file: WhatsApp Chat with Precious kangwa_EDOOFAZAMBNGS(03_01)SM24.txt
# 2024-01-06 10:38:31,899 - DEBUG - Row appended for chat file: WhatsApp Chat with Ronald Ganha_EA(26_12)TR.txt
# 2024-01-06 10:38:32,128 - DEBUG - Row appended for chat file: WhatsApp Chat with Rutendo Zindi_EA(05_10)TR.txt
# 2024-01-06 10:38:32,339 - DEBUG - Row appended for chat file: WhatsApp Chat with Shavi Mufarowashe_EA(27_10)TR.txt
# 2024-01-06 10:38:32,570 - DEBUG - Row appended for chat file: WhatsApp Chat with Sibanda D_EDOOFA(14_12)SM23.txt
# 2024-01-06 10:38:32,907 - DEBUG - Row appended for chat file: WhatsApp Chat with SIMPOSO MWAANGWA_EDOOFAZAMBNGS(12_12)GS.txt
# 2024-01-06 10:38:33,063 - DEBUG - Row appended for chat file: WhatsApp Chat with Takudzwa Magwenzi_EDOOFA(03_01)SM24.txt
# 2024-01-06 10:38:33,251 - DEBUG - Row appended for chat file: WhatsApp Chat with Tanaka Mushonga_EDOOFA(07_12)SM23.txt
# 2024-01-06 10:38:33,388 - DEBUG - Row appended for chat file: WhatsApp Chat with Tanatswa Tsopotsa_EA(28_12)TR.txt
# 2024-01-06 10:38:33,599 - DEBUG - Row appended for chat file: WhatsApp Chat with THEARA MUDIMU_EA(21_11)TR.txt
# 2024-01-06 10:38:33,740 - DEBUG - Row appended for chat file: WhatsApp Chat with Wesley Kangoma_EDOOFAIE(29_12)SM23.txt

# %%
csv_file_path = 'F:\\Github-mauriceyeng\\Chat-Analyzer-V2\\Chat Folder from Drive\\2024-01-06-20240106T044019Z-001\\data.csv'  # Define your desired path and file name
