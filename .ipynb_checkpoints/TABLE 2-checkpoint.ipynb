# %%
import os
import pandas as pd
import re
from datetime import datetime, timedelta
import logging
from datetime import timedelta

# Configure logging
logging.basicConfig(level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s')
# Set of processed chats to ensure each chat is analyzed only once
processed_chats = set()

# Function to process a single line of chat
def process_line(line):
    pattern = r'(\d{2}/\d{2}/\d{2}), (\d{1,2}:\d{2}\s?[APMapm]{2}) - (.*?): (.*)'
    match = re.match(pattern, line)
    if match:
        date_str, time_str, sender, message = match.groups()
        date = datetime.strptime(date_str, '%d/%m/%y')
        time = datetime.strptime(time_str, '%I:%M %p').strftime('%H:%M')
        return {'date': date, 'time': time, 'sender': sender, 'message': message}
    else:
        return None

def process_line_for_delay(line):
    pattern = r'(\d{2}/\d{2}/\d{2}), (\d{1,2}:\d{2}\s?[APMapm]{2}) - (.*?): (.*)'
    match = re.match(pattern, line)
    if match:
        date_str, time_str, sender, message = match.groups()
        datetime_str = date_str + ' ' + time_str
        datetime_obj = datetime.strptime(datetime_str, '%d/%m/%y %I:%M %p')
        return {'datetime': datetime_obj, 'sender': sender, 'message': message}
    else:
        return None

# Function to read the chat file specifically for delay calculation
def read_chat_file_for_delay(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        lines = file.readlines()

    concatenated_lines = []
    current_message = ""
    date_pattern = re.compile(r'^\d{2}/\d{2}/\d{2}, \d{1,2}:\d{2}\s?[APMapm]{2} - ')

    for line in lines:
        if date_pattern.match(line):
            if current_message:
                concatenated_lines.append(current_message)
            current_message = line.rstrip()
        else:
            # Append this line to the current message, if it's not empty
            if current_message:
                current_message += " " + line.strip()
    if current_message:
        concatenated_lines.append(current_message)

    return pd.DataFrame([process_line_for_delay(line) for line in concatenated_lines if process_line_for_delay(line) is not None])

# The process_line_for_delay function remains the same
       
    
def calculate_time_spent_student(chat_df, target_date, employee_name):
    student_messages = chat_df[(chat_df['date'].dt.date == target_date) & (chat_df['sender'] != employee_name)]
    total_chars = student_messages['message'].str.len().sum()
    time_spent_seconds = (total_chars / 10) * 5
    return strfdelta(timedelta(seconds=time_spent_seconds)) 

def format_delay_time(seconds):
    hours = seconds // 3600
    minutes = (seconds % 3600) // 60
    if hours > 0:
        return f"{hours} hr {minutes} mins"
    else:
        return f"{minutes} mins"

def calculate_employee_delay(chat_df, employee_name, target_date):
    delays = []
    delay_times = []
    messages_for_reference = []

    last_student_message_time = None
    employee_responded_after_student = False

    delay_counter = 1

    for index, row in chat_df.iterrows():
        # Ensure datetime is correctly formatted
        row_date = row['datetime'].date()

        if row_date != target_date:
            continue

        if row['sender'] != employee_name:
            last_student_message_time = row['datetime']
            employee_responded_after_student = False
        elif row['sender'] == employee_name and last_student_message_time is not None and not employee_responded_after_student:
            time_diff = row['datetime'] - last_student_message_time

            if time_diff > timedelta(minutes=15):
                formatted_time = row['datetime'].strftime('%d %b %Y %I:%M%p')
                delays.append(f"{delay_counter} - {formatted_time}")
                delay_counter += 1

                delay_times.append(format_delay_time(time_diff.seconds))

                start_index = max(0, index - 5)
                end_index = min(index + 5, len(chat_df))
                context_messages = chat_df.iloc[start_index:end_index]

                formatted_context_messages = [f"{idx+1} - {message_row['datetime'].strftime('%d %b %Y %I:%M%p')} - {message_row['sender']}: {message_row['message']}" for idx, message_row in context_messages.iterrows()]
                formatted_message = "\n".join(formatted_context_messages)
                messages_for_reference.append(formatted_message)

            employee_responded_after_student = True

    # Combine the lists into multiline strings
    delays_str = "\n".join(delays)
    delay_times_str = "\n".join(delay_times)
    messages_for_reference_str = "\n".join(messages_for_reference)

    return delays_str, delay_times_str, messages_for_reference_str

def is_broken_chat_student(chat_df, employee_name, target_date):
    # Adjust for the previous day
    previous_day = target_date - timedelta(days=1)

    # Filter messages for the previous day
    daily_messages = chat_df[chat_df['date'].dt.date == previous_day]

    # Check if both the employee and the student had at least one text on that day
    if daily_messages.empty:
        return 'No'  # No conversation happened on this day

    employee_messages = daily_messages[daily_messages['sender'] == employee_name]
    student_messages = daily_messages[daily_messages['sender'] != employee_name]

    # Check if both parties have sent at least one message
    if employee_messages.empty or student_messages.empty:
        return 'No'  # One of the parties did not send any message

    # Check the sender of the last message of the day
    last_message_sender = daily_messages.iloc[-1]['sender']

    # If the last message is from the employee, it's a broken chat by the student
    if last_message_sender == employee_name:
        return 'Yes'

    return 'No'
    
def count_missed_replies_student(chat_df, employee_name, report_date):
    count = 0
    for i in range(7):
        check_date = report_date - timedelta(days=i)
        messages_on_date = chat_df[chat_df['date'].dt.date == check_date]
        employee_messages = messages_on_date[messages_on_date['sender'] == employee_name]
        student_messages = messages_on_date[messages_on_date['sender'] != employee_name]
        if employee_messages.empty and not student_messages.empty:
            count += 1
    return count

def count_missed_replies_studentt(chat_df, employee_name, target_date):
    previous_day = target_date - timedelta(days=1)
    #print(f"Checking for missed replies on: {previous_day}")

    daily_messages = chat_df[chat_df['date'].dt.date == previous_day]
    
    employee_messages = daily_messages[daily_messages['sender'] == employee_name]
    student_messages = daily_messages[daily_messages['sender'] != employee_name]

    #print(f"Employee messages count: {len(employee_messages)}")
    #print(f"Student messages count: {len(student_messages)}")

    # Check if there are messages from the employee but none from the student
    if not employee_messages.empty and student_messages.empty:
        #print("Missed reply found.")
        return 'Yes'
    
    #print("No missed reply.")
    return 'No'

def count_missed_replies_last_7_days(chat_df, employee_name, start_date):
    missed_replies_count = 0

    # Iterate over the last 7 days
    for i in range(7):
        date_to_check = start_date - timedelta(days=i)
        messages_on_date = chat_df[chat_df['date'].dt.date == date_to_check]

        # Check if there are messages on this date
        if not messages_on_date.empty:
            # Check if there's any message from the employee on this day
            employee_messages = messages_on_date[messages_on_date['sender'] == employee_name]
            
            # Check if there's any message from others (leads) on this day
            lead_messages = messages_on_date[messages_on_date['sender'] != employee_name]

            # If there are messages from others but none from the employee, count as a missed reply
            if not lead_messages.empty and employee_messages.empty:
                missed_replies_count += 1

    return missed_replies_count

# Function to calculate the time spent in chat based on message lengths
def calculate_time_spent(chat_df, target_date, employee_name, team_folder):
    daily_messages = chat_df[(chat_df['date'].dt.date == target_date) & (chat_df['sender'] == employee_name)]

    if daily_messages.empty:
        return '00:00:00'

    total_time_spent_seconds = 0

    for index, row in daily_messages.iterrows():
        message = row['message']
        total_chars = len(message)

        if team_folder == "KAM" and total_chars > 700:
            time_spent_seconds = 5  # Cap at 5 seconds for long messages in KAM team folder
        else:
            time_spent_seconds = total_chars * 0.2  # Assuming 0.2 seconds per character

        total_time_spent_seconds += time_spent_seconds

        # Optional: Debug print
        #print(f"New Chat Found in {team_folder}")
        #print(f"Message Length: '{total_chars}'")
        #print(f"Message: '{message}' - Time Spent: {time_spent_seconds} seconds")

    time_spent_timedelta = timedelta(seconds=total_time_spent_seconds)
    formatted_time_spent = strfdelta(time_spent_timedelta)

    return formatted_time_spent

def strfdelta(tdelta):
    hours, remainder = divmod(tdelta.seconds, 3600)
    minutes, seconds = divmod(remainder, 60)
    return f"{hours:02}:{minutes:02}:{seconds:02}"   

def calculate_lead_response(chat_df, employee_name, target_date):
    """
    Calculates the lead response based on the number of texts exchanged between the employee and others (non-employee).
    - If only the employee sent messages, the response is 100%.
    - If only non-employees sent messages, the response is 0%.
    - Otherwise, it's the ratio of the employee's texts to the total texts, constrained between 1% and 99%.
    """
    # Filter messages for the target date
    daily_messages = chat_df[chat_df['date'].dt.date == target_date]
    
    # Check if there are any messages from the employee and others on the target date
    employee_messages = daily_messages[daily_messages['sender'] == employee_name]
    non_employee_messages = daily_messages[daily_messages['sender'] != employee_name]

    # If only the employee sent messages
    if not employee_messages.empty and non_employee_messages.empty:
        return 0

    # If only non-employees sent messages
    if employee_messages.empty and not non_employee_messages.empty:
        return 100

    # If both the employee and non-employees have sent messages
    if not employee_messages.empty and not non_employee_messages.empty:
        num_texts_employee = len(employee_messages)
        num_texts_non_employee = len(non_employee_messages)
        total_texts = num_texts_employee + num_texts_non_employee
        lead_response = (num_texts_employee / total_texts) * 100
        return max(min(lead_response, 99), 1)

    # If neither the employee nor non-employees sent messages
    return 0



def calculate_broken_chat_within_working_hrs(chat_df, employee_name, report_date, team_folder):
    # Adjust working hours based on team folder
    if team_folder == 'EWYL':
        # KAM Team working hours: 7:30 AM to 4:00 PM
        work_start_time = datetime(report_date.year, report_date.month, report_date.day, 7, 30, 0)
        work_end_time = datetime(report_date.year, report_date.month, report_date.day, 16, 30, 0)
    else:
        # Default working hours for other teams: 12:00 AM to 12:00 PM
        work_start_time = datetime(report_date.year, report_date.month, report_date.day, 0, 0, 0)
        work_end_time = datetime(report_date.year, report_date.month, report_date.day, 23, 59, 0)

    # Filter the messages for the given report date
    messages_on_date = chat_df[chat_df['datetime'].dt.date == report_date.date()]

    # Check if both employee and lead have messaged on the report date
    if not messages_on_date.empty:
        employee_messages = messages_on_date[messages_on_date['sender'] == employee_name]
        lead_messages = messages_on_date[messages_on_date['sender'] != employee_name]
        last_message_sender = messages_on_date.iloc[-1]['sender']
        # Ensure both the employee and lead have at least one message
        if not employee_messages.empty and not lead_messages.empty:
            # Get the time of the last message from the lead
            last_lead_message_time = lead_messages.iloc[-1]['datetime']

            # Check if the last message is from the lead and within working hours
            if last_message_sender != employee_name and (work_start_time <= last_lead_message_time <= work_end_time):
                return 'Yes'  # Broken chat if last message from the lead is within working hours
            else:
                return 'No'  # Not a broken chat if last message from the lead is outside working hours or from the employee

    # If no messages or only one party messaged, return 'No'
    return 'No'

def calculate_broken_chat(chat_df, employee_name, report_date):
    # Filter the messages for the given report date
    messages_on_date = chat_df[chat_df['date'].dt.date == report_date]
    
    # Check if both employee and lead have messaged on the report date
    if not messages_on_date.empty:
        employee_messages = messages_on_date[messages_on_date['sender'] == employee_name]
        lead_messages = messages_on_date[messages_on_date['sender'] != employee_name]
        
        # Ensure both the employee and lead have at least one message
        if not employee_messages.empty and not lead_messages.empty:
            # Check if the last message is from the lead
            last_message_sender = messages_on_date.iloc[-1]['sender']
            return last_message_sender != employee_name

    

def missed_replies_employee(chat_df, employee_name, target_date):
    # Filter messages for the target date
    daily_messages = chat_df[chat_df['date'].dt.date == target_date]
    
    # Check if there are any messages from the student
    student_messages = daily_messages[daily_messages['sender'] != employee_name]
    
    # Check if there are any messages from the employee
    employee_messages = daily_messages[daily_messages['sender'] == employee_name]
    
    # If there are student messages but no employee messages, consider it a missed reply
    if not student_messages.empty and employee_messages.empty:
        return 'Yes'
    
    return 'No'

def missed_replies_employee_after_working_hrs(chat_df, employee_name, target_date, team_folder):
    # Check if the team folder is 'KAM Team' to define different working hours
    if team_folder == 'EWYL':
        # EWYL Team working hours: 7:30 AM to 4:00 PM
        work_start_time = datetime(target_date.year, target_date.month, target_date.day, 7, 30, 0)
        work_end_time = datetime(target_date.year, target_date.month, target_date.day, 16, 30, 0)
    
    elif team_folder == 'KAM':
       # KAM Team working hours: 7:30 AM to 4:00 PM
        work_start_time = datetime(target_date.year, target_date.month, target_date.day, 11, 30, 0)
        work_end_time = datetime(target_date.year, target_date.month, target_date.day, 21, 30, 0)

    else:
        # Default working hours for other teams: 12:00 AM to 12:00 PM
        work_start_time = datetime(target_date.year, target_date.month, target_date.day, 0, 0, 0)
        work_end_time = datetime(target_date.year, target_date.month, target_date.day, 23, 59, 0)

    # Ensure target_date is a datetime object
    if not isinstance(target_date, datetime):
        raise ValueError("target_date must be a datetime object")

    # Filter messages for the target date using 'datetime' column
    daily_messages = chat_df[chat_df['datetime'].dt.date == target_date.date()]
    
    # Check if there are any messages from the student
    student_messages = daily_messages[daily_messages['sender'] != employee_name]
    
    # Check if there are any messages from the employee
    employee_messages = daily_messages[daily_messages['sender'] == employee_name]

    # If there are student messages but no employee messages
    if not student_messages.empty and employee_messages.empty:
        print(f"ENTER THE LOOP:{student_messages}")
        # Check if any student message is within working hours
        for _, row in student_messages.iterrows():
            message_time = row['datetime']
            if work_start_time <= message_time <= work_end_time:
                return 'Yes'  # Missed reply within working hours
        return 'No'  # All student messages are outside working hours

    return 'No'

# Function to read the chat file and return a dataframe
def read_chat_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        lines = file.readlines()

    concatenated_lines = []
    current_message = ""
    date_pattern = re.compile(r'^\d{2}/\d{2}/\d{2}, \d{1,2}:\d{2}\s?[APMapm]{2} - ')

    for line in lines:
        if date_pattern.match(line):
            if current_message:
                concatenated_lines.append(current_message)
            current_message = line.rstrip()
        else:
            # Append this line to the current message, if it's not empty
            if current_message:
                current_message += " " + line.strip()
    if current_message:
        concatenated_lines.append(current_message)

    return pd.DataFrame([process_line(line) for line in concatenated_lines if process_line(line) is not None])

# process_line function remains the same


# Function to extract the chat file name based on a specific pattern
def extract_chat_name(chat_file_name):
    #logging.debug(f"Extracting name from chat file: {chat_file_name}")
    match = re.search(r'WhatsApp Chat with _?(.*?)(?:\(\d+\))?_?\.txt', chat_file_name)
    if match:
        extracted_name = re.sub(r'_*(?:\(\d+\))?$', '', match.group(1))
        #logging.debug(f"Extracted chat name: {extracted_name}")
        return extracted_name
    #logging.warning(f"No match found for chat file name: {chat_file_name}")
    return None

# Function to calculate the total count of missed replies by the student for the last N days
def calculate_total_count_missed_replies_student(chat_df, employee_name, num_days):
    total_count = 0

    # Iterate over the last N days
    for i in range(num_days):
        target_date = report_date - timedelta(days=i)
        count = count_missed_replies_student(chat_df, employee_name, target_date)
        total_count += count

    return total_count

# Function to extract the start date from a chat file
def get_chat_start_date(chat_df):
    if not chat_df.empty:
        #logging.debug(f"Extracted chat name: {chat_df['date'].min().date()}")
        return chat_df['date'].min().date()
    return None

# Function to process a single chat file
def process_chat_file(file_path, report_date, main_directory, team_folder, employee_folder):
    global processed_chats
    broken_chat_count = 0
    missed_reply_count = 0
    max_time_spent = ('', '00:00:00')  # (date, time)

    chat_file_name = os.path.basename(file_path)
    #logging.debug(f"Processing chat file: {chat_file_name}")

    chat_name = extract_chat_name(chat_file_name)
    #logging.debug(f"Chat name extracted: {chat_name}")



    

    if chat_name is None:
        #logging.warning(f"Chat name could not be extracted for file: {chat_file_name}")
        return None
    if chat_name in processed_chats:
        #logging.info(f"Chat file already processed: {chat_name}")
        return None

    processed_chats.add(chat_name)
    #logging.debug(f"Chat file added to processed list: {chat_name}")

    chat_df = read_chat_file(file_path)
    if chat_df.empty:
        #logging.warning(f"Chat DataFrame is empty for file: {chat_file_name}")
        return None
    chat_start_date = get_chat_start_date(chat_df)

    # Use read_chat_file_for_delay specifically for delay calculations
    chat_df_for_delay = read_chat_file_for_delay(file_path)
    if chat_df_for_delay.empty:
        return None

    
    target_date = report_date - timedelta(days=1)

    # Call the function with the target date
    delays, delay_times, messages_for_reference = calculate_employee_delay(chat_df_for_delay, employee_folder, target_date)
    



    # Calculate the time spent on Day 0 (report_date - 1 day)
    day_0_date = report_date - timedelta(days=1)
    day_0_time_spent = calculate_time_spent(chat_df, day_0_date, employee_folder,team_folder)
    #day_0_time_spent = timedelta(hours=int(day_0_time_spent.split(':')[0]), minutes=int(day_0_time_spent.split(':')[1]), seconds=int(day_0_time_spent.split(':')[2]))
    # Calculate the lead response based on text length difference for Day 0
    lead_response_day_0 = calculate_lead_response(chat_df, employee_folder, day_0_date)
     
    day_0_date = report_date - timedelta(days=1)  # Assuming report_date is a datetime object of the target date
    broken_chat = calculate_broken_chat(chat_df, employee_folder, day_0_date)
    missed_replies_day_0 = missed_replies_employee(chat_df, employee_folder, day_0_date)

    # Get the current datetime
    today_datetime = datetime.now()

    # Get today's date with time part (assuming start of the day as default)
    today_date_1 = today_datetime.replace(hour=0, minute=0, second=0, microsecond=0)

    # If today_date.weekday() logic remains the same
    # ...

    # Now, when you calculate target_date, it remains a datetime object
    target_date_1 = today_date_1 - timedelta(days=1)


    Actual_missed_Reply = missed_replies_employee_after_working_hrs(chat_df_for_delay, employee_folder, target_date_1,team_folder)
    Actual_broken_chat = calculate_broken_chat_within_working_hrs(chat_df_for_delay, employee_folder, target_date_1,team_folder)
    total_count_missed_reply_student = calculate_total_count_missed_replies_student(chat_df, employee_folder, 14)
    


    
    for i in range(7):  # Assuming you're checking the past 7 days
        check_date = report_date - timedelta(days=i)
        
        # Check for broken chats
        if calculate_broken_chat(chat_df, employee_folder, check_date):
            broken_chat_count += 1

        # Check for missed replies
        start_date_for_missed_replies = report_date - timedelta(days=7)
        
        missed_replies_count = count_missed_replies_last_7_days(chat_df, employee_folder, start_date_for_missed_replies)

        # Check for max time spent
        time_spent = calculate_time_spent(chat_df, check_date, employee_folder,team_folder)
        if time_spent > max_time_spent[1]:
            max_time_spent = (check_date.strftime('%m-%d-%Y'), time_spent)
    
    
    
    # Calculate the time spent by students
    time_spent_student = {
    'Day 0 (Student)': calculate_time_spent_student(chat_df, report_date - timedelta(days=1), employee_folder),
    'Day 1 (Student)': calculate_time_spent_student(chat_df, report_date - timedelta(days=2), employee_folder),
    'Day 2 (Student)': calculate_time_spent_student(chat_df, report_date - timedelta(days=3), employee_folder),
    }
    
    # Inside the process_chat_file function, after calculating day_0_time_spent:
    day_0_date = report_date - timedelta(days=1)
    day_1_date = report_date - timedelta(days=2)
    day_2_date = report_date - timedelta(days=3)

    # Calculate time spent by student for Day 0, Day 1, and Day 2
    time_spent_student_day_0 = calculate_time_spent_student(chat_df, day_0_date, employee_folder)
    time_spent_student_day_1 = calculate_time_spent_student(chat_df, day_1_date, employee_folder)
    time_spent_student_day_2 = calculate_time_spent_student(chat_df, day_2_date, employee_folder)



    total_time_spent_student = time_spent_student['Day 0 (Student)']

    broken_chat_student = is_broken_chat_student(chat_df, employee_folder, report_date)

    mmissed_reply_student = count_missed_replies_studentt(chat_df, employee_folder, report_date)

    # Calculate the time spent on each day relative to the report date
    time_spent = {}
    for i in range(1, 4):  # Start from 1 since we want Day 0 to be the day before the report date
        target_date = report_date - timedelta(days=i)
        time_spent[f'Day {i-1}'] = calculate_time_spent(chat_df, target_date, employee_folder,team_folder)
    
    target_date_for_chat_start_Date = report_date - timedelta(days=1)
    day_indicator_employee = (target_date_for_chat_start_Date - chat_start_date).days
    #logging.debug(f"day indicator employee: {day_indicator_employee}")
    # Determine Day Indicator based on chat start date
    if chat_start_date:
        if (target_date_for_chat_start_Date - chat_start_date).days == 0:
          
            day_indicator = 'Day 0'
        elif (target_date_for_chat_start_Date - chat_start_date).days == 1:
            
            day_indicator = 'Day 1'
        elif (target_date_for_chat_start_Date - chat_start_date).days == 2:
            
            day_indicator = 'Day 2'

        elif (target_date_for_chat_start_Date - chat_start_date).days == 3:
            
            day_indicator = 'OLD'

        else:
            day_indicator = 'OLD'  # For chats that don't fall into Day 0, Day 1, or Day 2

    

    main_directory_name = os.path.basename(main_directory)

    row = {
        'Date': main_directory_name,
        'Team Folder': team_folder,
        'Employee Folder': employee_folder,
        'Chat File Name': chat_name,        # Inserting the extracted chat name
        'Day Indicator': day_indicator,
        'Total_Time_Spent_Employee': day_0_time_spent,  # Use Day 0 time as the total time spent
        'LR': lead_response_day_0,  # Add the lead response here
        'Broken Chat(Employee)': 'Yes' if broken_chat else 'No',
        'Missed Replies (Employee)': missed_replies_day_0,
        'Count_Broken_Chat_Employee (Employee)': broken_chat_count,
        'Count_Missed_Replies_Missed_Replies (Employee)': missed_replies_count,
        'Date of Max time': max_time_spent[0],
        **time_spent,
        'Total Time Spent (Student)': total_time_spent_student,
        'Broken Chat (Student)': broken_chat_student,
        'Missed Replies (Student)': mmissed_reply_student,
        'Day_0_Time_Spent_Student': time_spent_student_day_0,  # Add time spent for Day 0
        'Day_1_Time_Spent_Student': time_spent_student_day_1,  # Add time spent for Day 1
        'Day_2_Time_Spent_Student': time_spent_student_day_2,
        'Total_Count_Missed_Reply_Chat_Student' : total_count_missed_reply_student,
        'Employee Delays': delays,
        'Delay Durations': delay_times,
        'Messages for Reference': messages_for_reference,
        'Actual Missed Reply from Employee': Actual_missed_Reply,
        'Actual Broken Chat from Employee' : Actual_broken_chat,
    }
    #logging.debug(f"Row created for chat: {row}")
    return row

# Main directory path construction and report date setting
# Main directory path construction and report date setting
local_date_format = '%Y-%m-%d'  # Adjust this to your local date format
main_directory = 'D:\\Github\\Chat-Analyzer-V2\\Chat Folder from Drive\\2024-01-03-20240103T025503Z-001'  # Replace with your base directory path

# Get today's date
today_date = datetime.now().date()

# Check the day of the week
if today_date.weekday() in range(1, 6):  # Tuesday to Saturday
    report_date = today_date
else:  # Monday
    # You can adjust the number of days to subtract based on your specific requirements
    report_date = today_date - timedelta(days=1)
    logging.debug(f"Report Date: {report_date}")
report_date_str_local = report_date.strftime(local_date_format)
main_directory_path = os.path.join(main_directory, report_date_str_local)

# Function to navigate through the directory structure and process all chat files
def process_team_folders(main_directory, report_date):
    all_data = []
    for team_folder in os.listdir(main_directory):
        team_path = os.path.join(main_directory, team_folder)
        if not os.path.isdir(team_path):
            continue
        for employee_folder in os.listdir(team_path):
            employee_path = os.path.join(team_path, employee_folder)
            if not os.path.isdir(employee_path):
                continue
            for chat_file in os.listdir(employee_path):
                chat_file_path = os.path.join(employee_path, chat_file)
                row = process_chat_file(chat_file_path, report_date, main_directory, team_folder, employee_folder)
                if row:
                    all_data.append(row)
                    logging.debug(f"Row appended for chat file: {chat_file}")
    df = pd.DataFrame(all_data)
    #logging.debug(f"DataFrame constructed with {len(df)} rows")
    return df

# Process all team folders and chats based on the report date
all_chats_df = process_team_folders(main_directory_path, report_date)


# Save to a CSV file
csv_file_path = 'D:\\Github\\Chat-Analyzer-V2\\Chat Folder from Drive\\2024-01-03-20240103T025503Z-001\\chat_data6.csv'  # Define your desired path and file name
all_chats_df.to_csv(csv_file_path, index=False)
#print(f"DataFrame saved as CSV at {csv_file_path}")
# Display the result
#print(all_chats_df)
# Out:
# 2024-01-03 08:34:37,184 - DEBUG - Row appended for chat file: WhatsApp Chat with Admire EWYL22E1163.txt
# 2024-01-03 08:34:37,480 - DEBUG - Row appended for chat file: WhatsApp Chat with Allen EWYL22E0762.txt
# 2024-01-03 08:34:37,803 - DEBUG - Row appended for chat file: WhatsApp Chat with Alson EWYL22E0675.txt
# 2024-01-03 08:34:38,048 - DEBUG - Row appended for chat file: WhatsApp Chat with Anesu EWYL22E0418.txt
# 2024-01-03 08:34:38,331 - DEBUG - Row appended for chat file: WhatsApp Chat with Anotida EWYL23E0165.txt
# 2024-01-03 08:34:38,599 - DEBUG - Row appended for chat file: WhatsApp Chat with Anotidaishe EWYL23E0378.txt
# 2024-01-03 08:34:38,949 - DEBUG - Row appended for chat file: WhatsApp Chat with Ashley EWYL22E0726.txt
# 2024-01-03 08:34:39,331 - DEBUG - Row appended for chat file: WhatsApp Chat with Ayanda EWYL23E0703.txt
# 2024-01-03 08:34:39,631 - DEBUG - Row appended for chat file: WhatsApp Chat with Bathandile EWYL22E0577.txt
# 2024-01-03 08:34:40,047 - DEBUG - Row appended for chat file: WhatsApp Chat with Benjamin EWYL23E1044.txt
# 2024-01-03 08:34:40,380 - DEBUG - Row appended for chat file: WhatsApp Chat with Beverly EWYL22E1177.txt
# 2024-01-03 08:34:40,736 - DEBUG - Row appended for chat file: WhatsApp Chat with Bhekinkosi EWYL22E0840.txt
# 2024-01-03 08:34:41,031 - DEBUG - Row appended for chat file: WhatsApp Chat with Blessing EWYL22E1325.txt
# 2024-01-03 08:34:41,349 - DEBUG - Row appended for chat file: WhatsApp Chat with Brenda EWYL22E1282.txt
# 2024-01-03 08:34:41,627 - DEBUG - Row appended for chat file: WhatsApp Chat with Bright EWYL23E0153.txt
# 2024-01-03 08:34:41,893 - DEBUG - Row appended for chat file: WhatsApp Chat with Charlene EWYL23E0608.txt
# 2024-01-03 08:34:42,159 - DEBUG - Row appended for chat file: WhatsApp Chat with CHIKONDI EWYL23E0333.txt
# 2024-01-03 08:34:42,405 - DEBUG - Row appended for chat file: WhatsApp Chat with CHINAZVO EWYL22E0873.txt
# 2024-01-03 08:34:42,712 - DEBUG - Row appended for chat file: WhatsApp Chat with Cinderella EWYL23E0067.txt
# 2024-01-03 08:34:42,962 - DEBUG - Row appended for chat file: WhatsApp Chat with Colleen EWYL22E0929.txt
# 2024-01-03 08:34:43,372 - DEBUG - Row appended for chat file: WhatsApp Chat with Dylan EWYL23E0140.txt
# 2024-01-03 08:34:43,834 - DEBUG - Row appended for chat file: WhatsApp Chat with Eleanor EWYL22E0996.txt
# 2024-01-03 08:34:44,258 - DEBUG - Row appended for chat file: WhatsApp Chat with Enock EWYL23E0363.txt
# 2024-01-03 08:34:44,660 - DEBUG - Row appended for chat file: WhatsApp Chat with Getrude EWYL23E1062.txt
# 2024-01-03 08:34:44,939 - DEBUG - Row appended for chat file: WhatsApp Chat with Isheanesu EWYL22E1294.txt
# 2024-01-03 08:34:45,219 - DEBUG - Row appended for chat file: WhatsApp Chat with Jenipher EWYL22E0685.txt
# 2024-01-03 08:34:45,502 - DEBUG - Row appended for chat file: WhatsApp Chat with Jonathan EWYL23E0310.txt
# 2024-01-03 08:34:45,760 - DEBUG - Row appended for chat file: WhatsApp Chat with Kirsten EWYL22E0961.txt
# 2024-01-03 08:34:46,011 - DEBUG - Row appended for chat file: WhatsApp Chat with Kundai EWYL22E0828.txt
# 2024-01-03 08:34:46,277 - DEBUG - Row appended for chat file: WhatsApp Chat with Kupakwashe EWYL23E0939.txt
# 2024-01-03 08:34:46,575 - DEBUG - Row appended for chat file: WhatsApp Chat with Leonora EWYL23E0129.txt
# 2024-01-03 08:34:46,869 - DEBUG - Row appended for chat file: WhatsApp Chat with LISA EWYL22E0237.txt
# 2024-01-03 08:34:47,194 - DEBUG - Row appended for chat file: WhatsApp Chat with Loice EWYL22E1310.txt
# 2024-01-03 08:34:47,508 - DEBUG - Row appended for chat file: WhatsApp Chat with Lucia EWYL22E1322.txt
# 2024-01-03 08:34:47,835 - DEBUG - Row appended for chat file: WhatsApp Chat with Makanaka EWYL22E0918.txt
# 2024-01-03 08:34:48,269 - DEBUG - Row appended for chat file: WhatsApp Chat with Mangoma EWYL23E1040.txt
# 2024-01-03 08:34:48,581 - DEBUG - Row appended for chat file: WhatsApp Chat with Mbalenhle EWYL23E0069.txt
# 2024-01-03 08:34:48,915 - DEBUG - Row appended for chat file: WhatsApp Chat with Melisa EWYL23E0145.txt
# 2024-01-03 08:34:49,336 - DEBUG - Row appended for chat file: WhatsApp Chat with Michael EWYL23E0994.txt
# 2024-01-03 08:34:49,741 - DEBUG - Row appended for chat file: WhatsApp Chat with Mitchell EWYL23E0325.txt
# 2024-01-03 08:34:50,034 - DEBUG - Row appended for chat file: WhatsApp Chat with Moreblessing EWYL23E0520.txt
# 2024-01-03 08:34:50,357 - DEBUG - Row appended for chat file: WhatsApp Chat with Nathan EWYL23E0218.txt
# 2024-01-03 08:34:50,761 - DEBUG - Row appended for chat file: WhatsApp Chat with Nathanael EWYL22E1319.txt
# 2024-01-03 08:34:51,077 - DEBUG - Row appended for chat file: WhatsApp Chat with Nicole EWYL22E0025.txt
# 2024-01-03 08:34:51,398 - DEBUG - Row appended for chat file: WhatsApp Chat with Nicole EWYL23E0178.txt
# 2024-01-03 08:34:51,710 - DEBUG - Row appended for chat file: WhatsApp Chat with Nigel EWYL23E0738.txt
# 2024-01-03 08:34:52,003 - DEBUG - Row appended for chat file: WhatsApp Chat with Nyasha EWYL23E0540.txt
# 2024-01-03 08:34:52,360 - DEBUG - Row appended for chat file: WhatsApp Chat with Nyungu EWYL23E1084.txt
# 2024-01-03 08:34:52,691 - DEBUG - Row appended for chat file: WhatsApp Chat with Oliver EWYL23E1057.txt
# 2024-01-03 08:34:52,997 - DEBUG - Row appended for chat file: WhatsApp Chat with Panashe EWYL23E0674.txt
# 2024-01-03 08:34:53,404 - DEBUG - Row appended for chat file: WhatsApp Chat with Patience EWYL23E0298.txt
# 2024-01-03 08:34:53,726 - DEBUG - Row appended for chat file: WhatsApp Chat with Pauline EWYL23E0047.txt
# 2024-01-03 08:34:54,019 - DEBUG - Row appended for chat file: WhatsApp Chat with Rejoice EWYL22E0803.txt
# 2024-01-03 08:34:54,326 - DEBUG - Row appended for chat file: WhatsApp Chat with Reward EWYL22E0292.txt
# 2024-01-03 08:34:54,678 - DEBUG - Row appended for chat file: WhatsApp Chat with Richmore EWYL23E0931.txt
# 2024-01-03 08:34:55,036 - DEBUG - Row appended for chat file: WhatsApp Chat with Ruth EWYL23E0184.txt
# 2024-01-03 08:34:55,333 - DEBUG - Row appended for chat file: WhatsApp Chat with Sasha EWYL23E0235.txt
# 2024-01-03 08:34:55,634 - DEBUG - Row appended for chat file: WhatsApp Chat with Shalom EWYL23E0187.txt
# 2024-01-03 08:34:55,963 - DEBUG - Row appended for chat file: WhatsApp Chat with Sharmaine EWYL23E1030.txt
# 2024-01-03 08:34:56,279 - DEBUG - Row appended for chat file: WhatsApp Chat with Sibongile EWYL23E0041.txt
# 2024-01-03 08:34:56,566 - DEBUG - Row appended for chat file: WhatsApp Chat with Sikhululekile EWYL23E0108.txt
# 2024-01-03 08:34:56,961 - DEBUG - Row appended for chat file: WhatsApp Chat with Tadiwa EWYL23E0107.txt
# 2024-01-03 08:34:57,282 - DEBUG - Row appended for chat file: WhatsApp Chat with Tadiwa EWYL23E1065.txt
# 2024-01-03 08:34:57,579 - DEBUG - Row appended for chat file: WhatsApp Chat with Tadiwanashe EWYL22E0420.txt
# 2024-01-03 08:34:57,912 - DEBUG - Row appended for chat file: WhatsApp Chat with Tadiwanashe EWYL23E0943.txt
# 2024-01-03 08:34:58,307 - DEBUG - Row appended for chat file: WhatsApp Chat with Tafadzwa EWYL22E0128.txt
# 2024-01-03 08:34:58,584 - DEBUG - Row appended for chat file: WhatsApp Chat with Takudzwa EWYL22E0792.txt
# 2024-01-03 08:34:58,882 - DEBUG - Row appended for chat file: WhatsApp Chat with Takudzwa EWYL22E1184.txt
# 2024-01-03 08:34:59,322 - DEBUG - Row appended for chat file: WhatsApp Chat with Takudzwa EWYL23E0155.txt
# 2024-01-03 08:34:59,679 - DEBUG - Row appended for chat file: WhatsApp Chat with Takudzwa EWYL23E0688.txt
# 2024-01-03 08:35:00,047 - DEBUG - Row appended for chat file: WhatsApp Chat with Takudzwa EWYL23E1059.txt
# 2024-01-03 08:35:00,443 - DEBUG - Row appended for chat file: WhatsApp Chat with Talent EWYL22E0263.txt
# 2024-01-03 08:35:00,843 - DEBUG - Row appended for chat file: WhatsApp Chat with TANATSWA EWYL23E0910.txt
# 2024-01-03 08:35:01,226 - DEBUG - Row appended for chat file: WhatsApp Chat with Tanyaradzwa EWYL23E0301.txt
# 2024-01-03 08:35:01,547 - DEBUG - Row appended for chat file: WhatsApp Chat with Tapiwanashe EWYL23E0858.txt
# 2024-01-03 08:35:01,927 - DEBUG - Row appended for chat file: WhatsApp Chat with Tatenda EWYL23E0034.txt
# 2024-01-03 08:35:02,281 - DEBUG - Row appended for chat file: WhatsApp Chat with Tavongashe EWYL23E0511.txt
# 2024-01-03 08:35:02,626 - DEBUG - Row appended for chat file: WhatsApp Chat with Tawanda EWYL23E0945.txt
# 2024-01-03 08:35:02,947 - DEBUG - Row appended for chat file: WhatsApp Chat with Thomas EWYL23E1007.txt
# 2024-01-03 08:35:03,235 - DEBUG - Row appended for chat file: WhatsApp Chat with Tinashe EWYL22E0704.txt
# 2024-01-03 08:35:03,611 - DEBUG - Row appended for chat file: WhatsApp Chat with Tinashe EWYL23E1080.txt
# 2024-01-03 08:35:04,100 - DEBUG - Row appended for chat file: WhatsApp Chat with Trish EWYL23E1035.txt
# 2024-01-03 08:35:04,524 - DEBUG - Row appended for chat file: WhatsApp Chat with Twanani EWYL23E0599.txt
# 2024-01-03 08:35:04,956 - DEBUG - Row appended for chat file: WhatsApp Chat with Adelaide EWYL23E1006.txt
# 2024-01-03 08:35:05,374 - DEBUG - Row appended for chat file: WhatsApp Chat with Adrian EWYL23E0744.txt
# 2024-01-03 08:35:05,712 - DEBUG - Row appended for chat file: WhatsApp Chat with Allan EWYL23E0455.txt
# 2024-01-03 08:35:06,047 - DEBUG - Row appended for chat file: WhatsApp Chat with Anna EWYL23E0806.txt
# 2024-01-03 08:35:06,395 - DEBUG - Row appended for chat file: WhatsApp Chat with Anne EWYL23E0249.txt
# 2024-01-03 08:35:06,743 - DEBUG - Row appended for chat file: WhatsApp Chat with Anopa EWYL23E0772.txt
# 2024-01-03 08:35:07,079 - DEBUG - Row appended for chat file: WhatsApp Chat with BekithembaJNR EWYL23E1012.txt
# 2024-01-03 08:35:07,435 - DEBUG - Row appended for chat file: WhatsApp Chat with Benevolence EWYL23E0464.txt
# 2024-01-03 08:35:07,776 - DEBUG - Row appended for chat file: WhatsApp Chat with Betty EWYL23E1054.txt
# 2024-01-03 08:35:08,140 - DEBUG - Row appended for chat file: WhatsApp Chat with Blessing EWYL23E0338.txt
# 2024-01-03 08:35:08,464 - DEBUG - Row appended for chat file: WhatsApp Chat with Blessing EWYL23E0682.txt
# 2024-01-03 08:35:08,832 - DEBUG - Row appended for chat file: WhatsApp Chat with Blessing EWYL23E0729.txt
# 2024-01-03 08:35:09,186 - DEBUG - Row appended for chat file: WhatsApp Chat with Bongani EWYL23E1021.txt
# 2024-01-03 08:35:09,538 - DEBUG - Row appended for chat file: WhatsApp Chat with Bright EWYL22E0899.txt
# 2024-01-03 08:35:09,913 - DEBUG - Row appended for chat file: WhatsApp Chat with Bright EWYL23E0328.txt
# 2024-01-03 08:35:10,236 - DEBUG - Row appended for chat file: WhatsApp Chat with Cleave EWYL23E1069.txt
# 2024-01-03 08:35:10,581 - DEBUG - Row appended for chat file: WhatsApp Chat with Comfort EWYL23E0897.txt
# 2024-01-03 08:35:10,944 - DEBUG - Row appended for chat file: WhatsApp Chat with Covenant EWYL23E0238.txt
# 2024-01-03 08:35:11,321 - DEBUG - Row appended for chat file: WhatsApp Chat with Delight EWYL23E0697.txt
# 2024-01-03 08:35:11,651 - DEBUG - Row appended for chat file: WhatsApp Chat with Delight EWYL23E0948.txt
# 2024-01-03 08:35:11,955 - DEBUG - Row appended for chat file: WhatsApp Chat with Devine EWYL23E0146.txt
# 2024-01-03 08:35:12,310 - DEBUG - Row appended for chat file: WhatsApp Chat with Elshaddai EWYL23E0204.txt
# 2024-01-03 08:35:12,660 - DEBUG - Row appended for chat file: WhatsApp Chat with Emmanuel EWYL23E0741.txt
# 2024-01-03 08:35:13,013 - DEBUG - Row appended for chat file: WhatsApp Chat with Faith EWYL23E0244.txt
# 2024-01-03 08:35:13,346 - DEBUG - Row appended for chat file: WhatsApp Chat with Faith EWYL23E0740.txt
# 2024-01-03 08:35:13,712 - DEBUG - Row appended for chat file: WhatsApp Chat with Francesca EWYL23E0581.txt
# 2024-01-03 08:35:14,283 - DEBUG - Row appended for chat file: WhatsApp Chat with Garreth EWYL22E0096.txt
# 2024-01-03 08:35:14,935 - DEBUG - Row appended for chat file: WhatsApp Chat with Geilen EWYL23E0509.txt
# 2024-01-03 08:35:15,396 - DEBUG - Row appended for chat file: WhatsApp Chat with George EWYL23E1028.txt
# 2024-01-03 08:35:15,779 - DEBUG - Row appended for chat file: WhatsApp Chat with Godfrey EWYL23E0270.txt
# 2024-01-03 08:35:16,133 - DEBUG - Row appended for chat file: WhatsApp Chat with Gombe EWYL23E0849.txt
# 2024-01-03 08:35:16,561 - DEBUG - Row appended for chat file: WhatsApp Chat with Grace EWYL23E1014.txt
# 2024-01-03 08:35:16,925 - DEBUG - Row appended for chat file: WhatsApp Chat with Gracious EWYL23E0223.txt
# 2024-01-03 08:35:17,253 - DEBUG - Row appended for chat file: WhatsApp Chat with Hilda EWYL23E0916.txt
# 2024-01-03 08:35:17,568 - DEBUG - Row appended for chat file: WhatsApp Chat with Kabongwe EWYL23E0954.txt
# 2024-01-03 08:35:17,930 - DEBUG - Row appended for chat file: WhatsApp Chat with Kelvin EWYL23E0966.txt
# 2024-01-03 08:35:18,258 - DEBUG - Row appended for chat file: WhatsApp Chat with Kendie EWYL22E0562.txt
# 2024-01-03 08:35:18,572 - DEBUG - Row appended for chat file: WhatsApp Chat with Kimberly EWYL23E0828.txt
# 2024-01-03 08:35:18,927 - DEBUG - Row appended for chat file: WhatsApp Chat with Kunashe EWYL23E0883.txt
# 2024-01-03 08:35:19,278 - DEBUG - Row appended for chat file: WhatsApp Chat with Linet EWYL22E1044.txt
# 2024-01-03 08:35:19,624 - DEBUG - Row appended for chat file: WhatsApp Chat with Luckson EWYL23E0856.txt
# 2024-01-03 08:35:19,984 - DEBUG - Row appended for chat file: WhatsApp Chat with Lyncon EWYL23E0590.txt
# 2024-01-03 08:35:20,329 - DEBUG - Row appended for chat file: WhatsApp Chat with Lynnte EWYL22E0400.txt
# 2024-01-03 08:35:20,644 - DEBUG - Row appended for chat file: WhatsApp Chat with Malcolm EWYL23E0654.txt
# 2024-01-03 08:35:21,019 - DEBUG - Row appended for chat file: WhatsApp Chat with Marc EWYL23E0115.txt
# 2024-01-03 08:35:21,415 - DEBUG - Row appended for chat file: WhatsApp Chat with Memory EWYL23E0756.txt
# 2024-01-03 08:35:21,794 - DEBUG - Row appended for chat file: WhatsApp Chat with Milan EWYL23E0847.txt
# 2024-01-03 08:35:22,135 - DEBUG - Row appended for chat file: WhatsApp Chat with Mthuli EWYL23E0227.txt
# 2024-01-03 08:35:22,464 - DEBUG - Row appended for chat file: WhatsApp Chat with Munyaradzi EWYL23E1052.txt
# 2024-01-03 08:35:22,826 - DEBUG - Row appended for chat file: WhatsApp Chat with Mwenje EWYL23E0694.txt
# 2024-01-03 08:35:23,167 - DEBUG - Row appended for chat file: WhatsApp Chat with Natasha EWYL23E0684.txt
# 2024-01-03 08:35:23,497 - DEBUG - Row appended for chat file: WhatsApp Chat with Nicole EWYL23E0718.txt
# 2024-01-03 08:35:23,964 - DEBUG - Row appended for chat file: WhatsApp Chat with Nicole EWYL23E1068.txt
# 2024-01-03 08:35:24,431 - DEBUG - Row appended for chat file: WhatsApp Chat with Nicole EWYL23E1081.txt
# 2024-01-03 08:35:24,965 - DEBUG - Row appended for chat file: WhatsApp Chat with Nyasha EWYL23E0655.txt
# 2024-01-03 08:35:25,863 - DEBUG - Row appended for chat file: WhatsApp Chat with Panashe EWYL23E0291.txt
# 2024-01-03 08:35:26,473 - DEBUG - Row appended for chat file: WhatsApp Chat with Patience EWYL23E0870.txt
# 2024-01-03 08:35:26,957 - DEBUG - Row appended for chat file: WhatsApp Chat with Phelistas EWYL23E0829.txt
# 2024-01-03 08:35:27,578 - DEBUG - Row appended for chat file: WhatsApp Chat with Pritchard EWYL23E0321.txt
# 2024-01-03 08:35:28,181 - DEBUG - Row appended for chat file: WhatsApp Chat with Rangarirai EWYL23E0400.txt
# 2024-01-03 08:35:28,821 - DEBUG - Row appended for chat file: WhatsApp Chat with Rufaro EWYL23E0594.txt
# 2024-01-03 08:35:29,331 - DEBUG - Row appended for chat file: WhatsApp Chat with Rutendo EWYL23E1051.txt
# 2024-01-03 08:35:29,637 - DEBUG - Row appended for chat file: WhatsApp Chat with Sarah EWYL23E0864.txt
# 2024-01-03 08:35:30,044 - DEBUG - Row appended for chat file: WhatsApp Chat with Sarah EWYL23E0980.txt
# 2024-01-03 08:35:30,341 - DEBUG - Row appended for chat file: WhatsApp Chat with Scott EWYL22E0507.txt
# 2024-01-03 08:35:30,673 - DEBUG - Row appended for chat file: WhatsApp Chat with Shalom EWYL23E0717.txt
# 2024-01-03 08:35:31,080 - DEBUG - Row appended for chat file: WhatsApp Chat with Shepherd EWYL23E0578.txt
# 2024-01-03 08:35:31,612 - DEBUG - Row appended for chat file: WhatsApp Chat with Silibaziso EWYL23E0522.txt
# 2024-01-03 08:35:32,020 - DEBUG - Row appended for chat file: WhatsApp Chat with Stanley EWYL23E1036.txt
# 2024-01-03 08:35:32,304 - DEBUG - Row appended for chat file: WhatsApp Chat with Surprise EWYL23E1027.txt
# 2024-01-03 08:35:32,619 - DEBUG - Row appended for chat file: WhatsApp Chat with Sydwell EWYL23E0739.txt
# 2024-01-03 08:35:32,870 - DEBUG - Row appended for chat file: WhatsApp Chat with Tafadzwa EWYL23E0484.txt
# 2024-01-03 08:35:33,136 - DEBUG - Row appended for chat file: WhatsApp Chat with Takundanashe EWYL23E0357.txt
# 2024-01-03 08:35:33,386 - DEBUG - Row appended for chat file: WhatsApp Chat with Tanatswa EWYL23E0265.txt
# 2024-01-03 08:35:33,636 - DEBUG - Row appended for chat file: WhatsApp Chat with Tanyaradzwa EWYL23E0202.txt
# 2024-01-03 08:35:33,902 - DEBUG - Row appended for chat file: WhatsApp Chat with Tapiwanashe EWYL23E0356.txt
# 2024-01-03 08:35:34,154 - DEBUG - Row appended for chat file: WhatsApp Chat with Tatenda EWYL23E0550.txt
# 2024-01-03 08:35:34,392 - DEBUG - Row appended for chat file: WhatsApp Chat with Tatenda EWYL23E0627.txt
# 2024-01-03 08:35:34,673 - DEBUG - Row appended for chat file: WhatsApp Chat with Tatenda EWYL23E0817.txt
# 2024-01-03 08:35:34,924 - DEBUG - Row appended for chat file: WhatsApp Chat with Tawananyasha EWYL23E0962.txt
# 2024-01-03 08:35:35,176 - DEBUG - Row appended for chat file: WhatsApp Chat with Tawanda EWYL23E0777.txt
# 2024-01-03 08:35:35,411 - DEBUG - Row appended for chat file: WhatsApp Chat with TEHILA EWYL23E0467.txt
# 2024-01-03 08:35:35,677 - DEBUG - Row appended for chat file: WhatsApp Chat with Thandoluhle EWYL23E0942.txt
# 2024-01-03 08:35:35,914 - DEBUG - Row appended for chat file: WhatsApp Chat with Tinashe EWYL22E0943.txt
# 2024-01-03 08:35:36,227 - DEBUG - Row appended for chat file: WhatsApp Chat with TINEVIMBO EWYL23E0456.txt
# 2024-01-03 08:35:36,493 - DEBUG - Row appended for chat file: WhatsApp Chat with Tinotenda EWYL23E0385.txt
# 2024-01-03 08:35:36,743 - DEBUG - Row appended for chat file: WhatsApp Chat with Tinotenda EWYL23E1095.txt
# 2024-01-03 08:35:36,993 - DEBUG - Row appended for chat file: WhatsApp Chat with Valentine EWYL23E0872.txt
# 2024-01-03 08:35:37,261 - DEBUG - Row appended for chat file: WhatsApp Chat with Victor EWYL23E0822.txt
# 2024-01-03 08:35:37,498 - DEBUG - Row appended for chat file: WhatsApp Chat with Wellington EWYL22E1109.txt
# 2024-01-03 08:35:37,733 - DEBUG - Row appended for chat file: WhatsApp Chat with Wilma EWYL23E0811.txt
# 2024-01-03 08:35:37,985 - DEBUG - Row appended for chat file: WhatsApp Chat with Winnie EWYL23E0480.txt
# 2024-01-03 08:35:38,253 - DEBUG - Row appended for chat file: WhatsApp Chat with Abigail EWYL22E1215.txt
# 2024-01-03 08:35:38,503 - DEBUG - Row appended for chat file: WhatsApp Chat with Albert EWYL23E0769.txt
# 2024-01-03 08:35:38,756 - DEBUG - Row appended for chat file: WhatsApp Chat with ANESU EWYL23E0361.txt
# 2024-01-03 08:35:38,992 - DEBUG - Row appended for chat file: WhatsApp Chat with Anesu EWYL23E0721.txt
# 2024-01-03 08:35:39,212 - DEBUG - Row appended for chat file: WhatsApp Chat with Anna EWYL21E0882.txt
# 2024-01-03 08:35:39,449 - DEBUG - Row appended for chat file: WhatsApp Chat with Anna EWYL22E0289.txt
# 2024-01-03 08:35:39,684 - DEBUG - Row appended for chat file: WhatsApp Chat with Ariel EWYL23E0815.txt
# 2024-01-03 08:35:39,934 - DEBUG - Row appended for chat file: WhatsApp Chat with Ashley EWYL22E1236.txt
# 2024-01-03 08:35:40,187 - DEBUG - Row appended for chat file: WhatsApp Chat with Ashley EWYL23E0735.txt
# 2024-01-03 08:35:40,440 - DEBUG - Row appended for chat file: WhatsApp Chat with Audrey EWYL22E1080.txt
# 2024-01-03 08:35:40,675 - DEBUG - Row appended for chat file: WhatsApp Chat with Audrey EWYL23E0790.txt
# 2024-01-03 08:35:40,912 - DEBUG - Row appended for chat file: WhatsApp Chat with Bethel EWYL23E0313.txt
# 2024-01-03 08:35:41,149 - DEBUG - Row appended for chat file: WhatsApp Chat with Blessing EWYL23E1005.txt
# 2024-01-03 08:35:41,414 - DEBUG - Row appended for chat file: WhatsApp Chat with Bradley EWYL23E1046.txt
# 2024-01-03 08:35:41,666 - DEBUG - Row appended for chat file: WhatsApp Chat with Brendon EWYL23E0013.txt
# 2024-01-03 08:35:41,964 - DEBUG - Row appended for chat file: WhatsApp Chat with Bridget EWYL23E0746.txt
# 2024-01-03 08:35:42,200 - DEBUG - Row appended for chat file: WhatsApp Chat with Catherine EWYL23E0300.txt
# 2024-01-03 08:35:42,451 - DEBUG - Row appended for chat file: WhatsApp Chat with Charles EWYL23E0091.txt
# 2024-01-03 08:35:42,687 - DEBUG - Row appended for chat file: WhatsApp Chat with Cleopatra EWYL22E1223.txt
# 2024-01-03 08:35:42,953 - DEBUG - Row appended for chat file: WhatsApp Chat with CRYSTAL EWYL22E0541.txt
# 2024-01-03 08:35:43,203 - DEBUG - Row appended for chat file: WhatsApp Chat with Cuthbert EWYL22E0531.txt
# 2024-01-03 08:35:43,440 - DEBUG - Row appended for chat file: WhatsApp Chat with David EWYL23E0048.txt
# 2024-01-03 08:35:43,677 - DEBUG - Row appended for chat file: WhatsApp Chat with Delight EWYL22E0967.txt
# 2024-01-03 08:35:43,912 - DEBUG - Row appended for chat file: WhatsApp Chat with DELIGHT EWYL23E0086.txt
# 2024-01-03 08:35:44,162 - DEBUG - Row appended for chat file: WhatsApp Chat with Denzel EWYL23E0490.txt
# 2024-01-03 08:35:44,397 - DEBUG - Row appended for chat file: WhatsApp Chat with Dephine EWYL22E0579.txt
# 2024-01-03 08:35:44,647 - DEBUG - Row appended for chat file: WhatsApp Chat with Derylin EWYL23E0863.txt
# 2024-01-03 08:35:44,929 - DEBUG - Row appended for chat file: WhatsApp Chat with Edward EWYL23E1019.txt
# 2024-01-03 08:35:45,195 - DEBUG - Row appended for chat file: WhatsApp Chat with Elizabeth EWYL23E0179.txt
# 2024-01-03 08:35:45,430 - DEBUG - Row appended for chat file: WhatsApp Chat with George EWYL22E0992.txt
# 2024-01-03 08:35:45,665 - DEBUG - Row appended for chat file: WhatsApp Chat with Glory EWYL23E0796.txt
# 2024-01-03 08:35:45,902 - DEBUG - Row appended for chat file: WhatsApp Chat with Gugulethu EWYL23E0566.txt
# 2024-01-03 08:35:46,153 - DEBUG - Row appended for chat file: WhatsApp Chat with Ishmael EWYL23E0374.txt
# 2024-01-03 08:35:46,375 - DEBUG - Row appended for chat file: WhatsApp Chat with Jeston EWYL22E0671.txt
# 2024-01-03 08:35:46,609 - DEBUG - Row appended for chat file: WhatsApp Chat with Katelyn EWYL22E0584.txt
# 2024-01-03 08:35:46,891 - DEBUG - Row appended for chat file: WhatsApp Chat with Kelvin EWYL22E0047.txt
# 2024-01-03 08:35:47,125 - DEBUG - Row appended for chat file: WhatsApp Chat with Kevin EWYL23E0868.txt
# 2024-01-03 08:35:47,424 - DEBUG - Row appended for chat file: WhatsApp Chat with Lenny EWYL23E0895.txt
# 2024-01-03 08:35:47,724 - DEBUG - Row appended for chat file: WhatsApp Chat with Lorent EWYL22E0724.txt
# 2024-01-03 08:35:47,991 - DEBUG - Row appended for chat file: WhatsApp Chat with Lyvinia EWYL22E0981.txt
# 2024-01-03 08:35:48,290 - DEBUG - Row appended for chat file: WhatsApp Chat with Master EWYL23E0576.txt
# 2024-01-03 08:35:48,556 - DEBUG - Row appended for chat file: WhatsApp Chat with Matai EWYL22E0593.txt
# 2024-01-03 08:35:48,792 - DEBUG - Row appended for chat file: WhatsApp Chat with Mazvita EWYL22E0659.txt
# 2024-01-03 08:35:49,043 - DEBUG - Row appended for chat file: WhatsApp Chat with Mbuso EWYL23E0768.txt
# 2024-01-03 08:35:49,295 - DEBUG - Row appended for chat file: WhatsApp Chat with McKrion EWYL23E0515.txt
# 2024-01-03 08:35:49,577 - DEBUG - Row appended for chat file: WhatsApp Chat with Melody EWYL23E1038.txt
# 2024-01-03 08:35:49,798 - DEBUG - Row appended for chat file: WhatsApp Chat with Mercy EWYL23E0136.txt
# 2024-01-03 08:35:50,048 - DEBUG - Row appended for chat file: WhatsApp Chat with Monalisa EWYL23E0731.txt
# 2024-01-03 08:35:50,314 - DEBUG - Row appended for chat file: WhatsApp Chat with Moregrace EWYL23E0088.txt
# 2024-01-03 08:35:50,581 - DEBUG - Row appended for chat file: WhatsApp Chat with Munyaradzi EWYL23E0386.txt
# 2024-01-03 08:35:50,847 - DEBUG - Row appended for chat file: WhatsApp Chat with Mwenya EWYL23E0902.txt
# 2024-01-03 08:35:51,131 - DEBUG - Row appended for chat file: WhatsApp Chat with Namwaka EWYL23E1050.txt
# 2024-01-03 08:35:51,366 - DEBUG - Row appended for chat file: WhatsApp Chat with Nicassio EWYL22E0536.txt
# 2024-01-03 08:35:51,616 - DEBUG - Row appended for chat file: WhatsApp Chat with Nicole EWYL23E0098.txt
# 2024-01-03 08:35:51,882 - DEBUG - Row appended for chat file: WhatsApp Chat with Nokutenda EWYL23E0824.txt
# 2024-01-03 08:35:52,149 - DEBUG - Row appended for chat file: WhatsApp Chat with Nokuthaba EWYL22E0645.txt
# 2024-01-03 08:35:52,400 - DEBUG - Row appended for chat file: WhatsApp Chat with Nyashadzashe EWYL23E0028.txt
# 2024-01-03 08:35:52,683 - DEBUG - Row appended for chat file: WhatsApp Chat with Olivia EWYL22E1244.txt
# 2024-01-03 08:35:52,933 - DEBUG - Row appended for chat file: WhatsApp Chat with Panashe EWYL22E0474.txt
# 2024-01-03 08:35:53,186 - DEBUG - Row appended for chat file: WhatsApp Chat with Pardon EWYL23E0329.txt
# 2024-01-03 08:35:53,439 - DEBUG - Row appended for chat file: WhatsApp Chat with Patience EWYL23E0394.txt
# 2024-01-03 08:35:53,689 - DEBUG - Row appended for chat file: WhatsApp Chat with Patrick EWYL22E0592.txt
# 2024-01-03 08:35:53,970 - DEBUG - Row appended for chat file: WhatsApp Chat with Plaxedes EWYL22E0919.txt
# 2024-01-03 08:35:54,205 - DEBUG - Row appended for chat file: WhatsApp Chat with Praise EWYL23E0804.txt
# 2024-01-03 08:35:54,455 - DEBUG - Row appended for chat file: WhatsApp Chat with Precious EWYL23E0757.txt
# 2024-01-03 08:35:54,706 - DEBUG - Row appended for chat file: WhatsApp Chat with Priscillar EWYL22E0798.txt
# 2024-01-03 08:35:54,942 - DEBUG - Row appended for chat file: WhatsApp Chat with Promise EWYL22E1029.txt
# 2024-01-03 08:35:55,273 - DEBUG - Row appended for chat file: WhatsApp Chat with Promise EWYL23E0200.txt
# 2024-01-03 08:35:55,508 - DEBUG - Row appended for chat file: WhatsApp Chat with Prosper EWYL23E0587.txt
# 2024-01-03 08:35:55,758 - DEBUG - Row appended for chat file: WhatsApp Chat with Providence EWYL23E0488.txt
# 2024-01-03 08:35:55,993 - DEBUG - Row appended for chat file: WhatsApp Chat with Ropafadzo EWYL23E0229.txt
# 2024-01-03 08:35:56,228 - DEBUG - Row appended for chat file: WhatsApp Chat with Rudorwashe EWYL23E0128.txt
# 2024-01-03 08:35:56,480 - DEBUG - Row appended for chat file: WhatsApp Chat with Rumbidzai EWYL22E0628.txt
# 2024-01-03 08:35:56,717 - DEBUG - Row appended for chat file: WhatsApp Chat with Rutendo EWYL23E0845.txt
# 2024-01-03 08:35:57,030 - DEBUG - Row appended for chat file: WhatsApp Chat with Ruvimbo EWYL23E1016.txt
# 2024-01-03 08:35:57,296 - DEBUG - Row appended for chat file: WhatsApp Chat with Salma EWYL23E0208.txt
# 2024-01-03 08:35:57,514 - DEBUG - Row appended for chat file: WhatsApp Chat with Samantha EWYL23E0324.txt
# 2024-01-03 08:35:57,767 - DEBUG - Row appended for chat file: WhatsApp Chat with Senelisiwe EWYL22E0239.txt
# 2024-01-03 08:35:58,019 - DEBUG - Row appended for chat file: WhatsApp Chat with Shalom EWYL23E0026.txt
# 2024-01-03 08:35:58,306 - DEBUG - Row appended for chat file: WhatsApp Chat with Shalom EWYL23E1018.txt
# 2024-01-03 08:35:58,541 - DEBUG - Row appended for chat file: WhatsApp Chat with Sharon EWYL23E0497.txt
# 2024-01-03 08:35:58,778 - DEBUG - Row appended for chat file: WhatsApp Chat with Sibonginkosi EWYL23E0528.txt
# 2024-01-03 08:35:59,014 - DEBUG - Row appended for chat file: WhatsApp Chat with Stina EWYL23E0256.txt
# 2024-01-03 08:35:59,249 - DEBUG - Row appended for chat file: WhatsApp Chat with Tadiwanashe EWYL23E0095.txt
# 2024-01-03 08:35:59,499 - DEBUG - Row appended for chat file: WhatsApp Chat with Takudzwa EWYL23E0197.txt
# 2024-01-03 08:35:59,749 - DEBUG - Row appended for chat file: WhatsApp Chat with Takudzwa EWYL23E0774.txt
# 2024-01-03 08:35:59,969 - DEBUG - Row appended for chat file: WhatsApp Chat with Talent EWYL23E0649.txt
# 2024-01-03 08:36:00,222 - DEBUG - Row appended for chat file: WhatsApp Chat with TANAKA EWYL22E1052.txt
# 2024-01-03 08:36:00,489 - DEBUG - Row appended for chat file: WhatsApp Chat with Tanaka EWYL23E0370.txt
# 2024-01-03 08:36:00,742 - DEBUG - Row appended for chat file: WhatsApp Chat with Tanatswa EWYL23E0462.txt
# 2024-01-03 08:36:00,992 - DEBUG - Row appended for chat file: WhatsApp Chat with Tanyaradzwa EWYL22E0700.txt
# 2024-01-03 08:36:01,257 - DEBUG - Row appended for chat file: WhatsApp Chat with Tapiwanashe EWYL22E0517.txt
# 2024-01-03 08:36:01,494 - DEBUG - Row appended for chat file: WhatsApp Chat with TARIRO EWYL22E0205.txt
# 2024-01-03 08:36:01,730 - DEBUG - Row appended for chat file: WhatsApp Chat with Tashinga EWYL23E0460.txt
# 2024-01-03 08:36:02,012 - DEBUG - Row appended for chat file: WhatsApp Chat with Tashinga EWYL23E0517.txt
# 2024-01-03 08:36:02,246 - DEBUG - Row appended for chat file: WhatsApp Chat with Tashinga EWYL23E0794.txt
# 2024-01-03 08:36:02,512 - DEBUG - Row appended for chat file: WhatsApp Chat with Tatenda EWYL22E0845.txt
# 2024-01-03 08:36:02,748 - DEBUG - Row appended for chat file: WhatsApp Chat with Tawanda EWYL22E0652.txt
# 2024-01-03 08:36:02,983 - DEBUG - Row appended for chat file: WhatsApp Chat with Tecla EWYL22E0095.txt
# 2024-01-03 08:36:03,265 - DEBUG - Row appended for chat file: WhatsApp Chat with Tendai EWYL23E0335.txt
# 2024-01-03 08:36:03,564 - DEBUG - Row appended for chat file: WhatsApp Chat with Tiara EWYL23E0282.txt
# 2024-01-03 08:36:03,831 - DEBUG - Row appended for chat file: WhatsApp Chat with Trinity EWYL23E0100.txt
# 2024-01-03 08:36:04,100 - DEBUG - Row appended for chat file: WhatsApp Chat with Uphold EWYL23E0562.txt
# 2024-01-03 08:36:04,397 - DEBUG - Row appended for chat file: WhatsApp Chat with Vinah EWYL22E0844.txt
# 2024-01-03 08:36:04,647 - DEBUG - Row appended for chat file: WhatsApp Chat with Vincent EWYL22E1141.txt
# 2024-01-03 08:36:04,901 - DEBUG - Row appended for chat file: WhatsApp Chat with Walusungu EWYL22E0600.txt
# 2024-01-03 08:36:05,182 - DEBUG - Row appended for chat file: WhatsApp Chat with Whitney EWYL23E0836.txt
# 2024-01-03 08:36:05,458 - DEBUG - Row appended for chat file: WhatsApp Chat with Yankho EWYL22E0488.txt
# 2024-01-03 08:36:05,693 - DEBUG - Row appended for chat file: WhatsApp Chat with Yvonne EWYL22E1050.txt
# 2024-01-03 08:36:05,927 - DEBUG - Row appended for chat file: WhatsApp Chat with Agape EWYL23E0979.txt
# 2024-01-03 08:36:06,194 - DEBUG - Row appended for chat file: WhatsApp Chat with Ammy EWYL22E1242.txt
# 2024-01-03 08:36:06,491 - DEBUG - Row appended for chat file: WhatsApp Chat with Andrew EWYL21E0459.txt
# 2024-01-03 08:36:06,944 - DEBUG - Row appended for chat file: WhatsApp Chat with Anesu EWYL22E1129.txt
# 2024-01-03 08:36:07,319 - DEBUG - Row appended for chat file: WhatsApp Chat with Artwell EWYL23E0547.txt
# 2024-01-03 08:36:07,976 - DEBUG - Row appended for chat file: WhatsApp Chat with Audrey EWYL22E0747.txt
# 2024-01-03 08:36:08,461 - DEBUG - Row appended for chat file: WhatsApp Chat with Audrey EWYL22E0890.txt
# 2024-01-03 08:36:08,909 - DEBUG - Row appended for chat file: WhatsApp Chat with Beauty EWYL23E0009.txt
# 2024-01-03 08:36:09,364 - DEBUG - Row appended for chat file: WhatsApp Chat with Benvolence EWYL23E0242.txt
# 2024-01-03 08:36:09,811 - DEBUG - Row appended for chat file: WhatsApp Chat with Blessing EWYL22E1300.txt
# 2024-01-03 08:36:10,142 - DEBUG - Row appended for chat file: WhatsApp Chat with Blessing EWYL23E0156.txt
# 2024-01-03 08:36:10,424 - DEBUG - Row appended for chat file: WhatsApp Chat with Bright EWYL22E1216.txt
# 2024-01-03 08:36:10,690 - DEBUG - Row appended for chat file: WhatsApp Chat with Brooke EWYL23E0198.txt
# 2024-01-03 08:36:10,925 - DEBUG - Row appended for chat file: WhatsApp Chat with Caabilo EWYL23E0144.txt
# 2024-01-03 08:36:11,177 - DEBUG - Row appended for chat file: WhatsApp Chat with Chelsy EWYL23E0750.txt
# 2024-01-03 08:36:11,428 - DEBUG - Row appended for chat file: WhatsApp Chat with Clayton EWYL22E0436.txt
# 2024-01-03 08:36:11,696 - DEBUG - Row appended for chat file: WhatsApp Chat with Danai EWYL23E0751.txt
# 2024-01-03 08:36:11,946 - DEBUG - Row appended for chat file: WhatsApp Chat with Deborah EWYL23E0585.txt
# 2024-01-03 08:36:12,197 - DEBUG - Row appended for chat file: WhatsApp Chat with Emmanuel EWYL23E0171.txt
# 2024-01-03 08:36:12,449 - DEBUG - Row appended for chat file: WhatsApp Chat with Ethan EWYL22E0530.txt
# 2024-01-03 08:36:12,700 - DEBUG - Row appended for chat file: WhatsApp Chat with Fanuel EWYL22E0893.txt
# 2024-01-03 08:36:12,934 - DEBUG - Row appended for chat file: WhatsApp Chat with Fidelis EWYL22E0558.txt
# 2024-01-03 08:36:13,186 - DEBUG - Row appended for chat file: WhatsApp Chat with Fortunate EWYL22E1075.txt
# 2024-01-03 08:36:13,469 - DEBUG - Row appended for chat file: WhatsApp Chat with Freda EWYL23E0996.txt
# 2024-01-03 08:36:13,713 - DEBUG - Row appended for chat file: WhatsApp Chat with Gervais EWYL22E1186.txt
# 2024-01-03 08:36:13,963 - DEBUG - Row appended for chat file: WhatsApp Chat with Hazel EWYL22E0944.txt
# 2024-01-03 08:36:14,288 - DEBUG - Row appended for chat file: WhatsApp Chat with Henriata EWYL22E1139.txt
# 2024-01-03 08:36:14,541 - DEBUG - Row appended for chat file: WhatsApp Chat with Hester EWYL22E1303.txt
# 2024-01-03 08:36:14,775 - DEBUG - Row appended for chat file: WhatsApp Chat with Hilton EWYL22E1040.txt
# 2024-01-03 08:36:15,010 - DEBUG - Row appended for chat file: WhatsApp Chat with Innocent EWYL22E0879.txt
# 2024-01-03 08:36:15,261 - DEBUG - Row appended for chat file: WhatsApp Chat with Irvine EWYL23E0112.txt
# 2024-01-03 08:36:15,511 - DEBUG - Row appended for chat file: WhatsApp Chat with Jamie EWYL23E0154.txt
# 2024-01-03 08:36:15,748 - DEBUG - Row appended for chat file: WhatsApp Chat with Karen EWYL22E0647.txt
# 2024-01-03 08:36:15,984 - DEBUG - Row appended for chat file: WhatsApp Chat with Kelvin EWYL23E0911.txt
# 2024-01-03 08:36:16,218 - DEBUG - Row appended for chat file: WhatsApp Chat with Kirsty EWYL23E0457.txt
# 2024-01-03 08:36:16,453 - DEBUG - Row appended for chat file: WhatsApp Chat with Kubiku EWYL23E0799.txt
# 2024-01-03 08:36:16,721 - DEBUG - Row appended for chat file: WhatsApp Chat with Kudakwashe EWYL22E0465.txt
# 2024-01-03 08:36:16,956 - DEBUG - Row appended for chat file: WhatsApp Chat with Kudzai EWYL22E1116.txt
# 2024-01-03 08:36:17,225 - DEBUG - Row appended for chat file: WhatsApp Chat with Leiann EWYL23E0191.txt
# 2024-01-03 08:36:17,443 - DEBUG - Row appended for chat file: WhatsApp Chat with Leroy EWYL22E0990.txt
# 2024-01-03 08:36:17,709 - DEBUG - Row appended for chat file: WhatsApp Chat with Lordwell EWYL23E0760.txt
# 2024-01-03 08:36:17,960 - DEBUG - Row appended for chat file: WhatsApp Chat with Lushomo EWYL23E0598.txt
# 2024-01-03 08:36:18,194 - DEBUG - Row appended for chat file: WhatsApp Chat with Lydia EWYL23E0234.txt
# 2024-01-03 08:36:18,446 - DEBUG - Row appended for chat file: WhatsApp Chat with Makaita EWYL23E0969.txt
# 2024-01-03 08:36:18,698 - DEBUG - Row appended for chat file: WhatsApp Chat with Makanaka EWYL22E0814.txt
# 2024-01-03 08:36:18,932 - DEBUG - Row appended for chat file: WhatsApp Chat with Malvern EWYL23E1066.txt
# 2024-01-03 08:36:19,229 - DEBUG - Row appended for chat file: WhatsApp Chat with Mark EWYL23E0409.txt
# 2024-01-03 08:36:19,573 - DEBUG - Row appended for chat file: WhatsApp Chat with Mascelyn EWYL22E0755.txt
# 2024-01-03 08:36:19,857 - DEBUG - Row appended for chat file: WhatsApp Chat with Memory EWYL23E0596.txt
# 2024-01-03 08:36:20,123 - DEBUG - Row appended for chat file: WhatsApp Chat with Michelle EWYL22E0756.txt
# 2024-01-03 08:36:20,422 - DEBUG - Row appended for chat file: WhatsApp Chat with Michelle EWYL22E1039.txt
# 2024-01-03 08:36:20,672 - DEBUG - Row appended for chat file: WhatsApp Chat with Mphatso EWYL23E0395.txt
# 2024-01-03 08:36:20,923 - DEBUG - Row appended for chat file: WhatsApp Chat with MUFAROWASHE EWYL23E0070.txt
# 2024-01-03 08:36:21,188 - DEBUG - Row appended for chat file: WhatsApp Chat with Munashe EWYL23E0226.txt
# 2024-01-03 08:36:21,475 - DEBUG - Row appended for chat file: WhatsApp Chat with Munashe EWYL23E1034.txt
# 2024-01-03 08:36:21,742 - DEBUG - Row appended for chat file: WhatsApp Chat with Munyaradzi EWYL22E0836.txt
# 2024-01-03 08:36:21,993 - DEBUG - Row appended for chat file: WhatsApp Chat with Mwango EWYL23E0965.txt
# 2024-01-03 08:36:22,243 - DEBUG - Row appended for chat file: WhatsApp Chat with Natalie EWYL23E0040.txt
# 2024-01-03 08:36:22,495 - DEBUG - Row appended for chat file: WhatsApp Chat with Natalie EWYL23E0556.txt
# 2024-01-03 08:36:22,747 - DEBUG - Row appended for chat file: WhatsApp Chat with Natasha EWYL23E0074.txt
# 2024-01-03 08:36:22,999 - DEBUG - Row appended for chat file: WhatsApp Chat with Nissi EWYL23E0650.txt
# 2024-01-03 08:36:23,265 - DEBUG - Row appended for chat file: WhatsApp Chat with Nkazimulo EWYL23E0803.txt
# 2024-01-03 08:36:23,518 - DEBUG - Row appended for chat file: WhatsApp Chat with Nyasha EWYL22E1290.txt
# 2024-01-03 08:36:23,753 - DEBUG - Row appended for chat file: WhatsApp Chat with Nyasha EWYL23E0802.txt
# 2024-01-03 08:36:24,006 - DEBUG - Row appended for chat file: WhatsApp Chat with Nyasha EWYL23E1063.txt
# 2024-01-03 08:36:24,273 - DEBUG - Row appended for chat file: WhatsApp Chat with Nyashadzashe EWYL23E1045.txt
# 2024-01-03 08:36:24,526 - DEBUG - Row appended for chat file: WhatsApp Chat with Persistance EWYL21E0574.txt
# 2024-01-03 08:36:24,761 - DEBUG - Row appended for chat file: WhatsApp Chat with Phyllis EWYL23E0281.txt
# 2024-01-03 08:36:25,011 - DEBUG - Row appended for chat file: WhatsApp Chat with Praise EWYL23E0174.txt
# 2024-01-03 08:36:25,248 - DEBUG - Row appended for chat file: WhatsApp Chat with Praise EWYL23E0453.txt
# 2024-01-03 08:36:25,501 - DEBUG - Row appended for chat file: WhatsApp Chat with Pride EWYL23E0010.txt
# 2024-01-03 08:36:25,751 - DEBUG - Row appended for chat file: WhatsApp Chat with Primerose EWYL23E0061.txt
# 2024-01-03 08:36:26,002 - DEBUG - Row appended for chat file: WhatsApp Chat with Prosper EWYL23E0775.txt
# 2024-01-03 08:36:26,236 - DEBUG - Row appended for chat file: WhatsApp Chat with Rejoice EWYL22E1133.txt
# 2024-01-03 08:36:26,470 - DEBUG - Row appended for chat file: WhatsApp Chat with Resistance EWYL23E0195.txt
# 2024-01-03 08:36:26,705 - DEBUG - Row appended for chat file: WhatsApp Chat with Revelation EWYL23E0533.txt
# 2024-01-03 08:36:26,941 - DEBUG - Row appended for chat file: WhatsApp Chat with Rivhathihi EWYL23E0275.txt
# 2024-01-03 08:36:27,178 - DEBUG - Row appended for chat file: WhatsApp Chat with Ropafadzo EWYL22E0737.txt
# 2024-01-03 08:36:27,428 - DEBUG - Row appended for chat file: WhatsApp Chat with Ruvarashe EWYL22E1061.txt
# 2024-01-03 08:36:27,664 - DEBUG - Row appended for chat file: WhatsApp Chat with Salma EWYL23E0861.txt
# 2024-01-03 08:36:27,914 - DEBUG - Row appended for chat file: WhatsApp Chat with Shammah EWYL23E0212.txt
# 2024-01-03 08:36:28,150 - DEBUG - Row appended for chat file: WhatsApp Chat with Shantel EWYL23E0054.txt
# 2024-01-03 08:36:28,397 - DEBUG - Row appended for chat file: WhatsApp Chat with Sharon EWYL23E0203.txt
# 2024-01-03 08:36:28,632 - DEBUG - Row appended for chat file: WhatsApp Chat with Shingirai EWYL23E0991.txt
# 2024-01-03 08:36:28,869 - DEBUG - Row appended for chat file: WhatsApp Chat with Sibonginkhosi EWYL22E0928.txt
# 2024-01-03 08:36:29,104 - DEBUG - Row appended for chat file: WhatsApp Chat with Sibonokuhle EWYL23E0482.txt
# 2024-01-03 08:36:29,340 - DEBUG - Row appended for chat file: WhatsApp Chat with Silas EWYL23E0930.txt
# 2024-01-03 08:36:29,616 - DEBUG - Row appended for chat file: WhatsApp Chat with Sinqobile EWYL23E0838.txt
# 2024-01-03 08:36:29,853 - DEBUG - Row appended for chat file: WhatsApp Chat with Tadiwanashe EWYL23E0037.txt
# 2024-01-03 08:36:30,090 - DEBUG - Row appended for chat file: WhatsApp Chat with Tadiwanashe EWYL23E0795.txt
# 2024-01-03 08:36:30,340 - DEBUG - Row appended for chat file: WhatsApp Chat with Tafadzwa EWYL23E0250.txt
# 2024-01-03 08:36:30,607 - DEBUG - Row appended for chat file: WhatsApp Chat with TAFARA EWYL22E1329.txt
# 2024-01-03 08:36:30,841 - DEBUG - Row appended for chat file: WhatsApp Chat with Takudzwa EWYL22E1015.txt
# 2024-01-03 08:36:31,076 - DEBUG - Row appended for chat file: WhatsApp Chat with Takudzwa EWYL23E0123.txt
# 2024-01-03 08:36:31,310 - DEBUG - Row appended for chat file: WhatsApp Chat with Takudzwa EWYL23E0169.txt
# 2024-01-03 08:36:31,551 - DEBUG - Row appended for chat file: WhatsApp Chat with Tanaka EWYL23E0779.txt
# 2024-01-03 08:36:31,807 - DEBUG - Row appended for chat file: WhatsApp Chat with Tanatswanashe EWYL23E0749.txt
# 2024-01-03 08:36:32,075 - DEBUG - Row appended for chat file: WhatsApp Chat with Tanisha EWYL23E1067.txt
# 2024-01-03 08:36:32,295 - DEBUG - Row appended for chat file: WhatsApp Chat with Tanyaradzwa EWYL23E0167.txt
# 2024-01-03 08:36:32,546 - DEBUG - Row appended for chat file: WhatsApp Chat with Tapiwanashe EWYL22E0906.txt
# 2024-01-03 08:36:32,765 - DEBUG - Row appended for chat file: WhatsApp Chat with Tatenda EWYL23E0111.txt
# 2024-01-03 08:36:33,015 - DEBUG - Row appended for chat file: WhatsApp Chat with Tatenda EWYL23E0261.txt
# 2024-01-03 08:36:33,265 - DEBUG - Row appended for chat file: WhatsApp Chat with Tawananyasha EWYL23E1071.txt
# 2024-01-03 08:36:33,500 - DEBUG - Row appended for chat file: WhatsApp Chat with Tendaishe EWYL23E0664.txt
# 2024-01-03 08:36:33,737 - DEBUG - Row appended for chat file: WhatsApp Chat with Tinotenda EWYL22E1096.txt
# 2024-01-03 08:36:33,990 - DEBUG - Row appended for chat file: WhatsApp Chat with Tinotenda EWYL23E0219.txt
# 2024-01-03 08:36:34,275 - DEBUG - Row appended for chat file: WhatsApp Chat with Unathi EWYL23E1029.txt
# 2024-01-03 08:36:34,510 - DEBUG - Row appended for chat file: WhatsApp Chat with Vimbai EWYL23E0919.txt
# 2024-01-03 08:36:34,745 - DEBUG - Row appended for chat file: WhatsApp Chat with Vimbainashe EWYL23E1064.txt
# 2024-01-03 08:36:34,980 - DEBUG - Row appended for chat file: WhatsApp Chat with Whatfor EWYL23E0900.txt
# 2024-01-03 08:36:35,251 - DEBUG - Row appended for chat file: WhatsApp Chat with Wilbert EWYL22E1136.txt
# 2024-01-03 08:36:35,551 - DEBUG - Row appended for chat file: WhatsApp Chat with Witness EWYL23E0766.txt
# 2024-01-03 08:36:35,803 - DEBUG - Row appended for chat file: WhatsApp Chat with Zhylani EWYL23E1011.txt
# 2024-01-03 08:36:36,047 - DEBUG - Row appended for chat file: WhatsApp Chat with Acious EWYL22E0970.txt
# 2024-01-03 08:36:36,340 - DEBUG - Row appended for chat file: WhatsApp Chat with Akatendeka EWYL23E0481.txt
# 2024-01-03 08:36:36,606 - DEBUG - Row appended for chat file: WhatsApp Chat with Aletta EWYL22E0775.txt
# 2024-01-03 08:36:36,859 - DEBUG - Row appended for chat file: WhatsApp Chat with Alison EWYL23E0332.txt
# 2024-01-03 08:36:37,111 - DEBUG - Row appended for chat file: WhatsApp Chat with Blessing EWYL23E0389.txt
# 2024-01-03 08:36:37,375 - DEBUG - Row appended for chat file: WhatsApp Chat with Bridget EWYL23E0853.txt
# 2024-01-03 08:36:37,627 - DEBUG - Row appended for chat file: WhatsApp Chat with Chanice EWYL23E0375.txt
# 2024-01-03 08:36:37,880 - DEBUG - Row appended for chat file: WhatsApp Chat with Charity EWYL22E0910.txt
# 2024-01-03 08:36:38,125 - DEBUG - Row appended for chat file: WhatsApp Chat with Charmaine EWYL23E0734.txt
# 2024-01-03 08:36:38,386 - DEBUG - Row appended for chat file: WhatsApp Chat with Chiedza EWYL22E0810.txt
# 2024-01-03 08:36:38,626 - DEBUG - Row appended for chat file: WhatsApp Chat with Clarisah EWYL22E0766.txt
# 2024-01-03 08:36:38,876 - DEBUG - Row appended for chat file: WhatsApp Chat with Clemence EWYL22E0972.txt
# 2024-01-03 08:36:39,124 - DEBUG - Row appended for chat file: WhatsApp Chat with Deborah EWYL22E0835.txt
# 2024-01-03 08:36:39,357 - DEBUG - Row appended for chat file: WhatsApp Chat with Ecclesiastic EWYL23E0459.txt
# 2024-01-03 08:36:39,609 - DEBUG - Row appended for chat file: WhatsApp Chat with Ethan EWYL22E0941.txt
# 2024-01-03 08:36:39,859 - DEBUG - Row appended for chat file: WhatsApp Chat with Evan EWYL23E0369.txt
# 2024-01-03 08:36:40,096 - DEBUG - Row appended for chat file: WhatsApp Chat with Faith EWYL23E0602.txt
# 2024-01-03 08:36:40,331 - DEBUG - Row appended for chat file: WhatsApp Chat with Gertrude EWYL23E0524.txt
# 2024-01-03 08:36:40,615 - DEBUG - Row appended for chat file: WhatsApp Chat with Gugulethu EWYL23E0485.txt
# 2024-01-03 08:36:40,853 - DEBUG - Row appended for chat file: WhatsApp Chat with Hazel EWYL22E0966.txt
# 2024-01-03 08:36:41,087 - DEBUG - Row appended for chat file: WhatsApp Chat with Hazel EWYL22E1305.txt
# 2024-01-03 08:36:41,324 - DEBUG - Row appended for chat file: WhatsApp Chat with John EWYL22E0696.txt
# 2024-01-03 08:36:41,575 - DEBUG - Row appended for chat file: WhatsApp Chat with Joyce EWYL23E0857.txt
# 2024-01-03 08:36:41,826 - DEBUG - Row appended for chat file: WhatsApp Chat with Kelvin EWYL22E0956.txt
# 2024-01-03 08:36:42,047 - DEBUG - Row appended for chat file: WhatsApp Chat with Kelvin EWYL23E0302.txt
# 2024-01-03 08:36:42,300 - DEBUG - Row appended for chat file: WhatsApp Chat with Kudzaishe EWYL23E0743.txt
# 2024-01-03 08:36:42,543 - DEBUG - Row appended for chat file: WhatsApp Chat with Laiza EWYL23E1077.txt
# 2024-01-03 08:36:42,777 - DEBUG - Row appended for chat file: WhatsApp Chat with Leane EWYL23E0783.txt
# 2024-01-03 08:36:43,028 - DEBUG - Row appended for chat file: WhatsApp Chat with Lyosa EWYL23E0398.txt
# 2024-01-03 08:36:43,265 - DEBUG - Row appended for chat file: WhatsApp Chat with Magreth EWYL22E0838.txt
# 2024-01-03 08:36:43,500 - DEBUG - Row appended for chat file: WhatsApp Chat with Makanatsa EWYL22E1234.txt
# 2024-01-03 08:36:43,737 - DEBUG - Row appended for chat file: WhatsApp Chat with Mapalo EWYL23E0742.txt
# 2024-01-03 08:36:43,989 - DEBUG - Row appended for chat file: WhatsApp Chat with Melisa EWYL23E0709.txt
# 2024-01-03 08:36:44,240 - DEBUG - Row appended for chat file: WhatsApp Chat with Mitchell EWYL22E0991.txt
# 2024-01-03 08:36:44,474 - DEBUG - Row appended for chat file: WhatsApp Chat with Moline EWYL22E0664.txt
# 2024-01-03 08:36:44,710 - DEBUG - Row appended for chat file: WhatsApp Chat with Moreblessing EWYL22E0691.txt
# 2024-01-03 08:36:44,947 - DEBUG - Row appended for chat file: WhatsApp Chat with Muloongo EWYL23E0499.txt
# 2024-01-03 08:36:45,182 - DEBUG - Row appended for chat file: WhatsApp Chat with Munashe EWYL22E0606.txt
# 2024-01-03 08:36:45,418 - DEBUG - Row appended for chat file: WhatsApp Chat with Munashe EWYL22E0777.txt
# 2024-01-03 08:36:45,653 - DEBUG - Row appended for chat file: WhatsApp Chat with Nancy EWYL23E0489.txt
# 2024-01-03 08:36:45,903 - DEBUG - Row appended for chat file: WhatsApp Chat with Ngaakudzwe EWYL22E1311.txt
# 2024-01-03 08:36:46,184 - DEBUG - Row appended for chat file: WhatsApp Chat with Nkazimulo EWYL23E0680.txt
# 2024-01-03 08:36:46,402 - DEBUG - Row appended for chat file: WhatsApp Chat with Obidience EWYL22E1112.txt
# 2024-01-03 08:36:46,655 - DEBUG - Row appended for chat file: WhatsApp Chat with Panashe EWYL22E1077.txt
# 2024-01-03 08:36:46,905 - DEBUG - Row appended for chat file: WhatsApp Chat with Patience EWYL23E0862.txt
# 2024-01-03 08:36:47,142 - DEBUG - Row appended for chat file: WhatsApp Chat with Peter EWYL23E0818.txt
# 2024-01-03 08:36:47,378 - DEBUG - Row appended for chat file: WhatsApp Chat with Praise EWYL22E0920.txt
# 2024-01-03 08:36:47,615 - DEBUG - Row appended for chat file: WhatsApp Chat with Praymore EWYL23E0666.txt
# 2024-01-03 08:36:47,881 - DEBUG - Row appended for chat file: WhatsApp Chat with Precious EWYL22E0979.txt
# 2024-01-03 08:36:48,133 - DEBUG - Row appended for chat file: WhatsApp Chat with Precious EWYL22E1035.txt
# 2024-01-03 08:36:48,387 - DEBUG - Row appended for chat file: WhatsApp Chat with Precious EWYL23E0473.txt
# 2024-01-03 08:36:48,684 - DEBUG - Row appended for chat file: WhatsApp Chat with Pride EWYL23E1023.txt
# 2024-01-03 08:36:48,953 - DEBUG - Row appended for chat file: WhatsApp Chat with Primrose EWYL23E0759.txt
# 2024-01-03 08:36:49,191 - DEBUG - Row appended for chat file: WhatsApp Chat with Priviledge EWYL22E1164.txt
# 2024-01-03 08:36:49,413 - DEBUG - Row appended for chat file: WhatsApp Chat with Prosper EWYL23E0696.txt
# 2024-01-03 08:36:49,647 - DEBUG - Row appended for chat file: WhatsApp Chat with Providence EWYL23E0592.txt
# 2024-01-03 08:36:49,882 - DEBUG - Row appended for chat file: WhatsApp Chat with Rachel EWYL22E0932.txt
# 2024-01-03 08:36:50,119 - DEBUG - Row appended for chat file: WhatsApp Chat with Ratchel EWYL22E0779.txt
# 2024-01-03 08:36:50,369 - DEBUG - Row appended for chat file: WhatsApp Chat with Rhoda EWYL22E0988.txt
# ...
# 2024-01-03 08:39:49,035 - DEBUG - Row appended for chat file: WhatsApp Chat with Nkosinomusa Dile Dube  Edoofa(IE28_12)SR(1).txt
# 2024-01-03 08:39:49,365 - DEBUG - Row appended for chat file: WhatsApp Chat with Nokutenda_Edoofa(15_12)HP 2025(1).txt
# 2024-01-03 08:39:49,681 - DEBUG - Row appended for chat file: WhatsApp Chat with Panashe Chideme Edoofa (04_12) SZ 2025(1).txt
# 2024-01-03 08:39:50,025 - DEBUG - Row appended for chat file: WhatsApp Chat with Princess_Edoofa(21_09)HP(1).txt
# 2024-01-03 08:39:50,340 - DEBUG - Row appended for chat file: WhatsApp Chat with Ropafadzo Chindiya Edoofa (06_12) SZ(1).txt
# 2024-01-03 08:39:50,672 - DEBUG - Row appended for chat file: WhatsApp Chat with Samuel_DM01(15_11)HP(1).txt
# 2024-01-03 08:39:50,957 - DEBUG - Row appended for chat file: WhatsApp Chat with Serena Edoofa (20_12) SZ(1).txt
# 2024-01-03 08:39:51,320 - DEBUG - Row appended for chat file: WhatsApp Chat with Shamiso Chamusingarevi Edoofa (25_10) SZ(1).txt
# 2024-01-03 08:39:51,621 - DEBUG - Row appended for chat file: WhatsApp Chat with Shamma Malilwe Edoofa (22_11) SZ(1).txt
# 2024-01-03 08:39:51,936 - DEBUG - Row appended for chat file: WhatsApp Chat with Sharmaine Victoria Tore Edoofa (06_12) SZ 2025(1).txt
# 2024-01-03 08:39:52,249 - DEBUG - Row appended for chat file: WhatsApp Chat with Tadiwanashe Moyo Edoofa (05_12) SZ 2025(1).txt
# 2024-01-03 08:39:52,549 - DEBUG - Row appended for chat file: WhatsApp Chat with Tadiwanashe_Edoofa(27_11)HP(1).txt
# 2024-01-03 08:39:52,897 - DEBUG - Row appended for chat file: WhatsApp Chat with Takudzwa Chinyama Edoofa (22_11) SZ 2025(1).txt
# 2024-01-03 08:39:53,229 - DEBUG - Row appended for chat file: WhatsApp Chat with Tapuwanashe_EDOOFA(19_12)GJ(1).txt
# 2024-01-03 08:39:53,558 - DEBUG - Row appended for chat file: WhatsApp Chat with Tatiana Ruvimbo Kapungu Edoofa (25_10) SZ(1).txt
# 2024-01-03 08:39:53,858 - DEBUG - Row appended for chat file: WhatsApp Chat with Tinotenda_DM03(19_12)HP(1).txt
# 2024-01-03 08:39:54,190 - DEBUG - Row appended for chat file: WhatsApp Chat with Trish Lillian Nyamutsita Edoofa (30_11) SZ(1).txt
# 2024-01-03 08:39:54,458 - DEBUG - Row appended for chat file: WhatsApp Chat with Vanessa_SA(20_12)HP(1).txt
# 2024-01-03 08:39:54,759 - DEBUG - Row appended for chat file: WhatsApp Chat with Yolanda_Edoofa(15_12)HP(1).txt
# 2024-01-03 08:39:54,977 - DEBUG - Row appended for chat file: WhatsApp Chat with Adelaite Chinyerere Edoofa (13_12) SZ.txt
# 2024-01-03 08:39:55,182 - DEBUG - Row appended for chat file: WhatsApp Chat with Alice Muchara Edoofa (26_12) SZ.txt
# 2024-01-03 08:39:55,436 - DEBUG - Row appended for chat file: WhatsApp Chat with Auther Munhamo Edoofa (30_11) SZ.txt
# 2024-01-03 08:39:55,656 - DEBUG - Row appended for chat file: WhatsApp Chat with Bella Mutema Edoofa (30_11) SZ.txt
# 2024-01-03 08:39:55,973 - DEBUG - Row appended for chat file: WhatsApp Chat with Brighton Mudzukwa Edoofa (21_11) SZ 2025.txt
# 2024-01-03 08:39:56,194 - DEBUG - Row appended for chat file: WhatsApp Chat with Chibakwe Trish Edoofa (28_12) SZ.txt
# 2024-01-03 08:39:56,476 - DEBUG - Row appended for chat file: WhatsApp Chat with Chido Natalie Mberikwazvo Edoofa (20_12) SZ.txt
# 2024-01-03 08:39:56,775 - DEBUG - Row appended for chat file: WhatsApp Chat with Chiminya Rutendo H Edoofa (06_12) SZ.txt
# 2024-01-03 08:39:56,996 - DEBUG - Row appended for chat file: WhatsApp Chat with Chinyama Denzel Edoofa (26_12) SZ.txt
# 2024-01-03 08:39:57,280 - DEBUG - Row appended for chat file: WhatsApp Chat with Chirimhanzi Tinodaishe Edoofa (05_12) SZ 2025.txt
# 2024-01-03 08:39:57,580 - DEBUG - Row appended for chat file: WhatsApp Chat with Chiturumani Takudzwa Edoofa (05_12) SZ.txt
# 2024-01-03 08:39:57,817 - DEBUG - Row appended for chat file: WhatsApp Chat with Daryl T. Maenzanise Edoofa (20_12) SZ.txt
# 2024-01-03 08:39:58,102 - DEBUG - Row appended for chat file: WhatsApp Chat with Dhinda Tanyaradzwa Edoofa (18_12) SZ.txt
# 2024-01-03 08:39:58,291 - DEBUG - Row appended for chat file: WhatsApp Chat with Esther Princess Moyo Edoofa (02_01) SZ.txt
# 2024-01-03 08:39:58,560 - DEBUG - Row appended for chat file: WhatsApp Chat with Ethina Ngwenyama Edoofa (28_12) SZ 2025.txt
# 2024-01-03 08:39:58,813 - DEBUG - Row appended for chat file: WhatsApp Chat with Ezra Kawisi Edoofa (18_12) SZ.txt
# 2024-01-03 08:39:59,050 - DEBUG - Row appended for chat file: WhatsApp Chat with Faith Chama Edoofa (20_12) SZ.txt
# 2024-01-03 08:39:59,316 - DEBUG - Row appended for chat file: WhatsApp Chat with Fortune Magwenzi Edoofa (08_12) SZ.txt
# 2024-01-03 08:39:59,506 - DEBUG - Row appended for chat file: WhatsApp Chat with Gangazha Emily M Edoofa (02_01) SZ.txt
# 2024-01-03 08:39:59,727 - DEBUG - Row appended for chat file: WhatsApp Chat with James Mzila Edoofa (26_12) SZ.txt
# 2024-01-03 08:40:00,043 - DEBUG - Row appended for chat file: WhatsApp Chat with Joshua Tatenda Chipindu Edoofa (22_11) SZ 2025.txt
# 2024-01-03 08:40:00,233 - DEBUG - Row appended for chat file: WhatsApp Chat with Kamal Moyo Edoofa (02_01) SZ.txt
# 2024-01-03 08:40:00,438 - DEBUG - Row appended for chat file: WhatsApp Chat with Kasanda Blessings Edoofa (26_12) SZ.txt
# 2024-01-03 08:40:00,641 - DEBUG - Row appended for chat file: WhatsApp Chat with Kokera Derrick Edoofa (28_12) SZ.txt
# 2024-01-03 08:40:01,001 - DEBUG - Row appended for chat file: WhatsApp Chat with Kudakwashe Terrence Mabhegede Edoofa (19_12) SZ.txt
# 2024-01-03 08:40:01,282 - DEBUG - Row appended for chat file: WhatsApp Chat with Linda Malaba Edoofa (26_12) SZ.txt
# 2024-01-03 08:40:01,595 - DEBUG - Row appended for chat file: WhatsApp Chat with Lloyd T Tarwirei Edoofa (26_12) SZ.txt
# 2024-01-03 08:40:01,954 - DEBUG - Row appended for chat file: WhatsApp Chat with Manyonganise Komborero Edoofa (19_12) SZ.txt
# 2024-01-03 08:40:02,239 - DEBUG - Row appended for chat file: WhatsApp Chat with Masamba Salisha C Edoofa (04_12) SZ.txt
# 2024-01-03 08:40:02,460 - DEBUG - Row appended for chat file: WhatsApp Chat with Matongo Brighton Edoofa (26_12) SZ.txt
# 2024-01-03 08:40:02,726 - DEBUG - Row appended for chat file: WhatsApp Chat with Moyo Emma Edoofa (20_12) SZ.txt
# 2024-01-03 08:40:02,948 - DEBUG - Row appended for chat file: WhatsApp Chat with Mufuratirwa Grace Edoofa (08_12) SZ.txt
# 2024-01-03 08:40:03,153 - DEBUG - Row appended for chat file: WhatsApp Chat with Munashe Oniswence Tomy Edoofa (02_01) SZ.txt
# 2024-01-03 08:40:03,389 - DEBUG - Row appended for chat file: WhatsApp Chat with Munga Praise Edoofa (26_12) SZ.txt
# 2024-01-03 08:40:03,641 - DEBUG - Row appended for chat file: WhatsApp Chat with Mutsigiri Rufaro Edoofa (28_12) SZ.txt
# 2024-01-03 08:40:03,956 - DEBUG - Row appended for chat file: WhatsApp Chat with Mutsvairo Tanatswanashe Belinda Edoofa (19_12) SZ.txt
# 2024-01-03 08:40:04,316 - DEBUG - Row appended for chat file: WhatsApp Chat with Mwaiwathu Tatenda Nyendwa Edoofa (20_12) SZ.txt
# 2024-01-03 08:40:04,592 - DEBUG - Row appended for chat file: WhatsApp Chat with Nazare Daphane Edoofa (02_01) SZ.txt
# 2024-01-03 08:40:04,903 - DEBUG - Row appended for chat file: WhatsApp Chat with Njanji Ruvarashe S Edoofa (28_11) SZ 2025.txt
# 2024-01-03 08:40:05,154 - DEBUG - Row appended for chat file: WhatsApp Chat with Nokutenda Praise Mtoko Edoofa (13_12) SZ.txt
# 2024-01-03 08:40:05,502 - DEBUG - Row appended for chat file: WhatsApp Chat with Nyasha Chipwanya Edoofa (26_12) SZ.txt
# 2024-01-03 08:40:05,756 - DEBUG - Row appended for chat file: WhatsApp Chat with Persevere Mudavanhu Edoofa (28_12) SZ.txt
# 2024-01-03 08:40:06,133 - DEBUG - Row appended for chat file: WhatsApp Chat with Phiri Simphiwe Edoofa (08_12) SZ.txt
# 2024-01-03 08:40:06,478 - DEBUG - Row appended for chat file: WhatsApp Chat with Praise Rumbidzai Gutsa Edoofa (28_12) SZ 2025.txt
# 2024-01-03 08:40:06,787 - DEBUG - Row appended for chat file: WhatsApp Chat with Proceed Farai Dhanda Edoofa (08_12) SZ.txt
# 2024-01-03 08:40:07,069 - DEBUG - Row appended for chat file: WhatsApp Chat with Salem Mubvumbi Edoofa (26_12) SZ 2025.txt
# 2024-01-03 08:40:07,369 - DEBUG - Row appended for chat file: WhatsApp Chat with Sepo Akamandisa Edoofa (20_12) SZ.txt
# 2024-01-03 08:40:07,682 - DEBUG - Row appended for chat file: WhatsApp Chat with Similo Claire Thebe Edoofa (26_12) SZ.txt
# 2024-01-03 08:40:07,934 - DEBUG - Row appended for chat file: WhatsApp Chat with Stanley Nemashapa Edoofa (19_12) SZ.txt
# 2024-01-03 08:40:08,247 - DEBUG - Row appended for chat file: WhatsApp Chat with Tadisaishe Monica Mukarati Edoofa (11_12) SZ.txt
# 2024-01-03 08:40:08,579 - DEBUG - Row appended for chat file: WhatsApp Chat with Tafara Mukucha Edoofa (23_11) SZ 2025.txt
# 2024-01-03 08:40:08,831 - DEBUG - Row appended for chat file: WhatsApp Chat with Tafara Rooney Ekely Mombili Edoofa (18_12) SZ.txt
# 2024-01-03 08:40:09,146 - DEBUG - Row appended for chat file: WhatsApp Chat with Taizya Namwela Edoofa (28_12) SZ.txt
# 2024-01-03 08:40:09,477 - DEBUG - Row appended for chat file: WhatsApp Chat with Takunda Samantha Tinarwo Edoofa (18_11) SZ.txt
# 2024-01-03 08:40:09,837 - DEBUG - Row appended for chat file: WhatsApp Chat with Tanaka Dhenhera Edoofa (05_12) SZ 2025.txt
# 2024-01-03 08:40:10,088 - DEBUG - Row appended for chat file: WhatsApp Chat with Tatenda Marimo Edoofa (26_12) SZ.txt
# 2024-01-03 08:40:10,369 - DEBUG - Row appended for chat file: WhatsApp Chat with Tshuma Nokuthaba M Edoofa (18_12) SZ.txt
# 2024-01-03 08:40:10,777 - DEBUG - Row appended for chat file: WhatsApp Chat with Tsungi Nyasha Mushapaidze Edoofa (27_11) SZ 2025.txt
# 2024-01-03 08:40:11,044 - DEBUG - Row appended for chat file: WhatsApp Chat with Wellington Mnyama Edoofa (02_01) SZ.txt
# 2024-01-03 08:40:11,310 - DEBUG - Row appended for chat file: WhatsApp Chat with Wilbert Simango Edoofa (26_12) SZ.txt
# 2024-01-03 08:40:11,716 - DEBUG - Row appended for chat file: WhatsApp Chat with Wonekai Ornate Edoofa (26_12) SZ.txt
# 2024-01-03 08:40:12,232 - DEBUG - Row appended for chat file: WhatsApp Chat with Zalma F Mapepa Edoofa (11_12) SZ.txt
# 2024-01-03 08:40:12,623 - DEBUG - Row appended for chat file: WhatsApp Chat with Abigail Mudau_EDOOFA(03_01)SM24.txt
# 2024-01-03 08:40:13,320 - DEBUG - Row appended for chat file: WhatsApp Chat with Allan Nyapfumbi_EDOOFA(19_12)GS.txt
# 2024-01-03 08:40:13,700 - DEBUG - Row appended for chat file: WhatsApp Chat with Anotida_EDOOFAMHS(17_11)TR.txt
# 2024-01-03 08:40:13,982 - DEBUG - Row appended for chat file: WhatsApp Chat with Ashley Nyambi_EA(20_12)TR.txt
# 2024-01-03 08:40:14,298 - DEBUG - Row appended for chat file: WhatsApp Chat with Carlos_EA(21_11)TR.txt
# 2024-01-03 08:40:14,551 - DEBUG - Row appended for chat file: WhatsApp Chat with Cassandra Nyathi_EDOOFAIE(29_12)SM23.txt
# 2024-01-03 08:40:14,942 - DEBUG - Row appended for chat file: WhatsApp Chat with Cathrine MnyulwaIA_EA(21_12)TR.txt
# 2024-01-03 08:40:15,365 - DEBUG - Row appended for chat file: WhatsApp Chat with Chantell Zvenyika_EDOOFA(22_11)SM23.txt
# 2024-01-03 08:40:15,774 - DEBUG - Row appended for chat file: WhatsApp Chat with CHIREMBWE C_EA(22_12)TR.txt
# 2024-01-03 08:40:16,166 - DEBUG - Row appended for chat file: WhatsApp Chat with Claudius Ziyamba_EA(21_12)TR.txt
# 2024-01-03 08:40:16,386 - DEBUG - Row appended for chat file: WhatsApp Chat with Davintyne Chikanyanza_EDOOFAMHS(03_01)SM24.txt
# 2024-01-03 08:40:16,792 - DEBUG - Row appended for chat file: WhatsApp Chat with Deborah Kambatika_EDOOFAZAMBNGS(19_12)GS.txt
# 2024-01-03 08:40:17,059 - DEBUG - Row appended for chat file: WhatsApp Chat with Desire Musarivana_EDOOFA(07_12)SM23.txt
# 2024-01-03 08:40:17,529 - DEBUG - Row appended for chat file: WhatsApp Chat with DIVINE NOKUTENDA_EA(12_12)TR.txt
# 2024-01-03 08:40:17,735 - DEBUG - Row appended for chat file: WhatsApp Chat with Edinah Chipenya_EA(28_12)TR.txt
# 2024-01-03 08:40:18,159 - DEBUG - Row appended for chat file: WhatsApp Chat with Fumani Chauke_EDOOFA(18_12)GS.txt
# 2024-01-03 08:40:18,582 - DEBUG - Row appended for chat file: WhatsApp Chat with Gift Munsaka_EA(13_12)TR.txt
# 2024-01-03 08:40:18,958 - DEBUG - Row appended for chat file: WhatsApp Chat with Hilary Mukwesha_EDOOFA(29_12)SM23.txt
# 2024-01-03 08:40:19,476 - DEBUG - Row appended for chat file: WhatsApp Chat with Luyando Siasulingana_EA(15_12)TR.txt
# 2024-01-03 08:40:19,837 - DEBUG - Row appended for chat file: WhatsApp Chat with Mapesho Kakwata_EDOOFAZAMB(03_01)SM24.txt
# 2024-01-03 08:40:20,255 - DEBUG - Row appended for chat file: WhatsApp Chat with Mercy Chivhumba_EA(21_12)TR.txt
# 2024-01-03 08:40:20,882 - DEBUG - Row appended for chat file: WhatsApp Chat with Muyeyi Isabel_EDOOFAZAMBNGS(14_12)SM23.txt
# 2024-01-03 08:40:21,210 - DEBUG - Row appended for chat file: WhatsApp Chat with Mzimazisi Nombembe_EA(20_12)TR.txt
# 2024-01-03 08:40:21,416 - DEBUG - Row appended for chat file: WhatsApp Chat with Naomi Zulu_EDOOFAZAMBNGS(03_01)SM24.txt
# 2024-01-03 08:40:21,871 - DEBUG - Row appended for chat file: WhatsApp Chat with Natalie Msipa_EDOOFAIE(19_12)SM23.txt
# 2024-01-03 08:40:22,137 - DEBUG - Row appended for chat file: WhatsApp Chat with Neo Banda_EDOOFAIE(03_01)SM24.txt
# 2024-01-03 08:40:22,483 - DEBUG - Row appended for chat file: WhatsApp Chat with Ng_andu Felicity_EDOOFAZAMB(18_12)SM23.txt
# 2024-01-03 08:40:22,814 - DEBUG - Row appended for chat file: WhatsApp Chat with NICOLE NDLOVU_EDOOFA(18_12)GS.txt
# 2024-01-03 08:40:23,189 - DEBUG - Row appended for chat file: WhatsApp Chat with Nigel Marowa_EDOOFA(01_12)SM23.txt
# 2024-01-03 08:40:23,486 - DEBUG - Row appended for chat file: WhatsApp Chat with Nyabereka T_EA(21_12)TR.txt
# 2024-01-03 08:40:23,832 - DEBUG - Row appended for chat file: WhatsApp Chat with Nyungu A_EDOOFA(7_12)GS.txt
# 2024-01-03 08:40:24,129 - DEBUG - Row appended for chat file: WhatsApp Chat with Otilia Chivanganye_EA(21_12)TR.txt
# 2024-01-03 08:40:24,364 - DEBUG - Row appended for chat file: WhatsApp Chat with Precious kangwa_EDOOFAZAMBNGS(03_01)SM24.txt
# 2024-01-03 08:40:24,599 - DEBUG - Row appended for chat file: WhatsApp Chat with Precious Mpofu_EDOOFAIE(29_12)SM23.txt
# 2024-01-03 08:40:24,834 - DEBUG - Row appended for chat file: WhatsApp Chat with Precious_EDOOFAZAMBNGS(12_12)TR.txt
# 2024-01-03 08:40:25,194 - DEBUG - Row appended for chat file: WhatsApp Chat with Prince_EDOOFA(18_12)GS-IE.txt
# 2024-01-03 08:40:25,587 - DEBUG - Row appended for chat file: WhatsApp Chat with Ramona Chali_EDOOFAZAMB(12_12)SM23.txt
# 2024-01-03 08:40:25,853 - DEBUG - Row appended for chat file: WhatsApp Chat with Ronald Ganha_EA(26_12)TR.txt
# 2024-01-03 08:40:26,244 - DEBUG - Row appended for chat file: WhatsApp Chat with Shallom Chimhowa_EDOOFA(20_11)SM23.txt
# 2024-01-03 08:40:26,559 - DEBUG - Row appended for chat file: WhatsApp Chat with Shavi Mufarowashe_EA(27_10)TR.txt
# 2024-01-03 08:40:26,889 - DEBUG - Row appended for chat file: WhatsApp Chat with Sibanda D_EDOOFA(14_12)SM23.txt
# 2024-01-03 08:40:27,252 - DEBUG - Row appended for chat file: WhatsApp Chat with Sigireta Tariro_EDOOFA(22_11)GS.txt
# 2024-01-03 08:40:27,682 - DEBUG - Row appended for chat file: WhatsApp Chat with SIMPOSO MWAANGWA_EDOOFAZAMBNGS(12_12)GS.txt
# 2024-01-03 08:40:27,922 - DEBUG - Row appended for chat file: WhatsApp Chat with Tadiwanashe Jere_EDOOFAIE(29_12)SM23.txt
# 2024-01-03 08:40:28,255 - DEBUG - Row appended for chat file: WhatsApp Chat with Tadiwanashe Reginald Veva_EDOOFA(12_12)GS.txt
# 2024-01-03 08:40:28,472 - DEBUG - Row appended for chat file: WhatsApp Chat with Takudzwa Magwenzi_EDOOFA(03_01)SM24.txt
# 2024-01-03 08:40:28,729 - DEBUG - Row appended for chat file: WhatsApp Chat with Tanaka Mushonga_EDOOFA(07_12)SM23.txt
# 2024-01-03 08:40:28,939 - DEBUG - Row appended for chat file: WhatsApp Chat with Tanatswa Tsopotsa_EA(28_12)TR.txt
# 2024-01-03 08:40:29,297 - DEBUG - Row appended for chat file: WhatsApp Chat with Tawananyasha Mushambi_EDOOFA(14_12)GS.txt
# 2024-01-03 08:40:29,558 - DEBUG - Row appended for chat file: WhatsApp Chat with THEARA MUDIMU_EA(21_11)TR.txt
# 2024-01-03 08:40:29,747 - DEBUG - Row appended for chat file: WhatsApp Chat with Victoria Mihova_EDOOFAZAMBNGS(03_01)SM24.txt
# 2024-01-03 08:40:29,952 - DEBUG - Row appended for chat file: WhatsApp Chat with Wesley Kangoma_EDOOFAIE(29_12)SM23.txt
