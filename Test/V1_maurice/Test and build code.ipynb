# %% [markdown]
# ### Part 1, Fetch from directory and initiate dataframe for Table 1, or table_king

# %% [markdown]
# date_directory = 'C:\\Users\\mauriceyeng\\Python\\Daily-Reports\\Test\\V1_maurice\\TestingData'

# %%
import os
import pandas as pd
import re

def parse_chat_group_name(file_name, team_name):
    # Remove the "WhatsApp Chat with " prefix and the file extension
    group_name_with_extension = file_name.replace("WhatsApp Chat with ", "")
    group_name = os.path.splitext(group_name_with_extension)[0]

    # Check for duplicates like (1), (2) etc., and remove them
    group_name = re.sub(r'\(\d+\)$', '', group_name)

    # Special rule for 'SALES' team
    if team_name.lower() == 'sales':
        expected_format = 'yes' if re.search(r'.+?_EDOOFA', group_name) else 'no'
    else:
        # Check for special characters in the first two parts
        parts = group_name.split()
        if len(parts) >= 2 and not (re.search(r'[^A-Za-z0-9]', parts[0]) or re.search(r'[^A-Za-z0-9]', parts[1])):
            expected_format = 'yes'
        else:
            expected_format = 'no'

    return group_name, expected_format


def fetch_chat_data(date_directory):
    # Define the columns for the DataFrame
    columns = ['Date', 'Team', 'Person', 'Chat Name', 'Chat Group Name', 'Expected Format', 'File Size']
    data = []

    # Iterate through each 'Date' directory
    for date_folder in os.listdir(date_directory):
        date_path = os.path.join(date_directory, date_folder)
        if os.path.isdir(date_path):
            # Iterate through each 'Team' subdirectory
            for team_folder in os.listdir(date_path):
                team_path = os.path.join(date_path, team_folder)
                if os.path.isdir(team_path):
                    # Iterate through each 'Person' subdirectory
                    for person_folder in os.listdir(team_path):
                        person_path = os.path.join(team_path, person_folder)
                        if os.path.isdir(person_path):
                            # Process each chat file in the 'Person' subdirectory
                            for file in os.listdir(person_path):
                                if file.endswith('.txt'):  # Assuming chat files are .txt files
                                    file_path = os.path.join(person_path, file)
                                    file_size = os.path.getsize(file_path)

                                    # Extract chat group name and check format
                                    chat_group_name, expected_format = parse_chat_group_name(file, team_folder)



                                    # Add the extracted details to the data list
                                    data.append([date_folder, team_folder, person_folder, file, chat_group_name, expected_format, file_size])

    # Create a DataFrame from the data list
    df = pd.DataFrame(data, columns=columns)
    return df

# Replace 'your_date_directory_path' with the path to the 'Date' directory
date_directory = 'C:\\Users\\mauriceyeng\\Python\\Daily-Reports\\Test\\V1_maurice\\TestingData'
chat_data_df = fetch_chat_data(date_directory)

# Display the DataFrame
chat_data_df.head(5)
# Out:
#          Date       Team          Person  \
# 0  18-11-2023  EWYL TEAM   Ananya_Edoofa
# 1  18-11-2023  EWYL TEAM  Jasmine_Edoofa
# 2  18-11-2023  EWYL TEAM   Sharda_Edoofa
# 3  18-11-2023   KAM TEAM    Kirti_Edoofa
# 4  18-11-2023   KAM TEAM    Kirti_Edoofa
#
#                                         Chat Name          Chat Group Name  \
# 0     WhatsApp Chat with Twazanga EWYL22E1057.txt     Twazanga EWYL22E1057
# 1      WhatsApp Chat with Silence EWYL22E1150.txt      Silence EWYL22E1150
# 2  WhatsApp Chat with Tanyaradzwa EWYL22E0917.txt  Tanyaradzwa EWYL22E0917
# 3    WhatsApp Chat with Nostalgia 2K23JUL0492.txt    Nostalgia 2K23JUL0492
# 4         WhatsApp Chat with Paul 2K23MAY2657.txt         Paul 2K23MAY2657
#
#   Expected Format  File Size
# 0             yes      42960
# 1             yes      30154
# 2             yes      23280
# 3             yes      33749
# 4             yes      46550

# %% [markdown]
# ### Segregating by correct and incorrect formats

# %%
# Split the DataFrame based on 'Expected Format'
df_king = chat_data_df[chat_data_df['Expected Format'] == 'yes']
df_joker = chat_data_df[chat_data_df['Expected Format'] == 'no']

# Display the two DataFrames (optional, for verification)
print("DataFrame with Correct Format (df_king):")
print(df_king)
print("\nDataFrame with Incorrect Format (df_joker):")
print(df_joker)
# Out:
# DataFrame with Correct Format (df_king):
#            Date       Team           Person  \
# 0    18-11-2023  EWYL TEAM    Ananya_Edoofa
# 1    18-11-2023  EWYL TEAM   Jasmine_Edoofa
# 2    18-11-2023  EWYL TEAM    Sharda_Edoofa
# 3    18-11-2023   KAM TEAM     Kirti_Edoofa
# 4    18-11-2023   KAM TEAM     Kirti_Edoofa
# ..          ...        ...              ...
# 147  2023-11-21        KAM     Kirti_Edoofa
# 148  2023-11-21        KAM     Kirti_Edoofa
# 149  2023-11-21        KAM     Kirti_Edoofa
# 150  2023-11-21        KAM     Kirti_Edoofa
# 151  2023-11-21        KAM  Shivjeet_Edoofa
#
#                                            Chat Name  \
# 0        WhatsApp Chat with Twazanga EWYL22E1057.txt
# 1         WhatsApp Chat with Silence EWYL22E1150.txt
# 2     WhatsApp Chat with Tanyaradzwa EWYL22E0917.txt
# 3       WhatsApp Chat with Nostalgia 2K23JUL0492.txt
# 4            WhatsApp Chat with Paul 2K23MAY2657.txt
# ..                                               ...
# 147     WhatsApp Chat with Nostalgia 2K23JUL0492.txt
# 148          WhatsApp Chat with Paul 2K23MAY2657.txt
# 149     WhatsApp Chat with Sharmaine 2K23OCT2489.txt
# 150      WhatsApp Chat with Victoria 2K23JUL2174.txt
# 151  WhatsApp Chat with Moreblessing 2K23APR1124.txt
#
#               Chat Group Name Expected Format  File Size
# 0        Twazanga EWYL22E1057             yes      42960
# 1         Silence EWYL22E1150             yes      30154
# 2     Tanyaradzwa EWYL22E0917             yes      23280
# 3       Nostalgia 2K23JUL0492             yes      33749
# 4            Paul 2K23MAY2657             yes      46550
# ..                        ...             ...        ...
# 147     Nostalgia 2K23JUL0492             yes      33749
# 148          Paul 2K23MAY2657             yes      46550
# 149     Sharmaine 2K23OCT2489             yes      83710
# 150      Victoria 2K23JUL2174             yes      84612
# 151  Moreblessing 2K23APR1124             yes      33212
#
# [100 rows x 7 columns]
#
# DataFrame with Incorrect Format (df_joker):
#            Date   Team    Person  \
# 73   20-11-2023  Sales   Arshita
# 74   20-11-2023  Sales   Arshita
# 75   20-11-2023  Sales   Arshita
# 76   20-11-2023  Sales   Arshita
# 77   20-11-2023  Sales   Arshita
# 78   20-11-2023  Sales   Arshita
# 79   20-11-2023  Sales   Arshita
# 80   20-11-2023  Sales   Arshita
# 81   20-11-2023  Sales   Arshita
# 82   20-11-2023  Sales   Arshita
# 84   20-11-2023  Sales    Austin
# 85   20-11-2023  Sales    Austin
# 86   20-11-2023  Sales    Austin
# 87   20-11-2023  Sales    Austin
# 88   20-11-2023  Sales    Austin
# 89   20-11-2023  Sales    Austin
# 90   20-11-2023  Sales    Austin
# 91   20-11-2023  Sales    Austin
# 92   20-11-2023  Sales    Austin
# 93   20-11-2023  Sales    Austin
# 95   20-11-2023  Sales  Harmehak
# 96   20-11-2023  Sales  Harmehak
# 97   20-11-2023  Sales  Harmehak
# 98   20-11-2023  Sales  Harmehak
# 99   20-11-2023  Sales  Harmehak
# 100  20-11-2023  Sales   Pallika
# 101  20-11-2023  Sales   Pallika
# 102  20-11-2023  Sales   Pallika
# 103  20-11-2023  Sales   Pallika
# 104  20-11-2023  Sales   Pallika
# 105  20-11-2023  Sales   Pallika
# 106  20-11-2023  Sales   Pallika
# 107  20-11-2023  Sales   Pallika
# 108  20-11-2023  Sales   Pallika
# 109  20-11-2023  Sales   Pallika
# 110  20-11-2023  Sales   Pallika
# 111  20-11-2023  Sales   Pallika
# 112  20-11-2023  Sales     Sahil
# 113  20-11-2023  Sales     Sahil
# 114  20-11-2023  Sales     Sahil
# 121  20-11-2023  Sales     Sahil
# 132  20-11-2023  Sales  Shashwat
# 134  20-11-2023  Sales   Shubham
# 135  20-11-2023  Sales   Shubham
# 136  20-11-2023  Sales   Shubham
# 137  20-11-2023  Sales   Shubham
# 138  20-11-2023  Sales   Shubham
# 139  20-11-2023  Sales   Shubham
# 140  20-11-2023  Sales   Shubham
# 141  20-11-2023  Sales   Shubham
# 142  20-11-2023  Sales   Shubham
# 143  20-11-2023  Sales   Shubham
#
#                                              Chat Name  \
# 73     WhatsApp Chat with Madungwe_Edoofa(21_11)AA.txt
# 74      WhatsApp Chat with Melissa_Edoofa(21_11)AA.txt
# 75       WhatsApp Chat with Muwori_Edoofa(17_11)AA.txt
# 76       WhatsApp Chat with Tadiwa_Edoofa(16_11)AA.txt
# 77    WhatsApp Chat with Tangai_Edoofa(21_11)AA-IE.txt
# 78   WhatsApp Chat with Thandoluhle_Edoofa(08_11)AA...
# 79   WhatsApp Chat with Tinotenda_Edoofa(09_10)AA-I...
# 80        WhatsApp Chat with Trust_Edoofa(14_11)AA.txt
# 81      WhatsApp Chat with Valerie_Edoofa(14_11)AA.txt
# 82   WhatsApp Chat with Yolanda_Edoofa(21_11)AA-IE.txt
# 84   WhatsApp Chat with Chipamuriwo_Edoofa(14_11)AA...
# 85   WhatsApp Chat with Magombedze Blessing_Edoofa(...
# 86    WhatsApp Chat with Milton_Edoofa(16_10)PG-IE.txt
# 87       WhatsApp Chat with Praise_Edoofa(16_11)AA.txt
# 88        WhatsApp Chat with Sarah_Edoofa(15_11)AA.txt
# 89   WhatsApp Chat with Shimmah Munyaike_Edoofa(03_...
# 90   WhatsApp Chat with Simbarashe_Kayeruza_Edoofa(...
# 91     WhatsApp Chat with Tafadzwa_Edoofa(17_11)PG.txt
# 92   WhatsApp Chat with Tawanyasha_Edoofa(17_11)AA.txt
# 93    WhatsApp Chat with Tinotenda_Edoofa(09_11)PG.txt
# 95       WhatsApp Chat with Daniel_Edoofa(20_11)HP.txt
# 96      WhatsApp Chat with Natalie_Edoofa(08_11)HP.txt
# 97       WhatsApp Chat with Sharon_Edoofa(20_11)HP.txt
# 98   WhatsApp Chat with Tanyaradzwa_Edoofa(15_11)HP...
# 99      WhatsApp Chat with Zandile_Edoofa(20_11)HP.txt
# 100    WhatsApp Chat with Fadzisai_Edoofa(09_11)PG.txt
# 101   WhatsApp Chat with Mugede_Edoofa(20_11)PG-IE.txt
# 102  WhatsApp Chat with Privilege_Edoofa(20_11)PG-I...
# 103  WhatsApp Chat with Ruramai_Edoofa(20_11)PG-IE.txt
# 104   WhatsApp Chat with Sharon_Edoofa(16_11)PG-IE.txt
# 105       WhatsApp Chat with Steve_Edoofa(20_11)PG.txt
# 106  WhatsApp Chat with Tanyaradzwa_Edoofa(20_11)PG...
# 107     WhatsApp Chat with Thandiwe_Edoofa(7_11)PG.txt
# 108   WhatsApp Chat with Tinotenda_Edoofa(17_11)PG.txt
# 109    WhatsApp Chat with Vuyisile_Edoofa(20_11)PG.txt
# 110    WhatsApp Chat with Wayne_Edoofa(20_11)PG-IE.txt
# 111  WhatsApp Chat with Zvikomborero_Edoofa(15_11)P...
# 112  WhatsApp Chat with Siyamthanda_Edoofa(25_09)HP...
# 113  WhatsApp Chat with Tadiwanashe_Edoofa(23_10)HP...
# 114       WhatsApp Chat with Tatenda_DM01(15_11)HP.txt
# 121      WhatsApp Chat with Zanele_Edoofa(15_11)HP.txt
# 132  WhatsApp Chat with Vimbiso P. Dzvimbo Edoofa (...
# 134   WhatsApp Chat with Panash_EDOOFAMHS(14_11)TR.txt
# 135  WhatsApp Chat with Quinton Mudzi_Edoofa(16_11)...
# 136  WhatsApp Chat with Sikhanyile Gasela_EDOOFA(14...
# 137  WhatsApp Chat with Simeon Wamedzwa_EDOOFA(16_1...
# 138  WhatsApp Chat with Tamya Mutematsaka_EDOOFA(07...
# 139   WhatsApp Chat with Tendai Magaya_EA(30_10)TR.txt
# 140  WhatsApp Chat with Thandeka Sigauke_EDOOFA(20_...
# 141   WhatsApp Chat with Tinashe Gomwe_EA(15_11)TR.txt
# 142  WhatsApp Chat with Tinotenda Muzvidziwa_EA(02_...
# 143  WhatsApp Chat with Yolander Marange_EA(07_11)T...
#
#                           Chat Group Name Expected Format  File Size
# 73               Madungwe_Edoofa(21_11)AA              no       2235
# 74                Melissa_Edoofa(21_11)AA              no       1261
# 75                 Muwori_Edoofa(17_11)AA              no      43970
# 76                 Tadiwa_Edoofa(16_11)AA              no      54252
# 77              Tangai_Edoofa(21_11)AA-IE              no       2619
# 78            Thandoluhle_Edoofa(08_11)AA              no      72550
# 79           Tinotenda_Edoofa(09_10)AA-IE              no      51172
# 80                  Trust_Edoofa(14_11)AA              no      14531
# 81                Valerie_Edoofa(14_11)AA              no      12994
# 82             Yolanda_Edoofa(21_11)AA-IE              no       2895
# 84            Chipamuriwo_Edoofa(14_11)AA              no      65251
# 85    Magombedze Blessing_Edoofa(17_11)KA              no      59010
# 86              Milton_Edoofa(16_10)PG-IE              no      61602
# 87                 Praise_Edoofa(16_11)AA              no      57522
# 88                  Sarah_Edoofa(15_11)AA              no      64236
# 89       Shimmah Munyaike_Edoofa(03_11)KA              no      39122
# 90    Simbarashe_Kayeruza_Edoofa(15_11)KA              no      63348
# 91               Tafadzwa_Edoofa(17_11)PG              no      55782
# 92             Tawanyasha_Edoofa(17_11)AA              no      44158
# 93              Tinotenda_Edoofa(09_11)PG              no      67217
# 95                 Daniel_Edoofa(20_11)HP              no      11865
# 96                Natalie_Edoofa(08_11)HP              no      19216
# 97                 Sharon_Edoofa(20_11)HP              no      15111
# 98            Tanyaradzwa_Edoofa(15_11)HP              no      21732
# 99                Zandile_Edoofa(20_11)HP              no       2705
# 100              Fadzisai_Edoofa(09_11)PG              no      13723
# 101             Mugede_Edoofa(20_11)PG-IE              no       3249
# 102          Privilege_Edoofa(20_11)PG-IE              no       3051
# 103            Ruramai_Edoofa(20_11)PG-IE              no      24135
# 104             Sharon_Edoofa(16_11)PG-IE              no      51325
# 105                 Steve_Edoofa(20_11)PG              no      39931
# 106           Tanyaradzwa_Edoofa(20_11)PG              no       2465
# 107               Thandiwe_Edoofa(7_11)PG              no      16511
# 108             Tinotenda_Edoofa(17_11)PG              no       3505
# 109              Vuyisile_Edoofa(20_11)PG              no       2753
# 110              Wayne_Edoofa(20_11)PG-IE              no       2714
# 111          Zvikomborero_Edoofa(15_11)PG              no       4306
# 112           Siyamthanda_Edoofa(25_09)HP              no      66788
# 113           Tadiwanashe_Edoofa(23_10)HP              no      80252
# 114                 Tatenda_DM01(15_11)HP              no      61200
# 121                Zanele_Edoofa(15_11)HP              no      47289
# 132  Vimbiso P. Dzvimbo Edoofa (23_10) SZ              no      20504
# 134             Panash_EDOOFAMHS(14_11)TR              no      66545
# 135       Quinton Mudzi_Edoofa(16_11)SM23              no      22426
# 136   Sikhanyile Gasela_EDOOFA(14_11)SM23              no       5623
# 137     Simeon Wamedzwa_EDOOFA(16_11)SM23              no      12949
# 138   Tamya Mutematsaka_EDOOFA(07_11)SM23              no      16076
# 139             Tendai Magaya_EA(30_10)TR              no      98150
# 140    Thandeka Sigauke_EDOOFA(20_11)SM23              no       3229
# 141             Tinashe Gomwe_EA(15_11)TR              no      44627
# 142      Tinotenda Muzvidziwa_EA(02_11)TR              no      71233
# 143          Yolander Marange_EA(07_11)TR              no      40226
