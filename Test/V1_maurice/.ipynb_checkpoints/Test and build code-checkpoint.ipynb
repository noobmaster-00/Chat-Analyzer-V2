# %% [markdown]
# ### Part 1, Fetch from directory and initiate dataframe for Table 1, or table_king

# %% [markdown]
# date_directory = 'C:\\Users\\mauriceyeng\\Python\\Daily-Reports\\Test\\V1_maurice\\TestingData'

# %%
import os
import pandas as pd
import re

def parse_chat_group_name(file_name, team_name):
    # Remove the "WhatsApp Chat with " prefix and the file extension
    group_name_with_extension = file_name.replace("WhatsApp Chat with ", "")
    group_name = os.path.splitext(group_name_with_extension)[0]
    
    # Check for duplicates like (1), (2) etc., and remove them
    group_name = re.sub(r'\(\d+\)$', '', group_name)
    print(group_name)

    # Special rule for 'SALES' team
    if team_name.lower() == 'sales':
        # Check for specific patterns after an underscore or the bracketed date format
        pattern = re.compile(r'.+?_(EDOOFA|edoofa|Edoofa|EA)|\(\d{2}_\d{2}\)')
        expected_format = 'yes' if pattern.search(group_name) else 'no'
    else:
        # Check for special characters in the first two parts
        parts = group_name.split()
        print(parts)
        if len(parts) >= 2 and not (re.search(r'[^A-Za-z0-9]', parts[0]) or re.search(r'[^A-Za-z0-9]', parts[1])):
            expected_format = 'yes'
        else:
            expected_format = 'no'

    return group_name, expected_format


def fetch_chat_data(date_directory):
    # Define the columns for the DataFrame
    columns = ['Date', 'Team', 'Person', 'Chat Name', 'Chat Group Name', 'Expected Format', 'File Size']
    data = []

    # Iterate through each 'Date' directory
    for date_folder in os.listdir(date_directory):
        date_path = os.path.join(date_directory, date_folder)
        if os.path.isdir(date_path):
            # Iterate through each 'Team' subdirectory
            for team_folder in os.listdir(date_path):
                team_path = os.path.join(date_path, team_folder)
                if os.path.isdir(team_path):
                    # Iterate through each 'Person' subdirectory
                    for person_folder in os.listdir(team_path):
                        person_path = os.path.join(team_path, person_folder)
                        if os.path.isdir(person_path):
                            # Process each chat file in the 'Person' subdirectory
                            for file in os.listdir(person_path):
                                if file.endswith('.txt'):  # Assuming chat files are .txt files
                                    file_path = os.path.join(person_path, file)
                                    file_size = os.path.getsize(file_path)

                                    # Extract chat group name and check format
                                    chat_group_name, expected_format = parse_chat_group_name(file, team_folder)



                                    # Add the extracted details to the data list
                                    data.append([date_folder, team_folder, person_folder, file, chat_group_name, expected_format, file_size])

    # Create a DataFrame from the data list
    df = pd.DataFrame(data, columns=columns)
    return df

# Replace 'your_date_directory_path' with the path to the 'Date' directory
date_directory = 'C:\\Users\\mauriceyeng\\Python\\Daily-Reports\\Test\\V1_maurice\\TestingData'
chat_data_df = fetch_chat_data(date_directory)

# Display the DataFrame
chat_data_df.head(10)
# Out:
# Twazanga EWYL22E1057
# ['Twazanga', 'EWYL22E1057']
# Silence EWYL22E1150
# ['Silence', 'EWYL22E1150']
# Tanyaradzwa EWYL22E0917
# ['Tanyaradzwa', 'EWYL22E0917']
# Nostalgia 2K23JUL0492
# ['Nostalgia', '2K23JUL0492']
# Paul 2K23MAY2657
# ['Paul', '2K23MAY2657']
# Sharmaine 2K23OCT2489
# ['Sharmaine', '2K23OCT2489']
# Victoria 2K23JUL2174
# ['Victoria', '2K23JUL2174']
# Moreblessing 2K23APR1124
# ['Moreblessing', '2K23APR1124']
# Cloudious EWYL22E0796
# ['Cloudious', 'EWYL22E0796']
# Glory EWYL23E0161
# ['Glory', 'EWYL23E0161']
# Pride EWYL23E0728
# ['Pride', 'EWYL23E0728']
# Sharmaine EWYL23E0867
# ['Sharmaine', 'EWYL23E0867']
# Tafadzwa EWYL22E0128
# ['Tafadzwa', 'EWYL22E0128']
# Winnie 2K23JUL2129R
# ['Winnie', '2K23JUL2129R']
# Zvikomborero 2K23JUL0645
# ['Zvikomborero', '2K23JUL0645']
# _
# ['_']
# _Catherine 2K23JUN0779_ - Copy
# ['_Catherine', '2K23JUN0779_', '-', 'Copy']
# Anotidaishe 2K23NOV0674R
# ['Anotidaishe', '2K23NOV0674R']
# Brendon 2K23JUL2492
# ['Brendon', '2K23JUL2492']
# Kudzaishe 2K23AUG1288
# ['Kudzaishe', '2K23AUG1288']
# Nondumiso 2K23NOV0643
# ['Nondumiso', '2K23NOV0643']
# Richmore Makaza 2K23NOV0655
# ['Richmore', 'Makaza', '2K23NOV0655']
# Sharon 2K23NOV0689
# ['Sharon', '2K23NOV0689']
# Zibusiso 2K23JUL0199
# ['Zibusiso', '2K23JUL0199']
# Michelle 2K22SEP2291
# ['Michelle', '2K22SEP2291']
# Rachel 2K22NOV1502
# ['Rachel', '2K22NOV1502']
# Takunda 2K23AUG2458
# ['Takunda', '2K23AUG2458']
# Talent 2K23AUG2354
# ['Talent', '2K23AUG2354']
# Tavonga 2K23AUG2295
# ['Tavonga', '2K23AUG2295']
# Whitney 2K23OCT1853
# ['Whitney', '2K23OCT1853']
# Madungwe_Edoofa(21_11)AA
# Melissa_Edoofa(21_11)AA
# Muwori_Edoofa(17_11)AA
# Tadiwa_Edoofa(16_11)AA
# Tangai_Edoofa(21_11)AA-IE
# Thandoluhle_Edoofa(08_11)AA
# Tinotenda_Edoofa(09_10)AA-IE
# Trust_Edoofa(14_11)AA
# Valerie_Edoofa(14_11)AA
# Yolanda_Edoofa(21_11)AA-IE
# Anna Tadiwanashe Pepete_Edoofa(18_11)KA
# Chipamuriwo_Edoofa(14_11)AA
# Magombedze Blessing_Edoofa(17_11)KA
# Milton_Edoofa(16_10)PG-IE
# Praise_Edoofa(16_11)AA
# Sarah_Edoofa(15_11)AA
# Shimmah Munyaike_Edoofa(03_11)KA
# Simbarashe_Kayeruza_Edoofa(15_11)KA
# Tafadzwa_Edoofa(17_11)PG
# Tawanyasha_Edoofa(17_11)AA
# Tinotenda_Edoofa(09_11)PG
# Yvonne T Mugwagwa_Edoofa(23_10)KA
# Daniel_Edoofa(20_11)HP
# Natalie_Edoofa(08_11)HP
# Sharon_Edoofa(20_11)HP
# Tanyaradzwa_Edoofa(15_11)HP
# Zandile_Edoofa(20_11)HP
# Fadzisai_Edoofa(09_11)PG
# Mugede_Edoofa(20_11)PG-IE
# Privilege_Edoofa(20_11)PG-IE
# Ruramai_Edoofa(20_11)PG-IE
# Sharon_Edoofa(16_11)PG-IE
# Steve_Edoofa(20_11)PG
# Tanyaradzwa_Edoofa(20_11)PG
# Thandiwe_Edoofa(7_11)PG
# Tinotenda_Edoofa(17_11)PG
# Vuyisile_Edoofa(20_11)PG
# Wayne_Edoofa(20_11)PG-IE
# Zvikomborero_Edoofa(15_11)PG
# Siyamthanda_Edoofa(25_09)HP
# Tadiwanashe_Edoofa(23_10)HP
# Tatenda_DM01(15_11)HP
# Timothy Mushaikwa Edoofa (07_11) SZ 2025
# William Shambare Edoofa (12_09) SZ
# Wilma Makaza EDOOFA(15_11)SR
# Winnie Ali EDOOFA(01_11)SR
# Yolandah Sithole Edoofa(26_10)SR 2025
# Zanele Munatswa Edoofa(26_10)SR 2025
#
#   Expected Format  File Size
# 0             yes      42960
# 1             yes      30154
# 2             yes      23280
# 3             yes      33749
# 4             yes      46550
# 5             yes      83710
# 6             yes      84612
# 7             yes      33212
# 8             yes      20996
# 9             yes      56557

# %%
chat_data_df.to_csv("test.csv",index=False)

# %% [markdown]
# ### Segregating by correct and incorrect formats

# %%
# Split the DataFrame based on 'Expected Format'
df_king = chat_data_df[chat_data_df['Expected Format'] == 'yes']
df_joker = chat_data_df[chat_data_df['Expected Format'] == 'no']

# Display the two DataFrames (optional, for verification)
print("DataFrame with Correct Format (df_king):")
print(df_king)
print("\nDataFrame with Incorrect Format (df_joker):")
print(df_joker)
# Out:
# DataFrame with Correct Format (df_king):
#            Date       Team           Person  \
# 0    18-11-2023  EWYL TEAM    Ananya_Edoofa
# 1    18-11-2023  EWYL TEAM   Jasmine_Edoofa
# 2    18-11-2023  EWYL TEAM    Sharda_Edoofa
# 3    18-11-2023   KAM TEAM     Kirti_Edoofa
# 4    18-11-2023   KAM TEAM     Kirti_Edoofa
# ..          ...        ...              ...
# 150  2023-11-21        KAM     Kirti_Edoofa
# 151  2023-11-21        KAM     Kirti_Edoofa
# 152  2023-11-21        KAM     Kirti_Edoofa
# 153  2023-11-21        KAM     Kirti_Edoofa
# 154  2023-11-21        KAM  Shivjeet_Edoofa
#
#                                            Chat Name  \
# 0        WhatsApp Chat with Twazanga EWYL22E1057.txt
# 1         WhatsApp Chat with Silence EWYL22E1150.txt
# 2     WhatsApp Chat with Tanyaradzwa EWYL22E0917.txt
# 3       WhatsApp Chat with Nostalgia 2K23JUL0492.txt
# 4            WhatsApp Chat with Paul 2K23MAY2657.txt
# ..                                               ...
# 150     WhatsApp Chat with Nostalgia 2K23JUL0492.txt
# 151          WhatsApp Chat with Paul 2K23MAY2657.txt
# 152     WhatsApp Chat with Sharmaine 2K23OCT2489.txt
# 153      WhatsApp Chat with Victoria 2K23JUL2174.txt
# 154  WhatsApp Chat with Moreblessing 2K23APR1124.txt
#
#               Chat Group Name Expected Format  File Size
# 0        Twazanga EWYL22E1057             yes      42960
# 1         Silence EWYL22E1150             yes      30154
# 2     Tanyaradzwa EWYL22E0917             yes      23280
# 3       Nostalgia 2K23JUL0492             yes      33749
# 4            Paul 2K23MAY2657             yes      46550
# ..                        ...             ...        ...
# 150     Nostalgia 2K23JUL0492             yes      33749
# 151          Paul 2K23MAY2657             yes      46550
# 152     Sharmaine 2K23OCT2489             yes      83710
# 153      Victoria 2K23JUL2174             yes      84612
# 154  Moreblessing 2K23APR1124             yes      33212
#
# [151 rows x 7 columns]
#
# DataFrame with Incorrect Format (df_joker):
#           Date Team Person                                          Chat Name  \
# 52  20-11-2023  KAM  Kirti      WhatsApp Chat with Catherine __- Copy (3).txt
# 61  20-11-2023  KAM  Kirti                           WhatsApp Chat with _.txt
# 62  20-11-2023  KAM  Kirti  WhatsApp Chat with _Catherine 2K23JUN0779_ - C...
# 67  20-11-2023  KAM  Milan  WhatsApp Chat with Richmore Makaza 2K23NOV0655...
#
#                     Chat Group Name Expected Format  File Size
# 52              Catherine __- Copy               no       9351
# 61                                _              no       9351
# 62  _Catherine 2K23JUN0779_ - Copy               no       9351
# 67      Richmore Makaza 2K23NOV0655              no      15390
