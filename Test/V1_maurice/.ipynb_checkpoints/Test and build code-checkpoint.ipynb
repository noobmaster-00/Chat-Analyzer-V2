# %% [markdown]
# ### Part 1, Fetch from directory and initiate dataframe for Table 1, or table_king

# %% [markdown]
# date_directory = 'C:\\Users\\mauriceyeng\\Python\\Daily-Reports\\Test\\V1_maurice\\TestingData'

# %%
import os
import pandas as pd

def fetch_chat_data(date_directory):
    # Define the columns for the DataFrame
    columns = ['Date', 'Team', 'Person', 'Chats URL', 'Chat Name', 'Chat Group Name', 'File Size', 'Expected Format']
    data = []

    # Iterate through each 'Date' directory
    for date_folder in os.listdir(date_directory):
        date_path = os.path.join(date_directory, date_folder)
        if os.path.isdir(date_path):
            # Iterate through each 'Team' subdirectory
            for team_folder in os.listdir(date_path):
                team_path = os.path.join(date_path, team_folder)
                if os.path.isdir(team_path):
                    # Iterate through each 'Person' subdirectory
                    for person_folder in os.listdir(team_path):
                        person_path = os.path.join(team_path, person_folder)
                        if os.path.isdir(person_path):
                            # Process each chat file in the 'Person' subdirectory
                            for file in os.listdir(person_path):
                                if file.endswith('.txt'):  # Assuming chat files are .txt files
                                    file_path = os.path.join(person_path, file)
                                    file_size = os.path.getsize(file_path)

                                    # Placeholder values for now
                                    chats_url = "To be defined"
                                    chat_group_name = "To be defined"
                                    expected_format = "To be discussed"

                                    # Add the extracted details to the data list
                                    data.append([date_folder, team_folder, person_folder, chats_url, file, chat_group_name, file_size, expected_format])

    # Create a DataFrame from the data list
    df = pd.DataFrame(data, columns=columns)
    return df

# Replace 'your_date_directory_path' with the path to the 'Date' directory
date_directory = 'C:\\Users\\mauriceyeng\\Python\\Daily-Reports\\Test\\V1_maurice\\TestingData'
chat_data_df = fetch_chat_data(date_directory)

# Display the DataFrame
chat_data_df
# Out:
#          Date  Team           Person      Chats URL  \
# 0  2023-11-21  EWYL    Ananya_Edoofa  To be defined
# 1  2023-11-21  EWYL   Jasmine_Edoofa  To be defined
# 2  2023-11-21  EWYL    Sharda_Edoofa  To be defined
# 3  2023-11-21   KAM     Kirti_Edoofa  To be defined
# 4  2023-11-21   KAM     Kirti_Edoofa  To be defined
# 5  2023-11-21   KAM     Kirti_Edoofa  To be defined
# 6  2023-11-21   KAM     Kirti_Edoofa  To be defined
# 7  2023-11-21   KAM  Shivjeet_Edoofa  To be defined
#
#                                          Chat Name Chat Group Name  File Size  \
# 0      WhatsApp Chat with Twazanga EWYL22E1057.txt   To be defined      42960
# 1       WhatsApp Chat with Silence EWYL22E1150.txt   To be defined      30154
# 2   WhatsApp Chat with Tanyaradzwa EWYL22E0917.txt   To be defined      23280
# 3     WhatsApp Chat with Nostalgia 2K23JUL0492.txt   To be defined      33749
# 4          WhatsApp Chat with Paul 2K23MAY2657.txt   To be defined      46550
# 5     WhatsApp Chat with Sharmaine 2K23OCT2489.txt   To be defined      83710
# 6      WhatsApp Chat with Victoria 2K23JUL2174.txt   To be defined      84612
# 7  WhatsApp Chat with Moreblessing 2K23APR1124.txt   To be defined      33212
#
#    Expected Format
# 0  To be discussed
# 1  To be discussed
# 2  To be discussed
# 3  To be discussed
# 4  To be discussed
# 5  To be discussed
# 6  To be discussed
# 7  To be discussed
