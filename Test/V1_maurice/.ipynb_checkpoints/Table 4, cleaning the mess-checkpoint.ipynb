# %%
import os
import pandas as pd
import datetime
import re

# Function to list all chat files in the directory structure
def list_chat_files(date_directory):
    chat_files = []
    for date_folder in os.listdir(date_directory):
        date_path = os.path.join(date_directory, date_folder)
        if os.path.isdir(date_path):
            for team_folder in os.listdir(date_path):
                team_path = os.path.join(date_path, team_folder)
                if os.path.isdir(team_path):
                    for person_folder in os.listdir(team_path):
                        person_path = os.path.join(team_path, person_folder)
                        if os.path.isdir(person_path):
                            for file in os.listdir(person_path):
                                if file.endswith('.txt'):
                                    chat_files.append(os.path.join(person_path, file))
    return chat_files

def parse_chat_file(file_path):
    chat_data = []
    today_minus_one = datetime.datetime.now().date() - datetime.timedelta(days=1)

    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            message_match = re.match(r'(\d{2}/\d{2}/\d{2}, \d{1,2}:\d{2} [ap]m) - (.*?): (.*)', line)
            system_match = re.match(r'(\d{2}/\d{2}/\d{2}, \d{1,2}:\d{2} [ap]m) - (.*)', line)
            if message_match:
                date_time_str, sender, message = message_match.groups()
            elif system_match:
                date_time_str, info = system_match.groups()
                sender = None
            else:
                continue

            date_time = pd.to_datetime(date_time_str, format='%d/%m/%y, %I:%M %p')

            # Comparing parsed date with today - 1
            if date_time.date() != today_minus_one:
                continue

            # Adjusted logic to check for numeric sender (phone number)
            is_person = sender is not None and re.match(r'^[+\d\s-]+$', sender) is None  # True if sender is NOT purely numeric

            chat_data.append((date_time, sender, is_person))
    return chat_data



# Function to create a template dataframe
def create_template_dataframe():
    times = [datetime.datetime(2000, 1, 1, 0, 0) + datetime.timedelta(minutes=1 * i) for i in range(1440)]
    intervals = [time.strftime('%I:%M %p') for time in times]
    df = pd.DataFrame(index=intervals)
    return df

def populate_dataframe(df, parsed_data, start_column_index):
    new_columns = {}  # Dictionary to hold new data before concatenation

    for entry in parsed_data:
        date_time, sender, is_person = entry
        interval_index = min((date_time.hour * 60 + date_time.minute) // 1, 1439)
        interval = df.index[interval_index]

        print(f"Processing entry: {entry}, Interval: {interval}")  # Debug line

        # Initialize columns in new_columns dictionary if not exist
        if (start_column_index not in new_columns):
            new_columns[start_column_index] = pd.Series(0, index=df.index)
            print(f"Initialized new column: {start_column_index}")  # Debug line
        if (start_column_index + 1 not in new_columns):
            new_columns[start_column_index + 1] = pd.Series(0, index=df.index)
            print(f"Initialized new column: {start_column_index + 1}")  # Debug line

        # Populate the new_columns dictionary
        if is_person:
            new_columns[start_column_index].at[interval] = 1
            print(f"Populated person column {start_column_index} at interval {interval}")  # Debug line
        else:
            new_columns[start_column_index + 1].at[interval] = 1
            print(f"Populated system column {start_column_index + 1} at interval {interval}")  # Debug line

    print(f"New columns to be added: {new_columns.keys()}")  # Debug line

    # Concatenate new columns to the DataFrame at once
    df = pd.concat([df, pd.DataFrame(new_columns)], axis=1)
    print("Concatenated new columns to DataFrame")  # Debug line

    print(f"DataFrame after concatenation: {df.head()}")  # Debug line to show the top rows of the DataFrame

    return df, start_column_index + 2



def process_person_chats(chat_files):
    dataframes = {}
    for file in chat_files:
        parts = file.split(os.sep)
        date_folder, person = parts[-4], parts[-2]

        try:
            expected_date = pd.to_datetime(date_folder).date()
        except ValueError:
            print(f"Skipping file due to incorrect date format in folder name: {file}")
            continue

        key = f"{expected_date.strftime('%Y-%m-%d')}_{person}"

        if key not in dataframes:
            dataframes[key] = create_template_dataframe()
            start_column_index = 0
        else:
            if not dataframes[key].columns.empty:
                start_column_index = max(dataframes[key].columns) + 1
            else:
                start_column_index = 0

        # Updated call to parse_chat_file
        parsed_data = parse_chat_file(file)
        next_column_index = populate_dataframe(dataframes[key], parsed_data, start_column_index)
        # Use the returned DataFrame to update the dictionary
        dataframes[key], start_column_index = populate_dataframe(dataframes[key], parsed_data, start_column_index)
    
    return dataframes





# Main script
date_directory = "C:\\Users\\mauriceyeng\\Python\\Daily-Reports\\Test\\filtered_chats"
chat_files = list_chat_files(date_directory)
person_dataframes = process_person_chats(chat_files)
# Out:
# Processing entry: (Timestamp('2023-11-27 16:49:00'), None, False), Interval: 04:49 PM
# Initialized new column: 0
# Initialized new column: 1
# Populated system column 1 at interval 04:49 PM
# Processing entry: (Timestamp('2023-11-27 16:49:00'), None, False), Interval: 04:49 PM
# Populated system column 1 at interval 04:49 PM
# Processing entry: (Timestamp('2023-11-27 16:59:00'), 'Arshita', True), Interval: 04:59 PM
# Populated person column 0 at interval 04:59 PM
# Processing entry: (Timestamp('2023-11-27 16:59:00'), 'Arshita', True), Interval: 04:59 PM
# Populated person column 0 at interval 04:59 PM
# Processing entry: (Timestamp('2023-11-27 18:39:00'), 'Arshita', True), Interval: 06:39 PM
# Populated person column 0 at interval 06:39 PM
# Processing entry: (Timestamp('2023-11-27 18:50:00'), None, False), Interval: 06:50 PM
# Populated system column 1 at interval 06:50 PM
# Processing entry: (Timestamp('2023-11-27 18:50:00'), 'Arshita', True), Interval: 06:50 PM
# Populated person column 0 at interval 06:50 PM
# Processing entry: (Timestamp('2023-11-27 18:55:00'), 'Arshita', True), Interval: 06:55 PM
# Populated person column 0 at interval 06:55 PM
# Processing entry: (Timestamp('2023-11-27 18:56:00'), 'Arshita', True), Interval: 06:56 PM
# Populated person column 0 at interval 06:56 PM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 12:29:00'), 'Arshita', True), Interval: 12:29 PM
# Initialized new column: 0
# Initialized new column: 1
# Populated person column 0 at interval 12:29 PM
# Processing entry: (Timestamp('2023-11-27 19:22:00'), 'Arshita', True), Interval: 07:22 PM
# Populated person column 0 at interval 07:22 PM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 07:16:00'), '+263 77 211 4784', False), Interval: 07:16 AM
# Initialized new column: 0
# Initialized new column: 1
# Populated system column 1 at interval 07:16 AM
# Processing entry: (Timestamp('2023-11-27 10:55:00'), 'Arshita', True), Interval: 10:55 AM
# Populated person column 0 at interval 10:55 AM
# Processing entry: (Timestamp('2023-11-27 12:01:00'), '+263 77 211 4784', False), Interval: 12:01 PM
# Populated system column 1 at interval 12:01 PM
# Processing entry: (Timestamp('2023-11-27 12:09:00'), 'Arshita', True), Interval: 12:09 PM
# Populated person column 0 at interval 12:09 PM
# Processing entry: (Timestamp('2023-11-27 12:09:00'), 'Arshita', True), Interval: 12:09 PM
# Populated person column 0 at interval 12:09 PM
# Processing entry: (Timestamp('2023-11-27 12:16:00'), '+263 77 211 4784', False), Interval: 12:16 PM
# Populated system column 1 at interval 12:16 PM
# Processing entry: (Timestamp('2023-11-27 12:25:00'), '+263 77 211 4784', False), Interval: 12:25 PM
# Populated system column 1 at interval 12:25 PM
# Processing entry: (Timestamp('2023-11-27 12:28:00'), 'Arshita', True), Interval: 12:28 PM
# Populated person column 0 at interval 12:28 PM
# Processing entry: (Timestamp('2023-11-27 12:39:00'), '+263 77 211 4784', False), Interval: 12:39 PM
# Populated system column 1 at interval 12:39 PM
# Processing entry: (Timestamp('2023-11-27 12:41:00'), '+263 77 211 4784', False), Interval: 12:41 PM
# Populated system column 1 at interval 12:41 PM
# Processing entry: (Timestamp('2023-11-27 12:42:00'), 'Arshita', True), Interval: 12:42 PM
# Populated person column 0 at interval 12:42 PM
# Processing entry: (Timestamp('2023-11-27 12:44:00'), '+263 77 211 4784', False), Interval: 12:44 PM
# Populated system column 1 at interval 12:44 PM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 11:01:00'), 'Arshita', True), Interval: 11:01 AM
# Initialized new column: 0
# Initialized new column: 1
# Populated person column 0 at interval 11:01 AM
# Processing entry: (Timestamp('2023-11-27 17:59:00'), '+263 77 686 8729', False), Interval: 05:59 PM
# Populated system column 1 at interval 05:59 PM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 19:34:00'), 'Arshita', True), Interval: 07:34 PM
# Initialized new column: 0
# Initialized new column: 1
# Populated person column 0 at interval 07:34 PM
# Processing entry: (Timestamp('2023-11-27 19:34:00'), 'Arshita', True), Interval: 07:34 PM
# Populated person column 0 at interval 07:34 PM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 12:30:00'), 'Arshita', True), Interval: 12:30 PM
# Initialized new column: 0
# Initialized new column: 1
# Populated person column 0 at interval 12:30 PM
# Processing entry: (Timestamp('2023-11-27 19:25:00'), 'Arshita', True), Interval: 07:25 PM
# Populated person column 0 at interval 07:25 PM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 16:49:00'), None, False), Interval: 04:49 PM
# Initialized new column: 0
# Initialized new column: 1
# Populated system column 1 at interval 04:49 PM
# Processing entry: (Timestamp('2023-11-27 16:49:00'), None, False), Interval: 04:49 PM
# Populated system column 1 at interval 04:49 PM
# Processing entry: (Timestamp('2023-11-27 16:59:00'), 'Arshita', True), Interval: 04:59 PM
# Populated person column 0 at interval 04:59 PM
# Processing entry: (Timestamp('2023-11-27 16:59:00'), 'Arshita', True), Interval: 04:59 PM
# Populated person column 0 at interval 04:59 PM
# Processing entry: (Timestamp('2023-11-27 18:47:00'), None, False), Interval: 06:47 PM
# Populated system column 1 at interval 06:47 PM
# Processing entry: (Timestamp('2023-11-27 18:56:00'), 'Arshita', True), Interval: 06:56 PM
# Populated person column 0 at interval 06:56 PM
# Processing entry: (Timestamp('2023-11-27 18:58:00'), None, False), Interval: 06:58 PM
# Populated system column 1 at interval 06:58 PM
# Processing entry: (Timestamp('2023-11-27 18:58:00'), 'Arshita', True), Interval: 06:58 PM
# Populated person column 0 at interval 06:58 PM
# Processing entry: (Timestamp('2023-11-27 18:58:00'), 'Arshita', True), Interval: 06:58 PM
# Populated person column 0 at interval 06:58 PM
# Processing entry: (Timestamp('2023-11-27 19:15:00'), '+263 78 298 5241', False), Interval: 07:15 PM
# Populated system column 1 at interval 07:15 PM
# Processing entry: (Timestamp('2023-11-27 19:58:00'), '+263 77 288 9434', False), Interval: 07:58 PM
# Populated system column 1 at interval 07:58 PM
# Processing entry: (Timestamp('2023-11-27 21:20:00'), '+263 77 288 9434', False), Interval: 09:20 PM
# Populated system column 1 at interval 09:20 PM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 12:31:00'), 'Arshita', True), Interval: 12:31 PM
# Initialized new column: 0
# Initialized new column: 1
# Populated person column 0 at interval 12:31 PM
# Processing entry: (Timestamp('2023-11-27 19:32:00'), 'Arshita', True), Interval: 07:32 PM
# Populated person column 0 at interval 07:32 PM
# Processing entry: (Timestamp('2023-11-27 19:32:00'), 'Arshita', True), Interval: 07:32 PM
# Populated person column 0 at interval 07:32 PM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 12:29:00'), 'Arshita', True), Interval: 12:29 PM
# Initialized new column: 0
# Initialized new column: 1
# Populated person column 0 at interval 12:29 PM
# Processing entry: (Timestamp('2023-11-27 19:24:00'), 'Arshita', True), Interval: 07:24 PM
# Populated person column 0 at interval 07:24 PM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 12:34:00'), 'Arshita', True), Interval: 12:34 PM
# Initialized new column: 0
# Initialized new column: 1
# Populated person column 0 at interval 12:34 PM
# Processing entry: (Timestamp('2023-11-27 12:34:00'), '+263 71 499 2767', False), Interval: 12:34 PM
# Populated system column 1 at interval 12:34 PM
# Processing entry: (Timestamp('2023-11-27 12:34:00'), '+263 71 499 2767', False), Interval: 12:34 PM
# Populated system column 1 at interval 12:34 PM
# Processing entry: (Timestamp('2023-11-27 12:36:00'), 'Arshita', True), Interval: 12:36 PM
# Populated person column 0 at interval 12:36 PM
# Processing entry: (Timestamp('2023-11-27 12:37:00'), '+263 71 499 2767', False), Interval: 12:37 PM
# Populated system column 1 at interval 12:37 PM
# Processing entry: (Timestamp('2023-11-27 12:43:00'), 'Arshita', True), Interval: 12:43 PM
# Populated person column 0 at interval 12:43 PM
# Processing entry: (Timestamp('2023-11-27 12:43:00'), 'Arshita', True), Interval: 12:43 PM
# Populated person column 0 at interval 12:43 PM
# Processing entry: (Timestamp('2023-11-27 12:52:00'), '+263 71 499 2767', False), Interval: 12:52 PM
# Populated system column 1 at interval 12:52 PM
# Processing entry: (Timestamp('2023-11-27 13:40:00'), 'Arshita', True), Interval: 01:40 PM
# Populated person column 0 at interval 01:40 PM
# Processing entry: (Timestamp('2023-11-27 13:40:00'), 'Arshita', True), Interval: 01:40 PM
# Populated person column 0 at interval 01:40 PM
# Processing entry: (Timestamp('2023-11-27 14:03:00'), '+263 71 499 2767', False), Interval: 02:03 PM
# Populated system column 1 at interval 02:03 PM
# Processing entry: (Timestamp('2023-11-27 14:03:00'), 'Arshita', True), Interval: 02:03 PM
# Populated person column 0 at interval 02:03 PM
# Processing entry: (Timestamp('2023-11-27 15:07:00'), 'Arshita', True), Interval: 03:07 PM
# Populated person column 0 at interval 03:07 PM
# Processing entry: (Timestamp('2023-11-27 19:33:00'), 'Arshita', True), Interval: 07:33 PM
# Populated person column 0 at interval 07:33 PM
# Processing entry: (Timestamp('2023-11-27 19:33:00'), 'Arshita', True), Interval: 07:33 PM
# Populated person column 0 at interval 07:33 PM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 12:33:00'), 'Arshita', True), Interval: 12:33 PM
# Initialized new column: 0
# Initialized new column: 1
# Populated person column 0 at interval 12:33 PM
# Processing entry: (Timestamp('2023-11-27 12:45:00'), '+263 78 599 2436', False), Interval: 12:45 PM
# Populated system column 1 at interval 12:45 PM
# Processing entry: (Timestamp('2023-11-27 12:47:00'), 'Arshita', True), Interval: 12:47 PM
# Populated person column 0 at interval 12:47 PM
# Processing entry: (Timestamp('2023-11-27 12:49:00'), '+263 78 599 2436', False), Interval: 12:49 PM
# Populated system column 1 at interval 12:49 PM
# Processing entry: (Timestamp('2023-11-27 12:49:00'), 'Arshita', True), Interval: 12:49 PM
# Populated person column 0 at interval 12:49 PM
# Processing entry: (Timestamp('2023-11-27 12:49:00'), 'Arshita', True), Interval: 12:49 PM
# Populated person column 0 at interval 12:49 PM
# Processing entry: (Timestamp('2023-11-27 12:51:00'), '+263 78 599 2436', False), Interval: 12:51 PM
# Populated system column 1 at interval 12:51 PM
# Processing entry: (Timestamp('2023-11-27 12:51:00'), '+263 78 599 2436', False), Interval: 12:51 PM
# Populated system column 1 at interval 12:51 PM
# Processing entry: (Timestamp('2023-11-27 12:58:00'), '+263 78 599 2436', False), Interval: 12:58 PM
# Populated system column 1 at interval 12:58 PM
# Processing entry: (Timestamp('2023-11-27 13:08:00'), 'Arshita', True), Interval: 01:08 PM
# Populated person column 0 at interval 01:08 PM
# Processing entry: (Timestamp('2023-11-27 13:08:00'), 'Arshita', True), Interval: 01:08 PM
# Populated person column 0 at interval 01:08 PM
# Processing entry: (Timestamp('2023-11-27 13:09:00'), '+263 78 599 2436', False), Interval: 01:09 PM
# Populated system column 1 at interval 01:09 PM
# Processing entry: (Timestamp('2023-11-27 13:43:00'), 'Arshita', True), Interval: 01:43 PM
# Populated person column 0 at interval 01:43 PM
# Processing entry: (Timestamp('2023-11-27 14:11:00'), '+263 78 599 2436', False), Interval: 02:11 PM
# Populated system column 1 at interval 02:11 PM
# Processing entry: (Timestamp('2023-11-27 14:12:00'), 'Arshita', True), Interval: 02:12 PM
# Populated person column 0 at interval 02:12 PM
# Processing entry: (Timestamp('2023-11-27 14:14:00'), 'Arshita', True), Interval: 02:14 PM
# Populated person column 0 at interval 02:14 PM
# Processing entry: (Timestamp('2023-11-27 14:56:00'), '+263 78 599 2436', False), Interval: 02:56 PM
# Populated system column 1 at interval 02:56 PM
# Processing entry: (Timestamp('2023-11-27 14:56:00'), 'Arshita', True), Interval: 02:56 PM
# Populated person column 0 at interval 02:56 PM
# Processing entry: (Timestamp('2023-11-27 14:57:00'), '+263 78 599 2436', False), Interval: 02:57 PM
# Populated system column 1 at interval 02:57 PM
# Processing entry: (Timestamp('2023-11-27 14:58:00'), 'Arshita', True), Interval: 02:58 PM
# Populated person column 0 at interval 02:58 PM
# Processing entry: (Timestamp('2023-11-27 14:58:00'), 'Arshita', True), Interval: 02:58 PM
# Populated person column 0 at interval 02:58 PM
# Processing entry: (Timestamp('2023-11-27 14:58:00'), 'Arshita', True), Interval: 02:58 PM
# Populated person column 0 at interval 02:58 PM
# Processing entry: (Timestamp('2023-11-27 15:08:00'), '+263 78 599 2436', False), Interval: 03:08 PM
# Populated system column 1 at interval 03:08 PM
# Processing entry: (Timestamp('2023-11-27 19:33:00'), 'Arshita', True), Interval: 07:33 PM
# Populated person column 0 at interval 07:33 PM
# Processing entry: (Timestamp('2023-11-27 19:33:00'), 'Arshita', True), Interval: 07:33 PM
# Populated person column 0 at interval 07:33 PM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 11:03:00'), 'Arshita', True), Interval: 11:03 AM
# Initialized new column: 0
# Initialized new column: 1
# Populated person column 0 at interval 11:03 AM
# Processing entry: (Timestamp('2023-11-27 11:47:00'), '+263 77 616 3640', False), Interval: 11:47 AM
# Populated system column 1 at interval 11:47 AM
# Processing entry: (Timestamp('2023-11-27 11:50:00'), 'Arshita', True), Interval: 11:50 AM
# Populated person column 0 at interval 11:50 AM
# Processing entry: (Timestamp('2023-11-27 11:52:00'), '+263 77 616 3640', False), Interval: 11:52 AM
# Populated system column 1 at interval 11:52 AM
# Processing entry: (Timestamp('2023-11-27 11:57:00'), 'Arshita', True), Interval: 11:57 AM
# Populated person column 0 at interval 11:57 AM
# Processing entry: (Timestamp('2023-11-27 11:58:00'), '+263 77 616 3640', False), Interval: 11:58 AM
# Populated system column 1 at interval 11:58 AM
# Processing entry: (Timestamp('2023-11-27 12:07:00'), 'Arshita', True), Interval: 12:07 PM
# Populated person column 0 at interval 12:07 PM
# Processing entry: (Timestamp('2023-11-27 12:07:00'), 'Arshita', True), Interval: 12:07 PM
# Populated person column 0 at interval 12:07 PM
# Processing entry: (Timestamp('2023-11-27 14:13:00'), '+263 77 616 3640', False), Interval: 02:13 PM
# Populated system column 1 at interval 02:13 PM
# Processing entry: (Timestamp('2023-11-27 14:13:00'), '+263 77 616 3640', False), Interval: 02:13 PM
# Populated system column 1 at interval 02:13 PM
# Processing entry: (Timestamp('2023-11-27 14:58:00'), 'Arshita', True), Interval: 02:58 PM
# Populated person column 0 at interval 02:58 PM
# Processing entry: (Timestamp('2023-11-27 19:04:00'), '+263 77 612 0392', False), Interval: 07:04 PM
# Populated system column 1 at interval 07:04 PM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 16:52:00'), None, False), Interval: 04:52 PM
# Initialized new column: 0
# Initialized new column: 1
# Populated system column 1 at interval 04:52 PM
# Processing entry: (Timestamp('2023-11-27 16:52:00'), None, False), Interval: 04:52 PM
# Populated system column 1 at interval 04:52 PM
# Processing entry: (Timestamp('2023-11-27 17:01:00'), 'Arshita', True), Interval: 05:01 PM
# Populated person column 0 at interval 05:01 PM
# Processing entry: (Timestamp('2023-11-27 17:01:00'), 'Arshita', True), Interval: 05:01 PM
# Populated person column 0 at interval 05:01 PM
# Processing entry: (Timestamp('2023-11-27 18:54:00'), None, False), Interval: 06:54 PM
# Populated system column 1 at interval 06:54 PM
# Processing entry: (Timestamp('2023-11-27 18:57:00'), 'Arshita', True), Interval: 06:57 PM
# Populated person column 0 at interval 06:57 PM
# Processing entry: (Timestamp('2023-11-27 18:58:00'), 'Arshita', True), Interval: 06:58 PM
# Populated person column 0 at interval 06:58 PM
# Processing entry: (Timestamp('2023-11-27 18:58:00'), 'Arshita', True), Interval: 06:58 PM
# Populated person column 0 at interval 06:58 PM
# Processing entry: (Timestamp('2023-11-27 19:31:00'), None, False), Interval: 07:31 PM
# Populated system column 1 at interval 07:31 PM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 12:32:00'), 'Arshita', True), Interval: 12:32 PM
# Initialized new column: 0
# Initialized new column: 1
# Populated person column 0 at interval 12:32 PM
# Processing entry: (Timestamp('2023-11-27 19:33:00'), 'Arshita', True), Interval: 07:33 PM
# Populated person column 0 at interval 07:33 PM
# Processing entry: (Timestamp('2023-11-27 19:33:00'), 'Arshita', True), Interval: 07:33 PM
# Populated person column 0 at interval 07:33 PM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 10:52:00'), 'Arshita', True), Interval: 10:52 AM
# Initialized new column: 0
# Initialized new column: 1
# Populated person column 0 at interval 10:52 AM
# Processing entry: (Timestamp('2023-11-27 10:52:00'), 'Arshita', True), Interval: 10:52 AM
# Populated person column 0 at interval 10:52 AM
# Processing entry: (Timestamp('2023-11-27 10:52:00'), 'Arshita', True), Interval: 10:52 AM
# Populated person column 0 at interval 10:52 AM
# Processing entry: (Timestamp('2023-11-27 10:53:00'), 'Arshita', True), Interval: 10:53 AM
# Populated person column 0 at interval 10:53 AM
# Processing entry: (Timestamp('2023-11-27 10:53:00'), 'Arshita', True), Interval: 10:53 AM
# Populated person column 0 at interval 10:53 AM
# Processing entry: (Timestamp('2023-11-27 10:53:00'), 'Arshita', True), Interval: 10:53 AM
# Populated person column 0 at interval 10:53 AM
# Processing entry: (Timestamp('2023-11-27 10:53:00'), 'Arshita', True), Interval: 10:53 AM
# Populated person column 0 at interval 10:53 AM
# Processing entry: (Timestamp('2023-11-27 10:53:00'), 'Arshita', True), Interval: 10:53 AM
# Populated person column 0 at interval 10:53 AM
# Processing entry: (Timestamp('2023-11-27 10:53:00'), 'Arshita', True), Interval: 10:53 AM
# Populated person column 0 at interval 10:53 AM
# Processing entry: (Timestamp('2023-11-27 10:53:00'), 'Arshita', True), Interval: 10:53 AM
# Populated person column 0 at interval 10:53 AM
# Processing entry: (Timestamp('2023-11-27 10:53:00'), 'Arshita', True), Interval: 10:53 AM
# Populated person column 0 at interval 10:53 AM
# Processing entry: (Timestamp('2023-11-27 10:53:00'), 'Arshita', True), Interval: 10:53 AM
# Populated person column 0 at interval 10:53 AM
# Processing entry: (Timestamp('2023-11-27 10:53:00'), 'Arshita', True), Interval: 10:53 AM
# Populated person column 0 at interval 10:53 AM
# Processing entry: (Timestamp('2023-11-27 10:53:00'), 'Arshita', True), Interval: 10:53 AM
# Populated person column 0 at interval 10:53 AM
# Processing entry: (Timestamp('2023-11-27 10:53:00'), 'Arshita', True), Interval: 10:53 AM
# Populated person column 0 at interval 10:53 AM
# Processing entry: (Timestamp('2023-11-27 10:53:00'), 'Arshita', True), Interval: 10:53 AM
# Populated person column 0 at interval 10:53 AM
# Processing entry: (Timestamp('2023-11-27 10:53:00'), 'Arshita', True), Interval: 10:53 AM
# Populated person column 0 at interval 10:53 AM
# Processing entry: (Timestamp('2023-11-27 10:53:00'), 'Arshita', True), Interval: 10:53 AM
# Populated person column 0 at interval 10:53 AM
# Processing entry: (Timestamp('2023-11-27 10:53:00'), 'Arshita', True), Interval: 10:53 AM
# Populated person column 0 at interval 10:53 AM
# Processing entry: (Timestamp('2023-11-27 11:02:00'), '+27 78 092 7023', False), Interval: 11:02 AM
# Populated system column 1 at interval 11:02 AM
# Processing entry: (Timestamp('2023-11-27 18:29:00'), 'Arshita', True), Interval: 06:29 PM
# Populated person column 0 at interval 06:29 PM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 12:29:00'), 'Arshita', True), Interval: 12:29 PM
# Initialized new column: 0
# Initialized new column: 1
# Populated person column 0 at interval 12:29 PM
# Processing entry: (Timestamp('2023-11-27 19:24:00'), 'Arshita', True), Interval: 07:24 PM
# Populated person column 0 at interval 07:24 PM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 12:31:00'), 'Arshita', True), Interval: 12:31 PM
# Initialized new column: 0
# Initialized new column: 1
# Populated person column 0 at interval 12:31 PM
# Processing entry: (Timestamp('2023-11-27 19:32:00'), 'Arshita', True), Interval: 07:32 PM
# Populated person column 0 at interval 07:32 PM
# Processing entry: (Timestamp('2023-11-27 19:32:00'), 'Arshita', True), Interval: 07:32 PM
# Populated person column 0 at interval 07:32 PM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 12:30:00'), 'Arshita', True), Interval: 12:30 PM
# Initialized new column: 0
# Initialized new column: 1
# Populated person column 0 at interval 12:30 PM
# Processing entry: (Timestamp('2023-11-27 12:59:00'), '+263 78 341 4424', False), Interval: 12:59 PM
# Populated system column 1 at interval 12:59 PM
# Processing entry: (Timestamp('2023-11-27 13:02:00'), '+263 78 341 4424', False), Interval: 01:02 PM
# Populated system column 1 at interval 01:02 PM
# Processing entry: (Timestamp('2023-11-27 13:41:00'), 'Arshita', True), Interval: 01:41 PM
# Populated person column 0 at interval 01:41 PM
# Processing entry: (Timestamp('2023-11-27 15:06:00'), 'Arshita', True), Interval: 03:06 PM
# Populated person column 0 at interval 03:06 PM
# Processing entry: (Timestamp('2023-11-27 19:28:00'), 'Arshita', True), Interval: 07:28 PM
# Populated person column 0 at interval 07:28 PM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 12:30:00'), 'Arshita', True), Interval: 12:30 PM
# Initialized new column: 0
# Initialized new column: 1
# Populated person column 0 at interval 12:30 PM
# Processing entry: (Timestamp('2023-11-27 19:25:00'), 'Arshita', True), Interval: 07:25 PM
# Populated person column 0 at interval 07:25 PM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 16:50:00'), None, False), Interval: 04:50 PM
# Initialized new column: 0
# Initialized new column: 1
# Populated system column 1 at interval 04:50 PM
# Processing entry: (Timestamp('2023-11-27 16:50:00'), None, False), Interval: 04:50 PM
# Populated system column 1 at interval 04:50 PM
# Processing entry: (Timestamp('2023-11-27 17:00:00'), 'Arshita', True), Interval: 05:00 PM
# Populated person column 0 at interval 05:00 PM
# Processing entry: (Timestamp('2023-11-27 17:00:00'), 'Arshita', True), Interval: 05:00 PM
# Populated person column 0 at interval 05:00 PM
# Processing entry: (Timestamp('2023-11-27 18:40:00'), 'Arshita', True), Interval: 06:40 PM
# Populated person column 0 at interval 06:40 PM
# Processing entry: (Timestamp('2023-11-27 18:51:00'), None, False), Interval: 06:51 PM
# Populated system column 1 at interval 06:51 PM
# Processing entry: (Timestamp('2023-11-27 18:51:00'), 'Arshita', True), Interval: 06:51 PM
# Populated person column 0 at interval 06:51 PM
# Processing entry: (Timestamp('2023-11-27 18:55:00'), 'Arshita', True), Interval: 06:55 PM
# Populated person column 0 at interval 06:55 PM
# Processing entry: (Timestamp('2023-11-27 18:56:00'), 'Arshita', True), Interval: 06:56 PM
# Populated person column 0 at interval 06:56 PM
# Processing entry: (Timestamp('2023-11-27 19:07:00'), '+263 77 584 6699', False), Interval: 07:07 PM
# Populated system column 1 at interval 07:07 PM
# Processing entry: (Timestamp('2023-11-27 19:08:00'), 'Arshita', True), Interval: 07:08 PM
# Populated person column 0 at interval 07:08 PM
# Processing entry: (Timestamp('2023-11-27 19:09:00'), '+263 77 584 6699', False), Interval: 07:09 PM
# Populated system column 1 at interval 07:09 PM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 14:21:00'), 'Arshita', True), Interval: 02:21 PM
# Initialized new column: 0
# Initialized new column: 1
# Populated person column 0 at interval 02:21 PM
# Processing entry: (Timestamp('2023-11-27 14:26:00'), '+263 78 733 4360', False), Interval: 02:26 PM
# Populated system column 1 at interval 02:26 PM
# Processing entry: (Timestamp('2023-11-27 14:29:00'), 'Arshita', True), Interval: 02:29 PM
# Populated person column 0 at interval 02:29 PM
# Processing entry: (Timestamp('2023-11-27 14:31:00'), '+263 78 733 4360', False), Interval: 02:31 PM
# Populated system column 1 at interval 02:31 PM
# Processing entry: (Timestamp('2023-11-27 14:33:00'), 'Arshita', True), Interval: 02:33 PM
# Populated person column 0 at interval 02:33 PM
# Processing entry: (Timestamp('2023-11-27 14:40:00'), '+263 78 733 4360', False), Interval: 02:40 PM
# Populated system column 1 at interval 02:40 PM
# Processing entry: (Timestamp('2023-11-27 14:42:00'), 'Arshita', True), Interval: 02:42 PM
# Populated person column 0 at interval 02:42 PM
# Processing entry: (Timestamp('2023-11-27 14:42:00'), 'Arshita', True), Interval: 02:42 PM
# Populated person column 0 at interval 02:42 PM
# Processing entry: (Timestamp('2023-11-27 14:42:00'), 'Arshita', True), Interval: 02:42 PM
# Populated person column 0 at interval 02:42 PM
# Processing entry: (Timestamp('2023-11-27 14:42:00'), 'Arshita', True), Interval: 02:42 PM
# Populated person column 0 at interval 02:42 PM
# Processing entry: (Timestamp('2023-11-27 14:42:00'), 'Arshita', True), Interval: 02:42 PM
# Populated person column 0 at interval 02:42 PM
# Processing entry: (Timestamp('2023-11-27 14:42:00'), 'Arshita', True), Interval: 02:42 PM
# Populated person column 0 at interval 02:42 PM
# Processing entry: (Timestamp('2023-11-27 14:42:00'), 'Arshita', True), Interval: 02:42 PM
# Populated person column 0 at interval 02:42 PM
# Processing entry: (Timestamp('2023-11-27 14:42:00'), 'Arshita', True), Interval: 02:42 PM
# Populated person column 0 at interval 02:42 PM
# Processing entry: (Timestamp('2023-11-27 14:42:00'), 'Arshita', True), Interval: 02:42 PM
# Populated person column 0 at interval 02:42 PM
# Processing entry: (Timestamp('2023-11-27 14:42:00'), 'Arshita', True), Interval: 02:42 PM
# Populated person column 0 at interval 02:42 PM
# Processing entry: (Timestamp('2023-11-27 14:42:00'), 'Arshita', True), Interval: 02:42 PM
# Populated person column 0 at interval 02:42 PM
# Processing entry: (Timestamp('2023-11-27 14:42:00'), 'Arshita', True), Interval: 02:42 PM
# Populated person column 0 at interval 02:42 PM
# Processing entry: (Timestamp('2023-11-27 14:42:00'), 'Arshita', True), Interval: 02:42 PM
# Populated person column 0 at interval 02:42 PM
# Processing entry: (Timestamp('2023-11-27 14:54:00'), '+263 78 733 4360', False), Interval: 02:54 PM
# Populated system column 1 at interval 02:54 PM
# Processing entry: (Timestamp('2023-11-27 14:55:00'), '+263 78 733 4360', False), Interval: 02:55 PM
# Populated system column 1 at interval 02:55 PM
# Processing entry: (Timestamp('2023-11-27 14:55:00'), 'Arshita', True), Interval: 02:55 PM
# Populated person column 0 at interval 02:55 PM
# Processing entry: (Timestamp('2023-11-27 15:08:00'), '+263 78 733 4360', False), Interval: 03:08 PM
# Populated system column 1 at interval 03:08 PM
# Processing entry: (Timestamp('2023-11-27 15:08:00'), 'Arshita', True), Interval: 03:08 PM
# Populated person column 0 at interval 03:08 PM
# Processing entry: (Timestamp('2023-11-27 15:10:00'), '+263 78 733 4360', False), Interval: 03:10 PM
# Populated system column 1 at interval 03:10 PM
# Processing entry: (Timestamp('2023-11-27 15:10:00'), 'Arshita', True), Interval: 03:10 PM
# Populated person column 0 at interval 03:10 PM
# Processing entry: (Timestamp('2023-11-27 15:10:00'), 'Arshita', True), Interval: 03:10 PM
# Populated person column 0 at interval 03:10 PM
# Processing entry: (Timestamp('2023-11-27 15:10:00'), 'Arshita', True), Interval: 03:10 PM
# Populated person column 0 at interval 03:10 PM
# Processing entry: (Timestamp('2023-11-27 15:40:00'), '+263 78 733 4360', False), Interval: 03:40 PM
# Populated system column 1 at interval 03:40 PM
# Processing entry: (Timestamp('2023-11-27 15:41:00'), 'Arshita', True), Interval: 03:41 PM
# Populated person column 0 at interval 03:41 PM
# Processing entry: (Timestamp('2023-11-27 15:42:00'), '+263 78 733 4360', False), Interval: 03:42 PM
# Populated system column 1 at interval 03:42 PM
# Processing entry: (Timestamp('2023-11-27 15:45:00'), 'Arshita', True), Interval: 03:45 PM
# Populated person column 0 at interval 03:45 PM
# Processing entry: (Timestamp('2023-11-27 15:45:00'), 'Arshita', True), Interval: 03:45 PM
# Populated person column 0 at interval 03:45 PM
# Processing entry: (Timestamp('2023-11-27 15:45:00'), 'Arshita', True), Interval: 03:45 PM
# Populated person column 0 at interval 03:45 PM
# Processing entry: (Timestamp('2023-11-27 15:45:00'), 'Arshita', True), Interval: 03:45 PM
# Populated person column 0 at interval 03:45 PM
# Processing entry: (Timestamp('2023-11-27 15:45:00'), 'Arshita', True), Interval: 03:45 PM
# Populated person column 0 at interval 03:45 PM
# Processing entry: (Timestamp('2023-11-27 15:45:00'), 'Arshita', True), Interval: 03:45 PM
# Populated person column 0 at interval 03:45 PM
# Processing entry: (Timestamp('2023-11-27 15:45:00'), 'Arshita', True), Interval: 03:45 PM
# Populated person column 0 at interval 03:45 PM
# Processing entry: (Timestamp('2023-11-27 15:45:00'), 'Arshita', True), Interval: 03:45 PM
# Populated person column 0 at interval 03:45 PM
# Processing entry: (Timestamp('2023-11-27 19:33:00'), 'Arshita', True), Interval: 07:33 PM
# Populated person column 0 at interval 07:33 PM
# Processing entry: (Timestamp('2023-11-27 19:33:00'), 'Arshita', True), Interval: 07:33 PM
# Populated person column 0 at interval 07:33 PM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 12:34:00'), 'Arshita', True), Interval: 12:34 PM
# Initialized new column: 0
# Initialized new column: 1
# Populated person column 0 at interval 12:34 PM
# Processing entry: (Timestamp('2023-11-27 19:33:00'), 'Arshita', True), Interval: 07:33 PM
# Populated person column 0 at interval 07:33 PM
# Processing entry: (Timestamp('2023-11-27 19:33:00'), 'Arshita', True), Interval: 07:33 PM
# Populated person column 0 at interval 07:33 PM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 16:49:00'), None, False), Interval: 04:49 PM
# Initialized new column: 0
# Initialized new column: 1
# Populated system column 1 at interval 04:49 PM
# Processing entry: (Timestamp('2023-11-27 16:49:00'), None, False), Interval: 04:49 PM
# Populated system column 1 at interval 04:49 PM
# Processing entry: (Timestamp('2023-11-27 16:58:00'), 'Arshita', True), Interval: 04:58 PM
# Populated person column 0 at interval 04:58 PM
# Processing entry: (Timestamp('2023-11-27 16:58:00'), 'Arshita', True), Interval: 04:58 PM
# Populated person column 0 at interval 04:58 PM
# Processing entry: (Timestamp('2023-11-27 16:58:00'), 'Arshita', True), Interval: 04:58 PM
# Populated person column 0 at interval 04:58 PM
# Processing entry: (Timestamp('2023-11-27 16:58:00'), 'Arshita', True), Interval: 04:58 PM
# Populated person column 0 at interval 04:58 PM
# Processing entry: (Timestamp('2023-11-27 18:45:00'), None, False), Interval: 06:45 PM
# Populated system column 1 at interval 06:45 PM
# Processing entry: (Timestamp('2023-11-27 18:46:00'), 'Arshita', True), Interval: 06:46 PM
# Populated person column 0 at interval 06:46 PM
# Processing entry: (Timestamp('2023-11-27 18:58:00'), 'Arshita', True), Interval: 06:58 PM
# Populated person column 0 at interval 06:58 PM
# Processing entry: (Timestamp('2023-11-27 18:58:00'), 'Arshita', True), Interval: 06:58 PM
# Populated person column 0 at interval 06:58 PM
# Processing entry: (Timestamp('2023-11-27 20:57:00'), '+234 810 853 8550', False), Interval: 08:57 PM
# Populated system column 1 at interval 08:57 PM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 12:33:00'), 'Arshita', True), Interval: 12:33 PM
# Initialized new column: 0
# Initialized new column: 1
# Populated person column 0 at interval 12:33 PM
# Processing entry: (Timestamp('2023-11-27 19:33:00'), 'Arshita', True), Interval: 07:33 PM
# Populated person column 0 at interval 07:33 PM
# Processing entry: (Timestamp('2023-11-27 19:33:00'), 'Arshita', True), Interval: 07:33 PM
# Populated person column 0 at interval 07:33 PM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 12:33:00'), '+263 78 077 4346', False), Interval: 12:33 PM
# Initialized new column: 0
# Initialized new column: 1
# Populated system column 1 at interval 12:33 PM
# Processing entry: (Timestamp('2023-11-27 12:35:00'), 'Arshita', True), Interval: 12:35 PM
# Populated person column 0 at interval 12:35 PM
# Processing entry: (Timestamp('2023-11-27 12:35:00'), '+263 78 077 4346', False), Interval: 12:35 PM
# Populated system column 1 at interval 12:35 PM
# Processing entry: (Timestamp('2023-11-27 12:36:00'), 'Arshita', True), Interval: 12:36 PM
# Populated person column 0 at interval 12:36 PM
# Processing entry: (Timestamp('2023-11-27 12:41:00'), '+263 78 077 4346', False), Interval: 12:41 PM
# Populated system column 1 at interval 12:41 PM
# Processing entry: (Timestamp('2023-11-27 12:48:00'), 'Arshita', True), Interval: 12:48 PM
# Populated person column 0 at interval 12:48 PM
# Processing entry: (Timestamp('2023-11-27 12:49:00'), 'Arshita', True), Interval: 12:49 PM
# Populated person column 0 at interval 12:49 PM
# Processing entry: (Timestamp('2023-11-27 12:50:00'), '+263 78 077 4346', False), Interval: 12:50 PM
# Populated system column 1 at interval 12:50 PM
# Processing entry: (Timestamp('2023-11-27 12:59:00'), 'Arshita', True), Interval: 12:59 PM
# Populated person column 0 at interval 12:59 PM
# Processing entry: (Timestamp('2023-11-27 12:59:00'), 'Arshita', True), Interval: 12:59 PM
# Populated person column 0 at interval 12:59 PM
# Processing entry: (Timestamp('2023-11-27 13:00:00'), 'Arshita', True), Interval: 01:00 PM
# Populated person column 0 at interval 01:00 PM
# Processing entry: (Timestamp('2023-11-27 13:00:00'), 'Arshita', True), Interval: 01:00 PM
# Populated person column 0 at interval 01:00 PM
# Processing entry: (Timestamp('2023-11-27 13:00:00'), 'Arshita', True), Interval: 01:00 PM
# Populated person column 0 at interval 01:00 PM
# Processing entry: (Timestamp('2023-11-27 13:03:00'), '+263 78 077 4346', False), Interval: 01:03 PM
# Populated system column 1 at interval 01:03 PM
# Processing entry: (Timestamp('2023-11-27 13:41:00'), 'Arshita', True), Interval: 01:41 PM
# Populated person column 0 at interval 01:41 PM
# Processing entry: (Timestamp('2023-11-27 13:41:00'), 'Arshita', True), Interval: 01:41 PM
# Populated person column 0 at interval 01:41 PM
# Processing entry: (Timestamp('2023-11-27 13:49:00'), '+263 78 077 4346', False), Interval: 01:49 PM
# Populated system column 1 at interval 01:49 PM
# Processing entry: (Timestamp('2023-11-27 13:50:00'), 'Arshita', True), Interval: 01:50 PM
# Populated person column 0 at interval 01:50 PM
# Processing entry: (Timestamp('2023-11-27 13:57:00'), '+263 78 077 4346', False), Interval: 01:57 PM
# Populated system column 1 at interval 01:57 PM
# Processing entry: (Timestamp('2023-11-27 13:59:00'), 'Arshita', True), Interval: 01:59 PM
# Populated person column 0 at interval 01:59 PM
# Processing entry: (Timestamp('2023-11-27 14:49:00'), '+263 78 077 4346', False), Interval: 02:49 PM
# Populated system column 1 at interval 02:49 PM
# Processing entry: (Timestamp('2023-11-27 14:51:00'), 'Arshita', True), Interval: 02:51 PM
# Populated person column 0 at interval 02:51 PM
# Processing entry: (Timestamp('2023-11-27 14:51:00'), 'Arshita', True), Interval: 02:51 PM
# Populated person column 0 at interval 02:51 PM
# Processing entry: (Timestamp('2023-11-27 14:51:00'), 'Arshita', True), Interval: 02:51 PM
# Populated person column 0 at interval 02:51 PM
# Processing entry: (Timestamp('2023-11-27 14:51:00'), 'Arshita', True), Interval: 02:51 PM
# Populated person column 0 at interval 02:51 PM
# Processing entry: (Timestamp('2023-11-27 14:51:00'), 'Arshita', True), Interval: 02:51 PM
# Populated person column 0 at interval 02:51 PM
# Processing entry: (Timestamp('2023-11-27 14:51:00'), 'Arshita', True), Interval: 02:51 PM
# Populated person column 0 at interval 02:51 PM
# Processing entry: (Timestamp('2023-11-27 14:51:00'), 'Arshita', True), Interval: 02:51 PM
# Populated person column 0 at interval 02:51 PM
# Processing entry: (Timestamp('2023-11-27 14:51:00'), 'Arshita', True), Interval: 02:51 PM
# Populated person column 0 at interval 02:51 PM
# Processing entry: (Timestamp('2023-11-27 14:51:00'), 'Arshita', True), Interval: 02:51 PM
# Populated person column 0 at interval 02:51 PM
# Processing entry: (Timestamp('2023-11-27 14:51:00'), 'Arshita', True), Interval: 02:51 PM
# Populated person column 0 at interval 02:51 PM
# Processing entry: (Timestamp('2023-11-27 14:51:00'), 'Arshita', True), Interval: 02:51 PM
# Populated person column 0 at interval 02:51 PM
# Processing entry: (Timestamp('2023-11-27 14:51:00'), 'Arshita', True), Interval: 02:51 PM
# Populated person column 0 at interval 02:51 PM
# Processing entry: (Timestamp('2023-11-27 14:57:00'), '+263 78 077 4346', False), Interval: 02:57 PM
# Populated system column 1 at interval 02:57 PM
# Processing entry: (Timestamp('2023-11-27 14:57:00'), 'Arshita', True), Interval: 02:57 PM
# Populated person column 0 at interval 02:57 PM
# Processing entry: (Timestamp('2023-11-27 15:03:00'), '+263 78 077 4346', False), Interval: 03:03 PM
# Populated system column 1 at interval 03:03 PM
# Processing entry: (Timestamp('2023-11-27 15:03:00'), 'Arshita', True), Interval: 03:03 PM
# Populated person column 0 at interval 03:03 PM
# Processing entry: (Timestamp('2023-11-27 15:06:00'), '+263 78 077 4346', False), Interval: 03:06 PM
# Populated system column 1 at interval 03:06 PM
# Processing entry: (Timestamp('2023-11-27 15:07:00'), 'Arshita', True), Interval: 03:07 PM
# Populated person column 0 at interval 03:07 PM
# Processing entry: (Timestamp('2023-11-27 15:07:00'), 'Arshita', True), Interval: 03:07 PM
# Populated person column 0 at interval 03:07 PM
# Processing entry: (Timestamp('2023-11-27 15:07:00'), 'Arshita', True), Interval: 03:07 PM
# Populated person column 0 at interval 03:07 PM
# Processing entry: (Timestamp('2023-11-27 19:13:00'), '+263 78 077 4346', False), Interval: 07:13 PM
# Populated system column 1 at interval 07:13 PM
# Processing entry: (Timestamp('2023-11-27 19:13:00'), '+263 78 077 4346', False), Interval: 07:13 PM
# Populated system column 1 at interval 07:13 PM
# Processing entry: (Timestamp('2023-11-27 19:14:00'), 'Arshita', True), Interval: 07:14 PM
# Populated person column 0 at interval 07:14 PM
# Processing entry: (Timestamp('2023-11-27 19:34:00'), 'Arshita', True), Interval: 07:34 PM
# Populated person column 0 at interval 07:34 PM
# Processing entry: (Timestamp('2023-11-27 19:34:00'), 'Arshita', True), Interval: 07:34 PM
# Populated person column 0 at interval 07:34 PM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 12:30:00'), 'Arshita', True), Interval: 12:30 PM
# Initialized new column: 0
# Initialized new column: 1
# Populated person column 0 at interval 12:30 PM
# Processing entry: (Timestamp('2023-11-27 19:25:00'), 'Arshita', True), Interval: 07:25 PM
# Populated person column 0 at interval 07:25 PM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 12:30:00'), 'Arshita', True), Interval: 12:30 PM
# Initialized new column: 0
# Initialized new column: 1
# Populated person column 0 at interval 12:30 PM
# Processing entry: (Timestamp('2023-11-27 19:26:00'), 'Arshita', True), Interval: 07:26 PM
# Populated person column 0 at interval 07:26 PM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 12:31:00'), 'Arshita', True), Interval: 12:31 PM
# Initialized new column: 0
# Initialized new column: 1
# Populated person column 0 at interval 12:31 PM
# Processing entry: (Timestamp('2023-11-27 19:27:00'), 'Arshita', True), Interval: 07:27 PM
# Populated person column 0 at interval 07:27 PM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 12:32:00'), 'Arshita', True), Interval: 12:32 PM
# Initialized new column: 0
# Initialized new column: 1
# Populated person column 0 at interval 12:32 PM
# Processing entry: (Timestamp('2023-11-27 19:32:00'), 'Arshita', True), Interval: 07:32 PM
# Populated person column 0 at interval 07:32 PM
# Processing entry: (Timestamp('2023-11-27 19:32:00'), 'Arshita', True), Interval: 07:32 PM
# Populated person column 0 at interval 07:32 PM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 12:29:00'), 'Arshita', True), Interval: 12:29 PM
# Initialized new column: 0
# Initialized new column: 1
# Populated person column 0 at interval 12:29 PM
# Processing entry: (Timestamp('2023-11-27 19:24:00'), 'Arshita', True), Interval: 07:24 PM
# Populated person column 0 at interval 07:24 PM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 15:10:00'), '+263 78 445 1889', False), Interval: 03:10 PM
# Initialized new column: 0
# Initialized new column: 1
# Populated system column 1 at interval 03:10 PM
# Processing entry: (Timestamp('2023-11-27 15:10:00'), '+263 78 445 1889', False), Interval: 03:10 PM
# Populated system column 1 at interval 03:10 PM
# Processing entry: (Timestamp('2023-11-27 15:11:00'), 'Arshita', True), Interval: 03:11 PM
# Populated person column 0 at interval 03:11 PM
# Processing entry: (Timestamp('2023-11-27 19:00:00'), '+263 78 445 1889', False), Interval: 07:00 PM
# Populated system column 1 at interval 07:00 PM
# Processing entry: (Timestamp('2023-11-27 19:00:00'), '+263 78 445 1889', False), Interval: 07:00 PM
# Populated system column 1 at interval 07:00 PM
# Processing entry: (Timestamp('2023-11-27 19:00:00'), 'Arshita', True), Interval: 07:00 PM
# Populated person column 0 at interval 07:00 PM
# Processing entry: (Timestamp('2023-11-27 19:00:00'), '+263 78 445 1889', False), Interval: 07:00 PM
# Populated system column 1 at interval 07:00 PM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 12:30:00'), 'Arshita', True), Interval: 12:30 PM
# Initialized new column: 0
# Initialized new column: 1
# Populated person column 0 at interval 12:30 PM
# Processing entry: (Timestamp('2023-11-27 15:19:00'), '+263 78 901 7142', False), Interval: 03:19 PM
# Populated system column 1 at interval 03:19 PM
# Processing entry: (Timestamp('2023-11-27 15:20:00'), '+263 78 901 7142', False), Interval: 03:20 PM
# Populated system column 1 at interval 03:20 PM
# Processing entry: (Timestamp('2023-11-27 15:22:00'), 'Arshita', True), Interval: 03:22 PM
# Populated person column 0 at interval 03:22 PM
# Processing entry: (Timestamp('2023-11-27 15:27:00'), '+263 78 901 7142', False), Interval: 03:27 PM
# Populated system column 1 at interval 03:27 PM
# Processing entry: (Timestamp('2023-11-27 15:28:00'), 'Arshita', True), Interval: 03:28 PM
# Populated person column 0 at interval 03:28 PM
# Processing entry: (Timestamp('2023-11-27 15:28:00'), 'Arshita', True), Interval: 03:28 PM
# Populated person column 0 at interval 03:28 PM
# Processing entry: (Timestamp('2023-11-27 15:49:00'), 'Arshita', True), Interval: 03:49 PM
# Populated person column 0 at interval 03:49 PM
# Processing entry: (Timestamp('2023-11-27 16:36:00'), '+263 78 901 7142', False), Interval: 04:36 PM
# Populated system column 1 at interval 04:36 PM
# Processing entry: (Timestamp('2023-11-27 16:36:00'), '+263 78 901 7142', False), Interval: 04:36 PM
# ...
# Populated system column 1 at interval 03:14 PM
# Processing entry: (Timestamp('2023-11-27 15:53:00'), 'Shubham Madhwal', True), Interval: 03:53 PM
# Populated person column 0 at interval 03:53 PM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 10:00:00'), 'Shubham Madhwal', True), Interval: 10:00 AM
# Initialized new column: 0
# Initialized new column: 1
# Populated person column 0 at interval 10:00 AM
# Processing entry: (Timestamp('2023-11-27 10:01:00'), 'Shubham Madhwal', True), Interval: 10:01 AM
# Populated person column 0 at interval 10:01 AM
# Processing entry: (Timestamp('2023-11-27 11:31:00'), '+263 77 414 0106', False), Interval: 11:31 AM
# Populated system column 1 at interval 11:31 AM
# Processing entry: (Timestamp('2023-11-27 13:33:00'), 'Shubham Madhwal', True), Interval: 01:33 PM
# Populated person column 0 at interval 01:33 PM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 10:40:00'), '+263 77 623 2165', False), Interval: 10:40 AM
# Initialized new column: 0
# Initialized new column: 1
# Populated system column 1 at interval 10:40 AM
# Processing entry: (Timestamp('2023-11-27 10:43:00'), '+263 77 623 2165', False), Interval: 10:43 AM
# Populated system column 1 at interval 10:43 AM
# Processing entry: (Timestamp('2023-11-27 11:15:00'), 'Shubham Madhwal', True), Interval: 11:15 AM
# Populated person column 0 at interval 11:15 AM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 09:58:00'), '+263 77 987 0753', False), Interval: 09:58 AM
# Initialized new column: 0
# Initialized new column: 1
# Populated system column 1 at interval 09:58 AM
# Processing entry: (Timestamp('2023-11-27 10:04:00'), 'Shubham Madhwal', True), Interval: 10:04 AM
# Populated person column 0 at interval 10:04 AM
# Processing entry: (Timestamp('2023-11-27 10:04:00'), '+263 77 987 0753', False), Interval: 10:04 AM
# Populated system column 1 at interval 10:04 AM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 13:26:00'), '+27 78 996 7899', False), Interval: 01:26 PM
# Initialized new column: 0
# Initialized new column: 1
# Populated system column 1 at interval 01:26 PM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 09:58:00'), 'Shubham Madhwal', True), Interval: 09:58 AM
# Initialized new column: 0
# Initialized new column: 1
# Populated person column 0 at interval 09:58 AM
# Processing entry: (Timestamp('2023-11-27 09:58:00'), 'Shubham Madhwal', True), Interval: 09:58 AM
# Populated person column 0 at interval 09:58 AM
# Processing entry: (Timestamp('2023-11-27 09:58:00'), '+263 78 838 3513', False), Interval: 09:58 AM
# Populated system column 1 at interval 09:58 AM
# Processing entry: (Timestamp('2023-11-27 09:58:00'), 'Shubham Madhwal', True), Interval: 09:58 AM
# Populated person column 0 at interval 09:58 AM
# Processing entry: (Timestamp('2023-11-27 10:00:00'), '+263 78 838 3513', False), Interval: 10:00 AM
# Populated system column 1 at interval 10:00 AM
# Processing entry: (Timestamp('2023-11-27 10:01:00'), 'Shubham Madhwal', True), Interval: 10:01 AM
# Populated person column 0 at interval 10:01 AM
# Processing entry: (Timestamp('2023-11-27 10:01:00'), '+263 78 838 3513', False), Interval: 10:01 AM
# Populated system column 1 at interval 10:01 AM
# Processing entry: (Timestamp('2023-11-27 10:03:00'), 'Shubham Madhwal', True), Interval: 10:03 AM
# Populated person column 0 at interval 10:03 AM
# Processing entry: (Timestamp('2023-11-27 10:04:00'), '+263 78 838 3513', False), Interval: 10:04 AM
# Populated system column 1 at interval 10:04 AM
# Processing entry: (Timestamp('2023-11-27 10:04:00'), 'Shubham Madhwal', True), Interval: 10:04 AM
# Populated person column 0 at interval 10:04 AM
# Processing entry: (Timestamp('2023-11-27 10:04:00'), '+263 78 838 3513', False), Interval: 10:04 AM
# Populated system column 1 at interval 10:04 AM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 11:24:00'), '+263 71 914 9450', False), Interval: 11:24 AM
# Initialized new column: 0
# Initialized new column: 1
# Populated system column 1 at interval 11:24 AM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 06:47:00'), 'Shubham Madhwal', True), Interval: 06:47 AM
# Initialized new column: 0
# Initialized new column: 1
# Populated person column 0 at interval 06:47 AM
# Processing entry: (Timestamp('2023-11-27 06:58:00'), 'Shubham Madhwal', True), Interval: 06:58 AM
# Populated person column 0 at interval 06:58 AM
# Processing entry: (Timestamp('2023-11-27 07:00:00'), '+263 77 864 0240', False), Interval: 07:00 AM
# Populated system column 1 at interval 07:00 AM
# Processing entry: (Timestamp('2023-11-27 12:18:00'), '+263 77 864 0240', False), Interval: 12:18 PM
# Populated system column 1 at interval 12:18 PM
# Processing entry: (Timestamp('2023-11-27 12:21:00'), '+263 77 864 0240', False), Interval: 12:21 PM
# Populated system column 1 at interval 12:21 PM
# Processing entry: (Timestamp('2023-11-27 13:22:00'), 'Shubham Madhwal', True), Interval: 01:22 PM
# Populated person column 0 at interval 01:22 PM
# Processing entry: (Timestamp('2023-11-27 13:23:00'), '+263 77 864 0240', False), Interval: 01:23 PM
# Populated system column 1 at interval 01:23 PM
# Processing entry: (Timestamp('2023-11-27 13:24:00'), 'Shubham Madhwal', True), Interval: 01:24 PM
# Populated person column 0 at interval 01:24 PM
# Processing entry: (Timestamp('2023-11-27 13:25:00'), '+263 77 864 0240', False), Interval: 01:25 PM
# Populated system column 1 at interval 01:25 PM
# Processing entry: (Timestamp('2023-11-27 13:26:00'), 'Shubham Madhwal', True), Interval: 01:26 PM
# Populated person column 0 at interval 01:26 PM
# Processing entry: (Timestamp('2023-11-27 13:26:00'), '+263 77 864 0240', False), Interval: 01:26 PM
# Populated system column 1 at interval 01:26 PM
# Processing entry: (Timestamp('2023-11-27 13:26:00'), 'Shubham Madhwal', True), Interval: 01:26 PM
# Populated person column 0 at interval 01:26 PM
# Processing entry: (Timestamp('2023-11-27 13:28:00'), '+263 77 864 0240', False), Interval: 01:28 PM
# Populated system column 1 at interval 01:28 PM
# Processing entry: (Timestamp('2023-11-27 13:37:00'), 'Shubham Madhwal', True), Interval: 01:37 PM
# Populated person column 0 at interval 01:37 PM
# Processing entry: (Timestamp('2023-11-27 13:40:00'), '+263 77 864 0240', False), Interval: 01:40 PM
# Populated system column 1 at interval 01:40 PM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 13:30:00'), 'Shubham Madhwal', True), Interval: 01:30 PM
# Initialized new column: 0
# Initialized new column: 1
# Populated person column 0 at interval 01:30 PM
# Processing entry: (Timestamp('2023-11-27 13:31:00'), 'Shubham Madhwal', True), Interval: 01:31 PM
# Populated person column 0 at interval 01:31 PM
# Processing entry: (Timestamp('2023-11-27 13:32:00'), '+263 71 825 3252', False), Interval: 01:32 PM
# Populated system column 1 at interval 01:32 PM
# Processing entry: (Timestamp('2023-11-27 13:36:00'), 'Shubham Madhwal', True), Interval: 01:36 PM
# Populated person column 0 at interval 01:36 PM
# Processing entry: (Timestamp('2023-11-27 13:36:00'), '+263 71 825 3252', False), Interval: 01:36 PM
# Populated system column 1 at interval 01:36 PM
# Processing entry: (Timestamp('2023-11-27 13:37:00'), 'Shubham Madhwal', True), Interval: 01:37 PM
# Populated person column 0 at interval 01:37 PM
# Processing entry: (Timestamp('2023-11-27 13:38:00'), '+263 71 825 3252', False), Interval: 01:38 PM
# Populated system column 1 at interval 01:38 PM
# Processing entry: (Timestamp('2023-11-27 13:52:00'), 'Shubham Madhwal', True), Interval: 01:52 PM
# Populated person column 0 at interval 01:52 PM
# Processing entry: (Timestamp('2023-11-27 15:38:00'), '+263 71 825 3252', False), Interval: 03:38 PM
# Populated system column 1 at interval 03:38 PM
# Processing entry: (Timestamp('2023-11-27 18:21:00'), 'Shubham Madhwal', True), Interval: 06:21 PM
# Populated person column 0 at interval 06:21 PM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 10:52:00'), '+263 71 543 8646', False), Interval: 10:52 AM
# Initialized new column: 0
# Initialized new column: 1
# Populated system column 1 at interval 10:52 AM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 06:51:00'), 'Shubham Madhwal', True), Interval: 06:51 AM
# Initialized new column: 0
# Initialized new column: 1
# Populated person column 0 at interval 06:51 AM
# Processing entry: (Timestamp('2023-11-27 06:51:00'), 'Shubham Madhwal', True), Interval: 06:51 AM
# Populated person column 0 at interval 06:51 AM
# Processing entry: (Timestamp('2023-11-27 06:53:00'), 'Shubham Madhwal', True), Interval: 06:53 AM
# Populated person column 0 at interval 06:53 AM
# Processing entry: (Timestamp('2023-11-27 12:18:00'), '+27 74 676 1601', False), Interval: 12:18 PM
# Populated system column 1 at interval 12:18 PM
# Processing entry: (Timestamp('2023-11-27 12:18:00'), '+27 74 676 1601', False), Interval: 12:18 PM
# Populated system column 1 at interval 12:18 PM
# Processing entry: (Timestamp('2023-11-27 13:22:00'), 'Shubham Madhwal', True), Interval: 01:22 PM
# Populated person column 0 at interval 01:22 PM
# Processing entry: (Timestamp('2023-11-27 14:05:00'), '+27 74 676 1601', False), Interval: 02:05 PM
# Populated system column 1 at interval 02:05 PM
# Processing entry: (Timestamp('2023-11-27 14:05:00'), '+27 74 676 1601', False), Interval: 02:05 PM
# Populated system column 1 at interval 02:05 PM
# Processing entry: (Timestamp('2023-11-27 14:06:00'), 'Shubham Madhwal', True), Interval: 02:06 PM
# Populated person column 0 at interval 02:06 PM
# Processing entry: (Timestamp('2023-11-27 14:20:00'), '+27 74 676 1601', False), Interval: 02:20 PM
# Populated system column 1 at interval 02:20 PM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 09:58:00'), '+260 97 6182543', False), Interval: 09:58 AM
# Initialized new column: 0
# Initialized new column: 1
# Populated system column 1 at interval 09:58 AM
# Processing entry: (Timestamp('2023-11-27 10:04:00'), 'Shubham Madhwal', True), Interval: 10:04 AM
# Populated person column 0 at interval 10:04 AM
# Processing entry: (Timestamp('2023-11-27 10:04:00'), 'Shubham Madhwal', True), Interval: 10:04 AM
# Populated person column 0 at interval 10:04 AM
# Processing entry: (Timestamp('2023-11-27 10:07:00'), '+260 97 6182543', False), Interval: 10:07 AM
# Populated system column 1 at interval 10:07 AM
# Processing entry: (Timestamp('2023-11-27 11:10:00'), '+260 97 6182543', False), Interval: 11:10 AM
# Populated system column 1 at interval 11:10 AM
# Processing entry: (Timestamp('2023-11-27 13:23:00'), '+260 97 6182543', False), Interval: 01:23 PM
# Populated system column 1 at interval 01:23 PM
# Processing entry: (Timestamp('2023-11-27 13:29:00'), '+260 97 6182543', False), Interval: 01:29 PM
# Populated system column 1 at interval 01:29 PM
# Processing entry: (Timestamp('2023-11-27 13:29:00'), 'Shubham Madhwal', True), Interval: 01:29 PM
# Populated person column 0 at interval 01:29 PM
# Processing entry: (Timestamp('2023-11-27 13:29:00'), 'Shubham Madhwal', True), Interval: 01:29 PM
# Populated person column 0 at interval 01:29 PM
# Processing entry: (Timestamp('2023-11-27 13:32:00'), '+260 97 6182543', False), Interval: 01:32 PM
# Populated system column 1 at interval 01:32 PM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 19:27:00'), 'Shubham Madhwal', True), Interval: 07:27 PM
# Initialized new column: 0
# Initialized new column: 1
# Populated person column 0 at interval 07:27 PM
# Processing entry: (Timestamp('2023-11-27 19:27:00'), 'Shubham Madhwal', True), Interval: 07:27 PM
# Populated person column 0 at interval 07:27 PM
# Processing entry: (Timestamp('2023-11-27 19:30:00'), '+263 78 817 5746', False), Interval: 07:30 PM
# Populated system column 1 at interval 07:30 PM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 07:25:00'), '+27 72 699 5184', False), Interval: 07:25 AM
# Initialized new column: 0
# Initialized new column: 1
# Populated system column 1 at interval 07:25 AM
# Processing entry: (Timestamp('2023-11-27 07:25:00'), '+27 72 699 5184', False), Interval: 07:25 AM
# Populated system column 1 at interval 07:25 AM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 06:48:00'), 'Shubham Madhwal', True), Interval: 06:48 AM
# Initialized new column: 0
# Initialized new column: 1
# Populated person column 0 at interval 06:48 AM
# Processing entry: (Timestamp('2023-11-27 06:49:00'), 'Shubham Madhwal', True), Interval: 06:49 AM
# Populated person column 0 at interval 06:49 AM
# Processing entry: (Timestamp('2023-11-27 19:12:00'), 'Shubham Madhwal', True), Interval: 07:12 PM
# Populated person column 0 at interval 07:12 PM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 07:23:00'), '+263 71 319 2850', False), Interval: 07:23 AM
# Initialized new column: 0
# Initialized new column: 1
# Populated system column 1 at interval 07:23 AM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0
# Processing entry: (Timestamp('2023-11-27 06:39:00'), '+263 78 997 7912', False), Interval: 06:39 AM
# Initialized new column: 0
# Initialized new column: 1
# Populated system column 1 at interval 06:39 AM
# New columns to be added: dict_keys([0, 1])
# Concatenated new columns to DataFrame
# DataFrame after concatenation:           0  1
# 12:00 AM  0  0
# 12:01 AM  0  0
# 12:02 AM  0  0
# 12:03 AM  0  0
# 12:04 AM  0  0

# %%
person_dataframes
# Out:
# {'2023-11-28_Arshita': Empty DataFrame
#  Columns: []
#  Index: [12:00 AM, 12:01 AM, 12:02 AM, 12:03 AM, 12:04 AM, 12:05 AM, 12:06 AM, 12:07 AM, 12:08 AM, 12:09 AM, 12:10 AM, 12:11 AM, 12:12 AM, 12:13 AM, 12:14 AM, 12:15 AM, 12:16 AM, 12:17 AM, 12:18 AM, 12:19 AM, 12:20 AM, 12:21 AM, 12:22 AM, 12:23 AM, 12:24 AM, 12:25 AM, 12:26 AM, 12:27 AM, 12:28 AM, 12:29 AM, 12:30 AM, 12:31 AM, 12:32 AM, 12:33 AM, 12:34 AM, 12:35 AM, 12:36 AM, 12:37 AM, 12:38 AM, 12:39 AM, 12:40 AM, 12:41 AM, 12:42 AM, 12:43 AM, 12:44 AM, 12:45 AM, 12:46 AM, 12:47 AM, 12:48 AM, 12:49 AM, 12:50 AM, 12:51 AM, 12:52 AM, 12:53 AM, 12:54 AM, 12:55 AM, 12:56 AM, 12:57 AM, 12:58 AM, 12:59 AM, 01:00 AM, 01:01 AM, 01:02 AM, 01:03 AM, 01:04 AM, 01:05 AM, 01:06 AM, 01:07 AM, 01:08 AM, 01:09 AM, 01:10 AM, 01:11 AM, 01:12 AM, 01:13 AM, 01:14 AM, 01:15 AM, 01:16 AM, 01:17 AM, 01:18 AM, 01:19 AM, 01:20 AM, 01:21 AM, 01:22 AM, 01:23 AM, 01:24 AM, 01:25 AM, 01:26 AM, 01:27 AM, 01:28 AM, 01:29 AM, 01:30 AM, 01:31 AM, 01:32 AM, 01:33 AM, 01:34 AM, 01:35 AM, 01:36 AM, 01:37 AM, 01:38 AM, 01:39 AM, ...]
#
#  [1440 rows x 0 columns],
#  '2023-11-28_Austin#276': Empty DataFrame
#  Columns: []
#  Index: [12:00 AM, 12:01 AM, 12:02 AM, 12:03 AM, 12:04 AM, 12:05 AM, 12:06 AM, 12:07 AM, 12:08 AM, 12:09 AM, 12:10 AM, 12:11 AM, 12:12 AM, 12:13 AM, 12:14 AM, 12:15 AM, 12:16 AM, 12:17 AM, 12:18 AM, 12:19 AM, 12:20 AM, 12:21 AM, 12:22 AM, 12:23 AM, 12:24 AM, 12:25 AM, 12:26 AM, 12:27 AM, 12:28 AM, 12:29 AM, 12:30 AM, 12:31 AM, 12:32 AM, 12:33 AM, 12:34 AM, 12:35 AM, 12:36 AM, 12:37 AM, 12:38 AM, 12:39 AM, 12:40 AM, 12:41 AM, 12:42 AM, 12:43 AM, 12:44 AM, 12:45 AM, 12:46 AM, 12:47 AM, 12:48 AM, 12:49 AM, 12:50 AM, 12:51 AM, 12:52 AM, 12:53 AM, 12:54 AM, 12:55 AM, 12:56 AM, 12:57 AM, 12:58 AM, 12:59 AM, 01:00 AM, 01:01 AM, 01:02 AM, 01:03 AM, 01:04 AM, 01:05 AM, 01:06 AM, 01:07 AM, 01:08 AM, 01:09 AM, 01:10 AM, 01:11 AM, 01:12 AM, 01:13 AM, 01:14 AM, 01:15 AM, 01:16 AM, 01:17 AM, 01:18 AM, 01:19 AM, 01:20 AM, 01:21 AM, 01:22 AM, 01:23 AM, 01:24 AM, 01:25 AM, 01:26 AM, 01:27 AM, 01:28 AM, 01:29 AM, 01:30 AM, 01:31 AM, 01:32 AM, 01:33 AM, 01:34 AM, 01:35 AM, 01:36 AM, 01:37 AM, 01:38 AM, 01:39 AM, ...]
#
#  [1440 rows x 0 columns],
#  '2023-11-28_Harmehak': Empty DataFrame
#  Columns: []
#  Index: [12:00 AM, 12:01 AM, 12:02 AM, 12:03 AM, 12:04 AM, 12:05 AM, 12:06 AM, 12:07 AM, 12:08 AM, 12:09 AM, 12:10 AM, 12:11 AM, 12:12 AM, 12:13 AM, 12:14 AM, 12:15 AM, 12:16 AM, 12:17 AM, 12:18 AM, 12:19 AM, 12:20 AM, 12:21 AM, 12:22 AM, 12:23 AM, 12:24 AM, 12:25 AM, 12:26 AM, 12:27 AM, 12:28 AM, 12:29 AM, 12:30 AM, 12:31 AM, 12:32 AM, 12:33 AM, 12:34 AM, 12:35 AM, 12:36 AM, 12:37 AM, 12:38 AM, 12:39 AM, 12:40 AM, 12:41 AM, 12:42 AM, 12:43 AM, 12:44 AM, 12:45 AM, 12:46 AM, 12:47 AM, 12:48 AM, 12:49 AM, 12:50 AM, 12:51 AM, 12:52 AM, 12:53 AM, 12:54 AM, 12:55 AM, 12:56 AM, 12:57 AM, 12:58 AM, 12:59 AM, 01:00 AM, 01:01 AM, 01:02 AM, 01:03 AM, 01:04 AM, 01:05 AM, 01:06 AM, 01:07 AM, 01:08 AM, 01:09 AM, 01:10 AM, 01:11 AM, 01:12 AM, 01:13 AM, 01:14 AM, 01:15 AM, 01:16 AM, 01:17 AM, 01:18 AM, 01:19 AM, 01:20 AM, 01:21 AM, 01:22 AM, 01:23 AM, 01:24 AM, 01:25 AM, 01:26 AM, 01:27 AM, 01:28 AM, 01:29 AM, 01:30 AM, 01:31 AM, 01:32 AM, 01:33 AM, 01:34 AM, 01:35 AM, 01:36 AM, 01:37 AM, 01:38 AM, 01:39 AM, ...]
#
#  [1440 rows x 0 columns],
#  '2023-11-28_Pallika Edoofa': Empty DataFrame
#  Columns: []
#  Index: [12:00 AM, 12:01 AM, 12:02 AM, 12:03 AM, 12:04 AM, 12:05 AM, 12:06 AM, 12:07 AM, 12:08 AM, 12:09 AM, 12:10 AM, 12:11 AM, 12:12 AM, 12:13 AM, 12:14 AM, 12:15 AM, 12:16 AM, 12:17 AM, 12:18 AM, 12:19 AM, 12:20 AM, 12:21 AM, 12:22 AM, 12:23 AM, 12:24 AM, 12:25 AM, 12:26 AM, 12:27 AM, 12:28 AM, 12:29 AM, 12:30 AM, 12:31 AM, 12:32 AM, 12:33 AM, 12:34 AM, 12:35 AM, 12:36 AM, 12:37 AM, 12:38 AM, 12:39 AM, 12:40 AM, 12:41 AM, 12:42 AM, 12:43 AM, 12:44 AM, 12:45 AM, 12:46 AM, 12:47 AM, 12:48 AM, 12:49 AM, 12:50 AM, 12:51 AM, 12:52 AM, 12:53 AM, 12:54 AM, 12:55 AM, 12:56 AM, 12:57 AM, 12:58 AM, 12:59 AM, 01:00 AM, 01:01 AM, 01:02 AM, 01:03 AM, 01:04 AM, 01:05 AM, 01:06 AM, 01:07 AM, 01:08 AM, 01:09 AM, 01:10 AM, 01:11 AM, 01:12 AM, 01:13 AM, 01:14 AM, 01:15 AM, 01:16 AM, 01:17 AM, 01:18 AM, 01:19 AM, 01:20 AM, 01:21 AM, 01:22 AM, 01:23 AM, 01:24 AM, 01:25 AM, 01:26 AM, 01:27 AM, 01:28 AM, 01:29 AM, 01:30 AM, 01:31 AM, 01:32 AM, 01:33 AM, 01:34 AM, 01:35 AM, 01:36 AM, 01:37 AM, 01:38 AM, 01:39 AM, ...]
#
#  [1440 rows x 0 columns],
#  '2023-11-28_Sagar': Empty DataFrame
#  Columns: []
#  Index: [12:00 AM, 12:01 AM, 12:02 AM, 12:03 AM, 12:04 AM, 12:05 AM, 12:06 AM, 12:07 AM, 12:08 AM, 12:09 AM, 12:10 AM, 12:11 AM, 12:12 AM, 12:13 AM, 12:14 AM, 12:15 AM, 12:16 AM, 12:17 AM, 12:18 AM, 12:19 AM, 12:20 AM, 12:21 AM, 12:22 AM, 12:23 AM, 12:24 AM, 12:25 AM, 12:26 AM, 12:27 AM, 12:28 AM, 12:29 AM, 12:30 AM, 12:31 AM, 12:32 AM, 12:33 AM, 12:34 AM, 12:35 AM, 12:36 AM, 12:37 AM, 12:38 AM, 12:39 AM, 12:40 AM, 12:41 AM, 12:42 AM, 12:43 AM, 12:44 AM, 12:45 AM, 12:46 AM, 12:47 AM, 12:48 AM, 12:49 AM, 12:50 AM, 12:51 AM, 12:52 AM, 12:53 AM, 12:54 AM, 12:55 AM, 12:56 AM, 12:57 AM, 12:58 AM, 12:59 AM, 01:00 AM, 01:01 AM, 01:02 AM, 01:03 AM, 01:04 AM, 01:05 AM, 01:06 AM, 01:07 AM, 01:08 AM, 01:09 AM, 01:10 AM, 01:11 AM, 01:12 AM, 01:13 AM, 01:14 AM, 01:15 AM, 01:16 AM, 01:17 AM, 01:18 AM, 01:19 AM, 01:20 AM, 01:21 AM, 01:22 AM, 01:23 AM, 01:24 AM, 01:25 AM, 01:26 AM, 01:27 AM, 01:28 AM, 01:29 AM, 01:30 AM, 01:31 AM, 01:32 AM, 01:33 AM, 01:34 AM, 01:35 AM, 01:36 AM, 01:37 AM, 01:38 AM, 01:39 AM, ...]
#
#  [1440 rows x 0 columns],
#  '2023-11-28_Sahil Edoofa': Empty DataFrame
#  Columns: []
#  Index: [12:00 AM, 12:01 AM, 12:02 AM, 12:03 AM, 12:04 AM, 12:05 AM, 12:06 AM, 12:07 AM, 12:08 AM, 12:09 AM, 12:10 AM, 12:11 AM, 12:12 AM, 12:13 AM, 12:14 AM, 12:15 AM, 12:16 AM, 12:17 AM, 12:18 AM, 12:19 AM, 12:20 AM, 12:21 AM, 12:22 AM, 12:23 AM, 12:24 AM, 12:25 AM, 12:26 AM, 12:27 AM, 12:28 AM, 12:29 AM, 12:30 AM, 12:31 AM, 12:32 AM, 12:33 AM, 12:34 AM, 12:35 AM, 12:36 AM, 12:37 AM, 12:38 AM, 12:39 AM, 12:40 AM, 12:41 AM, 12:42 AM, 12:43 AM, 12:44 AM, 12:45 AM, 12:46 AM, 12:47 AM, 12:48 AM, 12:49 AM, 12:50 AM, 12:51 AM, 12:52 AM, 12:53 AM, 12:54 AM, 12:55 AM, 12:56 AM, 12:57 AM, 12:58 AM, 12:59 AM, 01:00 AM, 01:01 AM, 01:02 AM, 01:03 AM, 01:04 AM, 01:05 AM, 01:06 AM, 01:07 AM, 01:08 AM, 01:09 AM, 01:10 AM, 01:11 AM, 01:12 AM, 01:13 AM, 01:14 AM, 01:15 AM, 01:16 AM, 01:17 AM, 01:18 AM, 01:19 AM, 01:20 AM, 01:21 AM, 01:22 AM, 01:23 AM, 01:24 AM, 01:25 AM, 01:26 AM, 01:27 AM, 01:28 AM, 01:29 AM, 01:30 AM, 01:31 AM, 01:32 AM, 01:33 AM, 01:34 AM, 01:35 AM, 01:36 AM, 01:37 AM, 01:38 AM, 01:39 AM, ...]
#
#  [1440 rows x 0 columns],
#  '2023-11-28_Shashwat Edoofa 2': Empty DataFrame
#  Columns: []
#  Index: [12:00 AM, 12:01 AM, 12:02 AM, 12:03 AM, 12:04 AM, 12:05 AM, 12:06 AM, 12:07 AM, 12:08 AM, 12:09 AM, 12:10 AM, 12:11 AM, 12:12 AM, 12:13 AM, 12:14 AM, 12:15 AM, 12:16 AM, 12:17 AM, 12:18 AM, 12:19 AM, 12:20 AM, 12:21 AM, 12:22 AM, 12:23 AM, 12:24 AM, 12:25 AM, 12:26 AM, 12:27 AM, 12:28 AM, 12:29 AM, 12:30 AM, 12:31 AM, 12:32 AM, 12:33 AM, 12:34 AM, 12:35 AM, 12:36 AM, 12:37 AM, 12:38 AM, 12:39 AM, 12:40 AM, 12:41 AM, 12:42 AM, 12:43 AM, 12:44 AM, 12:45 AM, 12:46 AM, 12:47 AM, 12:48 AM, 12:49 AM, 12:50 AM, 12:51 AM, 12:52 AM, 12:53 AM, 12:54 AM, 12:55 AM, 12:56 AM, 12:57 AM, 12:58 AM, 12:59 AM, 01:00 AM, 01:01 AM, 01:02 AM, 01:03 AM, 01:04 AM, 01:05 AM, 01:06 AM, 01:07 AM, 01:08 AM, 01:09 AM, 01:10 AM, 01:11 AM, 01:12 AM, 01:13 AM, 01:14 AM, 01:15 AM, 01:16 AM, 01:17 AM, 01:18 AM, 01:19 AM, 01:20 AM, 01:21 AM, 01:22 AM, 01:23 AM, 01:24 AM, 01:25 AM, 01:26 AM, 01:27 AM, 01:28 AM, 01:29 AM, 01:30 AM, 01:31 AM, 01:32 AM, 01:33 AM, 01:34 AM, 01:35 AM, 01:36 AM, 01:37 AM, 01:38 AM, 01:39 AM, ...]
#
#  [1440 rows x 0 columns],
#  '2023-11-28_Shubham Madhwal': Empty DataFrame
#  Columns: []
#  Index: [12:00 AM, 12:01 AM, 12:02 AM, 12:03 AM, 12:04 AM, 12:05 AM, 12:06 AM, 12:07 AM, 12:08 AM, 12:09 AM, 12:10 AM, 12:11 AM, 12:12 AM, 12:13 AM, 12:14 AM, 12:15 AM, 12:16 AM, 12:17 AM, 12:18 AM, 12:19 AM, 12:20 AM, 12:21 AM, 12:22 AM, 12:23 AM, 12:24 AM, 12:25 AM, 12:26 AM, 12:27 AM, 12:28 AM, 12:29 AM, 12:30 AM, 12:31 AM, 12:32 AM, 12:33 AM, 12:34 AM, 12:35 AM, 12:36 AM, 12:37 AM, 12:38 AM, 12:39 AM, 12:40 AM, 12:41 AM, 12:42 AM, 12:43 AM, 12:44 AM, 12:45 AM, 12:46 AM, 12:47 AM, 12:48 AM, 12:49 AM, 12:50 AM, 12:51 AM, 12:52 AM, 12:53 AM, 12:54 AM, 12:55 AM, 12:56 AM, 12:57 AM, 12:58 AM, 12:59 AM, 01:00 AM, 01:01 AM, 01:02 AM, 01:03 AM, 01:04 AM, 01:05 AM, 01:06 AM, 01:07 AM, 01:08 AM, 01:09 AM, 01:10 AM, 01:11 AM, 01:12 AM, 01:13 AM, 01:14 AM, 01:15 AM, 01:16 AM, 01:17 AM, 01:18 AM, 01:19 AM, 01:20 AM, 01:21 AM, 01:22 AM, 01:23 AM, 01:24 AM, 01:25 AM, 01:26 AM, 01:27 AM, 01:28 AM, 01:29 AM, 01:30 AM, 01:31 AM, 01:32 AM, 01:33 AM, 01:34 AM, 01:35 AM, 01:36 AM, 01:37 AM, 01:38 AM, 01:39 AM, ...]
#
#  [1440 rows x 0 columns],
#  '2023-11-28_Tushti': Empty DataFrame
#  Columns: []
#  Index: [12:00 AM, 12:01 AM, 12:02 AM, 12:03 AM, 12:04 AM, 12:05 AM, 12:06 AM, 12:07 AM, 12:08 AM, 12:09 AM, 12:10 AM, 12:11 AM, 12:12 AM, 12:13 AM, 12:14 AM, 12:15 AM, 12:16 AM, 12:17 AM, 12:18 AM, 12:19 AM, 12:20 AM, 12:21 AM, 12:22 AM, 12:23 AM, 12:24 AM, 12:25 AM, 12:26 AM, 12:27 AM, 12:28 AM, 12:29 AM, 12:30 AM, 12:31 AM, 12:32 AM, 12:33 AM, 12:34 AM, 12:35 AM, 12:36 AM, 12:37 AM, 12:38 AM, 12:39 AM, 12:40 AM, 12:41 AM, 12:42 AM, 12:43 AM, 12:44 AM, 12:45 AM, 12:46 AM, 12:47 AM, 12:48 AM, 12:49 AM, 12:50 AM, 12:51 AM, 12:52 AM, 12:53 AM, 12:54 AM, 12:55 AM, 12:56 AM, 12:57 AM, 12:58 AM, 12:59 AM, 01:00 AM, 01:01 AM, 01:02 AM, 01:03 AM, 01:04 AM, 01:05 AM, 01:06 AM, 01:07 AM, 01:08 AM, 01:09 AM, 01:10 AM, 01:11 AM, 01:12 AM, 01:13 AM, 01:14 AM, 01:15 AM, 01:16 AM, 01:17 AM, 01:18 AM, 01:19 AM, 01:20 AM, 01:21 AM, 01:22 AM, 01:23 AM, 01:24 AM, 01:25 AM, 01:26 AM, 01:27 AM, 01:28 AM, 01:29 AM, 01:30 AM, 01:31 AM, 01:32 AM, 01:33 AM, 01:34 AM, 01:35 AM, 01:36 AM, 01:37 AM, 01:38 AM, 01:39 AM, ...]
#
#  [1440 rows x 0 columns]}

# %%
# Save each dataframe as a CSV file in the current working directory for testing purpose only, will be omiited in real application

for key, df in person_dataframes.items():
    csv_file_path = f"csvs/{key}.csv"
    df.to_csv(csv_file_path)
    print(f"Saved DataFrame to {csv_file_path}")
# Out:
# Saved DataFrame to csvs/2023-11-28_Arshita.csv
# Saved DataFrame to csvs/2023-11-28_Austin#276.csv
# Saved DataFrame to csvs/2023-11-28_Harmehak.csv
# Saved DataFrame to csvs/2023-11-28_Pallika Edoofa.csv
# Saved DataFrame to csvs/2023-11-28_Sagar.csv
# Saved DataFrame to csvs/2023-11-28_Sahil Edoofa.csv
# Saved DataFrame to csvs/2023-11-28_Shashwat Edoofa 2.csv
# Saved DataFrame to csvs/2023-11-28_Shubham Madhwal.csv
# Saved DataFrame to csvs/2023-11-28_Tushti.csv
