# %%
import os
import pandas as pd
import re
import datetime
import logging

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logging.basicConfig(level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s')


# Function to list all chat files in the directory structure
def list_chat_files(date_directory):
    chat_files = []
    for date_folder in os.listdir(date_directory):
        date_path = os.path.join(date_directory, date_folder)
        if os.path.isdir(date_path):
            for team_folder in os.listdir(date_path):
                team_path = os.path.join(date_path, team_folder)
                if os.path.isdir(team_path):
                    for person_folder in os.listdir(team_path):
                        person_path = os.path.join(team_path, person_folder)
                        if os.path.isdir(person_path):
                            for file in os.listdir(person_path):
                                if file.endswith('.txt'):
                                    chat_files.append(os.path.join(person_path, file))
    return chat_files

def parse_chat_file_for_delay_analysis(file_path):
    # Extract person_name and date from the file path
    person_name = os.path.basename(os.path.dirname(file_path))
    folder_date_str = os.path.basename(os.path.dirname(os.path.dirname(os.path.dirname(file_path))))
    expected_date_minus_one = pd.to_datetime(folder_date_str, format='%Y-%m-%d').date() - datetime.timedelta(days=1)

    delay_messages = []

    with open(file_path, 'r', encoding='utf-8') as file:
        lines = file.readlines()

    last_person_msg_time = None
    last_person_msg_index = None

    for i, line in enumerate(lines):
        message_match = re.match(r'(\d{2}/\d{2}/\d{2}, \d{1,2}:\d{2} [ap]m) - (.*?): (.*)', line)
        if message_match:
            date_time_str, sender, message = message_match.groups()
            date_time = pd.to_datetime(date_time_str, format='%d/%m/%y, %I:%M %p')

            if date_time.date() != expected_date_minus_one:
                continue

            # Check if the sender is a person (not purely numeric or starting with +)
            is_person = sender is not None and not (sender.strip().isnumeric() or sender.startswith('+'))

            logging.info(f"Sender: {sender}, Is Person: {is_person}, Message: {message}")  # Debug line

            if is_person:
                if last_person_msg_time is not None:
                    # Calculate the time difference in minutes
                    time_diff_seconds = (date_time - last_person_msg_time).total_seconds()
                    time_diff_minutes = time_diff_seconds / 60
                    logging.info(f"Time Difference (minutes): {time_diff_minutes}")  # Debug line
                    if time_diff_minutes > 15:
                        # There is a delay
                        delay = True
                    else:
                        # No delay
                        delay = False
                        time_diff_minutes = None
                else:
                    # No previous message from a person
                    delay = False
                    time_diff_minutes = None
                last_person_msg_time = date_time
                last_person_msg_index = i
            else:
                # Not a message from a person
                delay = False
                time_diff_minutes = None

            if delay:
                # Fetch reference messages
                start_index = max(last_person_msg_index - 3, 0)
                end_index = min(i + 4, len(lines) - 1)
                reference_msgs = lines[start_index:end_index + 1]

                delay_messages.append((date_time, sender, message, delay, time_diff_minutes, reference_msgs))

    return delay_messages, file_path

            
def process_all_files(chat_files):
    all_delay_messages = []

    for file_path in chat_files:
        logging.info(f"Processing file: {file_path}")  # Debug line
        delay_messages, file_path = parse_chat_file_for_delay_analysis(file_path)
        all_delay_messages.extend(delay_messages)

    return all_delay_messages


def create_delay_data_dataframe(all_delay_data):
    columns = ['Date', 'Person', 'Chat Group Name', 'Delay', 'Delay in Mins', 'Reference Messages']
    df_data = []

    for delay_instance in all_delay_data:
        date_time, sender, message, delay, time_diff_minutes, reference_msgs, file_path = delay_instance

        # Use the file name as the chat group name
        chat_group_name = os.path.basename(file_path)

        df_data.append([date_time, sender, chat_group_name, delay, time_diff_minutes, reference_msgs])

    delay_df = pd.DataFrame(df_data, columns=columns)
    return delay_df






# Main Execution
date_directory = "C:\\Users\\mauriceyeng\\Python\\Daily-Reports\\Test\\filtered_chats"
chat_files = list_chat_files(date_directory)
all_delay_data = process_all_files(chat_files)
delay_analysis_df = create_delay_data_dataframe(all_delay_data)

# Display the first few rows of the DataFrame
print(delay_analysis_df.head())
# Out:
# 2023-11-29 16:22:04,954 - INFO - Processing file: C:\Users\mauriceyeng\Python\Daily-Reports\Test\filtered_chats\2023-11-28\SALES\Arshita\WhatsApp Chat with Abdul_Edoofa(28_11)AA.txt
# 2023-11-29 16:22:04,955 - INFO - Sender: Arshita, Is Person: True, Message: 11/20/2023 11:33:18	Abdulrazak Abdullahi 	abdulrazak2abdul@gmail.com	+234906443753	3/27/2001	Male	Al-ihsan mallawa academy 	Private	Nigeria 	Abdullahi shuaibu 	+2347033854402	civil servant 	Aishatu Abdullahi 	+2349036605586	Housewife 	Bachelors Course	chemical engineering 	2019	2021	Yes	Close Friend or Relative.
# 2023-11-29 16:22:04,956 - INFO - Sender: Arshita, Is Person: True, Message: Source: Nirnoy EWYL23E0617
# 2023-11-29 16:22:04,956 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:04,957 - INFO - Sender: Arshita, Is Person: True, Message: Add child
# 2023-11-29 16:22:04,957 - INFO - Time Difference (minutes): 100.0
# 2023-11-29 16:22:04,958 - INFO - Sender: Arshita, Is Person: True, Message: Greetings !
# 2023-11-29 16:22:04,958 - INFO - Time Difference (minutes): 11.0
# 2023-11-29 16:22:04,959 - INFO - Sender: Arshita, Is Person: True, Message: <Media omitted>
# 2023-11-29 16:22:04,959 - INFO - Time Difference (minutes): 5.0
# 2023-11-29 16:22:04,959 - INFO - Sender: Arshita, Is Person: True, Message: <Media omitted>
# 2023-11-29 16:22:04,961 - INFO - Time Difference (minutes): 1.0
# 2023-11-29 16:22:04,961 - INFO - Processing file: C:\Users\mauriceyeng\Python\Daily-Reports\Test\filtered_chats\2023-11-28\SALES\Arshita\WhatsApp Chat with Alinafe_Edoofa(14_11)AA.txt
# 2023-11-29 16:22:04,966 - INFO - Sender: Arshita, Is Person: True, Message: Greetings!
# 2023-11-29 16:22:04,967 - INFO - Sender: Arshita, Is Person: True, Message: Greetings everyone
# 2023-11-29 16:22:04,967 - INFO - Time Difference (minutes): 413.0
# 2023-11-29 16:22:04,967 - INFO - Processing file: C:\Users\mauriceyeng\Python\Daily-Reports\Test\filtered_chats\2023-11-28\SALES\Arshita\WhatsApp Chat with Alistair_Edoofa(07_11)AA.txt
# 2023-11-29 16:22:04,987 - INFO - Sender: +263 77 211 4784, Is Person: False, Message: Greetings
# 2023-11-29 16:22:04,987 - INFO - Sender: Arshita, Is Person: True, Message: Greetings!
# 2023-11-29 16:22:04,987 - INFO - Sender: +263 77 211 4784, Is Person: False, Message: We are good, how about you
# 2023-11-29 16:22:04,987 - INFO - Sender: Arshita, Is Person: True, Message: Good to hear that!
# 2023-11-29 16:22:04,987 - INFO - Time Difference (minutes): 74.0
# 2023-11-29 16:22:04,987 - INFO - Sender: Arshita, Is Person: True, Message: Are you willing to continue the edoofa scholarship program?
# 2023-11-29 16:22:04,987 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:04,987 - INFO - Sender: +263 77 211 4784, Is Person: False, Message: Yes, with regards to the request that we made last time
# 2023-11-29 16:22:04,987 - INFO - Sender: +263 77 211 4784, Is Person: False, Message: The request was that Alistair wants to pursue Aerospace Engineering, but you said he doesn't qualify with his combination of
# 2023-11-29 16:22:04,987 - INFO - Sender: Arshita, Is Person: True, Message: No,besides computet science with the given combination he can only pursue :
# 2023-11-29 16:22:04,994 - INFO - Time Difference (minutes): 19.0
# 2023-11-29 16:22:04,995 - INFO - Sender: +263 77 211 4784, Is Person: False, Message: Ok, now I remember you saying that, and our conclusion was that you speak to Alistair about it and find out from him if he is interested and be willing to take any of those three.
# 2023-11-29 16:22:04,995 - INFO - Sender: +263 77 211 4784, Is Person: False, Message: We as parents wouldn't have to force him to divert his attention from what he is mostly interested in.
# 2023-11-29 16:22:04,996 - INFO - Sender: Arshita, Is Person: True, Message: I can understand that!
# 2023-11-29 16:22:04,997 - INFO - Time Difference (minutes): 14.0
# 2023-11-29 16:22:04,998 - INFO - Sender: +263 77 211 4784, Is Person: False, Message: Will let you know today evening
# 2023-11-29 16:22:04,999 - INFO - Processing file: C:\Users\mauriceyeng\Python\Daily-Reports\Test\filtered_chats\2023-11-28\SALES\Arshita\WhatsApp Chat with Andrea_Edoofa(14_11)AA.txt
# 2023-11-29 16:22:05,028 - INFO - Sender: Arshita, Is Person: True, Message: Sorry to hear about your father!
# 2023-11-29 16:22:05,028 - INFO - Sender: +263 77 686 8729, Is Person: False, Message: Am trying... thank you
# 2023-11-29 16:22:05,029 - INFO - Processing file: C:\Users\mauriceyeng\Python\Daily-Reports\Test\filtered_chats\2023-11-28\SALES\Arshita\WhatsApp Chat with Anenishe_Edoofa(24_11)AA.txt
# 2023-11-29 16:22:05,029 - INFO - Sender: Arshita, Is Person: True, Message: Let us connect at  *11:30 pm CAT on Tuesday(28/11/23) to resume your session (In case you have any challenges or lessons, you can let me know and we will plan accordingly)*
# 2023-11-29 16:22:05,029 - INFO - Sender: Arshita, Is Person: True, Message: <Media omitted>
# 2023-11-29 16:22:05,029 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,029 - INFO - Processing file: C:\Users\mauriceyeng\Python\Daily-Reports\Test\filtered_chats\2023-11-28\SALES\Arshita\WhatsApp Chat with Angel_Edoofa(16_11)AA.txt
# 2023-11-29 16:22:05,037 - INFO - Sender: Arshita, Is Person: True, Message: Greetings!
# 2023-11-29 16:22:05,037 - INFO - Sender: Arshita, Is Person: True, Message: Greetings everyone
# 2023-11-29 16:22:05,038 - INFO - Time Difference (minutes): 415.0
# 2023-11-29 16:22:05,038 - INFO - Processing file: C:\Users\mauriceyeng\Python\Daily-Reports\Test\filtered_chats\2023-11-28\SALES\Arshita\WhatsApp Chat with Asher_Edoofa(28_11)AA.txt
# 2023-11-29 16:22:05,039 - INFO - Sender: Arshita, Is Person: True, Message: *Offline Application Form Zimbabwe* -
# 2023-11-29 16:22:05,040 - INFO - Sender: Arshita, Is Person: True, Message: Organic
# 2023-11-29 16:22:05,040 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,041 - INFO - Sender: Arshita, Is Person: True, Message: Greetings !
# 2023-11-29 16:22:05,041 - INFO - Time Difference (minutes): 117.0
# 2023-11-29 16:22:05,043 - INFO - Sender: Arshita, Is Person: True, Message: <Media omitted>
# 2023-11-29 16:22:05,043 - INFO - Time Difference (minutes): 2.0
# 2023-11-29 16:22:05,044 - INFO - Sender: Arshita, Is Person: True, Message: <Media omitted>
# 2023-11-29 16:22:05,044 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,044 - INFO - Sender: +263 78 298 5241, Is Person: False, Message: Thank you
# 2023-11-29 16:22:05,045 - INFO - Sender: +263 77 288 9434, Is Person: False, Message: This message was deleted
# 2023-11-29 16:22:05,046 - INFO - Sender: +263 77 288 9434, Is Person: False, Message: Could you please reschedule the meeting to the 4th or 11th of December sametime. Thank you
# 2023-11-29 16:22:05,046 - INFO - Processing file: C:\Users\mauriceyeng\Python\Daily-Reports\Test\filtered_chats\2023-11-28\SALES\Arshita\WhatsApp Chat with Ashley_Edoofa(21_11)AA.txt
# 2023-11-29 16:22:05,048 - INFO - Sender: Arshita, Is Person: True, Message: Greetings!
# 2023-11-29 16:22:05,049 - INFO - Sender: Arshita, Is Person: True, Message: Let us connect at  *11:30 pm CAT on Tuesday(28/11/23) to resume your session (In case you have any challenges or lessons, you can let me know and we will plan accordingly)*
# 2023-11-29 16:22:05,050 - INFO - Time Difference (minutes): 421.0
# 2023-11-29 16:22:05,050 - INFO - Sender: Arshita, Is Person: True, Message: <Media omitted>
# 2023-11-29 16:22:05,050 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,051 - INFO - Processing file: C:\Users\mauriceyeng\Python\Daily-Reports\Test\filtered_chats\2023-11-28\SALES\Arshita\WhatsApp Chat with Audrey_Edoofa(15_11)AA.txt
# 2023-11-29 16:22:05,056 - INFO - Sender: Arshita, Is Person: True, Message: Greetings!
# 2023-11-29 16:22:05,057 - INFO - Sender: Arshita, Is Person: True, Message: Greetings everyone
# 2023-11-29 16:22:05,057 - INFO - Time Difference (minutes): 415.0
# 2023-11-29 16:22:05,057 - INFO - Processing file: C:\Users\mauriceyeng\Python\Daily-Reports\Test\filtered_chats\2023-11-28\SALES\Arshita\WhatsApp Chat with Bopoto_Edoofa(24_11)AA.txt
# 2023-11-29 16:22:05,064 - INFO - Sender: Arshita, Is Person: True, Message: Greetings!
# 2023-11-29 16:22:05,065 - INFO - Sender: +263 71 499 2767, Is Person: False, Message: good afternoon
# 2023-11-29 16:22:05,065 - INFO - Sender: +263 71 499 2767, Is Person: False, Message: yes
# 2023-11-29 16:22:05,065 - INFO - Sender: Arshita, Is Person: True, Message: Greetings!
# 2023-11-29 16:22:05,065 - INFO - Time Difference (minutes): 2.0
# 2023-11-29 16:22:05,065 - INFO - Sender: +263 71 499 2767, Is Person: False, Message: l'm good and you
# 2023-11-29 16:22:05,065 - INFO - Sender: Arshita, Is Person: True, Message: Good to hear that!
# 2023-11-29 16:22:05,065 - INFO - Time Difference (minutes): 7.0
# 2023-11-29 16:22:05,065 - INFO - Sender: Arshita, Is Person: True, Message: I hope you are aware that studying abroad involves a financial aspect. May I know who will support you financially with your education abroad?
# 2023-11-29 16:22:05,065 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,065 - INFO - Sender: +263 71 499 2767, Is Person: False, Message: my parents
# 2023-11-29 16:22:05,071 - INFO - Sender: Arshita, Is Person: True, Message: That is well noted.
# 2023-11-29 16:22:05,071 - INFO - Time Difference (minutes): 57.0
# 2023-11-29 16:22:05,071 - INFO - Sender: Arshita, Is Person: True, Message: Can you please confirm me your subjects in A level?
# 2023-11-29 16:22:05,071 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,071 - INFO - Sender: +263 71 499 2767, Is Person: False, Message: mathematics, biology and chemistry
# 2023-11-29 16:22:05,071 - INFO - Sender: Arshita, Is Person: True, Message: That is well noted
# 2023-11-29 16:22:05,071 - INFO - Time Difference (minutes): 23.0
# 2023-11-29 16:22:05,071 - INFO - Sender: Arshita, Is Person: True, Message: I would like to brief you that, as per the eligibility criteria before the covid, the minimum points required was 6 points in order to be eligible for the scholarship. But during the covid, the Government realized that not all students from African countries, in your case from Zimbabwe, are from a privileged background to afford a private high school, tuition, resources and online lessons. In order to help the students get a quality education and a scholarship, the Government has reconsidered the eligibility criteria and *as per the latest guidelines, the eligibility for the scholarship is a minimum of 2 Advanced Level passes.*
# 2023-11-29 16:22:05,071 - INFO - Time Difference (minutes): 64.0
# 2023-11-29 16:22:05,071 - INFO - Sender: Arshita, Is Person: True, Message: Let us connect at  *11:30 pm CAT on Tuesday(28/11/23) to resume your session (In case you have any challenges or lessons, you can let me know and we will plan accordingly)*
# 2023-11-29 16:22:05,071 - INFO - Time Difference (minutes): 266.0
# 2023-11-29 16:22:05,071 - INFO - Sender: Arshita, Is Person: True, Message: <Media omitted>
# 2023-11-29 16:22:05,071 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,077 - INFO - Processing file: C:\Users\mauriceyeng\Python\Daily-Reports\Test\filtered_chats\2023-11-28\SALES\Arshita\WhatsApp Chat with Caleb_Edoofa(23_11)AA.txt
# 2023-11-29 16:22:05,084 - INFO - Sender: Arshita, Is Person: True, Message: Greetings!
# 2023-11-29 16:22:05,084 - INFO - Sender: +263 78 599 2436, Is Person: False, Message: Yes
# 2023-11-29 16:22:05,084 - INFO - Sender: Arshita, Is Person: True, Message: Greetings!
# 2023-11-29 16:22:05,084 - INFO - Time Difference (minutes): 14.0
# 2023-11-29 16:22:05,084 - INFO - Sender: +263 78 599 2436, Is Person: False, Message: Im fine
# 2023-11-29 16:22:05,084 - INFO - Sender: Arshita, Is Person: True, Message: Good to hear that!
# 2023-11-29 16:22:05,084 - INFO - Time Difference (minutes): 2.0
# 2023-11-29 16:22:05,084 - INFO - Sender: Arshita, Is Person: True, Message: Have you confirmed the same with her?
# 2023-11-29 16:22:05,084 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,084 - INFO - Sender: +263 78 599 2436, Is Person: False, Message: This message was deleted
# 2023-11-29 16:22:05,084 - INFO - Sender: +263 78 599 2436, Is Person: False, Message: This message was deleted
# 2023-11-29 16:22:05,084 - INFO - Sender: +263 78 599 2436, Is Person: False, Message: Yes i confirmed
# 2023-11-29 16:22:05,091 - INFO - Sender: Arshita, Is Person: True, Message: Noted.
# 2023-11-29 16:22:05,091 - INFO - Time Difference (minutes): 19.0
# 2023-11-29 16:22:05,091 - INFO - Sender: Arshita, Is Person: True, Message: Do you have any past experience of learning in the field of accounts?
# 2023-11-29 16:22:05,091 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,091 - INFO - Sender: +263 78 599 2436, Is Person: False, Message: No
# 2023-11-29 16:22:05,091 - INFO - Sender: Arshita, Is Person: True, Message: That is well noted.
# 2023-11-29 16:22:05,091 - INFO - Time Difference (minutes): 35.0
# 2023-11-29 16:22:05,091 - INFO - Sender: +263 78 599 2436, Is Person: False, Message: Im awaiting for my A level results.
# 2023-11-29 16:22:05,091 - INFO - Sender: Arshita, Is Person: True, Message: That is well noted
# 2023-11-29 16:22:05,091 - INFO - Time Difference (minutes): 29.0
# 2023-11-29 16:22:05,091 - INFO - Sender: Arshita, Is Person: True, Message: I would like to brief you that, as per the eligibility criteria before the covid, the minimum points required was 6 points in order to be eligible for the scholarship. But during the covid, the Government realized that not all students from African countries, in your case from Zimbabwe, are from a privileged background to afford a private high school, tuition, resources and online lessons. In order to help the students get a quality education and a scholarship, the Government has reconsidered the eligibility criteria and *as per the latest guidelines, the eligibility for the scholarship is a minimum of 2 Advanced Level passes.*
# 2023-11-29 16:22:05,091 - INFO - Time Difference (minutes): 2.0
# 2023-11-29 16:22:05,098 - INFO - Sender: +263 78 599 2436, Is Person: False, Message: Yes
# 2023-11-29 16:22:05,098 - INFO - Sender: Arshita, Is Person: True, Message: As your evaluation progress, I would like to appreciate your interest in studying abroad, there are only a few who dream of such opportunities with the existing constraints in the country. In this process did you make any prior research on foreign education or applied to any University abroad?
# 2023-11-29 16:22:05,098 - INFO - Time Difference (minutes): 42.0
# 2023-11-29 16:22:05,098 - INFO - Sender: +263 78 599 2436, Is Person: False, Message: No
# 2023-11-29 16:22:05,098 - INFO - Sender: Arshita, Is Person: True, Message: I understand !
# 2023-11-29 16:22:05,098 - INFO - Time Difference (minutes): 2.0
# 2023-11-29 16:22:05,098 - INFO - Sender: Arshita, Is Person: True, Message: <Media omitted>
# 2023-11-29 16:22:05,098 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,098 - INFO - Sender: Arshita, Is Person: True, Message: Let me know once you are done
# 2023-11-29 16:22:05,098 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,098 - INFO - Sender: +263 78 599 2436, Is Person: False, Message: Ok
# 2023-11-29 16:22:05,098 - INFO - Sender: Arshita, Is Person: True, Message: Let us connect at  *11:30 pm CAT on Tuesday(28/11/23) to resume your session (In case you have any challenges or lessons, you can let me know and we will plan accordingly)*
# 2023-11-29 16:22:05,098 - INFO - Time Difference (minutes): 275.0
# 2023-11-29 16:22:05,098 - INFO - Sender: Arshita, Is Person: True, Message: <Media omitted>
# 2023-11-29 16:22:05,105 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,106 - INFO - Processing file: C:\Users\mauriceyeng\Python\Daily-Reports\Test\filtered_chats\2023-11-28\SALES\Arshita\WhatsApp Chat with Caroline_Edoofa(15_11)AA.txt
# 2023-11-29 16:22:05,133 - INFO - Sender: Arshita, Is Person: True, Message: Good to hear that!
# 2023-11-29 16:22:05,133 - INFO - Sender: +263 77 616 3640, Is Person: False, Message: Good morning.
# 2023-11-29 16:22:05,133 - INFO - Sender: Arshita, Is Person: True, Message: Caroline, The most important process of your eligibility check stage is your scholarship interview with the Program Director at Edoofa. Shall I share the schedule for the same?
# 2023-11-29 16:22:05,133 - INFO - Time Difference (minutes): 47.0
# 2023-11-29 16:22:05,133 - INFO - Sender: +263 77 616 3640, Is Person: False, Message: Yes maam
# 2023-11-29 16:22:05,133 - INFO - Sender: Arshita, Is Person: True, Message: Will you be available at 1:00 pm CAT Tomorrow for your final interview with a stable network to send and download WhatsApp voice notes?
# 2023-11-29 16:22:05,133 - INFO - Time Difference (minutes): 7.0
# 2023-11-29 16:22:05,133 - INFO - Sender: +263 77 616 3640, Is Person: False, Message: I will try my best.
# 2023-11-29 16:22:05,133 - INFO - Sender: Arshita, Is Person: True, Message: Caroline, Your final interview is scheduled for *1:00 PM CAT tomorrow(28/11/2023)* Let me share the guidelines with you that you need to keep in mind during the interview.
# 2023-11-29 16:22:05,133 - INFO - Time Difference (minutes): 10.0
# 2023-11-29 16:22:05,133 - INFO - Sender: Arshita, Is Person: True, Message: Please share the following details for your interview purpose
# 2023-11-29 16:22:05,133 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,133 - INFO - Sender: +263 77 616 3640, Is Person: False, Message: plakedes@92gmail.com
# 2023-11-29 16:22:05,140 - INFO - Sender: +263 77 616 3640, Is Person: False, Message: Year of intake :2025
# 2023-11-29 16:22:05,140 - INFO - Sender: Arshita, Is Person: True, Message: Please share a picture of your national ID too
# 2023-11-29 16:22:05,140 - INFO - Time Difference (minutes): 171.0
# 2023-11-29 16:22:05,140 - INFO - Sender: +263 77 612 0392, Is Person: False, Message: plakedes92@gmail.com
# 2023-11-29 16:22:05,140 - INFO - Processing file: C:\Users\mauriceyeng\Python\Daily-Reports\Test\filtered_chats\2023-11-28\SALES\Arshita\WhatsApp Chat with Chido_Edoofa(28_11)AA-IE.txt
# 2023-11-29 16:22:05,140 - INFO - Sender: Arshita, Is Person: True, Message: *Offline Application Form*
# 2023-11-29 16:22:05,140 - INFO - Sender: Arshita, Is Person: True, Message: Abigail EWYL22E1215-IE-300
# 2023-11-29 16:22:05,140 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,140 - INFO - Sender: Arshita, Is Person: True, Message: Greetings !
# 2023-11-29 16:22:05,140 - INFO - Time Difference (minutes): 116.0
# 2023-11-29 16:22:05,147 - INFO - Sender: Arshita, Is Person: True, Message: <Media omitted>
# 2023-11-29 16:22:05,147 - INFO - Time Difference (minutes): 1.0
# 2023-11-29 16:22:05,147 - INFO - Sender: Arshita, Is Person: True, Message: <Media omitted>
# 2023-11-29 16:22:05,147 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,147 - INFO - Processing file: C:\Users\mauriceyeng\Python\Daily-Reports\Test\filtered_chats\2023-11-28\SALES\Arshita\WhatsApp Chat with Chipise_Edoofa(22_11)AA.txt
# 2023-11-29 16:22:05,161 - INFO - Sender: Arshita, Is Person: True, Message: Greetings!
# 2023-11-29 16:22:05,161 - INFO - Sender: Arshita, Is Person: True, Message: Let us connect at  *11:30 pm CAT on Tuesday(28/11/23) to resume your session (In case you have any challenges or lessons, you can let me know and we will plan accordingly)*
# 2023-11-29 16:22:05,161 - INFO - Time Difference (minutes): 421.0
# 2023-11-29 16:22:05,161 - INFO - Sender: Arshita, Is Person: True, Message: <Media omitted>
# 2023-11-29 16:22:05,161 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,161 - INFO - Processing file: C:\Users\mauriceyeng\Python\Daily-Reports\Test\filtered_chats\2023-11-28\SALES\Arshita\WhatsApp Chat with Christabell_Edoofa(31_10)AA.txt
# 2023-11-29 16:22:05,189 - INFO - Sender: Arshita, Is Person: True, Message: Alright , we have come to the end of your counselling session, now before I guide you for Step 2 which is the Eligibility Check.
# 2023-11-29 16:22:05,189 - INFO - Sender: Arshita, Is Person: True, Message: To learn more about the type of students we look for, please go through these videos in which Edoofians from your country have shared their experience
# 2023-11-29 16:22:05,196 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,196 - INFO - Sender: Arshita, Is Person: True, Message: For any question apart from whatever has been discussed, I would appreciate it if you refer to the FAQ document which has answers to most of the queries. Furthermore, if you have any other query I would suggest that you note down all of the questions and get back to me
# 2023-11-29 16:22:05,196 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,196 - INFO - Sender: Arshita, Is Person: True, Message: Let me also share with you few pictures of Edoofians in India
# 2023-11-29 16:22:05,196 - INFO - Time Difference (minutes): 1.0
# 2023-11-29 16:22:05,196 - INFO - Sender: Arshita, Is Person: True, Message: <Media omitted>
# 2023-11-29 16:22:05,196 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,196 - INFO - Sender: Arshita, Is Person: True, Message: <Media omitted>
# 2023-11-29 16:22:05,196 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,196 - INFO - Sender: Arshita, Is Person: True, Message: <Media omitted>
# 2023-11-29 16:22:05,196 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,196 - INFO - Sender: Arshita, Is Person: True, Message: <Media omitted>
# 2023-11-29 16:22:05,196 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,196 - INFO - Sender: Arshita, Is Person: True, Message: <Media omitted>
# 2023-11-29 16:22:05,196 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,203 - INFO - Sender: Arshita, Is Person: True, Message: <Media omitted>
# 2023-11-29 16:22:05,203 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,203 - INFO - Sender: Arshita, Is Person: True, Message: <Media omitted>
# 2023-11-29 16:22:05,203 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,203 - INFO - Sender: Arshita, Is Person: True, Message: <Media omitted>
# 2023-11-29 16:22:05,203 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,203 - INFO - Sender: Arshita, Is Person: True, Message: <Media omitted>
# 2023-11-29 16:22:05,203 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,203 - INFO - Sender: Arshita, Is Person: True, Message: <Media omitted>
# 2023-11-29 16:22:05,203 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,203 - INFO - Sender: Arshita, Is Person: True, Message: <Media omitted>
# 2023-11-29 16:22:05,203 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,203 - INFO - Sender: Arshita, Is Person: True, Message: <Media omitted>
# 2023-11-29 16:22:05,203 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,210 - INFO - Sender: Arshita, Is Person: True, Message: Let me connect you with Valerie Rukobo, as she is a Zimbabwean Student who has completed BCA(Bachelor Of Computer Applications) from India through the Edoofa program. It is her 5th year here in India.
# 2023-11-29 16:22:05,211 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,211 - INFO - Sender: Arshita, Is Person: True, Message: 2 contacts.vcf (file attached)
# 2023-11-29 16:22:05,212 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,212 - INFO - Sender: Arshita, Is Person: True, Message: I will be informing you about the time for the next session very soon!
# 2023-11-29 16:22:05,213 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,213 - INFO - Sender: +27 78 092 7023, Is Person: False, Message: Okay
# 2023-11-29 16:22:05,213 - INFO - Sender: Arshita, Is Person: True, Message: It was a pleasure to host the session with you today!
# 2023-11-29 16:22:05,213 - INFO - Time Difference (minutes): 456.0
# 2023-11-29 16:22:05,213 - INFO - Processing file: C:\Users\mauriceyeng\Python\Daily-Reports\Test\filtered_chats\2023-11-28\SALES\Arshita\WhatsApp Chat with Deka_Edoofa(15_11)AA.txt
# 2023-11-29 16:22:05,220 - INFO - Sender: Arshita, Is Person: True, Message: Greetings!
# 2023-11-29 16:22:05,220 - INFO - Sender: Arshita, Is Person: True, Message: Greetings everyone
# 2023-11-29 16:22:05,220 - INFO - Time Difference (minutes): 415.0
# 2023-11-29 16:22:05,220 - INFO - Processing file: C:\Users\mauriceyeng\Python\Daily-Reports\Test\filtered_chats\2023-11-28\SALES\Arshita\WhatsApp Chat with Delight_Edoofa(21_11)AA.txt
# 2023-11-29 16:22:05,234 - INFO - Sender: Arshita, Is Person: True, Message: Greetings!
# 2023-11-29 16:22:05,234 - INFO - Sender: Arshita, Is Person: True, Message: Let us connect at  *11:30 pm CAT on Tuesday(28/11/23) to resume your session (In case you have any challenges or lessons, you can let me know and we will plan accordingly)*
# 2023-11-29 16:22:05,234 - INFO - Time Difference (minutes): 421.0
# 2023-11-29 16:22:05,238 - INFO - Sender: Arshita, Is Person: True, Message: <Media omitted>
# 2023-11-29 16:22:05,238 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,239 - INFO - Processing file: C:\Users\mauriceyeng\Python\Daily-Reports\Test\filtered_chats\2023-11-28\SALES\Arshita\WhatsApp Chat with Elitha_Edoofa(20_11)AA-IE.txt
# 2023-11-29 16:22:05,256 - INFO - Sender: Arshita, Is Person: True, Message: Greetings!
# 2023-11-29 16:22:05,257 - INFO - Sender: +263 78 341 4424, Is Person: False, Message: Hi how are you
# 2023-11-29 16:22:05,258 - INFO - Sender: +263 78 341 4424, Is Person: False, Message: Yes we can begin with the session
# 2023-11-29 16:22:05,258 - INFO - Sender: Arshita, Is Person: True, Message: Greetings!
# 2023-11-29 16:22:05,259 - INFO - Time Difference (minutes): 71.0
# 2023-11-29 16:22:05,260 - INFO - Sender: Arshita, Is Person: True, Message: Are we still connected?
# 2023-11-29 16:22:05,260 - INFO - Time Difference (minutes): 85.0
# 2023-11-29 16:22:05,261 - INFO - Sender: Arshita, Is Person: True, Message: Let us connect at  *11:30 pm CAT on Tuesday(28/11/23) to resume your session (In case you have any challenges or lessons, you can let me know and we will plan accordingly)*
# 2023-11-29 16:22:05,261 - INFO - Time Difference (minutes): 262.0
# 2023-11-29 16:22:05,261 - INFO - Processing file: C:\Users\mauriceyeng\Python\Daily-Reports\Test\filtered_chats\2023-11-28\SALES\Arshita\WhatsApp Chat with Emmanuel_Edoofa(16_11)AA.txt
# 2023-11-29 16:22:05,266 - INFO - Sender: Arshita, Is Person: True, Message: Greetings!
# 2023-11-29 16:22:05,266 - INFO - Sender: Arshita, Is Person: True, Message: Greetings everyone
# 2023-11-29 16:22:05,266 - INFO - Time Difference (minutes): 415.0
# 2023-11-29 16:22:05,266 - INFO - Processing file: C:\Users\mauriceyeng\Python\Daily-Reports\Test\filtered_chats\2023-11-28\SALES\Arshita\WhatsApp Chat with Faith_Edoofa(28_11)AA.txt
# 2023-11-29 16:22:05,266 - INFO - Sender: Arshita, Is Person: True, Message: 11/12/2023 21:35:42	Faith Munetsi	munetsifaith6@gmail.com	+263775846699	9/27/2002	Female	St Joseph's high school 	Zimbabwe 	Elton 	He passed 	He passed 	Esnathy	0773800398	Self employed 	Bachelor	Physiotherapy 	Others	Others	From Proud Edoofian
# 2023-11-29 16:22:05,266 - INFO - Sender: Arshita, Is Person: True, Message: Source: Organic
# 2023-11-29 16:22:05,266 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,266 - INFO - Sender: Arshita, Is Person: True, Message: +263773800398
# 2023-11-29 16:22:05,266 - INFO - Time Difference (minutes): 100.0
# 2023-11-29 16:22:05,272 - INFO - Sender: Arshita, Is Person: True, Message: Greetings !
# 2023-11-29 16:22:05,273 - INFO - Time Difference (minutes): 11.0
# 2023-11-29 16:22:05,273 - INFO - Sender: Arshita, Is Person: True, Message: <Media omitted>
# 2023-11-29 16:22:05,274 - INFO - Time Difference (minutes): 4.0
# 2023-11-29 16:22:05,275 - INFO - Sender: Arshita, Is Person: True, Message: <Media omitted>
# 2023-11-29 16:22:05,275 - INFO - Time Difference (minutes): 1.0
# 2023-11-29 16:22:05,276 - INFO - Sender: +263 77 584 6699, Is Person: False, Message: Since it  stated that it offers 50% scholarship,is there chance for me to do work study inorder to pay for that 50% which I'm not offered
# 2023-11-29 16:22:05,276 - INFO - Sender: Arshita, Is Person: True, Message: Greetings!
# 2023-11-29 16:22:05,277 - INFO - Time Difference (minutes): 12.0
# 2023-11-29 16:22:05,277 - INFO - Sender: +263 77 584 6699, Is Person: False, Message: Okay thank you
# 2023-11-29 16:22:05,278 - INFO - Processing file: C:\Users\mauriceyeng\Python\Daily-Reports\Test\filtered_chats\2023-11-28\SALES\Arshita\WhatsApp Chat with Greathyl_Edoofa(23_11)AA.txt
# 2023-11-29 16:22:05,286 - INFO - Sender: Arshita, Is Person: True, Message: If you have understood the course well, can you tell me how you see yourself in 5 years after your course and If you are provided with this career option and how can being an Edoofian enable you to achieve your career goals?
# 2023-11-29 16:22:05,287 - INFO - Sender: +263 78 733 4360, Is Person: False, Message: In the next five years would mean after I'm done with the 4year course, is it?
# 2023-11-29 16:22:05,288 - INFO - Sender: Arshita, Is Person: True, Message: Yes <This message was edited>
# 2023-11-29 16:22:05,288 - INFO - Time Difference (minutes): 8.0
# 2023-11-29 16:22:05,289 - INFO - Sender: +263 78 733 4360, Is Person: False, Message: I see myself helping patients who have undergone surgery or have serious medical conditions that require rehabilitation as a physiotherapist
# 2023-11-29 16:22:05,289 - INFO - Sender: Arshita, Is Person: True, Message: I am glad that you are willing to work hard for your career.I believe you will be researching more about the course in detail.
# 2023-11-29 16:22:05,289 - INFO - Time Difference (minutes): 4.0
# 2023-11-29 16:22:05,289 - INFO - Sender: +263 78 733 4360, Is Person: False, Message: From what i have researched about the Indian Education System I have learnt that it offers top-notch education especially in the field of science because of innovation, research, and technology. Also the Indian educational system is more accessible, adaptable, and practical as a result of technology. I have also learnt that its technology-based educational programme offers a larger selection of subjects.
# 2023-11-29 16:22:05,289 - INFO - Sender: Arshita, Is Person: True, Message: Good to know about your knowledge
# 2023-11-29 16:22:05,289 - INFO - Time Difference (minutes): 9.0
# 2023-11-29 16:22:05,293 - INFO - Sender: Arshita, Is Person: True, Message: Let me tell you why Edoofa recommends India for higher education.
# 2023-11-29 16:22:05,293 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,294 - INFO - Sender: Arshita, Is Person: True, Message: *1. It’s Home to the World’s Second-Largest Higher Education System*- The Indian Education system is the world's second largest Higher Education System with more than 1000+ universities, 39,931 colleges and a capacity of enrolling more than a whopping 20 million students. Higher Education Institutions in India offer courses/degrees that are competitive in the world market in terms of quality but are delivered at one fourth the cost, hence guaranteeing value-for-money education and has led to a robust placement oriented education as about 200 of the Fortune 500 companies hire regularly from Indian campuses.
# 2023-11-29 16:22:05,294 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,295 - INFO - Sender: Arshita, Is Person: True, Message: *2. Its Universities Are Well-Ranked and Climbing*- From politics/law to philosophy and biology to business and media/journalism there’s something for everyone in India’s massive higher education system. Indian education ranges from exposure to the latest advancements of science and technology like Virtual and Augmented Reality, Artificial Intelligence and Cognitive Computing to Yoga, Ayurveda, Sanskrit and classical dances.
# 2023-11-29 16:22:05,295 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,296 - INFO - Sender: Arshita, Is Person: True, Message: *3. It’ Affordable*- Compared to many of the world’s finest institutions, India’s low cost of education is a bargain. Additionally, various scholarships, loans, and financial schemes are available to offset the cost.
# 2023-11-29 16:22:05,296 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,296 - INFO - Sender: Arshita, Is Person: True, Message: *4. It’s the fastest growing Economy in the World*- India’s economy continues to surge. Not only do experts predict that it will be the world’s third-largest economy by 2030.India is also well known for Comprehensive Tax System,Business Friendly Laws,Low Operational Costs for Corporates and Industries,Vast trade Network,International Alliances and Work Ethics
# 2023-11-29 16:22:05,296 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,296 - INFO - Sender: Arshita, Is Person: True, Message: *5.Global Recognition of Indian Education*- Did you know that the CEOs of Google, Microsoft,IBM,Adobe are all Indians? 18 % of doctors in the US are Indians, as are 36 % of the scientists at the National Aeronautics and Space Administration (NASA) are Indians and 34 % of Microsoft employees are Indians as well, all of this is possible because of the education system in India.
# 2023-11-29 16:22:05,296 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,296 - INFO - Sender: Arshita, Is Person: True, Message: *6 Cultural Harmony and inclusiveness*- India is a country with diversities in Caste,creed,colour,culture,costume,convictions and cuisines.People come from different backgrounds and there is a Unity in this Diversity that makes India Unique. India ranks second in terms of the Number of English Speaking people in the world making India the most preferred destination for higher education for International Students
# 2023-11-29 16:22:05,300 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,301 - INFO - Sender: Arshita, Is Person: True, Message: Let me also show you some facts about India and global leaders who are the product of Indian Education.
# 2023-11-29 16:22:05,301 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,302 - INFO - Sender: Arshita, Is Person: True, Message: <Media omitted>
# 2023-11-29 16:22:05,302 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,303 - INFO - Sender: Arshita, Is Person: True, Message: <Media omitted>
# 2023-11-29 16:22:05,303 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,304 - INFO - Sender: Arshita, Is Person: True, Message: <Media omitted>
# 2023-11-29 16:22:05,304 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,304 - INFO - Sender: Arshita, Is Person: True, Message: <Media omitted>
# 2023-11-29 16:22:05,304 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,304 - INFO - Sender: +263 78 733 4360, Is Person: False, Message: That's informative
# 2023-11-29 16:22:05,307 - INFO - Sender: +263 78 733 4360, Is Person: False, Message: Thank you so much
# 2023-11-29 16:22:05,307 - INFO - Sender: Arshita, Is Person: True, Message: Well I am sure after seeing all these amazing facts, you are intrigued to study in India.So can you now tell me,How would studying in India implement a positive impact on your career and How do you aim to achieve your career aspirations by studying in India?
# 2023-11-29 16:22:05,308 - INFO - Time Difference (minutes): 13.0
# 2023-11-29 16:22:05,308 - INFO - Sender: +263 78 733 4360, Is Person: False, Message: am very intrigued actually
# 2023-11-29 16:22:05,309 - INFO - Sender: Arshita, Is Person: True, Message: As I can see,you have understood the quality of higher education which Edoofa aims to provide the students so that after completing the Education the student is capable enough to achieve their career aspirations and have a successful career ahead.
# 2023-11-29 16:22:05,309 - INFO - Time Difference (minutes): 13.0
# 2023-11-29 16:22:05,310 - INFO - Sender: +263 78 733 4360, Is Person: False, Message: I am not very sure
# 2023-11-29 16:22:05,310 - INFO - Sender: Arshita, Is Person: True, Message: Let me share with you the cost of higher education in India with respect to other countries in depth!
# 2023-11-29 16:22:05,311 - INFO - Time Difference (minutes): 2.0
# 2023-11-29 16:22:05,312 - INFO - Sender: Arshita, Is Person: True, Message: <Media omitted>
# 2023-11-29 16:22:05,312 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,312 - INFO - Sender: Arshita, Is Person: True, Message: Looking at the reduced cost of education, do you feel it is affordable to your family?
# 2023-11-29 16:22:05,312 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,313 - INFO - Sender: +263 78 733 4360, Is Person: False, Message: Yes that is quite affordable and it's reduced as well
# 2023-11-29 16:22:05,314 - INFO - Sender: Arshita, Is Person: True, Message: Good to know that!
# 2023-11-29 16:22:05,314 - INFO - Time Difference (minutes): 31.0
# 2023-11-29 16:22:05,315 - INFO - Sender: +263 78 733 4360, Is Person: False, Message: No can you please explain further and what the career opportunities might be?
# 2023-11-29 16:22:05,315 - INFO - Sender: Arshita, Is Person: True, Message: Let me tell you how Edoofa helps Edoofians bring down the fees themselves and make them affordable. It is through the
# 2023-11-29 16:22:05,316 - INFO - Time Difference (minutes): 4.0
# 2023-11-29 16:22:05,316 - INFO - Sender: Arshita, Is Person: True, Message: The Earn While You Learn Program or the EWYL Program is the backbone of Edoofa and the unique aspect of the whole program. It is a program in which the students are given real-time live online projects during which they gain excellent work experience while getting the opportunity to earn scholarship credits (based on student’s performance) that is equivalent to physical cash. However, the credits can be used to pay off a significant part of their higher education fees and make their university education more affordable.
# 2023-11-29 16:22:05,317 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,317 - INFO - Sender: Arshita, Is Person: True, Message: The EWYL Program, therefore, is going to help in the overall growth of a student and help them provide a boost in keeping up with the changing market strategies, needs, and tactics. Promising a better future for its students, and converting an Individual into a Market Ready Professional. Who would have every weapon in their arsenal to conquer the place they shall be landing their foot in.
# 2023-11-29 16:22:05,318 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,318 - INFO - Sender: Arshita, Is Person: True, Message: *Projects with Brands and Companies:* -
# 2023-11-29 16:22:05,318 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,318 - INFO - Sender: Arshita, Is Person: True, Message: *Recruitment Partners:* -
# 2023-11-29 16:22:05,320 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,321 - INFO - Sender: Arshita, Is Person: True, Message: * Webinars:* -
# 2023-11-29 16:22:05,321 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,322 - INFO - Sender: Arshita, Is Person: True, Message: <Media omitted>
# 2023-11-29 16:22:05,322 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,323 - INFO - Sender: Arshita, Is Person: True, Message: What are your views on the same? Do you think you will be benefiting from the Earn WHile You Learn Program?
# 2023-11-29 16:22:05,323 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,323 - INFO - Sender: Arshita, Is Person: True, Message: Let us connect at  *11:30 pm CAT on Tuesday(28/11/23) to resume your session (In case you have any challenges or lessons, you can let me know and we will plan accordingly)*
# 2023-11-29 16:22:05,323 - INFO - Time Difference (minutes): 228.0
# 2023-11-29 16:22:05,323 - INFO - Sender: Arshita, Is Person: True, Message: <Media omitted>
# 2023-11-29 16:22:05,323 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,323 - INFO - Processing file: C:\Users\mauriceyeng\Python\Daily-Reports\Test\filtered_chats\2023-11-28\SALES\Arshita\WhatsApp Chat with Gumbo_Edoofa(24_11)AA.txt
# 2023-11-29 16:22:05,329 - INFO - Sender: Arshita, Is Person: True, Message: Greetings!
# 2023-11-29 16:22:05,330 - INFO - Sender: Arshita, Is Person: True, Message: Let us connect at  *11:30 pm CAT on Tuesday(28/11/23) to resume your session (In case you have any challenges or lessons, you can let me know and we will plan accordingly)*
# 2023-11-29 16:22:05,330 - INFO - Time Difference (minutes): 419.0
# 2023-11-29 16:22:05,330 - INFO - Sender: Arshita, Is Person: True, Message: <Media omitted>
# 2023-11-29 16:22:05,330 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,330 - INFO - Processing file: C:\Users\mauriceyeng\Python\Daily-Reports\Test\filtered_chats\2023-11-28\SALES\Arshita\WhatsApp Chat with Homokade_Edoofa(28_11)AA.txt
# 2023-11-29 16:22:05,335 - INFO - Sender: Arshita, Is Person: True, Message: Homokade Tufedapwa
# 2023-11-29 16:22:05,335 - INFO - Sender: Arshita, Is Person: True, Message: Source: Organic Lead- Others
# 2023-11-29 16:22:05,336 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,336 - INFO - Sender: Arshita, Is Person: True, Message: This message was deleted
# 2023-11-29 16:22:05,337 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,337 - INFO - Sender: Arshita, Is Person: True, Message: This message was deleted
# 2023-11-29 16:22:05,337 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,337 - INFO - Sender: Arshita, Is Person: True, Message: Greetings !
# 2023-11-29 16:22:05,337 - INFO - Time Difference (minutes): 108.0
# 2023-11-29 16:22:05,337 - INFO - Sender: Arshita, Is Person: True, Message: <Media omitted>
# 2023-11-29 16:22:05,337 - INFO - Time Difference (minutes): 12.0
# 2023-11-29 16:22:05,337 - INFO - Sender: Arshita, Is Person: True, Message: <Media omitted>
# 2023-11-29 16:22:05,337 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,342 - INFO - Sender: +234 810 853 8550, Is Person: False, Message: Hello
# 2023-11-29 16:22:05,342 - INFO - Processing file: C:\Users\mauriceyeng\Python\Daily-Reports\Test\filtered_chats\2023-11-28\SALES\Arshita\WhatsApp Chat with Joyleen_Edoofa(23_11)AA.txt
# 2023-11-29 16:22:05,345 - INFO - Sender: Arshita, Is Person: True, Message: Greetings!
# 2023-11-29 16:22:05,345 - INFO - Sender: Arshita, Is Person: True, Message: Let us connect at  *11:30 pm CAT on Tuesday(28/11/23) to resume your session (In case you have any challenges or lessons, you can let me know and we will plan accordingly)*
# 2023-11-29 16:22:05,345 - INFO - Time Difference (minutes): 420.0
# 2023-11-29 16:22:05,348 - INFO - Sender: Arshita, Is Person: True, Message: <Media omitted>
# 2023-11-29 16:22:05,349 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,349 - INFO - Processing file: C:\Users\mauriceyeng\Python\Daily-Reports\Test\filtered_chats\2023-11-28\SALES\Arshita\WhatsApp Chat with Lenos_Edoofa(24_11)AA.txt
# 2023-11-29 16:22:05,359 - INFO - Sender: +263 78 077 4346, Is Person: False, Message: Hello
# 2023-11-29 16:22:05,359 - INFO - Sender: Arshita, Is Person: True, Message: Greetings!
# 2023-11-29 16:22:05,359 - INFO - Sender: +263 78 077 4346, Is Person: False, Message: Yes
# 2023-11-29 16:22:05,359 - INFO - Sender: Arshita, Is Person: True, Message: Greetings!
# 2023-11-29 16:22:05,359 - INFO - Time Difference (minutes): 1.0
# 2023-11-29 16:22:05,362 - INFO - Sender: +263 78 077 4346, Is Person: False, Message: Today lm very well and ready to carry on
# 2023-11-29 16:22:05,363 - INFO - Sender: Arshita, Is Person: True, Message: Good to know that!
# 2023-11-29 16:22:05,363 - INFO - Time Difference (minutes): 12.0
# 2023-11-29 16:22:05,364 - INFO - Sender: Arshita, Is Person: True, Message: I can understand that but it is not possible!
# 2023-11-29 16:22:05,364 - INFO - Time Difference (minutes): 1.0
# 2023-11-29 16:22:05,365 - INFO - Sender: +263 78 077 4346, Is Person: False, Message: I did talk to parul university and they said its possible
# 2023-11-29 16:22:05,366 - INFO - Sender: Arshita, Is Person: True, Message: <Media omitted>
# 2023-11-29 16:22:05,366 - INFO - Time Difference (minutes): 10.0
# 2023-11-29 16:22:05,366 - INFO - Sender: Arshita, Is Person: True, Message: Lenos you can see that these are the requirements for the engineering . These are set by the All India Council for Technical Education which is the regulatory body in India .
# 2023-11-29 16:22:05,366 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,366 - INFO - Sender: Arshita, Is Person: True, Message: First of all, the degree shared by Parul Universities are not recognized on a global level, if after spending $3000 for education abroad, degrees are not considered in other countries, would that be a worthwhile investment?
# 2023-11-29 16:22:05,370 - INFO - Time Difference (minutes): 1.0
# 2023-11-29 16:22:05,370 - INFO - Sender: Arshita, Is Person: True, Message: *The most important reason is that the University isn't ranked under the  NIRF ranking under the Ministry of Education of the Government of India!*
# 2023-11-29 16:22:05,371 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,372 - INFO - Sender: Arshita, Is Person: True, Message: https://www.nirfindia.org/2021/Ranking.html
# 2023-11-29 16:22:05,372 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,373 - INFO - Sender: +263 78 077 4346, Is Person: False, Message: So walk me into computer science engineering
# 2023-11-29 16:22:05,374 - INFO - Sender: Arshita, Is Person: True, Message: That is well noted
# 2023-11-29 16:22:05,374 - INFO - Time Difference (minutes): 41.0
# 2023-11-29 16:22:05,374 - INFO - Sender: Arshita, Is Person: True, Message: B.Tech. Computer Science
# 2023-11-29 16:22:05,374 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:05,376 - INFO - Sender: +263 78 077 4346, Is Person: False, Message: Thats great l will take that
# 2023-11-29 16:22:05,377 - INFO - Sender: Arshita, Is Person: True, Message: If you have understood the course well, can you tell me how you see yourself in 5 years after your course and If you are provided with this career option and how can being an Edoofian enable you to achieve your career goals?
# 2023-11-29 16:22:05,377 - INFO - Time Difference (minutes): 9.0
# 2023-11-29 16:22:05,378 - INFO - Sender: +263 78 077 4346, Is Person: False, Message: I see myself as a computer science engineer specialised as a software engineer and from what l have observed from my research edoofa can help me to study in one of the best universities in that field and it can help reduce the costs that my struggling parents cannot afford and thanks to this program l see myself as a successful young man
# 2023-11-29 16:22:05,379 - INFO - Sender: Arshita, Is Person: True, Message: I am glad that you are willing to work hard for your career.I believe you will be researching more about the course in detail.
# 2023-11-29 16:22:05,379 - INFO - Time Difference (minutes): 9.0
# 2023-11-29 16:22:05,380 - INFO - Sender: +263 78 077 4346, Is Person: False, Message: That l have not looked at
# 2023-11-29 16:22:05,380 - INFO - Sender: Arshita, Is Person: True, Message: Let me tell you why Edoofa recommends India for higher education.
# 2023-11-29 16:22:05,381 - INFO - Time Difference (minutes): 52.0
# 2023-11-29 16:22:05,381 - INFO - Sender: Arshita, Is Person: True, Message: *1. It’s Home to the World’s Second-Largest Higher Education System*- The Indian Education system is the world's second largest Higher Education System with more than 1000+ universities, 39,931 colleges and a capacity of enrolling more than a whopping 20 million students. Higher Education Institutions in India offer courses/degrees that are competitive in the world market in terms of quality but are delivered at one fourth the cost, hence guaranteeing value-for-money education and has led to a robust placement oriented education as about 200 of the Fortune 500 companies hire regularly from Indian campuses.
# 2023-11-29 16:22:05,381 - INFO - Time Difference (minutes): 0.0
# ...
# 2023-11-29 16:22:20,767 - INFO - Time Difference (minutes): 212.0
# 2023-11-29 16:22:20,767 - INFO - Processing file: C:\Users\mauriceyeng\Python\Daily-Reports\Test\filtered_chats\2023-11-28\SALES\Shubham Madhwal\WhatsApp Chat with Panash_EDOOFAMHS(14_11)TR.txt
# 2023-11-29 16:22:20,815 - INFO - Sender: +263 77 623 2165, Is Person: False, Message: Counsellor Name: Ms Tushti
# 2023-11-29 16:22:20,816 - INFO - Sender: +263 77 623 2165, Is Person: False, Message: Good morning Mr Shubham
# 2023-11-29 16:22:20,816 - INFO - Sender: Shubham Madhwal, Is Person: True, Message: Duly received please!
# 2023-11-29 16:22:20,817 - INFO - Processing file: C:\Users\mauriceyeng\Python\Daily-Reports\Test\filtered_chats\2023-11-28\SALES\Shubham Madhwal\WhatsApp Chat with Quinton Mudzi_Edoofa(16_11)SM23.txt
# 2023-11-29 16:22:20,850 - INFO - Sender: +263 77 987 0753, Is Person: False, Message: Ok
# 2023-11-29 16:22:20,850 - INFO - Sender: Shubham Madhwal, Is Person: True, Message: Shall I share the slots for the call today with you?
# 2023-11-29 16:22:20,850 - INFO - Sender: +263 77 987 0753, Is Person: False, Message: Let me check when my mom is free
# 2023-11-29 16:22:20,850 - INFO - Processing file: C:\Users\mauriceyeng\Python\Daily-Reports\Test\filtered_chats\2023-11-28\SALES\Shubham Madhwal\WhatsApp Chat with Rutendo Chitate_EDOOFA(30_10)SM23.txt
# 2023-11-29 16:22:20,888 - INFO - Sender: +27 78 996 7899, Is Person: False, Message: Good day Sir.
# 2023-11-29 16:22:20,888 - INFO - Processing file: C:\Users\mauriceyeng\Python\Daily-Reports\Test\filtered_chats\2023-11-28\SALES\Shubham Madhwal\WhatsApp Chat with Senior Tafanehama_EA(08_11)TR.txt
# 2023-11-29 16:22:20,919 - INFO - Sender: Shubham Madhwal, Is Person: True, Message: Good Morning @263788383513
# 2023-11-29 16:22:20,935 - INFO - Sender: Shubham Madhwal, Is Person: True, Message: Duly noted please!
# 2023-11-29 16:22:20,935 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:20,935 - INFO - Sender: +263 78 838 3513, Is Person: False, Message: Good morning sir
# 2023-11-29 16:22:20,935 - INFO - Sender: Shubham Madhwal, Is Person: True, Message: Counsellor Name: Ms Tushti
# 2023-11-29 16:22:20,935 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:20,935 - INFO - Sender: +263 78 838 3513, Is Person: False, Message: Counsellor Name: Ms Tushti
# 2023-11-29 16:22:20,935 - INFO - Sender: Shubham Madhwal, Is Person: True, Message: Duly received please!
# 2023-11-29 16:22:20,935 - INFO - Time Difference (minutes): 3.0
# 2023-11-29 16:22:20,935 - INFO - Sender: +263 78 838 3513, Is Person: False, Message: Okay sir
# 2023-11-29 16:22:20,935 - INFO - Sender: Shubham Madhwal, Is Person: True, Message: @263788383513 Kindly join your admission's group
# 2023-11-29 16:22:20,935 - INFO - Time Difference (minutes): 2.0
# 2023-11-29 16:22:20,940 - INFO - Sender: +263 78 838 3513, Is Person: False, Message: I joined sir
# 2023-11-29 16:22:20,941 - INFO - Sender: Shubham Madhwal, Is Person: True, Message: Alright please!
# 2023-11-29 16:22:20,941 - INFO - Time Difference (minutes): 1.0
# 2023-11-29 16:22:20,942 - INFO - Sender: +263 78 838 3513, Is Person: False, Message: Okay sir
# 2023-11-29 16:22:20,942 - INFO - Processing file: C:\Users\mauriceyeng\Python\Daily-Reports\Test\filtered_chats\2023-11-28\SALES\Shubham Madhwal\WhatsApp Chat with SHALOM CHIREMBWE_EA(16_10)TR.txt
# 2023-11-29 16:22:20,996 - INFO - Sender: +263 71 914 9450, Is Person: False, Message: Yes they did
# 2023-11-29 16:22:20,996 - INFO - Processing file: C:\Users\mauriceyeng\Python\Daily-Reports\Test\filtered_chats\2023-11-28\SALES\Shubham Madhwal\WhatsApp Chat with Shingirai Vunganai_EA(16_11)TR.txt
# 2023-11-29 16:22:21,031 - INFO - Sender: Shubham Madhwal, Is Person: True, Message: Good Morning @263778640240
# 2023-11-29 16:22:21,031 - INFO - Sender: Shubham Madhwal, Is Person: True, Message: @263778640240 , this is quite a good question, as a lot of people have a misconception, about what kind of religious practices are followed in India.
# 2023-11-29 16:22:21,031 - INFO - Time Difference (minutes): 11.0
# 2023-11-29 16:22:21,031 - INFO - Sender: +263 77 864 0240, Is Person: False, Message: Noted sir
# 2023-11-29 16:22:21,031 - INFO - Sender: +263 77 864 0240, Is Person: False, Message: Good morning sir
# 2023-11-29 16:22:21,031 - INFO - Sender: +263 77 864 0240, Is Person: False, Message: How much is the admission fee all in all..
# 2023-11-29 16:22:21,031 - INFO - Sender: Shubham Madhwal, Is Person: True, Message: @263778640240 I didn't get you please?
# 2023-11-29 16:22:21,031 - INFO - Time Difference (minutes): 384.0
# 2023-11-29 16:22:21,031 - INFO - Sender: +263 77 864 0240, Is Person: False, Message: How much is the admission fee all in all..
# 2023-11-29 16:22:21,031 - INFO - Sender: Shubham Madhwal, Is Person: True, Message: You mean after adding the transfer charges, or you meant to ask somthing else please?
# 2023-11-29 16:22:21,031 - INFO - Time Difference (minutes): 2.0
# 2023-11-29 16:22:21,031 - INFO - Sender: +263 77 864 0240, Is Person: False, Message: Yes
# 2023-11-29 16:22:21,031 - INFO - Sender: Shubham Madhwal, Is Person: True, Message: Transfer charges are flat 12.5% on the transaction please, so in total on $350 you would be bearing a transfer charge of $45.
# 2023-11-29 16:22:21,031 - INFO - Time Difference (minutes): 2.0
# 2023-11-29 16:22:21,044 - INFO - Sender: +263 77 864 0240, Is Person: False, Message: Ok
# 2023-11-29 16:22:21,044 - INFO - Sender: Shubham Madhwal, Is Person: True, Message: Now even if you pay $200 with a 12.5% charge it would be
# 2023-11-29 16:22:21,045 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:21,045 - INFO - Sender: +263 77 864 0240, Is Person: False, Message: Noted sir
# 2023-11-29 16:22:21,046 - INFO - Sender: Shubham Madhwal, Is Person: True, Message: What else would you like to ask?
# 2023-11-29 16:22:21,047 - INFO - Time Difference (minutes): 11.0
# 2023-11-29 16:22:21,047 - INFO - Sender: +263 77 864 0240, Is Person: False, Message: Nothing else.
# 2023-11-29 16:22:21,048 - INFO - Processing file: C:\Users\mauriceyeng\Python\Daily-Reports\Test\filtered_chats\2023-11-28\SALES\Shubham Madhwal\WhatsApp Chat with Sigireta Tariro_EDOOFA(22_11)GS.txt
# 2023-11-29 16:22:21,074 - INFO - Sender: Shubham Madhwal, Is Person: True, Message: Good Afternoon Everyone.
# 2023-11-29 16:22:21,074 - INFO - Sender: Shubham Madhwal, Is Person: True, Message: Excuse me for my delayed response I wasn't able to get back to you at our scheduled time because of a family emergency.
# 2023-11-29 16:22:21,074 - INFO - Time Difference (minutes): 1.0
# 2023-11-29 16:22:21,079 - INFO - Sender: +263 71 825 3252, Is Person: False, Message: Afternoon sir
# 2023-11-29 16:22:21,079 - INFO - Sender: Shubham Madhwal, Is Person: True, Message: How was your discussion with Mr Gurvinder?
# 2023-11-29 16:22:21,080 - INFO - Time Difference (minutes): 5.0
# 2023-11-29 16:22:21,080 - INFO - Sender: +263 71 825 3252, Is Person: False, Message: It was fine , I can't complain
# 2023-11-29 16:22:21,081 - INFO - Sender: Shubham Madhwal, Is Person: True, Message: Okay well would you like to ask anything from the entire discussion @263718253252?
# 2023-11-29 16:22:21,081 - INFO - Time Difference (minutes): 1.0
# 2023-11-29 16:22:21,081 - INFO - Sender: +263 71 825 3252, Is Person: False, Message: No everything was fully explained
# 2023-11-29 16:22:21,082 - INFO - Sender: Shubham Madhwal, Is Person: True, Message: Okay so now as we proceed ahead, can you share in 100 to 120 words about what all did you learn from the counseling session regarding the following aspects.
# 2023-11-29 16:22:21,082 - INFO - Time Difference (minutes): 15.0
# 2023-11-29 16:22:21,083 - INFO - Sender: +263 71 825 3252, Is Person: False, Message: I learnt that the course I want to take part in will benefit me since it can enable me to participate me in business , legislative law among others. The EWYLP will help me to persue with my studies whilst learning work experience. This program will help me to pay my fees so as to reduce my parents burden. The student has to follow certain steps which include counseling session after that ,the child will be interviewed then accepted into Edoofa ,following enrollment into Edoofa and this will be followed by admission into Edoofa then admission letter and visa process. This is what I learnt from the counseling session
# 2023-11-29 16:22:21,083 - INFO - Sender: Shubham Madhwal, Is Person: True, Message: Excellent I can see you understood the program in such detail, may I know if there is anything your family members like to ask for their clarity and better understanding?
# 2023-11-29 16:22:21,084 - INFO - Time Difference (minutes): 269.0
# 2023-11-29 16:22:21,084 - INFO - Processing file: C:\Users\mauriceyeng\Python\Daily-Reports\Test\filtered_chats\2023-11-28\SALES\Shubham Madhwal\WhatsApp Chat with Simeon Wamedzwa_EDOOFA(16_11)SM23.txt
# 2023-11-29 16:22:21,095 - INFO - Sender: +263 71 543 8646, Is Person: False, Message: Good morning sir am now available for the session
# 2023-11-29 16:22:21,096 - INFO - Processing file: C:\Users\mauriceyeng\Python\Daily-Reports\Test\filtered_chats\2023-11-28\SALES\Shubham Madhwal\WhatsApp Chat with Solomon Chere_EDOOFAMHS(14_11)SM23.txt
# 2023-11-29 16:22:21,142 - INFO - Sender: Shubham Madhwal, Is Person: True, Message: Good Morning @27746761601
# 2023-11-29 16:22:21,142 - INFO - Sender: Shubham Madhwal, Is Person: True, Message: Through FNB bank you can complete the formalities directly into the Indian Account using the first mode.
# 2023-11-29 16:22:21,142 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:21,142 - INFO - Sender: Shubham Madhwal, Is Person: True, Message: For transfer charges you would have to enquire the Bank for the same. However if we talk about Mama Money, you can complete the formalities using the same, as our Account's team would generate an Order for it and you would just have to visit the Mama Money agents to complete the formalities
# 2023-11-29 16:22:21,142 - INFO - Time Difference (minutes): 2.0
# 2023-11-29 16:22:21,148 - INFO - Sender: +27 74 676 1601, Is Person: False, Message: Ok sir thank you so mch.
# 2023-11-29 16:22:21,148 - INFO - Sender: +27 74 676 1601, Is Person: False, Message: Hope you are doing well today
# 2023-11-29 16:22:21,149 - INFO - Sender: Shubham Madhwal, Is Person: True, Message: I am doing well @27746761601
# 2023-11-29 16:22:21,149 - INFO - Time Difference (minutes): 389.0
# 2023-11-29 16:22:21,150 - INFO - Sender: +27 74 676 1601, Is Person: False, Message: Thats wonderfull
# 2023-11-29 16:22:21,150 - INFO - Sender: +27 74 676 1601, Is Person: False, Message: Have a blassed day
# 2023-11-29 16:22:21,151 - INFO - Sender: Shubham Madhwal, Is Person: True, Message: Same to you @27746761601
# 2023-11-29 16:22:21,151 - INFO - Time Difference (minutes): 44.0
# 2023-11-29 16:22:21,152 - INFO - Sender: +27 74 676 1601, Is Person: False, Message: Thank you
# 2023-11-29 16:22:21,152 - INFO - Processing file: C:\Users\mauriceyeng\Python\Daily-Reports\Test\filtered_chats\2023-11-28\SALES\Shubham Madhwal\WhatsApp Chat with Stermon Malambo_EDOOFAZAMB(22_11)SM23.txt
# 2023-11-29 16:22:21,158 - INFO - Sender: +260 97 6182543, Is Person: False, Message: Good morning Mr Shubham?
# 2023-11-29 16:22:21,158 - INFO - Sender: Shubham Madhwal, Is Person: True, Message: Good Morning @260976182543
# 2023-11-29 16:22:21,159 - INFO - Sender: Shubham Madhwal, Is Person: True, Message: How are you doing today please?
# 2023-11-29 16:22:21,159 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:21,161 - INFO - Sender: +260 97 6182543, Is Person: False, Message: I am doing fine sir, what about you there?
# 2023-11-29 16:22:21,161 - INFO - Sender: +260 97 6182543, Is Person: False, Message: Sir if you don't mind, I am asking, when am I going to have a session?
# 2023-11-29 16:22:21,161 - INFO - Sender: +260 97 6182543, Is Person: False, Message: Sir
# 2023-11-29 16:22:21,162 - INFO - Sender: +260 97 6182543, Is Person: False, Message: I am  kindly asking you to let me know when are you going to be free.I assume that you are busy with your work.
# 2023-11-29 16:22:21,162 - INFO - Sender: Shubham Madhwal, Is Person: True, Message: @260976182543 Excuse me for my delayed response I wasn't able to get back to you at our scheduled time because of a family emergency.
# 2023-11-29 16:22:21,163 - INFO - Time Difference (minutes): 205.0
# 2023-11-29 16:22:21,163 - INFO - Sender: Shubham Madhwal, Is Person: True, Message: Let me schedule our discussion for Wednesday 12pm CAT
# 2023-11-29 16:22:21,164 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:21,164 - INFO - Sender: +260 97 6182543, Is Person: False, Message: Okay sir, I understand.Thank you for the response,may  God bless you as I will be waiting patiently until Wednesday.
# 2023-11-29 16:22:21,165 - INFO - Processing file: C:\Users\mauriceyeng\Python\Daily-Reports\Test\filtered_chats\2023-11-28\SALES\Shubham Madhwal\WhatsApp Chat with Takudzwanashe Marange_EA(04_10)TR.txt
# 2023-11-29 16:22:21,211 - INFO - Sender: Shubham Madhwal, Is Person: True, Message: Good Morning @263788175746
# 2023-11-29 16:22:21,211 - INFO - Sender: Shubham Madhwal, Is Person: True, Message: Duly received please!
# 2023-11-29 16:22:21,211 - INFO - Time Difference (minutes): 0.0
# 2023-11-29 16:22:21,211 - INFO - Sender: +263 78 817 5746, Is Person: False, Message: Okay thank you Sir.
# 2023-11-29 16:22:21,211 - INFO - Processing file: C:\Users\mauriceyeng\Python\Daily-Reports\Test\filtered_chats\2023-11-28\SALES\Shubham Madhwal\WhatsApp Chat with Tamya Mutematsaka_EDOOFA(07_11)SM23.txt
# 2023-11-29 16:22:21,229 - INFO - Sender: +27 72 699 5184, Is Person: False, Message: Good morning Mr Shubham
# 2023-11-29 16:22:21,229 - INFO - Sender: +27 72 699 5184, Is Person: False, Message: Actually l have not been online because my phone was not working. We can proceed
# 2023-11-29 16:22:21,229 - INFO - Processing file: C:\Users\mauriceyeng\Python\Daily-Reports\Test\filtered_chats\2023-11-28\SALES\Shubham Madhwal\WhatsApp Chat with Tinotenda Muzvidziwa_EA(02_11)TR.txt
# 2023-11-29 16:22:21,274 - INFO - Sender: Shubham Madhwal, Is Person: True, Message: Good Morning @263773000585
# 2023-11-29 16:22:21,274 - INFO - Sender: Shubham Madhwal, Is Person: True, Message: May I know what happened?
# 2023-11-29 16:22:21,274 - INFO - Time Difference (minutes): 1.0
# 2023-11-29 16:22:21,274 - INFO - Sender: Shubham Madhwal, Is Person: True, Message: @263773000585 I am expecting a response please?
# 2023-11-29 16:22:21,274 - INFO - Time Difference (minutes): 743.0
# 2023-11-29 16:22:21,274 - INFO - Processing file: C:\Users\mauriceyeng\Python\Daily-Reports\Test\filtered_chats\2023-11-28\SALES\Shubham Madhwal\WhatsApp Chat with Wadzanai_EA(04_09)TR.txt
# 2023-11-29 16:22:21,302 - INFO - Sender: +263 71 319 2850, Is Person: False, Message: Hello
# 2023-11-29 16:22:21,302 - INFO - Processing file: C:\Users\mauriceyeng\Python\Daily-Reports\Test\filtered_chats\2023-11-28\SALES\Tushti\WhatsApp Chat with Kudzaishe Mwale_Edoofa(31_10)SM.txt
# 2023-11-29 16:22:21,317 - INFO - Sender: +263 78 997 7912, Is Person: False, Message: Hie sorry for late responses lately
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 126
#     124 chat_files = list_chat_files(date_directory)
#     125 all_delay_data = process_all_files(chat_files)
# --> 126 delay_analysis_df = create_delay_data_dataframe(all_delay_data)
#     128 # Display the first few rows of the DataFrame
#     129 print(delay_analysis_df.head())
#
# Cell In[15], line 107, in create_delay_data_dataframe(all_delay_data)
#     104 df_data = []
#     106 for delay_instance in all_delay_data:
# --> 107     date_time, sender, message, delay, time_diff_minutes, reference_msgs, file_path = delay_instance
#     109     # Use the file name as the chat group name
#     110     chat_group_name = os.path.basename(file_path)
#
# ValueError: not enough values to unpack (expected 7, got 6)

# %%
delay_analysis_df.to_csv("delays.csv", index=False)

# %%
all_delay_data
