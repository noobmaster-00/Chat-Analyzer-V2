# %%
import os
import pandas as pd
import datetime
import re
import logging

logging.basicConfig(level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s')

def list_chat_files(date_directory):
    chat_files = []
    for date_folder in os.listdir(date_directory):
        date_path = os.path.join(date_directory, date_folder)
        if os.path.isdir(date_path):
            for team_folder in os.listdir(date_path):
                team_path = os.path.join(date_path, team_folder)
                if os.path.isdir(team_path):
                    for person_folder in os.listdir(team_path):
                        person_path = os.path.join(team_path, person_folder)
                        if os.path.isdir(person_path):
                            for file in os.listdir(person_path):
                                if file.endswith('.txt'):
                                    chat_files.append(os.path.join(person_path, file))
    return chat_files

def parse_chat_file(file_path, expected_date_minus_one):
    chat_data = []
    last_person_time = None
    last_sender = None

    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            logging.debug(f"Reading message: {line.strip()}")
            message_match = re.match(r'(\d{2}/\d{2}/\d{2}, \d{1,2}:\d{2} [ap]m) - (.*?): (.*)', line)
            system_match = re.match(r'(\d{2}/\d{2}/\d{2}, \d{1,2}:\d{2} [ap]m) - (.*)', line)
            if message_match:
                date_time_str, sender, message = message_match.groups()
            elif system_match:
                date_time_str, info = system_match.groups()
                sender = None
            else:
                continue

            date_time = pd.to_datetime(date_time_str, format='%d/%m/%y, %I:%M %p')
            if date_time.date() != expected_date_minus_one:
                continue

            is_person = sender is not None and re.match(r'^[+\d\s-]+$', sender) is None
            delay = False
            if is_person:
                if last_person_time and sender != last_sender and (date_time - last_person_time).total_seconds() > 900:
                    delay = True
                if not delay:
                    last_person_time = date_time
                    last_sender = sender

            chat_data.append((date_time, sender, is_person, delay))

    return chat_data, extract_group_name(file_path)



def create_template_dataframe():
    times = [datetime.datetime(2000, 1, 1, 0, 0) + datetime.timedelta(minutes=1 * i) for i in range(1440)]
    intervals = [time.strftime('%I:%M %p') for time in times]
    df = pd.DataFrame(index=intervals)
    return df

def populate_dataframe(df, parsed_data, group_name):
    # Ensure all three columns for each chat
    for suffix in ['', '_others', '_delay']:
        column_name = f"{group_name}{suffix}"
        if column_name not in df.columns:
            df[column_name] = 0

    # Populate the DataFrame with parsed data
    for date_time, sender, is_person, delay in parsed_data:
        interval_index = min((date_time.hour * 60 + date_time.minute) // 1, 1439)
        interval = df.index[interval_index]

        # Update person, others, and delay columns
        df.at[interval, group_name] = 1 if is_person else df.at[interval, group_name]
        df.at[interval, f"{group_name}_others"] = 0 if is_person else 1
        df.at[interval, f"{group_name}_delay"] = 1 if delay else df.at[interval, f"{group_name}_delay"]

    # Calculate active chats for each interval
    if 'active_chat' not in df.columns:
        df['active_chat'] = 0
    for interval in df.index:
        active_chats = 0
        for col in df.columns:
            if '_others' in col or group_name in col:  # Check only person and others columns
                if df.at[interval, col] == 1:
                    active_chats += 1
                    break  # Break as we only need at least one active indicator per chat
        df.at[interval, 'active_chat'] = active_chats

    return df



def extract_group_name(file_path):
    group_name = os.path.basename(file_path).replace('WhatsApp Chat with ', '').split('.')[0]
    group_name = re.sub(r'\(\d+\)$', '', group_name)  # Remove any numbers in parentheses at the end
    return group_name

date_directory = "C:\\Users\\maurice\\Documents\\Chat-Analyzer-V2\\Chat Folder from Drive\\drive-download-20231201T052455Z-001"
chat_files = list_chat_files(date_directory)
dataframes = {}

for file in chat_files:
    parts = file.split(os.sep)
    date_folder, person = parts[-4], parts[-2]

    try:
        folder_date = pd.to_datetime(date_folder, format='%Y-%m-%d').date()
    except ValueError:
        continue

    expected_date_minus_one = folder_date - datetime.timedelta(days=1)
    key = f"{folder_date.strftime('%Y-%m-%d')}_{person}"

    if key not in dataframes:
        dataframes[key] = create_template_dataframe()
    parsed_data, group_name = parse_chat_file(file, expected_date_minus_one)
    dataframes[key] = populate_dataframe(dataframes[key], parsed_data, group_name)

# %%
# Loop through the dictionary of DataFrames
for key, df in dataframes.items():
    print(f"DataFrame for {key}:\n{df.head()}")

# %%
# Directory to save CSV files
csv_save_directory = "C:\\Users\\maurice\\Documents\\Chat-Analyzer-V2\\Chat CSVs"
os.makedirs(csv_save_directory, exist_ok=True)

# Saving each DataFrame as a CSV
for key, df in dataframes.items():
    csv_file_path = os.path.join(csv_save_directory, f"{key}.csv")
    df.to_csv(csv_file_path)

# %%
import os
import pandas as pd
import datetime
import re
import logging

logging.basicConfig(level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s')

def list_chat_files(date_directory):
    chat_files = []
    for date_folder in os.listdir(date_directory):
        date_path = os.path.join(date_directory, date_folder)
        if os.path.isdir(date_path):
            for team_folder in os.listdir(date_path):
                # Only proceed if the team folder is 'KAM'
                if team_folder != "KAM":
                    continue
                
                team_path = os.path.join(date_path, team_folder)
                if os.path.isdir(team_path):
                    for person_folder in os.listdir(team_path):
                        person_path = os.path.join(team_path, person_folder)
                        if os.path.isdir(person_path):
                            for file in os.listdir(person_path):
                                if file.endswith('.txt'):
                                    chat_files.append(os.path.join(person_path, file))
    return chat_files


def parse_chat_file(file_path, expected_date_minus_one):
    chat_data = []
    last_person_time = None
    last_sender = None
    delay_count = 0

    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            
            message_match = re.match(r'(\d{2}/\d{2}/\d{2}, \d{1,2}:\d{2} [ap]m) - (.*?): (.*)', line)
            system_match = re.match(r'(\d{2}/\d{2}/\d{2}, \d{1,2}:\d{2} [ap]m) - (.*)', line)
            if message_match:
                date_time_str, sender, message = message_match.groups()
            elif system_match:
                date_time_str, info = system_match.groups()
                sender = None
            else:
                continue

            date_time = pd.to_datetime(date_time_str, format='%d/%m/%y, %I:%M %p')
            if date_time.date() != expected_date_minus_one:
                continue

            is_person = sender is not None and re.match(r'^[+\d\s-]+$', sender) is None
            delay = False
            if is_person:
                if last_person_time and sender != last_sender and (date_time - last_person_time).total_seconds() > 900:
                    delay = True
                    delay_count += 1
                if not delay:
                    last_person_time = date_time
                    last_sender = sender

            chat_data.append((date_time, sender, is_person, delay))
    logging.debug(f"File parsed: {file_path}. Delays detected: {delay_count}")
    return chat_data, extract_group_name(file_path)



def create_template_dataframe():
    times = [datetime.datetime(2000, 1, 1, 0, 0) + datetime.timedelta(minutes=1 * i) for i in range(1440)]
    intervals = [time.strftime('%I:%M %p') for time in times]
    df = pd.DataFrame(index=pd.to_datetime(intervals).strftime('%I:%M %p').unique())  # Ensure unique intervals
    return df


def populate_dataframe(df, parsed_data, group_name):
    # Create new columns as separate DataFrames
    new_columns = {
        f"{group_name}": pd.Series(0, index=df.index),
        f"{group_name}_others": pd.Series(0, index=df.index),
        f"{group_name}_delay": pd.Series(0, index=df.index)
    }

    # Populate the new columns with parsed data
    for date_time, sender, is_person, delay in parsed_data:
        interval_index = min((date_time.hour * 60 + date_time.minute) // 1, 1439)
        interval = df.index[interval_index]

        # Update person, others, and delay columns
        new_columns[f"{group_name}"].at[interval] = 1 if is_person else new_columns[f"{group_name}"].at[interval]
        new_columns[f"{group_name}_others"].at[interval] = 0 if is_person else 1
        new_columns[f"{group_name}_delay"].at[interval] = 1 if delay else new_columns[f"{group_name}_delay"].at[interval]

    # Concatenate the new columns to the original DataFrame
    df = pd.concat([df, pd.DataFrame(new_columns)], axis=1)

    # Vectorized approach to calculate active chats
    if 'active_chat' not in df.columns:
        df['active_chat'] = 0

    # Filter columns for the current group
    relevant_columns = [col for col in df.columns if col.startswith(group_name) and ('_others' in col or '_person' in col)]
    df['active_chat'] = df[relevant_columns].any(axis=1).astype(int)

    return df


def extract_group_name(file_path):
    group_name = os.path.basename(file_path).replace('WhatsApp Chat with ', '').split('.')[0]
    group_name = re.sub(r'\(\d+\)$', '', group_name)  # Remove any numbers in parentheses at the end
    return group_name

date_directory = "C:\\Users\\mauriceyeng\\Python\\Daily-Reports\\Chat Folder from Drive\\drive-download-20231201T052455Z-001"
chat_files = list_chat_files(date_directory)
dataframes = {}

for file in chat_files:
    parts = file.split(os.sep)
    date_folder, person = parts[-4], parts[-2]

    try:
        folder_date = pd.to_datetime(date_folder, format='%Y-%m-%d').date()
    except ValueError:
        continue

    expected_date_minus_one = folder_date - datetime.timedelta(days=1)
    key = f"{folder_date.strftime('%Y-%m-%d')}_{person}"

    if key not in dataframes:
        dataframes[key] = create_template_dataframe()
    parsed_data, group_name = parse_chat_file(file, expected_date_minus_one)
    dataframes[key] = populate_dataframe(dataframes[key], parsed_data, group_name)
# Out:
# C:\Users\mauriceyeng\AppData\Local\Temp\ipykernel_17072\2244814449.py:72: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.DataFrame(index=pd.to_datetime(intervals).strftime('%I:%M %p').unique())  # Ensure unique intervals
# 2023-12-01 17:16:12,163 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Aaron 2K23OCT1666R(1).txt. Delays detected: 0
# 2023-12-01 17:16:12,212 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Aaron 2K23OCT1666R.txt. Delays detected: 0
# 2023-12-01 17:16:12,246 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Agutha 2K23FEB1751(1).txt. Delays detected: 0
# 2023-12-01 17:16:12,281 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Agutha 2K23FEB1751.txt. Delays detected: 0
# 2023-12-01 17:16:12,316 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Anesu 2K22JUN1424(1).txt. Delays detected: 0
# 2023-12-01 17:16:12,351 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Anesu 2K22JUN1424.txt. Delays detected: 0
# 2023-12-01 17:16:12,378 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Anesuishe 2K23JAN0525(1).txt. Delays detected: 0
# 2023-12-01 17:16:12,406 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Anesuishe 2K23JAN0525.txt. Delays detected: 0
# 2023-12-01 17:16:12,469 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Angeline 2K23FEB2804(1).txt. Delays detected: 0
# 2023-12-01 17:16:12,531 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Angeline 2K23FEB2804.txt. Delays detected: 0
# 2023-12-01 17:16:12,560 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Anna 2K21NOV3059(1).txt. Delays detected: 0
# 2023-12-01 17:16:12,587 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Anna 2K21NOV3059.txt. Delays detected: 0
# 2023-12-01 17:16:12,650 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Anotidaishe 2K23AUG1838(1).txt. Delays detected: 0
# 2023-12-01 17:16:12,707 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Anotidaishe 2K23AUG1838.txt. Delays detected: 0
# 2023-12-01 17:16:12,740 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Ashley 2K23FEB0130(1).txt. Delays detected: 0
# 2023-12-01 17:16:12,774 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Ashley 2K23FEB0130.txt. Delays detected: 0
# 2023-12-01 17:16:12,817 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Audrey 2K23OCT0992(1).txt. Delays detected: 0
# 2023-12-01 17:16:12,860 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Audrey 2K23OCT0992.txt. Delays detected: 0
# 2023-12-01 17:16:12,907 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Auxillia 2K23JUL1004(1).txt. Delays detected: 0
# 2023-12-01 17:16:12,962 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Auxillia 2K23JUL1004.txt. Delays detected: 0
# 2023-12-01 17:16:12,990 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Bervely 2K23FEB2310(1).txt. Delays detected: 0
# 2023-12-01 17:16:13,018 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Bervely 2K23FEB2310.txt. Delays detected: 0
# 2023-12-01 17:16:13,053 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Blessing 2K23SEP1692(1).txt. Delays detected: 0
# 2023-12-01 17:16:13,087 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Blessing 2K23SEP1692.txt. Delays detected: 0
# 2023-12-01 17:16:13,114 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Brooke 2K23MAY0260(1).txt. Delays detected: 0
# 2023-12-01 17:16:13,135 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Brooke 2K23MAY0260.txt. Delays detected: 0
# 2023-12-01 17:16:13,187 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with CHANTEL 2K23JUN2756(1).txt. Delays detected: 0
# 2023-12-01 17:16:13,238 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with CHANTEL 2K23JUN2756.txt. Delays detected: 0
# 2023-12-01 17:16:13,296 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Chirimuta 2K23SEP3047.txt. Delays detected: 0
# 2023-12-01 17:16:13,347 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Chisomo 2K23AUG0492.txt. Delays detected: 0
# 2023-12-01 17:16:13,402 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Christina 2K23SEP2595.txt. Delays detected: 0
# 2023-12-01 17:16:13,449 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Comfort 2K23NOV0225.txt. Delays detected: 0
# 2023-12-01 17:16:13,485 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Courage 2K22JUL1682.txt. Delays detected: 0
# 2023-12-01 17:16:13,517 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Dalitso 2K23OCT0589.txt. Delays detected: 0
# 2023-12-01 17:16:13,541 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Danai 2K23SEP1134R.txt. Delays detected: 0
# 2023-12-01 17:16:13,594 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Denzel 2K23OCT1175.txt. Delays detected: 0
# 2023-12-01 17:16:13,628 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Fanwell 2K22NOV1427.txt. Delays detected: 0
# 2023-12-01 17:16:13,716 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Francesca 2K23AUG1892.txt. Delays detected: 0
# 2023-12-01 17:16:13,777 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Glory 2K23JUL2188.txt. Delays detected: 0
# 2023-12-01 17:16:13,798 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Gracious 2K22JUL1545.txt. Delays detected: 0
# 2023-12-01 17:16:13,833 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Joyline 2k21OCT0992.txt. Delays detected: 0
# 2023-12-01 17:16:13,853 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Kelvin 2K23NOV1626R.txt. Delays detected: 0
# 2023-12-01 17:16:13,902 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Kester 2K22JUL1415.txt. Delays detected: 0
# 2023-12-01 17:16:13,917 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Kudakwashe 2K23NOV2061R.txt. Delays detected: 0
# 2023-12-01 17:16:13,962 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Kundai 2K22OCT2295.txt. Delays detected: 0
# 2023-12-01 17:16:13,976 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Kupakwashe 2K23NOV1024.txt. Delays detected: 0
# 2023-12-01 17:16:14,045 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Lenny 2K23SEP1854.txt. Delays detected: 0
# 2023-12-01 17:16:14,088 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Lorraine 2K23APR2606.txt. Delays detected: 0
# 2023-12-01 17:16:14,149 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Lyncon 2K23AUG2288R.txt. Delays detected: 0
# 2023-12-01 17:16:14,191 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Lynnte 2K22JUN0256.txt. Delays detected: 0
# 2023-12-01 17:16:14,233 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Marvellous 2K22AUG0965.txt. Delays detected: 0
# 2023-12-01 17:16:14,267 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Melanie 2K23FEB0409.txt. Delays detected: 0
# 2023-12-01 17:16:14,309 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Monalisa 2K23SEP2137.txt. Delays detected: 0
# 2023-12-01 17:16:14,330 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Moreblessing 2K22AUG1328.txt. Delays detected: 0
# 2023-12-01 17:16:14,365 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Munyaradzi 2K23APR1976.txt. Delays detected: 0
# 2023-12-01 17:16:14,392 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Mwango 2K23NOV2222R.txt. Delays detected: 0
# 2023-12-01 17:16:14,462 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Natasha 2K23JUN3045.txt. Delays detected: 0
# 2023-12-01 17:16:14,517 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Nathan 2K23APR2615.txt. Delays detected: 0
# 2023-12-01 17:16:14,552 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Nigel 2K23APR0768.txt. Delays detected: 0
# 2023-12-01 17:16:14,587 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Nontokozo 2K22MAY0312.txt. Delays detected: 0
# 2023-12-01 17:16:14,615 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Nyasha 2K23FEB1457.txt. Delays detected: 0
# 2023-12-01 17:16:14,649 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Paidamoyo 2K23OCT2188.txt. Delays detected: 0
# 2023-12-01 17:16:14,684 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Panashe 2K22MAR1786.txt. Delays detected: 0
# 2023-12-01 17:16:14,726 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Patrick 2K22AUG1384.txt. Delays detected: 0
# 2023-12-01 17:16:14,781 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Prosper 2K23SEP1234R.txt. Delays detected: 0
# 2023-12-01 17:16:14,823 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Redemption 2K23SEP2534R.txt. Delays detected: 0
# 2023-12-01 17:16:14,879 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Rufaro 2K23FEB0692.txt. Delays detected: 0
# 2023-12-01 17:16:14,920 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Rutendo 2K23SEP1192_.txt. Delays detected: 0
# 2023-12-01 17:16:14,955 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Shalom 2K21MAY0347.txt. Delays detected: 0
# 2023-12-01 17:16:15,004 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Shantelle 2K23SEP2868R.txt. Delays detected: 0
# 2023-12-01 17:16:15,046 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Sharmaine 2K23OCT0695.txt. Delays detected: 0
# 2023-12-01 17:16:15,088 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Shumba 2K23SEP1992.txt. Delays detected: 0
# 2023-12-01 17:16:15,115 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Siphosenkosi 2K22MAY1064.txt. Delays detected: 0
# 2023-12-01 17:16:15,172 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Tadiwanashe 2K22SEP1715.txt. Delays detected: 0
# 2023-12-01 17:16:15,220 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Tadiwanashe 2K23OCT0692.txt. Delays detected: 0
# 2023-12-01 17:16:15,267 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with TAKUDZWA 2K22OCT1358.txt. Delays detected: 0
# 2023-12-01 17:16:15,296 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Takudzwa 2K23APR1824.txt. Delays detected: 0
# 2023-12-01 17:16:15,358 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Tanaka 2K23OCT0462.txt. Delays detected: 0
# 2023-12-01 17:16:15,407 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Tanaka 2K23SEP3095.txt. Delays detected: 0
# 2023-12-01 17:16:15,460 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Tashinga 2K23OCT0971.txt. Delays detected: 0
# 2023-12-01 17:16:15,497 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Tawanda 2K23NOV1068R.txt. Delays detected: 0
# 2023-12-01 17:16:15,547 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Tawanda 2K23OCT0439.txt. Delays detected: 0
# 2023-12-01 17:16:15,580 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Tiara 2K23JUN0698.txt. Delays detected: 0
# 2023-12-01 17:16:15,615 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Tinashe 2K22SEP0752.txt. Delays detected: 0
# 2023-12-01 17:16:15,641 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Violet 2K23NOV1095.txt. Delays detected: 0
# 2023-12-01 17:16:15,699 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Ashi_Edoofa\WhatsApp Chat with Zibusiso 2K23JUL0199.txt. Delays detected: 0
# C:\Users\mauriceyeng\AppData\Local\Temp\ipykernel_17072\2244814449.py:72: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.DataFrame(index=pd.to_datetime(intervals).strftime('%I:%M %p').unique())  # Ensure unique intervals
# 2023-12-01 17:16:15,825 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Kirti Edoofa\WhatsApp Chat with Alson 2K22SEP0243R.txt. Delays detected: 0
# 2023-12-01 17:16:15,860 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Kirti Edoofa\WhatsApp Chat with ANESU 2K23JUN2742.txt. Delays detected: 0
# 2023-12-01 17:16:15,899 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Kirti Edoofa\WhatsApp Chat with Arthur 2K21AUG1124.txt. Delays detected: 0
# 2023-12-01 17:16:15,963 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Kirti Edoofa\WhatsApp Chat with Ashley 2K23AUG1607.txt. Delays detected: 0
# 2023-12-01 17:16:16,006 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Kirti Edoofa\WhatsApp Chat with Batsirai 2K23MAY1995.txt. Delays detected: 0
# 2023-12-01 17:16:16,048 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Kirti Edoofa\WhatsApp Chat with Blessing 2K23JUL0488.txt. Delays detected: 0
# 2023-12-01 17:16:16,082 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Kirti Edoofa\WhatsApp Chat with Blessing 2K23JUN2327.txt. Delays detected: 0
# 2023-12-01 17:16:16,110 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Kirti Edoofa\WhatsApp Chat with Bridget 2K23OCT1965.txt. Delays detected: 0
# 2023-12-01 17:16:16,152 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Kirti Edoofa\WhatsApp Chat with CHIKONDI 2K23JUN2048.txt. Delays detected: 0
# 2023-12-01 17:16:16,185 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Kirti Edoofa\WhatsApp Chat with Cuthbert 2K22JUL2192.txt. Delays detected: 5
# 2023-12-01 17:16:16,233 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Kirti Edoofa\WhatsApp Chat with Dephine 2K22AUG1346.txt. Delays detected: 0
# 2023-12-01 17:16:16,270 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Kirti Edoofa\WhatsApp Chat with Ecclesiastic 2K23JUL0892.txt. Delays detected: 0
# 2023-12-01 17:16:16,325 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Kirti Edoofa\WhatsApp Chat with Emmanuel 2k23APR1836.txt. Delays detected: 0
# 2023-12-01 17:16:16,358 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Kirti Edoofa\WhatsApp Chat with Fidelis 2K22AUG0986.txt. Delays detected: 0
# 2023-12-01 17:16:16,395 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Kirti Edoofa\WhatsApp Chat with Godfrey 2K23MAY2671.txt. Delays detected: 0
# 2023-12-01 17:16:16,449 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Kirti Edoofa\WhatsApp Chat with Gombe 2K23OCT0971R.txt. Delays detected: 0
# 2023-12-01 17:16:16,492 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Kirti Edoofa\WhatsApp Chat with Isaac 2K23OCT1366.txt. Delays detected: 0
# 2023-12-01 17:16:16,546 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Kirti Edoofa\WhatsApp Chat with Joy 2K23OCT2614R.txt. Delays detected: 0
# 2023-12-01 17:16:16,610 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Kirti Edoofa\WhatsApp Chat with Kudzaishe 2K23AUG1288.txt. Delays detected: 0
# 2023-12-01 17:16:16,658 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Kirti Edoofa\WhatsApp Chat with Kudzi 2K23OCT1768R.txt. Delays detected: 0
# 2023-12-01 17:16:16,692 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Kirti Edoofa\WhatsApp Chat with Mandlenkosi 2K23JUL2156.txt. Delays detected: 0
# 2023-12-01 17:16:16,747 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Kirti Edoofa\WhatsApp Chat with Mcwillard 2K23JUL2505.txt. Delays detected: 0
# 2023-12-01 17:16:16,782 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Kirti Edoofa\WhatsApp Chat with Moses 2K23MAY1822.txt. Delays detected: 0
# 2023-12-01 17:16:16,823 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Kirti Edoofa\WhatsApp Chat with Mphatso 2K23JUL0810.txt. Delays detected: 0
# 2023-12-01 17:16:16,879 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Kirti Edoofa\WhatsApp Chat with Mwenje 2K23SEP1192R.txt. Delays detected: 0
# 2023-12-01 17:16:16,935 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Kirti Edoofa\WhatsApp Chat with Nokutenda 2K23OCT1306R.txt. Delays detected: 0
# 2023-12-01 17:16:16,990 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Kirti Edoofa\WhatsApp Chat with Nokuthaba 2K23OCT1795.txt. Delays detected: 0
# 2023-12-01 17:16:17,025 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Kirti Edoofa\WhatsApp Chat with Nyasha 2K23JUN2334.txt. Delays detected: 0
# 2023-12-01 17:16:17,080 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Kirti Edoofa\WhatsApp Chat with Panashe 2K23APR2894.txt. Delays detected: 0
# 2023-12-01 17:16:17,123 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Kirti Edoofa\WhatsApp Chat with Patience 2K23JUN0992.txt. Delays detected: 0
# 2023-12-01 17:16:17,164 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Kirti Edoofa\WhatsApp Chat with Phyllis 2K23JUNE0891R.txt. Delays detected: 0
# 2023-12-01 17:16:17,206 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Kirti Edoofa\WhatsApp Chat with Pritchard 2K23JUN1355.txt. Delays detected: 0
# 2023-12-01 17:16:17,235 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Kirti Edoofa\WhatsApp Chat with Rangarirai 2K23JUL1024.txt. Delays detected: 0
# 2023-12-01 17:16:17,268 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Kirti Edoofa\WhatsApp Chat with Scott 2K22JUL2093.txt. Delays detected: 0
# 2023-12-01 17:16:17,309 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Kirti Edoofa\WhatsApp Chat with Shane 2K23OCT2588.txt. Delays detected: 0
# 2023-12-01 17:16:17,352 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Kirti Edoofa\WhatsApp Chat with Staylodge 2K23OCT2788.txt. Delays detected: 0
# 2023-12-01 17:16:17,381 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Kirti Edoofa\WhatsApp Chat with Tafadzwa 2K23MAY2588.txt. Delays detected: 0
# 2023-12-01 17:16:17,416 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Kirti Edoofa\WhatsApp Chat with Takudzwa 2K22JUL1350.txt. Delays detected: 0
# 2023-12-01 17:16:17,476 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Kirti Edoofa\WhatsApp Chat with Takunda 2K23OCT2459.txt. Delays detected: 0
# 2023-12-01 17:16:17,511 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Kirti Edoofa\WhatsApp Chat with Tinotenda 2K23AUG1863.txt. Delays detected: 0
# 2023-12-01 17:16:17,561 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Kirti Edoofa\WhatsApp Chat with Tirivashe 2K22AUG1207.txt. Delays detected: 0
# 2023-12-01 17:16:17,610 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Kirti Edoofa\WhatsApp Chat with Yamikani 2K22AUG1390.txt. Delays detected: 0
# 2023-12-01 17:16:17,650 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Kirti Edoofa\WhatsApp Chat with Zvikomborero 2K23JUL0645.txt. Delays detected: 0
# C:\Users\mauriceyeng\AppData\Local\Temp\ipykernel_17072\2244814449.py:72: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.DataFrame(index=pd.to_datetime(intervals).strftime('%I:%M %p').unique())  # Ensure unique intervals
# 2023-12-01 17:16:17,789 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Albert 2K23SEP0692.txt. Delays detected: 0
# 2023-12-01 17:16:17,852 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Alex 2K23AUG2224R.txt. Delays detected: 0
# 2023-12-01 17:16:17,893 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Anesuishe 2K22DEC0852.txt. Delays detected: 0
# 2023-12-01 17:16:17,921 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Beckham 2K22DEC1254.txt. Delays detected: 0
# 2023-12-01 17:16:17,976 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Charlene 2K23AUG2458.txt. Delays detected: 0
# 2023-12-01 17:16:18,018 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with David 2K22AUG2395.txt. Delays detected: 0
# 2023-12-01 17:16:18,060 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with David 2K23MAR0605.txt. Delays detected: 0
# 2023-12-01 17:16:18,101 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Diana 2K23MAR2362.txt. Delays detected: 0
# 2023-12-01 17:16:18,157 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Emily 2K23SEP0768.txt. Delays detected: 0
# 2023-12-01 17:16:18,220 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Emmanuel 2K23JUL1805.txt. Delays detected: 0
# 2023-12-01 17:16:18,276 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Ezra 2K23AUG0581.txt. Delays detected: 0
# 2023-12-01 17:16:18,316 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Fidelis 2K23AUG2558.txt. Delays detected: 0
# 2023-12-01 17:16:18,344 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Gracious 2K23MAY0959.txt. Delays detected: 0
# 2023-12-01 17:16:18,360 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Harriet 2K23AUG0392R.txt. Delays detected: 0
# 2023-12-01 17:16:18,393 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Isheanesu 2K23FEB1076.txt. Delays detected: 0
# 2023-12-01 17:16:18,435 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Jamie 2K23APR1804.txt. Delays detected: 0
# 2023-12-01 17:16:18,451 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Kelly 2K22NOV0779.txt. Delays detected: 0
# 2023-12-01 17:16:18,511 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Kudakwashe 2K23AUG0276.txt. Delays detected: 0
# 2023-12-01 17:16:18,548 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Loccadia 2K23AUG2212R.txt. Delays detected: 0
# 2023-12-01 17:16:18,594 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Lynn 2K23AUG1418.txt. Delays detected: 0
# 2023-12-01 17:16:18,659 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Malcolm 2K23AUG2903.txt. Delays detected: 0
# 2023-12-01 17:16:18,719 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Mazviita 2K23SEP0535R.txt. Delays detected: 0
# 2023-12-01 17:16:18,777 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Melisa 2K23SEP1378R.txt. Delays detected: 0
# 2023-12-01 17:16:18,810 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Merciah 2K22NOV2390.txt. Delays detected: 0
# 2023-12-01 17:16:18,900 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Michelle 2K23JUL2792.txt. Delays detected: 0
# 2023-12-01 17:16:18,935 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Michelle 2K23JUN0815.txt. Delays detected: 0
# 2023-12-01 17:16:18,974 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Moyo 2K22AUG1887.txt. Delays detected: 0
# 2023-12-01 17:16:19,034 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Natasha 2K23AUG3128.txt. Delays detected: 0
# 2023-12-01 17:16:19,060 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Nyasha 2K22JUL2255.txt. Delays detected: 0
# 2023-12-01 17:16:19,088 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Panashe 2K22JUL0527.txt. Delays detected: 0
# 2023-12-01 17:16:19,136 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Plaxedes 2K22NOV1192.txt. Delays detected: 0
# 2023-12-01 17:16:19,171 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Purity 2K22JUL0742.txt. Delays detected: 0
# 2023-12-01 17:16:19,212 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Recall 2K22MAY3019.txt. Delays detected: 0
# 2023-12-01 17:16:19,247 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Riyahboka 2K23JUL0436.txt. Delays detected: 0
# 2023-12-01 17:16:19,303 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Ruth 2K23AUG2588.txt. Delays detected: 0
# 2023-12-01 17:16:19,320 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Samantha 2K23JUN1705.txt. Delays detected: 0
# 2023-12-01 17:16:19,369 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Sandra 2K23SEP2692.txt. Delays detected: 0
# 2023-12-01 17:16:19,400 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Shantel 2K23JAN0755.txt. Delays detected: 0
# 2023-12-01 17:16:19,457 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Sharon 2K23JUL2576.txt. Delays detected: 0
# 2023-12-01 17:16:19,518 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Shumirai 2K23SEP3085.txt. Delays detected: 0
# 2023-12-01 17:16:19,567 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Sibonginkosi 2K23JUN1094.txt. Delays detected: 0
# 2023-12-01 17:16:19,609 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Tadiwanashe 2K22JUN1652.txt. Delays detected: 0
# 2023-12-01 17:16:19,643 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Tadiwanashe 2K23MAR2892R.txt. Delays detected: 0
# 2023-12-01 17:16:19,699 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Takunda 2K23AUG0788.txt. Delays detected: 0
# 2023-12-01 17:16:19,734 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Takunda 2K23MAY0651.txt. Delays detected: 0
# 2023-12-01 17:16:19,761 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Tanatswa 2K22DEC0732.txt. Delays detected: 0
# 2023-12-01 17:16:19,797 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Tendai 2K22OCT1847.txt. Delays detected: 0
# 2023-12-01 17:16:19,838 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Tinotenda 2K22SEP1947R.txt. Delays detected: 0
# 2023-12-01 17:16:19,900 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Triphine 2K23JUL2539R.txt. Delays detected: 0
# 2023-12-01 17:16:19,943 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Milan_Edoofa\WhatsApp Chat with Uyvett 2K22NOV1542.txt. Delays detected: 0
# C:\Users\mauriceyeng\AppData\Local\Temp\ipykernel_17072\2244814449.py:72: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.DataFrame(index=pd.to_datetime(intervals).strftime('%I:%M %p').unique())  # Ensure unique intervals
# 2023-12-01 17:16:20,067 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Abraham 2K22NOV0105.txt. Delays detected: 0
# 2023-12-01 17:16:20,101 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Aisha 2K22SEP0974.txt. Delays detected: 0
# 2023-12-01 17:16:20,119 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Allen 2K23NOV0995.txt. Delays detected: 0
# 2023-12-01 17:16:20,150 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Anushka 2K22NOV2273.txt. Delays detected: 0
# 2023-12-01 17:16:20,158 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Believe 2K22DEC0851.txt. Delays detected: 0
# 2023-12-01 17:16:20,192 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Bethel 2K22OCT2738.txt. Delays detected: 0
# 2023-12-01 17:16:20,227 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Beverly 2K23JAN0615.txt. Delays detected: 0
# 2023-12-01 17:16:20,262 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Bridget 2K23SEP2291.txt. Delays detected: 0
# 2023-12-01 17:16:20,310 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Bright 2K23SEP2363.txt. Delays detected: 0
# 2023-12-01 17:16:20,351 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Charity 2K22DEC2363.txt. Delays detected: 0
# 2023-12-01 17:16:20,365 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Chelsie 2K23NOV1864R.txt. Delays detected: 0
# 2023-12-01 17:16:20,394 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Cleopatra 2K23JAN1914.txt. Delays detected: 0
# 2023-12-01 17:16:20,409 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Craig 2K23NOV2145R.txt. Delays detected: 0
# 2023-12-01 17:16:20,463 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Daniel 2K23SEP1495.txt. Delays detected: 0
# 2023-12-01 17:16:20,484 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Diana 2K23JAN2323R.txt. Delays detected: 0
# 2023-12-01 17:16:20,533 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Hazel 2K22NOV1095.txt. Delays detected: 0
# 2023-12-01 17:16:20,581 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Henriata 2K23JANO766R.txt. Delays detected: 0
# 2023-12-01 17:16:20,595 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Jacquline 2K23NOV2056R.txt. Delays detected: 0
# 2023-12-01 17:16:20,644 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Kubiku 2K23OCT0734.txt. Delays detected: 0
# 2023-12-01 17:16:20,696 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Kudzai 2K23OCT2095.txt. Delays detected: 0
# 2023-12-01 17:16:20,748 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Kuvimbanashe 2K23AUG2570.txt. Delays detected: 0
# 2023-12-01 17:16:20,784 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Leonora 2K23APR0552.txt. Delays detected: 0
# 2023-12-01 17:16:20,824 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Leroy 2K22DEC0817.txt. Delays detected: 0
# 2023-12-01 17:16:20,838 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Malcom 2K23NOV2028.txt. Delays detected: 0
# 2023-12-01 17:16:20,922 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Master 2K23AUG1589.txt. Delays detected: 0
# 2023-12-01 17:16:20,970 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Mbuso 2K23SEP2424.txt. Delays detected: 0
# 2023-12-01 17:16:21,004 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Moreblessing 2K23APR1124.txt. Delays detected: 0
# 2023-12-01 17:16:21,039 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Mutsawashe 2K23MAR1607.txt. Delays detected: 0
# 2023-12-01 17:16:21,053 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Ngaakudzwe 2K23FEB1795.txt. Delays detected: 0
# 2023-12-01 17:16:21,122 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Nicole 2K23AUG2582.txt. Delays detected: 0
# 2023-12-01 17:16:21,171 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Panashe 2K23AUG1852.txt. Delays detected: 0
# 2023-12-01 17:16:21,187 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Panashe 2K23NOV2054R.txt. Delays detected: 0
# 2023-12-01 17:16:21,250 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Providence 2K23AUG1715.txt. Delays detected: 0
# 2023-12-01 17:16:21,271 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Prudence 2K23NOV1070R.txt. Delays detected: 0
# 2023-12-01 17:16:21,319 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Rachel 2K22NOV1502.txt. Delays detected: 0
# 2023-12-01 17:16:21,361 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Rutendo 2K23OCT1934R.txt. Delays detected: 0
# 2023-12-01 17:16:21,382 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Ryan 2K23NOV0411.txt. Delays detected: 0
# 2023-12-01 17:16:21,390 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Senior 2K23NOV1790.txt. Delays detected: 0
# 2023-12-01 17:16:21,423 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Sharon 2K22NOV1528.txt. Delays detected: 0
# 2023-12-01 17:16:21,479 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Shepherd 2K23AUG1035.txt. Delays detected: 0
# 2023-12-01 17:16:21,500 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Shyleen 2K23OCT3022R.txt. Delays detected: 0
# 2023-12-01 17:16:21,534 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Simbarashe 2K22DEC2390.txt. Delays detected: 0
# 2023-12-01 17:16:21,548 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Simbarashe 2K23NOV1506.txt. Delays detected: 0
# 2023-12-01 17:16:21,581 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Tadiwa 2K23APR0113.txt. Delays detected: 0
# 2023-12-01 17:16:21,611 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Tafadzwa 2K22DEC2028.txt. Delays detected: 0
# 2023-12-01 17:16:21,664 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Talent 2K23AUG2354.txt. Delays detected: 0
# 2023-12-01 17:16:21,685 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Tanaka 2K22OCT2314R.txt. Delays detected: 0
# 2023-12-01 17:16:21,747 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Tanaka 2K23SEP1123.txt. Delays detected: 0
# 2023-12-01 17:16:21,798 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Tanyaradzwa 2K23AUG2992.txt. Delays detected: 0
# 2023-12-01 17:16:21,831 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Tapiwanashe 2K22NOV1445.txt. Delays detected: 0
# 2023-12-01 17:16:21,866 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Tapiwanashe 2K23OCT1992.txt. Delays detected: 0
# 2023-12-01 17:16:21,888 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Tawananyasha 2K23NOV2371R.txt. Delays detected: 0
# 2023-12-01 17:16:21,900 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Tinevimbo 2K23NOV1559.txt. Delays detected: 0
# 2023-12-01 17:16:21,930 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Tinotenda 2K22DEC2606.txt. Delays detected: 0
# 2023-12-01 17:16:21,977 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Tinotenda 2K23FEB2181R.txt. Delays detected: 0
# 2023-12-01 17:16:22,028 - DEBUG - File parsed: C:\Users\mauriceyeng\Python\Daily-Reports\Chat Folder from Drive\drive-download-20231201T052455Z-001\2023-12-01\KAM\Shivjeet Edoofa\WhatsApp Chat with Trish 2K23AUG1639.txt. Delays detected: 0

# %%
# Directory to save CSV files
csv_save_directory = "C:\\Users\\mauriceyeng\\Python\\Daily-Reports\\Chat CSVs"
os.makedirs(csv_save_directory, exist_ok=True)

# Saving each DataFrame as a CSV
for key, df in dataframes.items():
    csv_file_path = os.path.join(csv_save_directory, f"{key}.csv")
    df.to_csv(csv_file_path)
